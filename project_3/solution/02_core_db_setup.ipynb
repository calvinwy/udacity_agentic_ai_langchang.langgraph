# %%
import json
import uuid
from sqlalchemy import create_engine, inspect
from utils import reset_db, get_session, model_to_dict
from data.models import udahub

# %% [markdown]
# # Udahub Application

# %% [markdown]
# ## Core Database

# %% [markdown]
# **Init DB**

# %%
udahub_db = "data/core/udahub.db"
reset_db(udahub_db)
engine = create_engine(f"sqlite:///{udahub_db}", echo=False)
udahub.Base.metadata.create_all(bind=engine)
# Out:
# 2026-04-18 11:35:47,991 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-18 11:35:47,991 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Recreated data/core/udahub.db with fresh schema

# %% [markdown]
# **Account**

# %%
account_id = "cultpass"
account_name = "CultPass Card"

with get_session(engine) as session:
    account = udahub.Account(
        account_id=account_id,
        account_name=account_name,
    )
    session.add(account)

# %% [markdown]
# ---

# %% [markdown]
# ## Integrations

# %% [markdown]
# **Use LLM to Generate Sample Data**

# %%
import os
import pandas as pd
import random
from dotenv import load_dotenv
from typing import List
from pydantic import BaseModel, Field
from typing import List, Optional, Dict, Any, Literal, TypedDict, Annotated
from langgraph.prebuilt import create_react_agent
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import SystemMessage
from langchain_chroma import Chroma
from langchain_core.documents import Document

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# llm_base_url = "https://openai.vocareum.com/v1"

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0.0,
    # base_url=llm_base_url,
    api_key=OPENAI_API_KEY,
)

embeddings_fn = OpenAIEmbeddings(
    model="text-embedding-3-large",
    # base_url=llm_base_url,
    api_key=OPENAI_API_KEY,
)

# %% [markdown]
# **Data Generation Parameters**

# %%
num_articles = 20
num_account = 10
num_user = 25
num_ticket = 50
num_msg = num_ticket
num_expected_tag_msg = round(num_msg * 0.8)
num_unexpected_tag_msg = num_msg - num_expected_tag_msg
chromadb_directory = "vectorstore"
collection_name = "knowledge_vecotr_store"

# %% [markdown]
# ### Sampling Schema
#
# For LLM to produce the data samples

# %%
class ArticlesSchema(BaseModel):
    title: Annotated[str, Field(description="Title of the article.")]
    content: Annotated[str, Field(description="Content of the article.")]
    tags: Annotated[str, Field(description="Tags of the article")]

class ArticlesListSchema(BaseModel):
    samples: Annotated[List[ArticlesSchema], Field(description="List of CultpassArticles")]

class AccountSamples(BaseModel):
    """Structured response for account table"""
    company_name: List[str] = Field(description="List of first name and last name")

class UsersSchema(BaseModel):
    name: Annotated[str, Field(description="User's name with first and last name.")]
    email: Annotated[str, Field(description="User's email address.")]
    is_blocked: Annotated[bool, Field(description="User's blocking status.")]
    account_id: Annotated[str, Field(description="Company account ID")]

class UsersListSchema(BaseModel):
    samples: Annotated[List[UsersSchema], Field(description="List of users")]

class SingleTicket(BaseModel):
    """Structured response for a ticket"""
    status: Annotated[Literal['open','pending','closed'], Field(description="Status of the ticket")]
    content: Annotated[str, Field(description="The ticket body message content.")]
    owner_id: Annotated[str, Field(description="User ID")]
    owner_name: Annotated[str, Field(description="User's name")]
    channel: Annotated[Literal['email','chat','web','sms','social','phone'], Field(description="Ticket priority")]
    tags: Annotated[str, Field(description="List of tags used for creating this message")]
    account_id: Annotated[str, Field(description="Company account ID")]
    urgency_score: Annotated[float, Field(description="Urgency of the ticket")]

class TicketSamples(BaseModel):
    """Structured response of ticket list"""
    samples: List[SingleTicket]

# %% [markdown]
# ## Loading Default Data
#
# * Knowledge Base
# * Users Data

# %%
# Load Sample Articles
cultpass_articles = []
with open('data/external/cultpass_articles.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_articles.append(json.loads(line))

# Extract Tags from Samples
sample_tags = [ article['tags'].split(', ') for article in cultpass_articles ]
sample_tags = set([ item for subtags in sample_tags for item in subtags ])
sample_tags_str = ", ".join(sample_tags)

# Define Tags with Expected Knowledge and Tags without Expected Knowledge
# (This is for sampling ticket questions "with vs without knowledge to answer" using LLM)
expected_tags = sample_tags
unexpected_tags = ['weather', 'stock price', 'dietary', 'health advice']

# %%
sample_tags
# Out:
# {'access',
#  'attendance',
#  'benefits',
#  'billing',
#  'booking',
#  'cancelation',
#  'escalation',
#  'events',
#  'login',
#  'password',
#  'pause',
#  'pricing',
#  'reservation',
#  'subscription'}

# %%
# Load Users Data
cultpass_users = []
with open('data/external/cultpass_users.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_users.append(json.loads(line))

# %% [markdown]
# #### Generate Knowledge Articles

# %%
# Create Additional Knowledge Articles
num_cultpass_articles = len(cultpass_articles)
num_new_articles = num_articles - num_cultpass_articles
sample_articles_template = """
    You are an helpful expert creating sample of python sample article data based on given examples.  Do not provide any additional description or explanation.
    There is a mock-up project, it has the following description:

    You’ve joined a fast-growing AI startup building the next frontier in customer support automation. Your team is responsible for building UDA-Hub, 
    a Universal Decision Agent designed to plug into existing customer support systems (Zendesk, Intercom, Freshdesk, internal CRMs) and intelligently 
    resolve tickets. You need to generate sample knowledge articles in area including: {sample_tags}.  
    
    The knowledge areas given above will be used as tags for the generated articles.

    The first UDA-Hub customer Cultpass has the following sample articles to be used as knowledge to be used by the system:
    {samples}

    Cultpass is a online travel and leisure platform that provides a subscription-based card for travelers, offering access to airport lounges, travel discounts, 
    and exclusive experiences worldwide. Please create the new articles based on this context and the sample articles provided above.

    Provide {num_articles} more example like above and double check if all articles uses tags from {sample_tags}, if not try again.
    """

sample_articles_prompt = PromptTemplate(
    template = sample_articles_template,
    input_variables = ["samples","num_articles","sample_tags"],
    ).invoke({"samples": cultpass_articles,
              "num_articles": num_new_articles,
              "sample_tags": sample_tags}).to_messages()

new_cultpass_articles = llm.with_structured_output(ArticlesListSchema).invoke(sample_articles_prompt).model_dump()['samples']
cultpass_articles_ls = cultpass_articles + new_cultpass_articles

# Extracting Sample Tags for Each Sample
# new_sample_tags = [ article['tags'].split(', ') for article in cultpass_articles_ls ]
# new_sample_tags = set([ item for subtags in new_sample_tags for item in subtags ])
# new_sample_tags_str = ", ".join(new_sample_tags)

if len(cultpass_articles_ls) < 14:
    raise AssertionError("You should load the articles with at least 14 records")

# %%
cultpass_articles_ls
# Out:
# [{'title': 'How to Reserve a Spot for an Event',
#   'content': 'If a user asks how to reserve an event:\n\n- Guide them to the CultPass app\n- Instruct them to browse the experience catalog and tap \'Reserve\'\n- If it\'s a premium or limited event, check if reservation confirmation is required via email\n- Remind them to arrive at least 15 minutes early with their QR code visible\n\n**Suggested phrasing:**\n"You can reserve an experience by opening the CultPass app, selecting your desired event, and tapping \'Reserve\'. Be sure to arrive 15 minutes early with your QR code ready."',
#   'tags': 'reservation, events, booking, attendance'},
#  {'title': "What's Included in a CultPass Subscription",
#   'content': 'Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."',
#   'tags': 'subscription, benefits, pricing, access'},
#  {'title': 'How to Cancel or Pause a Subscription',
#   'content': 'Users can manage their subscription via the app > \'My Account\' > \'Manage Plan\'.\n\n- Cancel: Effective at the end of the billing cycle\n- Pause: Preserves user data, resumes automatically when reactivated\n- Do NOT offer refunds unless approved by support lead\n\n**Suggested phrasing:**\n"You can cancel or pause your subscription at any time via the \'My Account\' section in the CultPass app. Cancelation takes effect at the end of your billing cycle."',
#   'tags': 'cancelation, pause, subscription, billing'},
#  {'title': 'How to Handle Login Issues?',
#   'content': 'Most login issues are resolved with password reset:\n\n- Ask the user to tap \'Forgot Password\' on the login screen\n- Ensure they are using the correct registered email\n- If they did not receive the reset email, check spam folder or retry after 10 minutes\n- For persistent login issues, escalate to human support\n\n**Suggested phrasing:**\n"Try tapping \'Forgot Password\' on the login screen. Make sure you\'re using the email associated with your account. If the email doesn\'t arrive, check spam or try again in a few minutes."',
#   'tags': 'login, password, access, escalation'},
#  {'title': 'How to Access Airport Lounges with CultPass',
#   'content': 'To access airport lounges:\n\n- Open the CultPass app and navigate to \'Lounge Access\'\n- Select your desired airport and lounge\n- Show your CultPass QR code at the lounge entrance\n\n**Suggested phrasing:**\n"Access airport lounges by selecting \'Lounge Access\' in the CultPass app and presenting your QR code at the entrance."',
#   'tags': 'access, benefits, reservation'},
#  {'title': 'Understanding CultPass Pricing Tiers',
#   'content': 'CultPass offers multiple pricing tiers:\n\n- Basic: Access to standard experiences\n- Premium: Includes premium events and lounge access\n- VIP: All-inclusive with additional perks\n\n**Suggested phrasing:**\n"Explore our pricing tiers to find the perfect CultPass for your travel needs, from basic to VIP options."',
#   'tags': 'pricing, subscription, benefits'},
#  {'title': 'How to Book Exclusive Experiences',
#   'content': 'To book exclusive experiences:\n\n- Open the CultPass app and browse the \'Exclusive\' section\n- Select your desired experience and tap \'Book Now\'\n- Confirm your booking details and receive a confirmation email\n\n**Suggested phrasing:**\n"Book exclusive experiences by navigating to the \'Exclusive\' section in the CultPass app and tapping \'Book Now\'."',
#   'tags': 'booking, reservation, events'},
#  {'title': 'Managing Your CultPass Billing Information',
#   'content': 'To update billing information:\n\n- Go to \'My Account\' in the CultPass app\n- Select \'Billing Information\'\n- Update your payment method and save changes\n\n**Suggested phrasing:**\n"Update your billing information by visiting \'My Account\' and selecting \'Billing Information\' in the CultPass app."',
#   'tags': 'billing, subscription, access'},
#  {'title': 'How to Pause Your CultPass Subscription',
#   'content': 'To pause your subscription:\n\n- Navigate to \'My Account\' > \'Manage Plan\'\n- Select \'Pause Subscription\'\n- Confirm your choice; your data will be preserved\n\n**Suggested phrasing:**\n"Pause your CultPass subscription anytime via \'My Account\' > \'Manage Plan\'. Your data will be preserved."',
#   'tags': 'pause, subscription, billing'},
#  {'title': 'Resolving Password Reset Issues',
#   'content': 'If users face issues resetting passwords:\n\n- Ensure they use the correct email\n- Advise checking spam/junk folders for reset emails\n- Suggest retrying after 10 minutes\n- Escalate to support if unresolved\n\n**Suggested phrasing:**\n"If you\'re having trouble resetting your password, ensure you\'re using the correct email and check your spam folder."',
#   'tags': 'password, login, escalation'},
#  {'title': 'How to Escalate a Support Ticket',
#   'content': 'To escalate a ticket:\n\n- Open the CultPass app and go to \'Support\'\n- Select the ticket and tap \'Escalate\'\n- Provide additional details if prompted\n\n**Suggested phrasing:**\n"Escalate your support ticket by selecting \'Support\' in the CultPass app and tapping \'Escalate\'."',
#   'tags': 'escalation, support, access'},
#  {'title': 'Benefits of CultPass Membership',
#   'content': 'CultPass membership includes:\n\n- Access to exclusive events\n- Airport lounge access\n- Travel discounts worldwide\n\n**Suggested phrasing:**\n"Enjoy exclusive events, lounge access, and travel discounts with your CultPass membership."',
#   'tags': 'benefits, subscription, access'},
#  {'title': 'How to Cancel a Booking',
#   'content': 'To cancel a booking:\n\n- Open the CultPass app and go to \'My Bookings\'\n- Select the booking and tap \'Cancel\'\n- Confirm cancellation; check for any fees\n\n**Suggested phrasing:**\n"Cancel your booking by navigating to \'My Bookings\' in the CultPass app and selecting \'Cancel\'."',
#   'tags': 'cancelation, booking, reservation'},
#  {'title': 'Troubleshooting Login Errors',
#   'content': 'For login errors:\n\n- Verify email and password\n- Suggest password reset if needed\n- Check for app updates\n- Escalate to support if unresolved\n\n**Suggested phrasing:**\n"Ensure your email and password are correct. If issues persist, try resetting your password or updating the app."',
#   'tags': 'login, password, escalation'},
#  {'title': 'How to Attend CultPass Events',
#   'content': 'To attend events:\n\n- Reserve your spot via the CultPass app\n- Check event details and location\n- Arrive early with your QR code ready\n\n**Suggested phrasing:**\n"Attend CultPass events by reserving your spot in the app and arriving early with your QR code."',
#   'tags': 'attendance, events, reservation'},
#  {'title': 'Understanding CultPass Billing Cycles',
#   'content': 'Billing cycles:\n\n- Monthly: Charges occur on the same date each month\n- Annual: One-time charge for the year\n- Check \'Billing Information\' for details\n\n**Suggested phrasing:**\n"Understand your billing cycle by checking \'Billing Information\' in the CultPass app."',
#   'tags': 'billing, subscription, pricing'},
#  {'title': 'How to Update Your CultPass Profile',
#   'content': 'To update your profile:\n\n- Go to \'My Account\' in the CultPass app\n- Select \'Edit Profile\'\n- Update your details and save changes\n\n**Suggested phrasing:**\n"Update your CultPass profile by selecting \'Edit Profile\' in the \'My Account\' section."',
#   'tags': 'access, subscription, benefits'},
#  {'title': 'How to Handle Event Cancelations',
#   'content': 'For event cancelations:\n\n- Notify users via email and app notifications\n- Offer alternative dates or refunds\n- Update the event status in the app\n\n**Suggested phrasing:**\n"In case of event cancelation, check your email or app notifications for updates and alternatives."',
#   'tags': 'cancelation, events, booking'},
#  {'title': 'How to Access CultPass Travel Discounts',
#   'content': 'To access travel discounts:\n\n- Open the CultPass app and go to \'Travel Discounts\'\n- Browse available offers and select\n- Follow instructions to redeem\n\n**Suggested phrasing:**\n"Access travel discounts by navigating to \'Travel Discounts\' in the CultPass app and selecting your offer."',
#   'tags': 'access, benefits, pricing'},
#  {'title': 'How to Reactivate a Paused Subscription',
#   'content': 'To reactivate:\n\n- Go to \'My Account\' > \'Manage Plan\'\n- Select \'Reactivate Subscription\'\n- Confirm reactivation; billing resumes\n\n**Suggested phrasing:**\n"Reactivate your paused subscription by selecting \'Manage Plan\' in \'My Account\' and tapping \'Reactivate Subscription\'."',
#   'tags': 'pause, subscription, billing'}]

# %% [markdown]
# Creating Vector Embedding for RAG

# %%
# Create vector store for knowledge articles
vector_store = Chroma(
    collection_name=collection_name,
    embedding_function=embeddings_fn,
    persist_directory=chromadb_directory,
)

cultpass_articles_docs = [ Document(page_content=article['title']+": "+article["content"],
                                      metadata={"tags": article['tags']},
                                      id=i) for i, article in enumerate(cultpass_articles_ls) ]
_ = vector_store.add_documents(documents=cultpass_articles_docs)

# %%
question = "Hi, I have a question regarding the billing for the events I attended last month. There seems to be a discrepancy in the charges, and I would like to understand the breakdown of the costs. Could you please provide a detailed billing statement? Thank you."
vector_store.similarity_search(question)
# Out:
# [Document(id='15', metadata={'tags': 'billing, subscription, pricing'}, page_content='Understanding CultPass Billing Cycles: Billing cycles:\n\n- Monthly: Charges occur on the same date each month\n- Annual: One-time charge for the year\n- Check \'Billing Information\' for details\n\n**Suggested phrasing:**\n"Understand your billing cycle by checking \'Billing Information\' in the CultPass app."'),
#  Document(id='7', metadata={'tags': 'billing, subscription, access'}, page_content='Managing Your CultPass Billing Information: To update billing information:\n\n- Go to \'My Account\' in the CultPass app\n- Select \'Billing Information\'\n- Update your payment method and save changes\n\n**Suggested phrasing:**\n"Update your billing information by visiting \'My Account\' and selecting \'Billing Information\' in the CultPass app."'),
#  Document(id='1', metadata={'tags': 'subscription, benefits, pricing, access'}, page_content='What\'s Included in a CultPass Subscription: Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."'),
#  Document(id='5', metadata={'tags': 'pricing, subscription, benefits'}, page_content='Understanding CultPass Pricing Tiers: CultPass offers multiple pricing tiers:\n\n- Basic: Access to standard experiences\n- Premium: Includes premium events and lounge access\n- VIP: All-inclusive with additional perks\n\n**Suggested phrasing:**\n"Explore our pricing tiers to find the perfect CultPass for your travel needs, from basic to VIP options."')]

# %% [markdown]
# #### Generate Users and Tickets

# %%
# Create Company List
account_prompt_template = """You are a company naming expert. Please come up with {num_account} company names."""

account_prompt = PromptTemplate(
    template = account_prompt_template,
    input_variables = ["num_account"],
    ).invoke({"num_account": num_account}).to_messages()

account = llm.with_structured_output(AccountSamples).invoke(account_prompt).model_dump()['company_name']
account_table = pd.DataFrame({"company_name": account})
# account_table['id'] = account_table.index
account_table['account_id'] = [ str(uuid.uuid4()) for i in range(num_account) ]
account_table_ls = account_table.to_dict(orient='records')
# account_table

# %%
# Create Additional Users
num_cultpass_users = len(cultpass_users)
num_new_users = num_user - num_cultpass_users
user_prompt_template = """
    You are a people naming expert. Please come up with {num_user} names with both first and last name.
    Randomly choose a company for each user from the account list and based on the name of the company,
    create an email address for this person.  Some companies should have more users than others.
    All users from the same company must have the same domain name on their email address.

    The `is_blocked` status should be randomly choosen as 'True' or 'False'

    List of account (companies): {account_table}"""

user_prompt = PromptTemplate(
    template = user_prompt_template,
    input_variables = ["num_user","account_table"],
    ).invoke({"num_user": num_new_users, "account_table": account_table}).to_messages()

user_ls = llm.with_structured_output(UsersListSchema).invoke(user_prompt).model_dump()['samples']
user_table = pd.DataFrame(user_ls)
user_table['id'] = [ str(uuid.uuid4().hex[:6]) for i in range(num_new_users) ]
user_table = user_table[['id', 'name', 'email', 'is_blocked','account_id']]
cultpass_users_table = pd.DataFrame(cultpass_users)
user_table = pd.concat([user_table, cultpass_users_table])
user_table['account_id'] = [ str(uuid.uuid4()) for i in range(num_user) ]     # account ID of LLM generated user should be replaced with true uuid4.

# %%
cultpass_users_table
# Out:
#        id            name                          email  is_blocked
# 0  a4ab87  Alice Kingsley  alice.kingsley@wonderland.com        True
# 1  f556c0       Bob Stone          bob.stone@granite.com       False
# 2  88382b     Cathy Bloom        cathy.bloom@florals.org       False
# 3  888fb2      David Noir      david.noir@shadowmail.com        True
# 4  f1f10d       Eva Green          eva.green@ecosoul.net       False
# 5  e6376d     Frank Ocean        frank.ocean@seawaves.io       False

# %%
user_table
# Out:
#         id             name                                      email  \
# 0   848b1e    Liam Anderson      liam.anderson@innovatechsolutions.com
# 1   ec60e2    Emma Thompson      emma.thompson@innovatechsolutions.com
# 2   7d844c     Noah Johnson       noah.johnson@innovatechsolutions.com
# 3   169cc3  Olivia Martinez    olivia.martinez@ecospherenterprises.com
# 4   aa1c45        Ava Brown          ava.brown@ecospherenterprises.com
# 5   ed925a     Sophia Davis       sophia.davis@quantumleapdynamics.com
# 6   b7a90e     Mason Wilson     mason.wilson@greenwavetechnologies.com
# 7   b6d951  Isabella Garcia  isabella.garcia@greenwavetechnologies.com
# 8   645afe   Lucas Martinez         lucas.martinez@skylineventures.com
# 9   c422ae    Mia Rodriguez          mia.rodriguez@skylineventures.com
# 10  598712        Ethan Lee       ethan.lee@bluehorizoninnovations.com
# 11  e30920    Amelia Harris   amelia.harris@bluehorizoninnovations.com
# 12  36bf47      James Clark           james.clark@pinnaclepathways.com
# 13  97a140  Charlotte Lewis       charlotte.lewis@pinnaclepathways.com
# 14  f6dbb0  Benjamin Walker    benjamin.walker@synergysystemsgroup.com
# 15  13598d     Harper Young       harper.young@synergysystemsgroup.com
# 16  4981cf   Alexander King     alexander.king@vanguardvisionaries.com
# 17  8287e1       Ella Scott               ella.scott@nexusnetworks.com
# 18  7917c1      Henry Adams              henry.adams@nexusnetworks.com
# 0   a4ab87   Alice Kingsley              alice.kingsley@wonderland.com
# 1   f556c0        Bob Stone                      bob.stone@granite.com
# 2   88382b      Cathy Bloom                    cathy.bloom@florals.org
# 3   888fb2       David Noir                  david.noir@shadowmail.com
# 4   f1f10d        Eva Green                      eva.green@ecosoul.net
# 5   e6376d      Frank Ocean                    frank.ocean@seawaves.io
#
#     is_blocked                            account_id
# 0        False  a2840676-0355-45b0-bf37-6ee3b9ea76d1
# 1         True  6b75e6b0-84f2-4a54-a606-ef8618462b00
# 2        False  97c2db30-fca6-4f25-97fc-4a489099e75e
# 3         True  b2f36026-01ca-4740-bbab-4e1bf003f9a9
# 4        False  99bf1c71-0342-46d8-9cb9-e647c029f893
# 5         True  78504ef9-8fb2-4bcf-bbc0-878f17190b99
# 6        False  36428f69-f82b-4cfa-9c44-0516011e737e
# 7         True  120d9d1a-c93a-4f1f-81bc-5d2abae8b6ab
# 8        False  b947c6d6-935d-4dac-be8c-dd15357139e7
# 9         True  2dad0543-87ff-4edb-ab2a-0f3fc9765d2c
# 10       False  bcf2d8a7-d352-4db6-b294-6af066ca4b02
# 11        True  3074945c-9a80-4313-a901-aff1fdaf2bec
# 12       False  57ff5678-0716-4c5a-ac8c-ee73741f557b
# 13        True  04070bfc-cbc4-4e50-afc7-e74af570dbe8
# 14       False  6f991b5c-fb29-476f-a30f-f1f4a4bf534f
# 15        True  71ab1421-ede1-4bb3-9186-6aa486112d42
# 16       False  137b6baa-9362-4ba1-94b4-2939656d2370
# 17        True  cae5d49d-cd72-4935-9a3f-c64e241612ae
# 18       False  23fc6f15-5b97-41ee-a452-74bc631e9cbe
# 0         True  ed8d4770-c0fc-4ae3-b736-92b584333f4e
# 1        False  d49e2b52-ccc4-4911-89f7-17c7a8ff3770
# 2        False  588e1373-31f6-445c-ad34-824ed557938f
# 3         True  479bb4d4-7d46-47a1-8478-cbf5129c1919
# 4        False  74e8dabf-d07a-4d05-8822-4521a53e2cb3
# 5        False  70c292d6-d512-49cb-bc2a-e5bfe8500f80

# %%
# Random Combination of Tags
expected_list_min_expected_tag = 1
expected_list_max_expected_tag = 4
unexpected_list_min_expected_tag = 0
unexpected_list_max_expected_tag = 2
unexpected_list_min_unexpected_tag = 1
unexpected_list_max_unexpected_tag = 2

expected_tag_combination = [ random.sample(list(expected_tags), random.randint(expected_list_min_expected_tag,expected_list_max_expected_tag)) for i in range(num_expected_tag_msg) ]
unexpected_tag_combination = [ random.sample(list(expected_tags), random.randint(unexpected_list_min_expected_tag,unexpected_list_max_expected_tag)) +
                               random.sample(list(unexpected_tags), random.randint(unexpected_list_min_unexpected_tag,unexpected_list_max_unexpected_tag)) for i in range(num_unexpected_tag_msg) ]
tag_combination = expected_tag_combination + unexpected_tag_combination

# %%
# Create Tickets
ticket_prompt_template = """
    You are a IT ticket generation emulator focusing on generating the actual message of users.
    
    Step 1: Generate {num_ticket} tickets, 
        (a) Each `content` should be 20 to 200 words
        (b) Make occasional minor typos in the `content`
        (c) Each ticket `content` should be written based on the topic in the followin table:
        {tag_combination}  

    Step 2: For the `owner_id` (use `id` column in the table), `owner_name` (use `name` column in the table), account_id (`account_id`)
            and allow one user to have multiple tickets:
        {user_table}

    Step 3: Randomly selected a `channel` from ['email','chat','web','sms','social','phone'] for each ticket.
    """

ticket_prompt = PromptTemplate(
    template = ticket_prompt_template,
    input_variables = ["num_ticket","num_expected_tag_msg","num_unexpected_tag_msg","expected_tags","unexpected_tags","ticket_table"],
    ).invoke({"num_ticket": num_ticket,
              "tag_combination": tag_combination, 
              "unexpected_tags": unexpected_tags, 
              "user_table": user_table,
            }).to_messages()

ticket_ls = llm.with_structured_output(TicketSamples).invoke(ticket_prompt).model_dump()['samples']
ticket_table = pd.DataFrame(ticket_ls)
# ticket_table['id'] = msg_table.index
ticket_table['role'] = "user"
ticket_table['status'] = "open"
ticket_table['urgency_score'] = [random.random() for _ in range(num_ticket)]
# ticket_table

# %%
for ticket in ticket_table['content']:
    print(ticket)
# Out:
# Hi team, I need to escalate an issue regarding the recent software update. It seems that after the update, several features are not functioning as expected. The dashboard is not loading properly, and the analytics section is showing incorrect data. This is affecting our daily operations, and we need a resolution as soon as possible. Please prioritize this issue and provide an update on the progress. Thank you.
# Hello, I am unable to access the booking system for our upcoming conference. Every time I try to log in, it says my credentials are incorrect, even though I have reset my password multiple times. Can someone please assist me with this issue? I need to finalize the bookings by the end of the week. Thank you.
# Hi, I am trying to book a meeting room for next week, but the system keeps showing an error message. It says that the room is unavailable, even though the calendar shows it as free. Can you please check and resolve this issue? I need to confirm the booking with my team. Thanks.
# Hello, I am facing an issue with my password. I have tried resetting it multiple times, but the system does not recognize the new password. Additionally, I need to escalate this issue as it is preventing me from accessing important files. Please assist me at the earliest. Thank you.
# Hi, I am trying to book a flight for a business trip, but the booking portal is not working. It keeps crashing every time I try to proceed to payment. Can you please look into this issue? I need to book the flight by tomorrow. Thank you.
# Hello, I have a query regarding the benefits of attending the upcoming events. I also need clarification on the pricing structure as it seems to have changed recently. Additionally, I would like to escalate this matter as it is affecting our budget planning. Please provide the necessary details at your earliest convenience. Thank you.
# Hi, I am having trouble with my password and need to book a subscription for our team. Additionally, I would like to know more about the benefits included in the subscription package. Can you please assist me with these issues? Thank you.
# Hello, I have a billing issue related to the recent events we hosted. The invoice amount seems incorrect, and I need clarification on the charges. Can you please provide a detailed breakdown of the billing? Thank you.
# Hi, I am unable to make a reservation due to access issues. Additionally, I am having trouble with my password and need to pause my current subscription. Can you please assist me with these issues? Thank you.
# Hello, I have a question regarding attendance at the upcoming events. Additionally, I need clarification on the pricing structure as it seems to have changed recently. Can you please provide the necessary details? Thank you.
# Hi, I need clarification on the pricing structure for our current subscription. It seems that the rates have increased without prior notice. Can you please provide a detailed breakdown of the charges? Thank you.
# Hello, I am trying to book a hotel for an upcoming conference, but the booking portal is not working. It keeps showing an error message. Can you please look into this issue? Thank you.
# Hi, I am trying to book a flight for a business trip, but the booking system is not working. It keeps crashing every time I try to proceed to payment. Can you please look into this issue? Thank you.
# Hello, I am facing an issue with my password and need to cancel a reservation. Additionally, I need clarification on the pricing structure as it seems to have changed recently. Can you please assist me with these issues? Thank you.
# Hi, I am unable to access the subscription portal and need clarification on the pricing structure. Can you please assist me with these issues? Thank you.
# Hello, I need to escalate an issue regarding my subscription. Additionally, I am having trouble with my password and need to book a service. Can you please assist me with these issues? Thank you.
# Hi, I am facing an issue with my password and need to book a service. Additionally, I need to escalate a billing issue. Can you please assist me with these issues? Thank you.
# Hello, I am unable to make a reservation due to an escalation issue. Additionally, I need clarification on the attendance policy. Can you please assist me with these issues? Thank you.
# Hi, I am unable to access the billing portal and need clarification on the attendance policy. Additionally, I need to pause my current subscription. Can you please assist me with these issues? Thank you.
# Hello, I need to cancel a booking and need clarification on the cancellation policy. Can you please assist me with these issues? Thank you.
# Hi, I am unable to log in to the billing portal and need to book a service. Additionally, I need clarification on the access policy. Can you please assist me with these issues? Thank you.
# Hello, I am unable to access the billing portal and need to book a service. Additionally, I need clarification on the pricing structure. Can you please assist me with these issues? Thank you.
# Hi, I have a billing issue related to a recent reservation. Additionally, I need clarification on the pricing structure. Can you please assist me with these issues? Thank you.
# Hello, I am facing an issue with my password and need to book a service. Additionally, I need clarification on the benefits included in the package. Can you please assist me with these issues? Thank you.
# Hi, I am facing an issue with my password. Can you please assist me with resetting it? Thank you.
# Hello, I need to escalate an issue regarding attendance at the upcoming events. Additionally, I need to cancel a reservation. Can you please assist me with these issues? Thank you.
# Hi, I am facing an issue with my password and need to cancel a subscription. Additionally, I need clarification on the attendance policy. Can you please assist me with these issues? Thank you.
# Hello, I need clarification on the benefits included in the package. Additionally, I am facing an issue with my password and need access to the portal. Can you please assist me with these issues? Thank you.
# Hi, I need to cancel a reservation and need clarification on the cancellation policy. Additionally, I need clarification on the pricing structure. Can you please assist me with these issues? Thank you.
# Hello, I am trying to book a subscription for our team. Can you please assist me with this issue? Thank you.
# Hi, I am unable to make a reservation due to access issues. Additionally, I need clarification on the pricing structure for our current subscription. Can you please assist me with these issues? Thank you.
# Hello, I need to escalate an issue regarding attendance at the upcoming events. Additionally, I am unable to access the billing portal. Can you please assist me with these issues? Thank you.
# Hi, I need to pause my current subscription and need clarification on the benefits included in the package. Additionally, I need access to the portal. Can you please assist me with these issues? Thank you.
# Hello, I am trying to book a subscription for our team and need to log in to the portal. Can you please assist me with these issues? Thank you.
# Hi, I need to escalate an issue regarding the pricing structure. Additionally, I am unable to log in to the portal. Can you please assist me with these issues? Thank you.
# Hello, I have a query regarding the upcoming events. Can you please provide the necessary details? Thank you.
# Hi, I have a billing issue related to a recent transaction. Additionally, I am facing an issue with my password. Can you please assist me with these issues? Thank you.
# Hello, I am facing an issue with my password and need to pause my current subscription. Additionally, I have a billing query. Can you please assist me with these issues? Thank you.
# Hi, I am unable to access the portal and need to log in to my account. Can you please assist me with these issues? Thank you.
# Hello, I am facing an issue with my password and need to log in to the portal. Additionally, I need to make a reservation. Can you please assist me with these issues? Thank you.
# Hi, I need to pause my current subscription and need health advice. Additionally, I have a query regarding stock prices. Can you please assist me with these issues? Thank you.
# Hello, I am trying to book a service and need clarification on the stock prices. Additionally, I am facing an issue with my password. Can you please assist me with these issues? Thank you.
# Hi, I am unable to access the portal and need clarification on the weather conditions. Additionally, I have a query regarding dietary requirements. Can you please assist me with these issues? Thank you.
# Hello, I have a billing issue related to a recent transaction. Additionally, I need clarification on the weather conditions and dietary requirements. Can you please assist me with these issues? Thank you.
# Hi, I need health advice and have a query regarding stock prices. Can you please assist me with these issues? Thank you.
# Hello, I have a query regarding stock prices and need clarification on the weather conditions. Can you please assist me with these issues? Thank you.
# Hi, I have a billing issue related to a recent reservation. Additionally, I need health advice and clarification on the weather conditions. Can you please assist me with these issues? Thank you.
# Hello, I have a query regarding attendance at the upcoming events. Additionally, I need clarification on the weather conditions. Can you please assist me with these issues? Thank you.
# Hi, I am trying to book a service and need health advice. Additionally, I have a query regarding dietary requirements. Can you please assist me with these issues? Thank you.
# Hello, I have a query regarding attendance at the upcoming events. Additionally, I need clarification on the weather conditions and stock prices. Can you please assist me with these issues? Thank you.

# %%
ticket_table
# Out:
#    status                                            content owner_id  \
# 0    open  Hi team, I need to escalate an issue regarding...   848b1e
# 1    open  Hello, I am unable to access the booking syste...   ec60e2
# 2    open  Hi, I am trying to book a meeting room for nex...   7d844c
# 3    open  Hello, I am facing an issue with my password. ...   169cc3
# 4    open  Hi, I am trying to book a flight for a busines...   aa1c45
# 5    open  Hello, I have a query regarding the benefits o...   ed925a
# 6    open  Hi, I am having trouble with my password and n...   b7a90e
# 7    open  Hello, I have a billing issue related to the r...   b6d951
# 8    open  Hi, I am unable to make a reservation due to a...   645afe
# 9    open  Hello, I have a question regarding attendance ...   c422ae
# 10   open  Hi, I need clarification on the pricing struct...   598712
# 11   open  Hello, I am trying to book a hotel for an upco...   e30920
# 12   open  Hi, I am trying to book a flight for a busines...   36bf47
# 13   open  Hello, I am facing an issue with my password a...   97a140
# 14   open  Hi, I am unable to access the subscription por...   f6dbb0
# 15   open  Hello, I need to escalate an issue regarding m...   13598d
# 16   open  Hi, I am facing an issue with my password and ...   4981cf
# 17   open  Hello, I am unable to make a reservation due t...   8287e1
# 18   open  Hi, I am unable to access the billing portal a...   7917c1
# 19   open  Hello, I need to cancel a booking and need cla...   a4ab87
# 20   open  Hi, I am unable to log in to the billing porta...   f556c0
# 21   open  Hello, I am unable to access the billing porta...   88382b
# 22   open  Hi, I have a billing issue related to a recent...   888fb2
# 23   open  Hello, I am facing an issue with my password a...   f1f10d
# 24   open  Hi, I am facing an issue with my password. Can...   e6376d
# 25   open  Hello, I need to escalate an issue regarding a...   848b1e
# 26   open  Hi, I am facing an issue with my password and ...   ec60e2
# 27   open  Hello, I need clarification on the benefits in...   7d844c
# 28   open  Hi, I need to cancel a reservation and need cl...   169cc3
# 29   open  Hello, I am trying to book a subscription for ...   aa1c45
# 30   open  Hi, I am unable to make a reservation due to a...   ed925a
# 31   open  Hello, I need to escalate an issue regarding a...   b7a90e
# 32   open  Hi, I need to pause my current subscription an...   b6d951
# 33   open  Hello, I am trying to book a subscription for ...   645afe
# 34   open  Hi, I need to escalate an issue regarding the ...   c422ae
# 35   open  Hello, I have a query regarding the upcoming e...   598712
# 36   open  Hi, I have a billing issue related to a recent...   e30920
# 37   open  Hello, I am facing an issue with my password a...   36bf47
# 38   open  Hi, I am unable to access the portal and need ...   97a140
# 39   open  Hello, I am facing an issue with my password a...   f6dbb0
# 40   open  Hi, I need to pause my current subscription an...   13598d
# 41   open  Hello, I am trying to book a service and need ...   4981cf
# 42   open  Hi, I am unable to access the portal and need ...   8287e1
# 43   open  Hello, I have a billing issue related to a rec...   7917c1
# 44   open  Hi, I need health advice and have a query rega...   a4ab87
# 45   open  Hello, I have a query regarding stock prices a...   f556c0
# 46   open  Hi, I have a billing issue related to a recent...   88382b
# 47   open  Hello, I have a query regarding attendance at ...   888fb2
# 48   open  Hi, I am trying to book a service and need hea...   f1f10d
# 49   open  Hello, I have a query regarding attendance at ...   e6376d
#
#          owner_name channel                                             tags  \
# 0     Liam Anderson   email                                       escalation
# 1     Emma Thompson    chat                                  access, booking
# 2      Noah Johnson     web                                          booking
# 3   Olivia Martinez     sms                             password, escalation
# 4         Ava Brown  social                                          booking
# 5      Sophia Davis   phone            benefits, events, escalation, pricing
# 6      Mason Wilson   email        password, booking, subscription, benefits
# 7   Isabella Garcia    chat                                  billing, events
# 8    Lucas Martinez     web             reservation, access, password, pause
# 9     Mia Rodriguez     sms                      attendance, events, pricing
# 10        Ethan Lee  social                                          pricing
# 11    Amelia Harris   phone                                          booking
# 12      James Clark   email                                          booking
# 13  Charlotte Lewis    chat      password, cancelation, reservation, pricing
# 14  Benjamin Walker     web                    access, subscription, pricing
# 15     Harper Young     sms      escalation, subscription, booking, password
# 16   Alexander King  social           password, booking, escalation, billing
# 17       Ella Scott   phone              reservation, escalation, attendance
# 18      Henry Adams   email               access, attendance, pause, billing
# 19   Alice Kingsley    chat                             booking, cancelation
# 20        Bob Stone     web                  login, billing, access, booking
# 21      Cathy Bloom     sms                access, billing, booking, pricing
# 22       David Noir  social        billing, escalation, reservation, pricing
# 23        Eva Green   phone             password, billing, booking, benefits
# 24      Frank Ocean   email                                         password
# 25    Liam Anderson    chat              escalation, attendance, cancelation
# 26    Emma Thompson     web  password, subscription, attendance, cancelation
# 27     Noah Johnson     sms                       benefits, password, access
# 28  Olivia Martinez  social                 attendance, cancelation, pricing
# 29        Ava Brown   phone                            subscription, booking
# 30     Sophia Davis   email       reservation, pricing, subscription, access
# 31     Mason Wilson    chat          escalation, attendance, access, billing
# 32  Isabella Garcia     web                          pause, benefits, access
# 33   Lucas Martinez     sms                     booking, subscription, login
# 34    Mia Rodriguez  social                       login, escalation, pricing
# 35        Ethan Lee   phone                                           events
# 36    Amelia Harris   email                                billing, password
# 37      James Clark    chat                 events, password, pause, billing
# 38  Charlotte Lewis     web                                    access, login
# 39  Benjamin Walker     sms             password, events, login, reservation
# 40     Harper Young  social                pause, health advice, stock price
# 41   Alexander King   phone          booking, password, stock price, weather
# 42       Ella Scott   email                         access, weather, dietary
# 43      Henry Adams    chat                        billing, weather, dietary
# 44   Alice Kingsley     web                       health advice, stock price
# 45        Bob Stone     sms                             stock price, weather
# 46      Cathy Bloom  social     billing, reservation, health advice, weather
# 47       David Noir   phone                     attendance, billing, weather
# 48        Eva Green   email          booking, events, health advice, dietary
# 49      Frank Ocean    chat                 attendance, weather, stock price
#
#                               account_id  urgency_score  role
# 0   a2840676-0355-45b0-bf37-6ee3b9ea76d1       0.725836  user
# 1   6b75e6b0-84f2-4a54-a606-ef8618462b00       0.972852  user
# 2   97c2db30-fca6-4f25-97fc-4a489099e75e       0.692159  user
# 3   b2f36026-01ca-4740-bbab-4e1bf003f9a9       0.013740  user
# 4   99bf1c71-0342-46d8-9cb9-e647c029f893       0.258161  user
# 5   78504ef9-8fb2-4bcf-bbc0-878f17190b99       0.286977  user
# 6   36428f69-f82b-4cfa-9c44-0516011e737e       0.202956  user
# 7   120d9d1a-c93a-4f1f-81bc-5d2abae8b6ab       0.040877  user
# 8   b947c6d6-935d-4dac-be8c-dd15357139e7       0.880982  user
# 9   2dad0543-87ff-4edb-ab2a-0f3fc9765d2c       0.222629  user
# 10  bcf2d8a7-d352-4db6-b294-6af066ca4b02       0.641938  user
# 11  3074945c-9a80-4313-a901-aff1fdaf2bec       0.213858  user
# 12  57ff5678-0716-4c5a-ac8c-ee73741f557b       0.106462  user
# 13  04070bfc-cbc4-4e50-afc7-e74af570dbe8       0.689661  user
# 14  6f991b5c-fb29-476f-a30f-f1f4a4bf534f       0.444682  user
# 15  71ab1421-ede1-4bb3-9186-6aa486112d42       0.049842  user
# 16  137b6baa-9362-4ba1-94b4-2939656d2370       0.105318  user
# 17  cae5d49d-cd72-4935-9a3f-c64e241612ae       0.093773  user
# 18  23fc6f15-5b97-41ee-a452-74bc631e9cbe       0.767219  user
# 19  ed8d4770-c0fc-4ae3-b736-92b584333f4e       0.017878  user
# 20  d49e2b52-ccc4-4911-89f7-17c7a8ff3770       0.473319  user
# 21  588e1373-31f6-445c-ad34-824ed557938f       0.712241  user
# 22  479bb4d4-7d46-47a1-8478-cbf5129c1919       0.947416  user
# 23  74e8dabf-d07a-4d05-8822-4521a53e2cb3       0.431715  user
# 24  70c292d6-d512-49cb-bc2a-e5bfe8500f80       0.118527  user
# 25  a2840676-0355-45b0-bf37-6ee3b9ea76d1       0.736191  user
# 26  6b75e6b0-84f2-4a54-a606-ef8618462b00       0.406046  user
# 27  97c2db30-fca6-4f25-97fc-4a489099e75e       0.007890  user
# 28  b2f36026-01ca-4740-bbab-4e1bf003f9a9       0.833087  user
# 29  99bf1c71-0342-46d8-9cb9-e647c029f893       0.599235  user
# 30  78504ef9-8fb2-4bcf-bbc0-878f17190b99       0.471778  user
# 31  36428f69-f82b-4cfa-9c44-0516011e737e       0.067259  user
# 32  120d9d1a-c93a-4f1f-81bc-5d2abae8b6ab       0.908760  user
# 33  b947c6d6-935d-4dac-be8c-dd15357139e7       0.506259  user
# 34  2dad0543-87ff-4edb-ab2a-0f3fc9765d2c       0.022723  user
# 35  bcf2d8a7-d352-4db6-b294-6af066ca4b02       0.419581  user
# 36  3074945c-9a80-4313-a901-aff1fdaf2bec       0.025057  user
# 37  57ff5678-0716-4c5a-ac8c-ee73741f557b       0.758606  user
# 38  04070bfc-cbc4-4e50-afc7-e74af570dbe8       0.599014  user
# 39  6f991b5c-fb29-476f-a30f-f1f4a4bf534f       0.685640  user
# 40  71ab1421-ede1-4bb3-9186-6aa486112d42       0.958665  user
# 41  137b6baa-9362-4ba1-94b4-2939656d2370       0.611388  user
# 42  cae5d49d-cd72-4935-9a3f-c64e241612ae       0.862982  user
# 43  23fc6f15-5b97-41ee-a452-74bc631e9cbe       0.817005  user
# 44  ed8d4770-c0fc-4ae3-b736-92b584333f4e       0.395209  user
# 45  d49e2b52-ccc4-4911-89f7-17c7a8ff3770       0.593431  user
# 46  588e1373-31f6-445c-ad34-824ed557938f       0.527654  user
# 47  479bb4d4-7d46-47a1-8478-cbf5129c1919       0.861627  user
# 48  74e8dabf-d07a-4d05-8822-4521a53e2cb3       0.022188  user
# 49  70c292d6-d512-49cb-bc2a-e5bfe8500f80       0.660970  user

# %%
len(ticket_table)
# Out:
# 50

# %% [markdown]
# ## Load Samples into Database

# %%
with get_session(engine) as session:
    kb = []
    for article in cultpass_articles:
        knowledge = udahub.Knowledge(
            article_id=str(uuid.uuid4()),
            account_id=account_id,
            title=article["title"],
            content=article["content"],
            tags=article["tags"]
        )
        kb.append(knowledge)
    session.add_all(kb)

# %% [markdown]
# **Ticket**

# %%
user_table.columns
# Out:
# Index(['id', 'name', 'email', 'is_blocked', 'account_id'], dtype='object')

# %%
def add_user(user_info):
    """
    Adding a single user to the database.
    """
    with get_session(engine) as session:
        user = udahub.User(
            user_id=user_info["account_id"],
            account_id=account_id,
            external_user_id=user_info["id"],
            user_name=user_info["name"],
            is_blocked=user_info["is_blocked"],
            email_address=user_info["email"]
            )
        session.add_all([user])

# %%
for index, row in user_table.iterrows():
    add_user(row)

# %%
def add_ticket(ticket_info):
    """
    Adding a single ticket to the database
    """
    with get_session(engine) as session:
        user = session.query(udahub.User).filter_by(
            account_id=account_id,
            external_user_id=ticket_info["owner_id"],
        ).first()

        print(ticket_info)
        print(user)

        if not user:
            user = udahub.User(
                # user_id=str(uuid.uuid4()),
                user_id=ticket_info["account_id"],
                account_id=account_id,
                external_user_id=ticket_info["owner_id"],
                user_name=ticket_info["owner_name"],
                is_blocked=False,     # Data structure in data/models/udahub.py had been modified to include this flag for advanced agent capability
                email_address=None    # Data structure in data/models/udahub.py had been modified to include this flag for advanced agent capability
            )
        
        ticket = udahub.Ticket(
            ticket_id=str(uuid.uuid4()),
            account_id=account_id,
            user_id=user.user_id,
            channel=ticket_info["channel"],
        )
        metadata = udahub.TicketMetadata(
            ticket_id=ticket.ticket_id,
            status=ticket_info["status"],
            main_issue_type=None,
            tags=ticket_info["tags"],
            urgency_score=ticket_info["urgency_score"]
        )

        first_message = udahub.TicketMessage(
            message_id=str(uuid.uuid4()),
            ticket_id=ticket.ticket_id,
            role=ticket_info["role"],
            content=ticket_info["content"],
        )

        # print(user)
        session.add_all([user, ticket, metadata, first_message])

# %%
for index, row in ticket_table.iterrows():
    add_ticket(row)
# Out:
# status                                                        open
# content          Hi team, I need to escalate an issue regarding...
# owner_id                                                    848b1e
# owner_name                                           Liam Anderson
# channel                                                      email
# tags                                                    escalation
# account_id                    a2840676-0355-45b0-bf37-6ee3b9ea76d1
# urgency_score                                             0.725836
# role                                                          user
# Name: 0, dtype: object
# <User(user_id='a2840676-0355-45b0-bf37-6ee3b9ea76d1', user_name='Liam Anderson', external_user_id='848b1e')>
# status                                                        open
# content          Hello, I am unable to access the booking syste...
# owner_id                                                    ec60e2
# owner_name                                           Emma Thompson
# channel                                                       chat
# tags                                               access, booking
# account_id                    6b75e6b0-84f2-4a54-a606-ef8618462b00
# urgency_score                                             0.972852
# role                                                          user
# Name: 1, dtype: object
# <User(user_id='6b75e6b0-84f2-4a54-a606-ef8618462b00', user_name='Emma Thompson', external_user_id='ec60e2')>
# status                                                        open
# content          Hi, I am trying to book a meeting room for nex...
# owner_id                                                    7d844c
# owner_name                                            Noah Johnson
# channel                                                        web
# tags                                                       booking
# account_id                    97c2db30-fca6-4f25-97fc-4a489099e75e
# urgency_score                                             0.692159
# role                                                          user
# Name: 2, dtype: object
# <User(user_id='97c2db30-fca6-4f25-97fc-4a489099e75e', user_name='Noah Johnson', external_user_id='7d844c')>
# status                                                        open
# content          Hello, I am facing an issue with my password. ...
# owner_id                                                    169cc3
# owner_name                                         Olivia Martinez
# channel                                                        sms
# tags                                          password, escalation
# account_id                    b2f36026-01ca-4740-bbab-4e1bf003f9a9
# urgency_score                                              0.01374
# role                                                          user
# Name: 3, dtype: object
# <User(user_id='b2f36026-01ca-4740-bbab-4e1bf003f9a9', user_name='Olivia Martinez', external_user_id='169cc3')>
# status                                                        open
# content          Hi, I am trying to book a flight for a busines...
# owner_id                                                    aa1c45
# owner_name                                               Ava Brown
# channel                                                     social
# tags                                                       booking
# account_id                    99bf1c71-0342-46d8-9cb9-e647c029f893
# urgency_score                                             0.258161
# role                                                          user
# Name: 4, dtype: object
# <User(user_id='99bf1c71-0342-46d8-9cb9-e647c029f893', user_name='Ava Brown', external_user_id='aa1c45')>
# status                                                        open
# content          Hello, I have a query regarding the benefits o...
# owner_id                                                    ed925a
# owner_name                                            Sophia Davis
# channel                                                      phone
# tags                         benefits, events, escalation, pricing
# account_id                    78504ef9-8fb2-4bcf-bbc0-878f17190b99
# urgency_score                                             0.286977
# role                                                          user
# Name: 5, dtype: object
# <User(user_id='78504ef9-8fb2-4bcf-bbc0-878f17190b99', user_name='Sophia Davis', external_user_id='ed925a')>
# status                                                        open
# content          Hi, I am having trouble with my password and n...
# owner_id                                                    b7a90e
# owner_name                                            Mason Wilson
# channel                                                      email
# tags                     password, booking, subscription, benefits
# account_id                    36428f69-f82b-4cfa-9c44-0516011e737e
# urgency_score                                             0.202956
# role                                                          user
# Name: 6, dtype: object
# <User(user_id='36428f69-f82b-4cfa-9c44-0516011e737e', user_name='Mason Wilson', external_user_id='b7a90e')>
# status                                                        open
# content          Hello, I have a billing issue related to the r...
# owner_id                                                    b6d951
# owner_name                                         Isabella Garcia
# channel                                                       chat
# tags                                               billing, events
# account_id                    120d9d1a-c93a-4f1f-81bc-5d2abae8b6ab
# urgency_score                                             0.040877
# role                                                          user
# Name: 7, dtype: object
# <User(user_id='120d9d1a-c93a-4f1f-81bc-5d2abae8b6ab', user_name='Isabella Garcia', external_user_id='b6d951')>
# status                                                        open
# content          Hi, I am unable to make a reservation due to a...
# owner_id                                                    645afe
# owner_name                                          Lucas Martinez
# channel                                                        web
# tags                          reservation, access, password, pause
# account_id                    b947c6d6-935d-4dac-be8c-dd15357139e7
# urgency_score                                             0.880982
# role                                                          user
# Name: 8, dtype: object
# <User(user_id='b947c6d6-935d-4dac-be8c-dd15357139e7', user_name='Lucas Martinez', external_user_id='645afe')>
# status                                                        open
# content          Hello, I have a question regarding attendance ...
# owner_id                                                    c422ae
# owner_name                                           Mia Rodriguez
# channel                                                        sms
# tags                                   attendance, events, pricing
# account_id                    2dad0543-87ff-4edb-ab2a-0f3fc9765d2c
# urgency_score                                             0.222629
# role                                                          user
# Name: 9, dtype: object
# <User(user_id='2dad0543-87ff-4edb-ab2a-0f3fc9765d2c', user_name='Mia Rodriguez', external_user_id='c422ae')>
# status                                                        open
# content          Hi, I need clarification on the pricing struct...
# owner_id                                                    598712
# owner_name                                               Ethan Lee
# channel                                                     social
# tags                                                       pricing
# account_id                    bcf2d8a7-d352-4db6-b294-6af066ca4b02
# urgency_score                                             0.641938
# role                                                          user
# Name: 10, dtype: object
# <User(user_id='bcf2d8a7-d352-4db6-b294-6af066ca4b02', user_name='Ethan Lee', external_user_id='598712')>
# status                                                        open
# content          Hello, I am trying to book a hotel for an upco...
# owner_id                                                    e30920
# owner_name                                           Amelia Harris
# channel                                                      phone
# tags                                                       booking
# account_id                    3074945c-9a80-4313-a901-aff1fdaf2bec
# urgency_score                                             0.213858
# role                                                          user
# Name: 11, dtype: object
# <User(user_id='3074945c-9a80-4313-a901-aff1fdaf2bec', user_name='Amelia Harris', external_user_id='e30920')>
# status                                                        open
# content          Hi, I am trying to book a flight for a busines...
# owner_id                                                    36bf47
# owner_name                                             James Clark
# channel                                                      email
# tags                                                       booking
# account_id                    57ff5678-0716-4c5a-ac8c-ee73741f557b
# urgency_score                                             0.106462
# role                                                          user
# Name: 12, dtype: object
# <User(user_id='57ff5678-0716-4c5a-ac8c-ee73741f557b', user_name='James Clark', external_user_id='36bf47')>
# status                                                        open
# content          Hello, I am facing an issue with my password a...
# owner_id                                                    97a140
# owner_name                                         Charlotte Lewis
# channel                                                       chat
# tags                   password, cancelation, reservation, pricing
# account_id                    04070bfc-cbc4-4e50-afc7-e74af570dbe8
# urgency_score                                             0.689661
# role                                                          user
# Name: 13, dtype: object
# <User(user_id='04070bfc-cbc4-4e50-afc7-e74af570dbe8', user_name='Charlotte Lewis', external_user_id='97a140')>
# status                                                        open
# content          Hi, I am unable to access the subscription por...
# owner_id                                                    f6dbb0
# owner_name                                         Benjamin Walker
# channel                                                        web
# tags                                 access, subscription, pricing
# account_id                    6f991b5c-fb29-476f-a30f-f1f4a4bf534f
# urgency_score                                             0.444682
# role                                                          user
# Name: 14, dtype: object
# <User(user_id='6f991b5c-fb29-476f-a30f-f1f4a4bf534f', user_name='Benjamin Walker', external_user_id='f6dbb0')>
# status                                                        open
# content          Hello, I need to escalate an issue regarding m...
# owner_id                                                    13598d
# owner_name                                            Harper Young
# channel                                                        sms
# tags                   escalation, subscription, booking, password
# account_id                    71ab1421-ede1-4bb3-9186-6aa486112d42
# urgency_score                                             0.049842
# role                                                          user
# Name: 15, dtype: object
# <User(user_id='71ab1421-ede1-4bb3-9186-6aa486112d42', user_name='Harper Young', external_user_id='13598d')>
# status                                                        open
# content          Hi, I am facing an issue with my password and ...
# owner_id                                                    4981cf
# owner_name                                          Alexander King
# channel                                                     social
# tags                        password, booking, escalation, billing
# account_id                    137b6baa-9362-4ba1-94b4-2939656d2370
# urgency_score                                             0.105318
# role                                                          user
# Name: 16, dtype: object
# <User(user_id='137b6baa-9362-4ba1-94b4-2939656d2370', user_name='Alexander King', external_user_id='4981cf')>
# status                                                        open
# content          Hello, I am unable to make a reservation due t...
# owner_id                                                    8287e1
# owner_name                                              Ella Scott
# channel                                                      phone
# tags                           reservation, escalation, attendance
# account_id                    cae5d49d-cd72-4935-9a3f-c64e241612ae
# urgency_score                                             0.093773
# role                                                          user
# Name: 17, dtype: object
# <User(user_id='cae5d49d-cd72-4935-9a3f-c64e241612ae', user_name='Ella Scott', external_user_id='8287e1')>
# status                                                        open
# content          Hi, I am unable to access the billing portal a...
# owner_id                                                    7917c1
# owner_name                                             Henry Adams
# channel                                                      email
# tags                            access, attendance, pause, billing
# account_id                    23fc6f15-5b97-41ee-a452-74bc631e9cbe
# urgency_score                                             0.767219
# role                                                          user
# Name: 18, dtype: object
# <User(user_id='23fc6f15-5b97-41ee-a452-74bc631e9cbe', user_name='Henry Adams', external_user_id='7917c1')>
# status                                                        open
# content          Hello, I need to cancel a booking and need cla...
# owner_id                                                    a4ab87
# owner_name                                          Alice Kingsley
# channel                                                       chat
# tags                                          booking, cancelation
# account_id                    ed8d4770-c0fc-4ae3-b736-92b584333f4e
# urgency_score                                             0.017878
# role                                                          user
# Name: 19, dtype: object
# <User(user_id='ed8d4770-c0fc-4ae3-b736-92b584333f4e', user_name='Alice Kingsley', external_user_id='a4ab87')>
# status                                                        open
# content          Hi, I am unable to log in to the billing porta...
# owner_id                                                    f556c0
# owner_name                                               Bob Stone
# channel                                                        web
# tags                               login, billing, access, booking
# account_id                    d49e2b52-ccc4-4911-89f7-17c7a8ff3770
# urgency_score                                             0.473319
# role                                                          user
# Name: 20, dtype: object
# <User(user_id='d49e2b52-ccc4-4911-89f7-17c7a8ff3770', user_name='Bob Stone', external_user_id='f556c0')>
# status                                                        open
# content          Hello, I am unable to access the billing porta...
# owner_id                                                    88382b
# owner_name                                             Cathy Bloom
# channel                                                        sms
# tags                             access, billing, booking, pricing
# account_id                    588e1373-31f6-445c-ad34-824ed557938f
# urgency_score                                             0.712241
# role                                                          user
# Name: 21, dtype: object
# <User(user_id='588e1373-31f6-445c-ad34-824ed557938f', user_name='Cathy Bloom', external_user_id='88382b')>
# status                                                        open
# content          Hi, I have a billing issue related to a recent...
# owner_id                                                    888fb2
# owner_name                                              David Noir
# channel                                                     social
# tags                     billing, escalation, reservation, pricing
# account_id                    479bb4d4-7d46-47a1-8478-cbf5129c1919
# urgency_score                                             0.947416
# role                                                          user
# Name: 22, dtype: object
# <User(user_id='479bb4d4-7d46-47a1-8478-cbf5129c1919', user_name='David Noir', external_user_id='888fb2')>
# status                                                        open
# content          Hello, I am facing an issue with my password a...
# owner_id                                                    f1f10d
# owner_name                                               Eva Green
# channel                                                      phone
# tags                          password, billing, booking, benefits
# account_id                    74e8dabf-d07a-4d05-8822-4521a53e2cb3
# urgency_score                                             0.431715
# role                                                          user
# Name: 23, dtype: object
# <User(user_id='74e8dabf-d07a-4d05-8822-4521a53e2cb3', user_name='Eva Green', external_user_id='f1f10d')>
# status                                                        open
# content          Hi, I am facing an issue with my password. Can...
# owner_id                                                    e6376d
# owner_name                                             Frank Ocean
# channel                                                      email
# tags                                                      password
# account_id                    70c292d6-d512-49cb-bc2a-e5bfe8500f80
# urgency_score                                             0.118527
# role                                                          user
# Name: 24, dtype: object
# <User(user_id='70c292d6-d512-49cb-bc2a-e5bfe8500f80', user_name='Frank Ocean', external_user_id='e6376d')>
# status                                                        open
# content          Hello, I need to escalate an issue regarding a...
# owner_id                                                    848b1e
# owner_name                                           Liam Anderson
# channel                                                       chat
# tags                           escalation, attendance, cancelation
# account_id                    a2840676-0355-45b0-bf37-6ee3b9ea76d1
# urgency_score                                             0.736191
# role                                                          user
# Name: 25, dtype: object
# <User(user_id='a2840676-0355-45b0-bf37-6ee3b9ea76d1', user_name='Liam Anderson', external_user_id='848b1e')>
# status                                                        open
# content          Hi, I am facing an issue with my password and ...
# owner_id                                                    ec60e2
# owner_name                                           Emma Thompson
# channel                                                        web
# tags               password, subscription, attendance, cancelation
# account_id                    6b75e6b0-84f2-4a54-a606-ef8618462b00
# urgency_score                                             0.406046
# role                                                          user
# Name: 26, dtype: object
# <User(user_id='6b75e6b0-84f2-4a54-a606-ef8618462b00', user_name='Emma Thompson', external_user_id='ec60e2')>
# status                                                        open
# content          Hello, I need clarification on the benefits in...
# owner_id                                                    7d844c
# owner_name                                            Noah Johnson
# channel                                                        sms
# tags                                    benefits, password, access
# account_id                    97c2db30-fca6-4f25-97fc-4a489099e75e
# urgency_score                                              0.00789
# role                                                          user
# Name: 27, dtype: object
# <User(user_id='97c2db30-fca6-4f25-97fc-4a489099e75e', user_name='Noah Johnson', external_user_id='7d844c')>
# status                                                        open
# content          Hi, I need to cancel a reservation and need cl...
# owner_id                                                    169cc3
# owner_name                                         Olivia Martinez
# channel                                                     social
# tags                              attendance, cancelation, pricing
# account_id                    b2f36026-01ca-4740-bbab-4e1bf003f9a9
# urgency_score                                             0.833087
# role                                                          user
# Name: 28, dtype: object
# <User(user_id='b2f36026-01ca-4740-bbab-4e1bf003f9a9', user_name='Olivia Martinez', external_user_id='169cc3')>
# status                                                        open
# content          Hello, I am trying to book a subscription for ...
# owner_id                                                    aa1c45
# owner_name                                               Ava Brown
# channel                                                      phone
# tags                                         subscription, booking
# account_id                    99bf1c71-0342-46d8-9cb9-e647c029f893
# urgency_score                                             0.599235
# role                                                          user
# Name: 29, dtype: object
# <User(user_id='99bf1c71-0342-46d8-9cb9-e647c029f893', user_name='Ava Brown', external_user_id='aa1c45')>
# status                                                        open
# content          Hi, I am unable to make a reservation due to a...
# owner_id                                                    ed925a
# owner_name                                            Sophia Davis
# channel                                                      email
# tags                    reservation, pricing, subscription, access
# account_id                    78504ef9-8fb2-4bcf-bbc0-878f17190b99
# urgency_score                                             0.471778
# role                                                          user
# Name: 30, dtype: object
# <User(user_id='78504ef9-8fb2-4bcf-bbc0-878f17190b99', user_name='Sophia Davis', external_user_id='ed925a')>
# status                                                        open
# content          Hello, I need to escalate an issue regarding a...
# owner_id                                                    b7a90e
# owner_name                                            Mason Wilson
# channel                                                       chat
# tags                       escalation, attendance, access, billing
# account_id                    36428f69-f82b-4cfa-9c44-0516011e737e
# urgency_score                                             0.067259
# role                                                          user
# Name: 31, dtype: object
# <User(user_id='36428f69-f82b-4cfa-9c44-0516011e737e', user_name='Mason Wilson', external_user_id='b7a90e')>
# status                                                        open
# content          Hi, I need to pause my current subscription an...
# owner_id                                                    b6d951
# owner_name                                         Isabella Garcia
# channel                                                        web
# tags                                       pause, benefits, access
# account_id                    120d9d1a-c93a-4f1f-81bc-5d2abae8b6ab
# urgency_score                                              0.90876
# role                                                          user
# Name: 32, dtype: object
# <User(user_id='120d9d1a-c93a-4f1f-81bc-5d2abae8b6ab', user_name='Isabella Garcia', external_user_id='b6d951')>
# status                                                        open
# content          Hello, I am trying to book a subscription for ...
# owner_id                                                    645afe
# owner_name                                          Lucas Martinez
# channel                                                        sms
# tags                                  booking, subscription, login
# account_id                    b947c6d6-935d-4dac-be8c-dd15357139e7
# urgency_score                                             0.506259
# role                                                          user
# Name: 33, dtype: object
# <User(user_id='b947c6d6-935d-4dac-be8c-dd15357139e7', user_name='Lucas Martinez', external_user_id='645afe')>
# status                                                        open
# content          Hi, I need to escalate an issue regarding the ...
# owner_id                                                    c422ae
# owner_name                                           Mia Rodriguez
# channel                                                     social
# tags                                    login, escalation, pricing
# account_id                    2dad0543-87ff-4edb-ab2a-0f3fc9765d2c
# urgency_score                                             0.022723
# role                                                          user
# Name: 34, dtype: object
# <User(user_id='2dad0543-87ff-4edb-ab2a-0f3fc9765d2c', user_name='Mia Rodriguez', external_user_id='c422ae')>
# status                                                        open
# content          Hello, I have a query regarding the upcoming e...
# owner_id                                                    598712
# owner_name                                               Ethan Lee
# channel                                                      phone
# tags                                                        events
# account_id                    bcf2d8a7-d352-4db6-b294-6af066ca4b02
# urgency_score                                             0.419581
# role                                                          user
# Name: 35, dtype: object
# <User(user_id='bcf2d8a7-d352-4db6-b294-6af066ca4b02', user_name='Ethan Lee', external_user_id='598712')>
# status                                                        open
# content          Hi, I have a billing issue related to a recent...
# owner_id                                                    e30920
# owner_name                                           Amelia Harris
# channel                                                      email
# tags                                             billing, password
# account_id                    3074945c-9a80-4313-a901-aff1fdaf2bec
# urgency_score                                             0.025057
# role                                                          user
# Name: 36, dtype: object
# <User(user_id='3074945c-9a80-4313-a901-aff1fdaf2bec', user_name='Amelia Harris', external_user_id='e30920')>
# status                                                        open
# content          Hello, I am facing an issue with my password a...
# owner_id                                                    36bf47
# owner_name                                             James Clark
# channel                                                       chat
# tags                              events, password, pause, billing
# account_id                    57ff5678-0716-4c5a-ac8c-ee73741f557b
# urgency_score                                             0.758606
# role                                                          user
# Name: 37, dtype: object
# <User(user_id='57ff5678-0716-4c5a-ac8c-ee73741f557b', user_name='James Clark', external_user_id='36bf47')>
# status                                                        open
# content          Hi, I am unable to access the portal and need ...
# owner_id                                                    97a140
# owner_name                                         Charlotte Lewis
# channel                                                        web
# tags                                                 access, login
# account_id                    04070bfc-cbc4-4e50-afc7-e74af570dbe8
# urgency_score                                             0.599014
# role                                                          user
# Name: 38, dtype: object
# <User(user_id='04070bfc-cbc4-4e50-afc7-e74af570dbe8', user_name='Charlotte Lewis', external_user_id='97a140')>
# status                                                        open
# content          Hello, I am facing an issue with my password a...
# owner_id                                                    f6dbb0
# owner_name                                         Benjamin Walker
# channel                                                        sms
# tags                          password, events, login, reservation
# account_id                    6f991b5c-fb29-476f-a30f-f1f4a4bf534f
# urgency_score                                              0.68564
# role                                                          user
# Name: 39, dtype: object
# <User(user_id='6f991b5c-fb29-476f-a30f-f1f4a4bf534f', user_name='Benjamin Walker', external_user_id='f6dbb0')>
# status                                                        open
# content          Hi, I need to pause my current subscription an...
# owner_id                                                    13598d
# owner_name                                            Harper Young
# channel                                                     social
# tags                             pause, health advice, stock price
# account_id                    71ab1421-ede1-4bb3-9186-6aa486112d42
# urgency_score                                             0.958665
# role                                                          user
# Name: 40, dtype: object
# <User(user_id='71ab1421-ede1-4bb3-9186-6aa486112d42', user_name='Harper Young', external_user_id='13598d')>
# status                                                        open
# content          Hello, I am trying to book a service and need ...
# owner_id                                                    4981cf
# owner_name                                          Alexander King
# channel                                                      phone
# tags                       booking, password, stock price, weather
# account_id                    137b6baa-9362-4ba1-94b4-2939656d2370
# urgency_score                                             0.611388
# role                                                          user
# Name: 41, dtype: object
# <User(user_id='137b6baa-9362-4ba1-94b4-2939656d2370', user_name='Alexander King', external_user_id='4981cf')>
# status                                                        open
# content          Hi, I am unable to access the portal and need ...
# owner_id                                                    8287e1
# owner_name                                              Ella Scott
# channel                                                      email
# tags                                      access, weather, dietary
# account_id                    cae5d49d-cd72-4935-9a3f-c64e241612ae
# urgency_score                                             0.862982
# role                                                          user
# Name: 42, dtype: object
# <User(user_id='cae5d49d-cd72-4935-9a3f-c64e241612ae', user_name='Ella Scott', external_user_id='8287e1')>
# status                                                        open
# content          Hello, I have a billing issue related to a rec...
# owner_id                                                    7917c1
# owner_name                                             Henry Adams
# channel                                                       chat
# tags                                     billing, weather, dietary
# account_id                    23fc6f15-5b97-41ee-a452-74bc631e9cbe
# urgency_score                                             0.817005
# role                                                          user
# Name: 43, dtype: object
# <User(user_id='23fc6f15-5b97-41ee-a452-74bc631e9cbe', user_name='Henry Adams', external_user_id='7917c1')>
# status                                                        open
# content          Hi, I need health advice and have a query rega...
# owner_id                                                    a4ab87
# owner_name                                          Alice Kingsley
# channel                                                        web
# tags                                    health advice, stock price
# account_id                    ed8d4770-c0fc-4ae3-b736-92b584333f4e
# urgency_score                                             0.395209
# role                                                          user
# Name: 44, dtype: object
# <User(user_id='ed8d4770-c0fc-4ae3-b736-92b584333f4e', user_name='Alice Kingsley', external_user_id='a4ab87')>
# status                                                        open
# content          Hello, I have a query regarding stock prices a...
# owner_id                                                    f556c0
# owner_name                                               Bob Stone
# channel                                                        sms
# tags                                          stock price, weather
# account_id                    d49e2b52-ccc4-4911-89f7-17c7a8ff3770
# urgency_score                                             0.593431
# role                                                          user
# Name: 45, dtype: object
# <User(user_id='d49e2b52-ccc4-4911-89f7-17c7a8ff3770', user_name='Bob Stone', external_user_id='f556c0')>
# status                                                        open
# content          Hi, I have a billing issue related to a recent...
# owner_id                                                    88382b
# owner_name                                             Cathy Bloom
# channel                                                     social
# tags                  billing, reservation, health advice, weather
# account_id                    588e1373-31f6-445c-ad34-824ed557938f
# urgency_score                                             0.527654
# role                                                          user
# Name: 46, dtype: object
# <User(user_id='588e1373-31f6-445c-ad34-824ed557938f', user_name='Cathy Bloom', external_user_id='88382b')>
# status                                                        open
# content          Hello, I have a query regarding attendance at ...
# owner_id                                                    888fb2
# owner_name                                              David Noir
# channel                                                      phone
# tags                                  attendance, billing, weather
# account_id                    479bb4d4-7d46-47a1-8478-cbf5129c1919
# urgency_score                                             0.861627
# role                                                          user
# Name: 47, dtype: object
# <User(user_id='479bb4d4-7d46-47a1-8478-cbf5129c1919', user_name='David Noir', external_user_id='888fb2')>
# status                                                        open
# content          Hi, I am trying to book a service and need hea...
# owner_id                                                    f1f10d
# owner_name                                               Eva Green
# channel                                                      email
# tags                       booking, events, health advice, dietary
# account_id                    74e8dabf-d07a-4d05-8822-4521a53e2cb3
# urgency_score                                             0.022188
# role                                                          user
# Name: 48, dtype: object
# <User(user_id='74e8dabf-d07a-4d05-8822-4521a53e2cb3', user_name='Eva Green', external_user_id='f1f10d')>
# status                                                        open
# content          Hello, I have a query regarding attendance at ...
# owner_id                                                    e6376d
# owner_name                                             Frank Ocean
# channel                                                       chat
# tags                              attendance, weather, stock price
# account_id                    70c292d6-d512-49cb-bc2a-e5bfe8500f80
# urgency_score                                              0.66097
# role                                                          user
# Name: 49, dtype: object
# <User(user_id='70c292d6-d512-49cb-bc2a-e5bfe8500f80', user_name='Frank Ocean', external_user_id='e6376d')>

# %% [markdown]
# # Tests

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    print(account)
# Out:
# <Account(account_id='cultpass', account_name='CultPass Card')>

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    for article in account.knowledge_articles:
        print(article)
# Out:
# <Knowledge(article_id='2100599f-d4b1-4cd9-b90c-69f689b7157a', title='How to Reserve a Spot for an Event')>
# <Knowledge(article_id='0b2b97b2-f76e-496b-9292-a6086a6cc491', title='What's Included in a CultPass Subscription')>
# <Knowledge(article_id='35cd73ac-93b8-4e38-b1ce-910df292d81e', title='How to Cancel or Pause a Subscription')>
# <Knowledge(article_id='07a93fb6-a8fd-41a6-a901-7303ac749348', title='How to Handle Login Issues?')>

# %%
with get_session(engine) as session:
    users = session.query(udahub.User).all()
    for user in users:
        # Get all column names for this model
        inst = inspect(user)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(user, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'user_id': 'a2840676-0355-45b0-bf37-6ee3b9ea76d1', 'account_id': 'cultpass', 'external_user_id': '848b1e', 'user_name': 'Liam Anderson', 'is_blocked': False, 'email_address': 'liam.anderson@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '6b75e6b0-84f2-4a54-a606-ef8618462b00', 'account_id': 'cultpass', 'external_user_id': 'ec60e2', 'user_name': 'Emma Thompson', 'is_blocked': True, 'email_address': 'emma.thompson@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '97c2db30-fca6-4f25-97fc-4a489099e75e', 'account_id': 'cultpass', 'external_user_id': '7d844c', 'user_name': 'Noah Johnson', 'is_blocked': False, 'email_address': 'noah.johnson@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': 'b2f36026-01ca-4740-bbab-4e1bf003f9a9', 'account_id': 'cultpass', 'external_user_id': '169cc3', 'user_name': 'Olivia Martinez', 'is_blocked': True, 'email_address': 'olivia.martinez@ecospherenterprises.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '99bf1c71-0342-46d8-9cb9-e647c029f893', 'account_id': 'cultpass', 'external_user_id': 'aa1c45', 'user_name': 'Ava Brown', 'is_blocked': False, 'email_address': 'ava.brown@ecospherenterprises.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '78504ef9-8fb2-4bcf-bbc0-878f17190b99', 'account_id': 'cultpass', 'external_user_id': 'ed925a', 'user_name': 'Sophia Davis', 'is_blocked': True, 'email_address': 'sophia.davis@quantumleapdynamics.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '36428f69-f82b-4cfa-9c44-0516011e737e', 'account_id': 'cultpass', 'external_user_id': 'b7a90e', 'user_name': 'Mason Wilson', 'is_blocked': False, 'email_address': 'mason.wilson@greenwavetechnologies.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '120d9d1a-c93a-4f1f-81bc-5d2abae8b6ab', 'account_id': 'cultpass', 'external_user_id': 'b6d951', 'user_name': 'Isabella Garcia', 'is_blocked': True, 'email_address': 'isabella.garcia@greenwavetechnologies.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': 'b947c6d6-935d-4dac-be8c-dd15357139e7', 'account_id': 'cultpass', 'external_user_id': '645afe', 'user_name': 'Lucas Martinez', 'is_blocked': False, 'email_address': 'lucas.martinez@skylineventures.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '2dad0543-87ff-4edb-ab2a-0f3fc9765d2c', 'account_id': 'cultpass', 'external_user_id': 'c422ae', 'user_name': 'Mia Rodriguez', 'is_blocked': True, 'email_address': 'mia.rodriguez@skylineventures.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': 'bcf2d8a7-d352-4db6-b294-6af066ca4b02', 'account_id': 'cultpass', 'external_user_id': '598712', 'user_name': 'Ethan Lee', 'is_blocked': False, 'email_address': 'ethan.lee@bluehorizoninnovations.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '3074945c-9a80-4313-a901-aff1fdaf2bec', 'account_id': 'cultpass', 'external_user_id': 'e30920', 'user_name': 'Amelia Harris', 'is_blocked': True, 'email_address': 'amelia.harris@bluehorizoninnovations.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '57ff5678-0716-4c5a-ac8c-ee73741f557b', 'account_id': 'cultpass', 'external_user_id': '36bf47', 'user_name': 'James Clark', 'is_blocked': False, 'email_address': 'james.clark@pinnaclepathways.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '04070bfc-cbc4-4e50-afc7-e74af570dbe8', 'account_id': 'cultpass', 'external_user_id': '97a140', 'user_name': 'Charlotte Lewis', 'is_blocked': True, 'email_address': 'charlotte.lewis@pinnaclepathways.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '6f991b5c-fb29-476f-a30f-f1f4a4bf534f', 'account_id': 'cultpass', 'external_user_id': 'f6dbb0', 'user_name': 'Benjamin Walker', 'is_blocked': False, 'email_address': 'benjamin.walker@synergysystemsgroup.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '71ab1421-ede1-4bb3-9186-6aa486112d42', 'account_id': 'cultpass', 'external_user_id': '13598d', 'user_name': 'Harper Young', 'is_blocked': True, 'email_address': 'harper.young@synergysystemsgroup.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '137b6baa-9362-4ba1-94b4-2939656d2370', 'account_id': 'cultpass', 'external_user_id': '4981cf', 'user_name': 'Alexander King', 'is_blocked': False, 'email_address': 'alexander.king@vanguardvisionaries.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': 'cae5d49d-cd72-4935-9a3f-c64e241612ae', 'account_id': 'cultpass', 'external_user_id': '8287e1', 'user_name': 'Ella Scott', 'is_blocked': True, 'email_address': 'ella.scott@nexusnetworks.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '23fc6f15-5b97-41ee-a452-74bc631e9cbe', 'account_id': 'cultpass', 'external_user_id': '7917c1', 'user_name': 'Henry Adams', 'is_blocked': False, 'email_address': 'henry.adams@nexusnetworks.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': 'ed8d4770-c0fc-4ae3-b736-92b584333f4e', 'account_id': 'cultpass', 'external_user_id': 'a4ab87', 'user_name': 'Alice Kingsley', 'is_blocked': True, 'email_address': 'alice.kingsley@wonderland.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': 'd49e2b52-ccc4-4911-89f7-17c7a8ff3770', 'account_id': 'cultpass', 'external_user_id': 'f556c0', 'user_name': 'Bob Stone', 'is_blocked': False, 'email_address': 'bob.stone@granite.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '588e1373-31f6-445c-ad34-824ed557938f', 'account_id': 'cultpass', 'external_user_id': '88382b', 'user_name': 'Cathy Bloom', 'is_blocked': False, 'email_address': 'cathy.bloom@florals.org', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '479bb4d4-7d46-47a1-8478-cbf5129c1919', 'account_id': 'cultpass', 'external_user_id': '888fb2', 'user_name': 'David Noir', 'is_blocked': True, 'email_address': 'david.noir@shadowmail.com', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '74e8dabf-d07a-4d05-8822-4521a53e2cb3', 'account_id': 'cultpass', 'external_user_id': 'f1f10d', 'user_name': 'Eva Green', 'is_blocked': False, 'email_address': 'eva.green@ecosoul.net', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'user_id': '70c292d6-d512-49cb-bc2a-e5bfe8500f80', 'account_id': 'cultpass', 'external_user_id': 'e6376d', 'user_name': 'Frank Ocean', 'is_blocked': False, 'email_address': 'frank.ocean@seawaves.io', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}

# %%
with get_session(engine) as session:
    tickets = session.query(udahub.Ticket).all()
    for ticket in tickets:
        # Get all column names for this model
        inst = inspect(ticket)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(ticket, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'ticket_id': '03dbb4a3-c755-4756-9c13-62fba741c716', 'account_id': 'cultpass', 'user_id': 'a2840676-0355-45b0-bf37-6ee3b9ea76d1', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '3a9f4f5b-3ae6-4671-8cc9-ee425a07ed12', 'account_id': 'cultpass', 'user_id': '6b75e6b0-84f2-4a54-a606-ef8618462b00', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'e4f13e44-7e93-482b-82d6-5a4f54e3846c', 'account_id': 'cultpass', 'user_id': '97c2db30-fca6-4f25-97fc-4a489099e75e', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'fa824ab4-ea4d-40b6-9954-3ab733947f46', 'account_id': 'cultpass', 'user_id': 'b2f36026-01ca-4740-bbab-4e1bf003f9a9', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'f0087c4c-20ae-4253-a13c-4763a3223af0', 'account_id': 'cultpass', 'user_id': '99bf1c71-0342-46d8-9cb9-e647c029f893', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '6a39bbea-9b37-4a70-9265-5cd18b6a2ffd', 'account_id': 'cultpass', 'user_id': '78504ef9-8fb2-4bcf-bbc0-878f17190b99', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '65eeae81-384a-45dd-8db0-1dc248907d9d', 'account_id': 'cultpass', 'user_id': '36428f69-f82b-4cfa-9c44-0516011e737e', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'be0a9af6-14f3-4b4a-9a3a-4236ca40cdbc', 'account_id': 'cultpass', 'user_id': '120d9d1a-c93a-4f1f-81bc-5d2abae8b6ab', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '7ba78d57-f7ea-47e0-a7b3-b7bd610352be', 'account_id': 'cultpass', 'user_id': 'b947c6d6-935d-4dac-be8c-dd15357139e7', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'fdb81a78-c367-4d26-9e96-e9a6e1e707dd', 'account_id': 'cultpass', 'user_id': '2dad0543-87ff-4edb-ab2a-0f3fc9765d2c', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '81ff23e5-d2c9-47ec-8e53-a2180e608e18', 'account_id': 'cultpass', 'user_id': 'bcf2d8a7-d352-4db6-b294-6af066ca4b02', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '72a1f4fe-e593-4025-b058-1fc52700646a', 'account_id': 'cultpass', 'user_id': '3074945c-9a80-4313-a901-aff1fdaf2bec', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '595e4a1e-c363-4a97-911f-039f5b228dca', 'account_id': 'cultpass', 'user_id': '57ff5678-0716-4c5a-ac8c-ee73741f557b', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'f76205bc-0290-4a06-a5a5-256986be916e', 'account_id': 'cultpass', 'user_id': '04070bfc-cbc4-4e50-afc7-e74af570dbe8', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'ad5f78a8-d422-4e64-abec-898d8decde1f', 'account_id': 'cultpass', 'user_id': '6f991b5c-fb29-476f-a30f-f1f4a4bf534f', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '8c30f69b-7a16-4fca-afa7-d5d802e2cd58', 'account_id': 'cultpass', 'user_id': '71ab1421-ede1-4bb3-9186-6aa486112d42', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '38563fc8-74df-4231-8aae-d4483a1ba6e8', 'account_id': 'cultpass', 'user_id': '137b6baa-9362-4ba1-94b4-2939656d2370', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '93448618-b722-4ec7-bf6b-d255347f6501', 'account_id': 'cultpass', 'user_id': 'cae5d49d-cd72-4935-9a3f-c64e241612ae', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '441f5ddf-aabb-4d54-82f5-02d8f49f726f', 'account_id': 'cultpass', 'user_id': '23fc6f15-5b97-41ee-a452-74bc631e9cbe', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '1c812796-6e54-406d-8f41-5c3bdfd5a56f', 'account_id': 'cultpass', 'user_id': 'ed8d4770-c0fc-4ae3-b736-92b584333f4e', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '13973959-0b02-4ec2-ba0c-12c599c86806', 'account_id': 'cultpass', 'user_id': 'd49e2b52-ccc4-4911-89f7-17c7a8ff3770', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '4c92184a-080f-4dbb-9e91-f38332c767a3', 'account_id': 'cultpass', 'user_id': '588e1373-31f6-445c-ad34-824ed557938f', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '085cf62a-e12d-417e-acaa-22cf16d60430', 'account_id': 'cultpass', 'user_id': '479bb4d4-7d46-47a1-8478-cbf5129c1919', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '30346442-edb4-4080-b3f6-565ffcd353fa', 'account_id': 'cultpass', 'user_id': '74e8dabf-d07a-4d05-8822-4521a53e2cb3', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '1242e4e9-5500-4a1b-95ad-db30b315b304', 'account_id': 'cultpass', 'user_id': '70c292d6-d512-49cb-bc2a-e5bfe8500f80', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'd554ab25-aaf9-4c6f-9f90-3c99dd62a21c', 'account_id': 'cultpass', 'user_id': 'a2840676-0355-45b0-bf37-6ee3b9ea76d1', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'ae20d46f-6f0d-40d8-b1b9-9bfb93c570a7', 'account_id': 'cultpass', 'user_id': '6b75e6b0-84f2-4a54-a606-ef8618462b00', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '395bcfa8-78d3-4598-a140-ef92d674c1d4', 'account_id': 'cultpass', 'user_id': '97c2db30-fca6-4f25-97fc-4a489099e75e', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '50b02e95-b1df-42bb-9808-b2dbff137c2d', 'account_id': 'cultpass', 'user_id': 'b2f36026-01ca-4740-bbab-4e1bf003f9a9', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '3b27f7e7-0f8a-4836-8f6a-94a73336b10a', 'account_id': 'cultpass', 'user_id': '99bf1c71-0342-46d8-9cb9-e647c029f893', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '12b331dc-4c22-44f4-9127-0d32a3f522b6', 'account_id': 'cultpass', 'user_id': '78504ef9-8fb2-4bcf-bbc0-878f17190b99', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'f55bf6e6-1576-4539-ad90-2d38d7b0ba2a', 'account_id': 'cultpass', 'user_id': '36428f69-f82b-4cfa-9c44-0516011e737e', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'ab16d4f0-3c6b-4cce-a5c2-8097b74e146e', 'account_id': 'cultpass', 'user_id': '120d9d1a-c93a-4f1f-81bc-5d2abae8b6ab', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '6016ed99-3f66-4b22-a58d-291d53d85046', 'account_id': 'cultpass', 'user_id': 'b947c6d6-935d-4dac-be8c-dd15357139e7', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'ff819438-66b8-4463-a1a1-6471baa32233', 'account_id': 'cultpass', 'user_id': '2dad0543-87ff-4edb-ab2a-0f3fc9765d2c', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '152b8842-bad8-4275-b169-4df1b9048f02', 'account_id': 'cultpass', 'user_id': 'bcf2d8a7-d352-4db6-b294-6af066ca4b02', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '13e6f529-45f3-4f65-965e-6ecb9162a3cd', 'account_id': 'cultpass', 'user_id': '3074945c-9a80-4313-a901-aff1fdaf2bec', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'c535fac8-8412-49f7-a638-7b5aff7d3afe', 'account_id': 'cultpass', 'user_id': '57ff5678-0716-4c5a-ac8c-ee73741f557b', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'cd830d5c-ac72-4517-b4d7-676b2feca601', 'account_id': 'cultpass', 'user_id': '04070bfc-cbc4-4e50-afc7-e74af570dbe8', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '83c1b2b9-0f9d-4caa-8398-e8d471b0cdbd', 'account_id': 'cultpass', 'user_id': '6f991b5c-fb29-476f-a30f-f1f4a4bf534f', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'b74edc43-a35d-40ff-9771-06e527af5b47', 'account_id': 'cultpass', 'user_id': '71ab1421-ede1-4bb3-9186-6aa486112d42', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '12d39d28-1be0-431b-bd30-0d4eb037705b', 'account_id': 'cultpass', 'user_id': '137b6baa-9362-4ba1-94b4-2939656d2370', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'a446c775-a89f-4843-97e0-c1f59234b5a4', 'account_id': 'cultpass', 'user_id': 'cae5d49d-cd72-4935-9a3f-c64e241612ae', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'f1b3b3b0-25e1-4761-833c-f9eafadb1cfd', 'account_id': 'cultpass', 'user_id': '23fc6f15-5b97-41ee-a452-74bc631e9cbe', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '1e22dff9-6db1-4c33-892e-b5224e3df2c4', 'account_id': 'cultpass', 'user_id': 'ed8d4770-c0fc-4ae3-b736-92b584333f4e', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '76bf55f1-5d8c-45bc-a375-395847ee33ff', 'account_id': 'cultpass', 'user_id': 'd49e2b52-ccc4-4911-89f7-17c7a8ff3770', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '0363dbd4-5885-4d4a-9034-f0bf9a2dc8c7', 'account_id': 'cultpass', 'user_id': '588e1373-31f6-445c-ad34-824ed557938f', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '3c274447-5dde-442c-a713-324a9fe8589a', 'account_id': 'cultpass', 'user_id': '479bb4d4-7d46-47a1-8478-cbf5129c1919', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '6e88f6dd-1797-421d-9d8b-d62676d67de4', 'account_id': 'cultpass', 'user_id': '74e8dabf-d07a-4d05-8822-4521a53e2cb3', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'c4df3979-2b0a-477d-adae-09d0bfc9fddc', 'account_id': 'cultpass', 'user_id': '70c292d6-d512-49cb-bc2a-e5bfe8500f80', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}

# %%
with get_session(engine) as session:
    messages = session.query(udahub.TicketMessage).all()
    for message in messages:
        # Get all column names for this model
        inst = inspect(message)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(message, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'message_id': '44ec8577-dbb8-4c45-9da5-6ce231843bef', 'ticket_id': '03dbb4a3-c755-4756-9c13-62fba741c716', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi team, I need to escalate an issue regarding the recent software update. It seems that after the update, several features are not functioning as expected. The dashboard is not loading properly, and the analytics section is showing incorrect data. This is affecting our daily operations, and we need a resolution as soon as possible. Please prioritize this issue and provide an update on the progress. Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'edc45cd5-319c-428a-b5d8-72a4d01d2fff', 'ticket_id': '3a9f4f5b-3ae6-4671-8cc9-ee425a07ed12', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am unable to access the booking system for our upcoming conference. Every time I try to log in, it says my credentials are incorrect, even though I have reset my password multiple times. Can someone please assist me with this issue? I need to finalize the bookings by the end of the week. Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'a8450da9-7ce6-477c-a00e-3a15c7d7c732', 'ticket_id': 'e4f13e44-7e93-482b-82d6-5a4f54e3846c', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am trying to book a meeting room for next week, but the system keeps showing an error message. It says that the room is unavailable, even though the calendar shows it as free. Can you please check and resolve this issue? I need to confirm the booking with my team. Thanks.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '41d7ab61-5a07-4690-b7f6-ef8e4bc2b131', 'ticket_id': 'fa824ab4-ea4d-40b6-9954-3ab733947f46', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am facing an issue with my password. I have tried resetting it multiple times, but the system does not recognize the new password. Additionally, I need to escalate this issue as it is preventing me from accessing important files. Please assist me at the earliest. Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '84c8162a-dfdd-4534-be9f-47a3cbfc3580', 'ticket_id': 'f0087c4c-20ae-4253-a13c-4763a3223af0', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am trying to book a flight for a business trip, but the booking portal is not working. It keeps crashing every time I try to proceed to payment. Can you please look into this issue? I need to book the flight by tomorrow. Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'd90d62e3-0527-4893-b018-80f423815ba6', 'ticket_id': '6a39bbea-9b37-4a70-9265-5cd18b6a2ffd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a query regarding the benefits of attending the upcoming events. I also need clarification on the pricing structure as it seems to have changed recently. Additionally, I would like to escalate this matter as it is affecting our budget planning. Please provide the necessary details at your earliest convenience. Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '8ec56dd7-a794-44d8-9035-4b21d1d9edc9', 'ticket_id': '65eeae81-384a-45dd-8db0-1dc248907d9d', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am having trouble with my password and need to book a subscription for our team. Additionally, I would like to know more about the benefits included in the subscription package. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'e790f41d-df29-4586-8053-76130e3d907a', 'ticket_id': 'be0a9af6-14f3-4b4a-9a3a-4236ca40cdbc', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a billing issue related to the recent events we hosted. The invoice amount seems incorrect, and I need clarification on the charges. Can you please provide a detailed breakdown of the billing? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'be91ac75-43f8-4725-b284-87a5502f63a9', 'ticket_id': '7ba78d57-f7ea-47e0-a7b3-b7bd610352be', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am unable to make a reservation due to access issues. Additionally, I am having trouble with my password and need to pause my current subscription. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'ff4af29f-fc87-4bbf-9fae-29f4775498e1', 'ticket_id': 'fdb81a78-c367-4d26-9e96-e9a6e1e707dd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a question regarding attendance at the upcoming events. Additionally, I need clarification on the pricing structure as it seems to have changed recently. Can you please provide the necessary details? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '38cb4f28-e325-4f58-88d2-7a80380c4439', 'ticket_id': '81ff23e5-d2c9-47ec-8e53-a2180e608e18', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need clarification on the pricing structure for our current subscription. It seems that the rates have increased without prior notice. Can you please provide a detailed breakdown of the charges? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'bbd92415-d2ee-4120-9551-a084a84fb8ca', 'ticket_id': '72a1f4fe-e593-4025-b058-1fc52700646a', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am trying to book a hotel for an upcoming conference, but the booking portal is not working. It keeps showing an error message. Can you please look into this issue? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '9b7b503c-55f1-4a99-b4e4-f6995d17400e', 'ticket_id': '595e4a1e-c363-4a97-911f-039f5b228dca', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am trying to book a flight for a business trip, but the booking system is not working. It keeps crashing every time I try to proceed to payment. Can you please look into this issue? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '30d6096a-dd84-46d1-b202-cc9bdb903bf2', 'ticket_id': 'f76205bc-0290-4a06-a5a5-256986be916e', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am facing an issue with my password and need to cancel a reservation. Additionally, I need clarification on the pricing structure as it seems to have changed recently. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '8b27ad01-ecb4-48e5-8cfa-e977bc711857', 'ticket_id': 'ad5f78a8-d422-4e64-abec-898d8decde1f', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am unable to access the subscription portal and need clarification on the pricing structure. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'b89300c8-fe1f-43aa-8170-0fd6759d1dc8', 'ticket_id': '8c30f69b-7a16-4fca-afa7-d5d802e2cd58', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to escalate an issue regarding my subscription. Additionally, I am having trouble with my password and need to book a service. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '3ea6b128-98fa-45ec-9804-e4ab435b31f8', 'ticket_id': '38563fc8-74df-4231-8aae-d4483a1ba6e8', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am facing an issue with my password and need to book a service. Additionally, I need to escalate a billing issue. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '85431402-4708-4f93-a24a-2e2f7cb23d2a', 'ticket_id': '93448618-b722-4ec7-bf6b-d255347f6501', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am unable to make a reservation due to an escalation issue. Additionally, I need clarification on the attendance policy. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'f66a30cb-e880-4551-9564-d6fccb06482e', 'ticket_id': '441f5ddf-aabb-4d54-82f5-02d8f49f726f', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am unable to access the billing portal and need clarification on the attendance policy. Additionally, I need to pause my current subscription. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'b70d8eb4-2743-4b88-babf-8abd473867cc', 'ticket_id': '1c812796-6e54-406d-8f41-5c3bdfd5a56f', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to cancel a booking and need clarification on the cancellation policy. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '881a68a9-b48e-4221-ae7b-4dbbe200a591', 'ticket_id': '13973959-0b02-4ec2-ba0c-12c599c86806', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am unable to log in to the billing portal and need to book a service. Additionally, I need clarification on the access policy. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '8867f609-94f7-41f0-a646-bafa92a01355', 'ticket_id': '4c92184a-080f-4dbb-9e91-f38332c767a3', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am unable to access the billing portal and need to book a service. Additionally, I need clarification on the pricing structure. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '9da6d4fb-c111-4c4f-8f8a-2bef3a6b62f5', 'ticket_id': '085cf62a-e12d-417e-acaa-22cf16d60430', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I have a billing issue related to a recent reservation. Additionally, I need clarification on the pricing structure. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '6aeeddd7-5619-45d8-ad0c-5dd22a4aa6c9', 'ticket_id': '30346442-edb4-4080-b3f6-565ffcd353fa', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am facing an issue with my password and need to book a service. Additionally, I need clarification on the benefits included in the package. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '1666a74d-8e35-4104-9707-ce78f6782e49', 'ticket_id': '1242e4e9-5500-4a1b-95ad-db30b315b304', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am facing an issue with my password. Can you please assist me with resetting it? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'af0836ee-8417-4b6b-af97-150953b0b372', 'ticket_id': 'd554ab25-aaf9-4c6f-9f90-3c99dd62a21c', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to escalate an issue regarding attendance at the upcoming events. Additionally, I need to cancel a reservation. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '246e38b6-cea0-4f40-bab0-f82870df1c5f', 'ticket_id': 'ae20d46f-6f0d-40d8-b1b9-9bfb93c570a7', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am facing an issue with my password and need to cancel a subscription. Additionally, I need clarification on the attendance policy. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'de9490ec-f305-407c-9734-e05e361d6b1d', 'ticket_id': '395bcfa8-78d3-4598-a140-ef92d674c1d4', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need clarification on the benefits included in the package. Additionally, I am facing an issue with my password and need access to the portal. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '8a4099d2-eb63-4ff7-9b10-b39d9fb86348', 'ticket_id': '50b02e95-b1df-42bb-9808-b2dbff137c2d', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to cancel a reservation and need clarification on the cancellation policy. Additionally, I need clarification on the pricing structure. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '0612b99a-cd31-467e-b649-82df7cb5ecbf', 'ticket_id': '3b27f7e7-0f8a-4836-8f6a-94a73336b10a', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am trying to book a subscription for our team. Can you please assist me with this issue? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'aa5f9eb1-63d6-4bac-8006-73cd934478d2', 'ticket_id': '12b331dc-4c22-44f4-9127-0d32a3f522b6', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am unable to make a reservation due to access issues. Additionally, I need clarification on the pricing structure for our current subscription. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '0163e1e4-dca8-4745-8d5d-ae03ff595b48', 'ticket_id': 'f55bf6e6-1576-4539-ad90-2d38d7b0ba2a', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to escalate an issue regarding attendance at the upcoming events. Additionally, I am unable to access the billing portal. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '0c230aef-517a-423f-8a2e-e8653d8b464d', 'ticket_id': 'ab16d4f0-3c6b-4cce-a5c2-8097b74e146e', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to pause my current subscription and need clarification on the benefits included in the package. Additionally, I need access to the portal. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '134f5291-2878-4eef-bf74-f4c03609e844', 'ticket_id': '6016ed99-3f66-4b22-a58d-291d53d85046', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am trying to book a subscription for our team and need to log in to the portal. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '04bd6d32-060f-4207-8192-d31a94c00a81', 'ticket_id': 'ff819438-66b8-4463-a1a1-6471baa32233', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to escalate an issue regarding the pricing structure. Additionally, I am unable to log in to the portal. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '484768d1-a976-4373-9a8e-47da378fc88c', 'ticket_id': '152b8842-bad8-4275-b169-4df1b9048f02', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a query regarding the upcoming events. Can you please provide the necessary details? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '700c053e-96a9-46d7-bc32-f4b420f1c173', 'ticket_id': '13e6f529-45f3-4f65-965e-6ecb9162a3cd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I have a billing issue related to a recent transaction. Additionally, I am facing an issue with my password. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '667700cb-6f13-4a12-85fd-be25d4528ed5', 'ticket_id': 'c535fac8-8412-49f7-a638-7b5aff7d3afe', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am facing an issue with my password and need to pause my current subscription. Additionally, I have a billing query. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'f76d0a7a-8eb2-4a27-9e80-27d151e92f69', 'ticket_id': 'cd830d5c-ac72-4517-b4d7-676b2feca601', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am unable to access the portal and need to log in to my account. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'e7526920-9117-4902-bb63-8ef8f052df26', 'ticket_id': '83c1b2b9-0f9d-4caa-8398-e8d471b0cdbd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am facing an issue with my password and need to log in to the portal. Additionally, I need to make a reservation. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '894b5a98-d4ff-4126-a42d-c0a2016ab430', 'ticket_id': 'b74edc43-a35d-40ff-9771-06e527af5b47', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to pause my current subscription and need health advice. Additionally, I have a query regarding stock prices. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '74c18dac-4d30-4ce8-a993-f87fe9be9f5b', 'ticket_id': '12d39d28-1be0-431b-bd30-0d4eb037705b', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am trying to book a service and need clarification on the stock prices. Additionally, I am facing an issue with my password. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '3b7ebb94-87f0-42e8-a791-cd8e3de2f9a0', 'ticket_id': 'a446c775-a89f-4843-97e0-c1f59234b5a4', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am unable to access the portal and need clarification on the weather conditions. Additionally, I have a query regarding dietary requirements. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '4ddec1bc-2225-4195-bfb4-71f2b5ca9946', 'ticket_id': 'f1b3b3b0-25e1-4761-833c-f9eafadb1cfd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a billing issue related to a recent transaction. Additionally, I need clarification on the weather conditions and dietary requirements. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'e24a2f4c-5f18-4f5e-98f7-c08109c21f6d', 'ticket_id': '1e22dff9-6db1-4c33-892e-b5224e3df2c4', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need health advice and have a query regarding stock prices. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'bbf1a570-0dcb-42c1-bad2-2fb2ce492a43', 'ticket_id': '76bf55f1-5d8c-45bc-a375-395847ee33ff', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a query regarding stock prices and need clarification on the weather conditions. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '32be9bb2-01dd-4bcc-a40d-0b47b0ba544c', 'ticket_id': '0363dbd4-5885-4d4a-9034-f0bf9a2dc8c7', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I have a billing issue related to a recent reservation. Additionally, I need health advice and clarification on the weather conditions. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '5c567e51-273f-4847-bdc5-a64efd10a452', 'ticket_id': '3c274447-5dde-442c-a713-324a9fe8589a', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a query regarding attendance at the upcoming events. Additionally, I need clarification on the weather conditions. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': 'cb9d475d-f5d9-4302-8894-a7d0d0862b66', 'ticket_id': '6e88f6dd-1797-421d-9d8b-d62676d67de4', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am trying to book a service and need health advice. Additionally, I have a query regarding dietary requirements. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'message_id': '881911de-135b-4318-bc97-8d64cc66cad5', 'ticket_id': 'c4df3979-2b0a-477d-adae-09d0bfc9fddc', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a query regarding attendance at the upcoming events. Additionally, I need clarification on the weather conditions and stock prices. Can you please assist me with these issues? Thank you.', 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}

# %%
with get_session(engine) as session:
    metas = session.query(udahub.TicketMetadata).all()
    for meta in metas:
        # Get all column names for this model
        inst = inspect(meta)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(meta, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'ticket_id': '03dbb4a3-c755-4756-9c13-62fba741c716', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation', 'urgency_score': 0.7258358547631155, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '3a9f4f5b-3ae6-4671-8cc9-ee425a07ed12', 'status': 'open', 'main_issue_type': None, 'tags': 'access, booking', 'urgency_score': 0.9728521442352538, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'e4f13e44-7e93-482b-82d6-5a4f54e3846c', 'status': 'open', 'main_issue_type': None, 'tags': 'booking', 'urgency_score': 0.6921589073501229, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'fa824ab4-ea4d-40b6-9954-3ab733947f46', 'status': 'open', 'main_issue_type': None, 'tags': 'password, escalation', 'urgency_score': 0.013740323841405777, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'f0087c4c-20ae-4253-a13c-4763a3223af0', 'status': 'open', 'main_issue_type': None, 'tags': 'booking', 'urgency_score': 0.2581611741569787, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '6a39bbea-9b37-4a70-9265-5cd18b6a2ffd', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits, events, escalation, pricing', 'urgency_score': 0.2869770458526414, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '65eeae81-384a-45dd-8db0-1dc248907d9d', 'status': 'open', 'main_issue_type': None, 'tags': 'password, booking, subscription, benefits', 'urgency_score': 0.20295640439011065, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'be0a9af6-14f3-4b4a-9a3a-4236ca40cdbc', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, events', 'urgency_score': 0.04087741096912323, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '7ba78d57-f7ea-47e0-a7b3-b7bd610352be', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, access, password, pause', 'urgency_score': 0.8809823296680662, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'fdb81a78-c367-4d26-9e96-e9a6e1e707dd', 'status': 'open', 'main_issue_type': None, 'tags': 'attendance, events, pricing', 'urgency_score': 0.2226293534218582, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '81ff23e5-d2c9-47ec-8e53-a2180e608e18', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing', 'urgency_score': 0.6419381385304803, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '72a1f4fe-e593-4025-b058-1fc52700646a', 'status': 'open', 'main_issue_type': None, 'tags': 'booking', 'urgency_score': 0.21385778949136713, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '595e4a1e-c363-4a97-911f-039f5b228dca', 'status': 'open', 'main_issue_type': None, 'tags': 'booking', 'urgency_score': 0.10646164173951833, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'f76205bc-0290-4a06-a5a5-256986be916e', 'status': 'open', 'main_issue_type': None, 'tags': 'password, cancelation, reservation, pricing', 'urgency_score': 0.689660529003254, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'ad5f78a8-d422-4e64-abec-898d8decde1f', 'status': 'open', 'main_issue_type': None, 'tags': 'access, subscription, pricing', 'urgency_score': 0.44468171400129164, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '8c30f69b-7a16-4fca-afa7-d5d802e2cd58', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, subscription, booking, password', 'urgency_score': 0.049841873604551834, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '38563fc8-74df-4231-8aae-d4483a1ba6e8', 'status': 'open', 'main_issue_type': None, 'tags': 'password, booking, escalation, billing', 'urgency_score': 0.10531760491678954, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '93448618-b722-4ec7-bf6b-d255347f6501', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, escalation, attendance', 'urgency_score': 0.09377285901861998, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '441f5ddf-aabb-4d54-82f5-02d8f49f726f', 'status': 'open', 'main_issue_type': None, 'tags': 'access, attendance, pause, billing', 'urgency_score': 0.7672186174534039, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '1c812796-6e54-406d-8f41-5c3bdfd5a56f', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, cancelation', 'urgency_score': 0.01787757416489355, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '13973959-0b02-4ec2-ba0c-12c599c86806', 'status': 'open', 'main_issue_type': None, 'tags': 'login, billing, access, booking', 'urgency_score': 0.4733189005995194, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '4c92184a-080f-4dbb-9e91-f38332c767a3', 'status': 'open', 'main_issue_type': None, 'tags': 'access, billing, booking, pricing', 'urgency_score': 0.7122411774798102, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '085cf62a-e12d-417e-acaa-22cf16d60430', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, escalation, reservation, pricing', 'urgency_score': 0.9474164228210739, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '30346442-edb4-4080-b3f6-565ffcd353fa', 'status': 'open', 'main_issue_type': None, 'tags': 'password, billing, booking, benefits', 'urgency_score': 0.431715362120494, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '1242e4e9-5500-4a1b-95ad-db30b315b304', 'status': 'open', 'main_issue_type': None, 'tags': 'password', 'urgency_score': 0.11852653770242327, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'd554ab25-aaf9-4c6f-9f90-3c99dd62a21c', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, attendance, cancelation', 'urgency_score': 0.7361909985177022, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'ae20d46f-6f0d-40d8-b1b9-9bfb93c570a7', 'status': 'open', 'main_issue_type': None, 'tags': 'password, subscription, attendance, cancelation', 'urgency_score': 0.40604567617207976, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '395bcfa8-78d3-4598-a140-ef92d674c1d4', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits, password, access', 'urgency_score': 0.00788991401128547, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '50b02e95-b1df-42bb-9808-b2dbff137c2d', 'status': 'open', 'main_issue_type': None, 'tags': 'attendance, cancelation, pricing', 'urgency_score': 0.83308680421856, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '3b27f7e7-0f8a-4836-8f6a-94a73336b10a', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, booking', 'urgency_score': 0.599234729252278, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '12b331dc-4c22-44f4-9127-0d32a3f522b6', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, pricing, subscription, access', 'urgency_score': 0.47177783749717317, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'f55bf6e6-1576-4539-ad90-2d38d7b0ba2a', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, attendance, access, billing', 'urgency_score': 0.06725869976359744, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'ab16d4f0-3c6b-4cce-a5c2-8097b74e146e', 'status': 'open', 'main_issue_type': None, 'tags': 'pause, benefits, access', 'urgency_score': 0.9087599774483738, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '6016ed99-3f66-4b22-a58d-291d53d85046', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, subscription, login', 'urgency_score': 0.5062594890369937, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'ff819438-66b8-4463-a1a1-6471baa32233', 'status': 'open', 'main_issue_type': None, 'tags': 'login, escalation, pricing', 'urgency_score': 0.022723322444101468, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '152b8842-bad8-4275-b169-4df1b9048f02', 'status': 'open', 'main_issue_type': None, 'tags': 'events', 'urgency_score': 0.4195813313511597, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '13e6f529-45f3-4f65-965e-6ecb9162a3cd', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, password', 'urgency_score': 0.02505741587003496, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'c535fac8-8412-49f7-a638-7b5aff7d3afe', 'status': 'open', 'main_issue_type': None, 'tags': 'events, password, pause, billing', 'urgency_score': 0.7586061745065081, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'cd830d5c-ac72-4517-b4d7-676b2feca601', 'status': 'open', 'main_issue_type': None, 'tags': 'access, login', 'urgency_score': 0.5990141016099213, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '83c1b2b9-0f9d-4caa-8398-e8d471b0cdbd', 'status': 'open', 'main_issue_type': None, 'tags': 'password, events, login, reservation', 'urgency_score': 0.6856395849850357, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'b74edc43-a35d-40ff-9771-06e527af5b47', 'status': 'open', 'main_issue_type': None, 'tags': 'pause, health advice, stock price', 'urgency_score': 0.9586645747082342, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '12d39d28-1be0-431b-bd30-0d4eb037705b', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, password, stock price, weather', 'urgency_score': 0.6113878778360192, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'a446c775-a89f-4843-97e0-c1f59234b5a4', 'status': 'open', 'main_issue_type': None, 'tags': 'access, weather, dietary', 'urgency_score': 0.8629822222363024, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'f1b3b3b0-25e1-4761-833c-f9eafadb1cfd', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, weather, dietary', 'urgency_score': 0.8170054652032597, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '1e22dff9-6db1-4c33-892e-b5224e3df2c4', 'status': 'open', 'main_issue_type': None, 'tags': 'health advice, stock price', 'urgency_score': 0.39520858006032333, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '76bf55f1-5d8c-45bc-a375-395847ee33ff', 'status': 'open', 'main_issue_type': None, 'tags': 'stock price, weather', 'urgency_score': 0.5934306207035395, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '0363dbd4-5885-4d4a-9034-f0bf9a2dc8c7', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, reservation, health advice, weather', 'urgency_score': 0.5276543399735758, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '3c274447-5dde-442c-a713-324a9fe8589a', 'status': 'open', 'main_issue_type': None, 'tags': 'attendance, billing, weather', 'urgency_score': 0.8616267446863132, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': '6e88f6dd-1797-421d-9d8b-d62676d67de4', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, events, health advice, dietary', 'urgency_score': 0.022188430541761117, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}
# {'ticket_id': 'c4df3979-2b0a-477d-adae-09d0bfc9fddc', 'status': 'open', 'main_issue_type': None, 'tags': 'attendance, weather, stock price', 'urgency_score': 0.660969763647349, 'created_at': datetime.datetime(2026, 4, 18, 9, 36, 49), 'updated_at': datetime.datetime(2026, 4, 18, 9, 36, 49)}

# %%
with get_session(engine) as session:
    user = session.query(udahub.User).filter_by(
        account_id=account_id,
        external_user_id=ticket_table.iloc[2].to_dict()["owner_id"],
    ).first()
    
    ticket:udahub.Ticket = user.tickets[0]
    for message in ticket.messages:
        print(message)
# Out:
# <TicketMessage(message_id='a8450da9-7ce6-477c-a00e-3a15c7d7c732', role='user', content='Hi, I am trying to book a meet...')>
