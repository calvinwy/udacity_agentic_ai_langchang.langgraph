# %%
import json
import uuid
from sqlalchemy import create_engine, inspect
from utils import reset_db, get_session, model_to_dict
from data.models import udahub

# %% [markdown]
# # Udahub Application

# %% [markdown]
# ## Core Database

# %% [markdown]
# **Init DB**

# %%
udahub_db = "data/core/udahub.db"
reset_db(udahub_db)
engine = create_engine(f"sqlite:///{udahub_db}", echo=False)
udahub.Base.metadata.create_all(bind=engine)
# Out:
# 2026-04-19 02:40:42,112 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-19 02:40:42,112 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Recreated data/core/udahub.db with fresh schema

# %% [markdown]
# **Account**

# %%
account_id = "cultpass"
account_name = "CultPass Card"

with get_session(engine) as session:
    account = udahub.Account(
        account_id=account_id,
        account_name=account_name,
    )
    session.add(account)

# %% [markdown]
# ---

# %% [markdown]
# ## Integrations

# %% [markdown]
# **Use LLM to Generate Sample Data**

# %%
import os
import pandas as pd
import random
from dotenv import load_dotenv
from typing import List
from pydantic import BaseModel, Field
from typing import List, Optional, Dict, Any, Literal, TypedDict, Annotated
from langgraph.prebuilt import create_react_agent
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import SystemMessage
from langchain_chroma import Chroma
from langchain_core.documents import Document

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# llm_base_url = "https://openai.vocareum.com/v1"

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0.0,
    # base_url=llm_base_url,
    api_key=OPENAI_API_KEY,
)

embeddings_fn = OpenAIEmbeddings(
    model="text-embedding-3-large",
    # base_url=llm_base_url,
    api_key=OPENAI_API_KEY,
)

# %% [markdown]
# **Data Generation Parameters**

# %%
num_articles = 20
num_account = 10
num_user = 25
num_ticket = 50
num_msg = num_ticket
num_expected_tag_msg = round(num_msg * 0.8)
num_unexpected_tag_msg = num_msg - num_expected_tag_msg
chromadb_directory = "vectorstore"
collection_name = "knowledge_vecotr_store"

# %% [markdown]
# ### Sampling Schema
#
# For LLM to produce the data samples

# %%
class ArticlesSchema(BaseModel):
    title: Annotated[str, Field(description="Title of the article.")]
    content: Annotated[str, Field(description="Content of the article.")]
    tags: Annotated[str, Field(description="Tags of the article")]

class ArticlesListSchema(BaseModel):
    samples: Annotated[List[ArticlesSchema], Field(description="List of CultpassArticles")]

class AccountSamples(BaseModel):
    """Structured response for account table"""
    company_name: List[str] = Field(description="List of first name and last name")

class UsersSchema(BaseModel):
    name: Annotated[str, Field(description="User's name with first and last name.")]
    email: Annotated[str, Field(description="User's email address.")]
    is_blocked: Annotated[bool, Field(description="User's blocking status.")]
    account_id: Annotated[str, Field(description="Company account ID")]

class UsersListSchema(BaseModel):
    samples: Annotated[List[UsersSchema], Field(description="List of users")]

class SingleTicket(BaseModel):
    """Structured response for a ticket"""
    status: Annotated[Literal['open','pending','closed'], Field(description="Status of the ticket")]
    content: Annotated[str, Field(description="The ticket body message content.")]
    owner_id: Annotated[str, Field(description="User ID")]
    owner_name: Annotated[str, Field(description="User's name")]
    channel: Annotated[Literal['email','chat','web','sms','social','phone'], Field(description="Ticket priority")]
    tags: Annotated[str, Field(description="List of tags used for creating this message")]
    account_id: Annotated[str, Field(description="Company account ID")]
    urgency_score: Annotated[float, Field(description="Urgency of the ticket")]

class TicketSamples(BaseModel):
    """Structured response of ticket list"""
    samples: List[SingleTicket]

# %% [markdown]
# ## Loading Default Data
#
# * Knowledge Base
# * Users Data

# %%
# Load Sample Articles
cultpass_articles = []
with open('data/external/cultpass_articles.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_articles.append(json.loads(line))

# Extract Tags from Samples
sample_tags = [ article['tags'].split(', ') for article in cultpass_articles ]
sample_tags = set([ item for subtags in sample_tags for item in subtags ])
sample_tags_str = ", ".join(sample_tags)

# Define Tags with Expected Knowledge and Tags without Expected Knowledge
# (This is for sampling ticket questions "with vs without knowledge to answer" using LLM)
expected_tags = sample_tags
unexpected_tags = ['weather', 'stock price', 'dietary', 'health advice']

# %%
sample_tags
# Out:
# {'access',
#  'attendance',
#  'benefits',
#  'billing',
#  'booking',
#  'cancelation',
#  'escalation',
#  'events',
#  'login',
#  'password',
#  'pause',
#  'pricing',
#  'reservation',
#  'subscription'}

# %%
# Load Users Data
cultpass_users = []
with open('data/external/cultpass_users.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_users.append(json.loads(line))

# %% [markdown]
# #### Generate Knowledge Articles

# %%
# Create Additional Knowledge Articles
num_cultpass_articles = len(cultpass_articles)
num_new_articles = num_articles - num_cultpass_articles
sample_articles_template = """
    You are an helpful expert creating sample of python sample article data based on given examples.  Do not provide any additional description or explanation.
    There is a mock-up project, it has the following description:

    You’ve joined a fast-growing AI startup building the next frontier in customer support automation. Your team is responsible for building UDA-Hub, 
    a Universal Decision Agent designed to plug into existing customer support systems (Zendesk, Intercom, Freshdesk, internal CRMs) and intelligently 
    resolve tickets. You need to generate sample knowledge articles in area including: {sample_tags}.  
    
    The knowledge areas given above will be used as tags for the generated articles.

    The first UDA-Hub customer Cultpass has the following sample articles to be used as knowledge to be used by the system:
    {samples}

    Cultpass is a online travel and leisure platform that provides a subscription-based card for travelers, offering access to airport lounges, travel discounts, 
    and exclusive experiences worldwide. Please create the new articles based on this context and the sample articles provided above.

    Provide {num_articles} more example like above and double check if all articles uses tags from {sample_tags}, if not try again.
    """

sample_articles_prompt = PromptTemplate(
    template = sample_articles_template,
    input_variables = ["samples","num_articles","sample_tags"],
    ).invoke({"samples": cultpass_articles,
              "num_articles": num_new_articles,
              "sample_tags": sample_tags}).to_messages()

new_cultpass_articles = llm.with_structured_output(ArticlesListSchema).invoke(sample_articles_prompt).model_dump()['samples']
cultpass_articles_ls = cultpass_articles + new_cultpass_articles

# Extracting Sample Tags for Each Sample
# new_sample_tags = [ article['tags'].split(', ') for article in cultpass_articles_ls ]
# new_sample_tags = set([ item for subtags in new_sample_tags for item in subtags ])
# new_sample_tags_str = ", ".join(new_sample_tags)

if len(cultpass_articles_ls) < 14:
    raise AssertionError("You should load the articles with at least 14 records")

# %%
cultpass_articles_ls
# Out:
# [{'title': 'How to Reserve a Spot for an Event',
#   'content': 'If a user asks how to reserve an event:\n\n- Guide them to the CultPass app\n- Instruct them to browse the experience catalog and tap \'Reserve\'\n- If it\'s a premium or limited event, check if reservation confirmation is required via email\n- Remind them to arrive at least 15 minutes early with their QR code visible\n\n**Suggested phrasing:**\n"You can reserve an experience by opening the CultPass app, selecting your desired event, and tapping \'Reserve\'. Be sure to arrive 15 minutes early with your QR code ready."',
#   'tags': 'reservation, events, booking, attendance'},
#  {'title': "What's Included in a CultPass Subscription",
#   'content': 'Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."',
#   'tags': 'subscription, benefits, pricing, access'},
#  {'title': 'How to Cancel or Pause a Subscription',
#   'content': 'Users can manage their subscription via the app > \'My Account\' > \'Manage Plan\'.\n\n- Cancel: Effective at the end of the billing cycle\n- Pause: Preserves user data, resumes automatically when reactivated\n- Do NOT offer refunds unless approved by support lead\n\n**Suggested phrasing:**\n"You can cancel or pause your subscription at any time via the \'My Account\' section in the CultPass app. Cancelation takes effect at the end of your billing cycle."',
#   'tags': 'cancelation, pause, subscription, billing'},
#  {'title': 'How to Handle Login Issues?',
#   'content': 'Most login issues are resolved with password reset:\n\n- Ask the user to tap \'Forgot Password\' on the login screen\n- Ensure they are using the correct registered email\n- If they did not receive the reset email, check spam folder or retry after 10 minutes\n- For persistent login issues, escalate to human support\n\n**Suggested phrasing:**\n"Try tapping \'Forgot Password\' on the login screen. Make sure you\'re using the email associated with your account. If the email doesn\'t arrive, check spam or try again in a few minutes."',
#   'tags': 'login, password, access, escalation'},
#  {'title': 'How to Access Airport Lounges with CultPass',
#   'content': 'To access airport lounges:\n\n- Open the CultPass app and navigate to \'Lounge Access\'\n- Select your current location or search for available lounges\n- Tap \'Access\' and show the QR code at the lounge entrance\n\n**Suggested phrasing:**\n"You can access airport lounges by selecting \'Lounge Access\' in the CultPass app and showing your QR code at the entrance."',
#   'tags': 'access, benefits, booking'},
#  {'title': 'Understanding CultPass Billing Cycle',
#   'content': 'CultPass billing is straightforward:\n\n- Monthly charges occur on the same date each month\n- Check \'Billing History\' in the app for past transactions\n- Contact support for any discrepancies\n\n**Suggested phrasing:**\n"Your CultPass billing cycle is monthly. You can view your billing history in the app under \'Billing History\'."',
#   'tags': 'billing, subscription, benefits'},
#  {'title': 'How to Book Exclusive Experiences',
#   'content': 'Booking exclusive experiences is easy:\n\n- Open the CultPass app and browse \'Exclusive Experiences\'\n- Tap \'Book Now\' on your chosen experience\n- Confirm your booking and check your email for details\n\n**Suggested phrasing:**\n"To book an exclusive experience, browse the \'Exclusive Experiences\' section in the CultPass app and tap \'Book Now\'."',
#   'tags': 'booking, events, reservation'},
#  {'title': 'Steps to Reset Your CultPass Password',
#   'content': 'Resetting your password is simple:\n\n- Tap \'Forgot Password\' on the login screen\n- Enter your registered email and follow the link sent to you\n- Create a new password and log in\n\n**Suggested phrasing:**\n"If you need to reset your password, tap \'Forgot Password\' and follow the instructions sent to your email."',
#   'tags': 'password, login, access'},
#  {'title': 'How to Pause Your CultPass Subscription',
#   'content': 'Pausing your subscription is hassle-free:\n\n- Go to \'My Account\' > \'Manage Plan\' in the app\n- Select \'Pause Subscription\' and choose the duration\n- Your subscription will resume automatically\n\n**Suggested phrasing:**\n"You can pause your subscription anytime via \'My Account\' in the CultPass app. It will resume automatically after the selected duration."',
#   'tags': 'pause, subscription, billing'},
#  {'title': 'Handling Escalated Support Tickets',
#   'content': 'For escalated tickets:\n\n- Verify the issue and gather all necessary details\n- Escalate to the appropriate support team\n- Follow up with the user once resolved\n\n**Suggested phrasing:**\n"For complex issues, we escalate tickets to our specialized support team to ensure a swift resolution."',
#   'tags': 'escalation, support, access'},
#  {'title': 'How to Benefit from CultPass Travel Discounts',
#   'content': 'Maximize your travel savings:\n\n- Check \'Travel Discounts\' in the app for current offers\n- Apply discounts at checkout when booking flights or hotels\n- Ensure your CultPass is active for discounts to apply\n\n**Suggested phrasing:**\n"Explore \'Travel Discounts\' in the CultPass app to save on flights and hotels. Ensure your CultPass is active to enjoy these benefits."',
#   'tags': 'benefits, pricing, access'},
#  {'title': 'How to Cancel a Booking',
#   'content': 'Canceling a booking is straightforward:\n\n- Open the CultPass app and go to \'My Bookings\'\n- Select the booking you wish to cancel\n- Tap \'Cancel Booking\' and confirm\n\n**Suggested phrasing:**\n"To cancel a booking, navigate to \'My Bookings\' in the CultPass app and select \'Cancel Booking\'."',
#   'tags': 'cancelation, booking, reservation'},
#  {'title': 'How to Attend CultPass Events',
#   'content': 'Attending events is simple:\n\n- Reserve your spot via the CultPass app\n- Arrive at the venue with your QR code ready\n- Enjoy the event and check-in via the app\n\n**Suggested phrasing:**\n"Reserve your spot in the CultPass app and arrive with your QR code ready to attend the event."',
#   'tags': 'attendance, events, reservation'},
#  {'title': 'Understanding CultPass Pricing Plans',
#   'content': 'CultPass offers flexible pricing:\n\n- Choose from monthly or annual plans\n- View detailed pricing in the app under \'Plans & Pricing\'\n- Contact support for custom corporate plans\n\n**Suggested phrasing:**\n"Explore our flexible pricing plans in the CultPass app under \'Plans & Pricing\'."',
#   'tags': 'pricing, subscription, benefits'},
#  {'title': 'How to Resolve Billing Discrepancies',
#   'content': 'For billing issues:\n\n- Check \'Billing History\' in the app for transaction details\n- Contact support with your billing ID for assistance\n- Allow 3-5 business days for resolution\n\n**Suggested phrasing:**\n"If you notice any billing discrepancies, check \'Billing History\' in the app and contact support with your billing ID."',
#   'tags': 'billing, escalation, support'},
#  {'title': 'How to Access CultPass Member Benefits',
#   'content': 'Unlock member benefits:\n\n- Explore \'Member Benefits\' in the app for exclusive offers\n- Redeem benefits directly through the app\n- Ensure your membership is active\n\n**Suggested phrasing:**\n"Access exclusive offers in the \'Member Benefits\' section of the CultPass app. Ensure your membership is active to redeem benefits."',
#   'tags': 'benefits, access, subscription'},
#  {'title': 'How to Manage Your CultPass Account',
#   'content': 'Managing your account is easy:\n\n- Go to \'My Account\' in the app\n- Update personal details, payment methods, and preferences\n- Contact support for account-related queries\n\n**Suggested phrasing:**\n"Manage your account details and preferences in the \'My Account\' section of the CultPass app."',
#   'tags': 'access, subscription, support'},
#  {'title': 'How to Handle Event Overbooking',
#   'content': 'In case of overbooking:\n\n- Inform the user and offer alternative dates or events\n- Provide a refund if no alternatives are suitable\n- Escalate to support if necessary\n\n**Suggested phrasing:**\n"If an event is overbooked, we\'ll offer alternative dates or a refund. Contact support for further assistance."',
#   'tags': 'escalation, events, booking'},
#  {'title': 'How to Update Your CultPass Payment Method',
#   'content': 'Updating payment methods is simple:\n\n- Go to \'My Account\' > \'Payment Methods\' in the app\n- Add or remove payment options\n- Ensure your primary method is up-to-date\n\n**Suggested phrasing:**\n"Update your payment methods in the \'My Account\' section of the CultPass app to ensure seamless transactions."',
#   'tags': 'billing, access, subscription'},
#  {'title': 'How to Resolve Login Authentication Issues',
#   'content': 'For authentication issues:\n\n- Ensure your device is connected to the internet\n- Verify your login credentials\n- Contact support if issues persist\n\n**Suggested phrasing:**\n"If you\'re facing authentication issues, check your internet connection and login credentials. Contact support if the problem continues."',
#   'tags': 'login, access, escalation'}]

# %% [markdown]
# Creating Vector Embedding for RAG

# %%
# Create vector store for knowledge articles
vector_store = Chroma(
    collection_name=collection_name,
    embedding_function=embeddings_fn,
    persist_directory=chromadb_directory,
)

cultpass_articles_docs = [ Document(page_content=article['title']+": "+article["content"],
                                      metadata={"tags": article['tags']},
                                      id=i) for i, article in enumerate(cultpass_articles_ls) ]
_ = vector_store.add_documents(documents=cultpass_articles_docs)

# %%
question = "Hi, I have a question regarding the billing for the events I attended last month. There seems to be a discrepancy in the charges, and I would like to understand the breakdown of the costs. Could you please provide a detailed billing statement? Thank you."
vector_store.similarity_search(question)
# Out:
# [Document(id='14', metadata={'tags': 'billing, escalation, support'}, page_content='How to Resolve Billing Discrepancies: For billing issues:\n\n- Check \'Billing History\' in the app for transaction details\n- Contact support with your billing ID for assistance\n- Allow 3-5 business days for resolution\n\n**Suggested phrasing:**\n"If you notice any billing discrepancies, check \'Billing History\' in the app and contact support with your billing ID."'),
#  Document(id='5', metadata={'tags': 'billing, subscription, benefits'}, page_content='Understanding CultPass Billing Cycle: CultPass billing is straightforward:\n\n- Monthly charges occur on the same date each month\n- Check \'Billing History\' in the app for past transactions\n- Contact support for any discrepancies\n\n**Suggested phrasing:**\n"Your CultPass billing cycle is monthly. You can view your billing history in the app under \'Billing History\'."'),
#  Document(id='13', metadata={'tags': 'pricing, subscription, benefits'}, page_content='Understanding CultPass Pricing Plans: CultPass offers flexible pricing:\n\n- Choose from monthly or annual plans\n- View detailed pricing in the app under \'Plans & Pricing\'\n- Contact support for custom corporate plans\n\n**Suggested phrasing:**\n"Explore our flexible pricing plans in the CultPass app under \'Plans & Pricing\'."'),
#  Document(id='1', metadata={'tags': 'subscription, benefits, pricing, access'}, page_content='What\'s Included in a CultPass Subscription: Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."')]

# %% [markdown]
# #### Generate Users and Tickets

# %%
# Create Company List
account_prompt_template = """You are a company naming expert. Please come up with {num_account} company names."""

account_prompt = PromptTemplate(
    template = account_prompt_template,
    input_variables = ["num_account"],
    ).invoke({"num_account": num_account}).to_messages()

account = llm.with_structured_output(AccountSamples).invoke(account_prompt).model_dump()['company_name']
account_table = pd.DataFrame({"company_name": account})
# account_table['id'] = account_table.index
account_table['account_id'] = [ str(uuid.uuid4()) for i in range(num_account) ]
account_table_ls = account_table.to_dict(orient='records')
# account_table

# %%
# Create Additional Users
num_cultpass_users = len(cultpass_users)
num_new_users = num_user - num_cultpass_users
user_prompt_template = """
    You are a people naming expert. Please come up with {num_user} names with both first and last name.
    Randomly choose a company for each user from the account list and based on the name of the company,
    create an email address for this person.  Some companies should have more users than others.
    All users from the same company must have the same domain name on their email address.

    The `is_blocked` status should be randomly choosen as 'True' or 'False'

    List of account (companies): {account_table}"""

user_prompt = PromptTemplate(
    template = user_prompt_template,
    input_variables = ["num_user","account_table"],
    ).invoke({"num_user": num_new_users, "account_table": account_table}).to_messages()

user_ls = llm.with_structured_output(UsersListSchema).invoke(user_prompt).model_dump()['samples']
user_table = pd.DataFrame(user_ls)
user_table['id'] = [ str(uuid.uuid4().hex[:6]) for i in range(num_new_users) ]
user_table = user_table[['id', 'name', 'email', 'is_blocked','account_id']]
cultpass_users_table = pd.DataFrame(cultpass_users)
user_table = pd.concat([user_table, cultpass_users_table])
user_table['account_id'] = [ str(uuid.uuid4()) for i in range(num_user) ]     # account ID of LLM generated user should be replaced with true uuid4.

# %%
cultpass_users_table
# Out:
#        id            name                          email  is_blocked
# 0  a4ab87  Alice Kingsley  alice.kingsley@wonderland.com        True
# 1  f556c0       Bob Stone          bob.stone@granite.com       False
# 2  88382b     Cathy Bloom        cathy.bloom@florals.org       False
# 3  888fb2      David Noir      david.noir@shadowmail.com        True
# 4  f1f10d       Eva Green          eva.green@ecosoul.net       False
# 5  e6376d     Frank Ocean        frank.ocean@seawaves.io       False

# %%
user_table
# Out:
#         id             name                                    email  \
# 0   427e02    Alice Johnson    alice.johnson@innovatechsolutions.com
# 1   c78831    Michael Smith    michael.smith@innovatechsolutions.com
# 2   7bdf7c       Emma Brown       emma.brown@ecospherenterprises.com
# 3   c482cf       Liam Davis       liam.davis@quantumleapdynamics.com
# 4   7f693e    Olivia Wilson  olivia.wilson@greenwavetechnologies.com
# 5   8da0ce    Noah Martinez        noah.martinez@skylineventures.com
# 6   2a0c63  Sophia Anderson      sophia.anderson@apexinnovations.com
# 7   e436cb     James Taylor   james.taylor@bluehorizonindustries.com
# 8   5d03df  Isabella Thomas     isabella.thomas@pinnaclepathways.com
# 9   947b40      Ethan White      ethan.white@synergysystemsgroup.com
# 10  f001f5       Mia Harris       mia.harris@vanguardvisionaries.com
# 11  610877      Lucas Clark      lucas.clark@innovatechsolutions.com
# 12  a813af     Amelia Lewis     amelia.lewis@innovatechsolutions.com
# 13  3026f6  Benjamin Walker  benjamin.walker@ecospherenterprises.com
# 14  5142e4   Charlotte Hall   charlotte.hall@quantumleapdynamics.com
# 15  898e18      Henry Allen    henry.allen@greenwavetechnologies.com
# 16  5de55b        Ava Young            ava.young@skylineventures.com
# 17  3783ff     William King         william.king@apexinnovations.com
# 18  2151a1     Evelyn Scott   evelyn.scott@bluehorizonindustries.com
# 0   a4ab87   Alice Kingsley            alice.kingsley@wonderland.com
# 1   f556c0        Bob Stone                    bob.stone@granite.com
# 2   88382b      Cathy Bloom                  cathy.bloom@florals.org
# 3   888fb2       David Noir                david.noir@shadowmail.com
# 4   f1f10d        Eva Green                    eva.green@ecosoul.net
# 5   e6376d      Frank Ocean                  frank.ocean@seawaves.io
#
#     is_blocked                            account_id
# 0        False  9d2e95e8-9d52-40ab-9983-3273c94d4579
# 1         True  be5df8ee-09b2-429e-96f6-23891b32aab8
# 2        False  53838228-26c5-43a1-85c1-1884d8631d34
# 3         True  e6b9bf00-6f47-4980-9eaa-2016d0932c0a
# 4        False  f284499e-eec1-4603-b567-1292769cb381
# 5         True  05a7efa6-9f71-4d58-bcca-0e0fa9203449
# 6        False  a797750f-fe84-410d-a92a-6ecdbd828328
# 7         True  0785aa0f-5957-4166-ac93-ef3d0dfc5713
# 8        False  4dc9019a-819d-43d7-b49c-572b7fa57202
# 9         True  2164efce-3905-4eb2-9d33-787bbc46cf32
# 10       False  2eeefb9a-3443-4432-935f-d74f0a0620de
# 11        True  d8dd121f-a950-43c5-a064-0baee58734aa
# 12       False  f40010c7-c75e-49bf-94aa-044052588961
# 13        True  0d68f151-9424-409c-91de-f99065b15a3e
# 14       False  277333e6-658e-4acf-a134-9a9d7bf96c77
# 15        True  8820c399-359b-4294-9fe0-16788c75a586
# 16       False  b22327a3-3e8a-43a0-a967-da834581daa5
# 17        True  53565334-18a2-4438-9ff3-7e9a3b2a640b
# 18       False  852abfc7-30fa-470e-b498-096835c63e90
# 0         True  5e29ca38-ca1a-4ff6-ac7e-9e2be65a0dfc
# 1        False  e3dd5b4b-e507-47f7-a4e7-b521e1ced93c
# 2        False  520a78d9-40b8-408c-93e0-323b0057d64e
# 3         True  eebfb9ee-4c2e-4241-b83f-d8ab628ffbb2
# 4        False  15f83690-6903-4679-b6f6-4dd666b5dce0
# 5        False  8eb13c63-e36c-4e03-ab86-2eb5e760781d

# %%
# Random Combination of Tags
expected_list_min_expected_tag = 1
expected_list_max_expected_tag = 4
unexpected_list_min_expected_tag = 0
unexpected_list_max_expected_tag = 2
unexpected_list_min_unexpected_tag = 1
unexpected_list_max_unexpected_tag = 2

expected_tag_combination = [ random.sample(list(expected_tags), random.randint(expected_list_min_expected_tag,expected_list_max_expected_tag)) for i in range(num_expected_tag_msg) ]
unexpected_tag_combination = [ random.sample(list(expected_tags), random.randint(unexpected_list_min_expected_tag,unexpected_list_max_expected_tag)) +
                               random.sample(list(unexpected_tags), random.randint(unexpected_list_min_unexpected_tag,unexpected_list_max_unexpected_tag)) for i in range(num_unexpected_tag_msg) ]
tag_combination = expected_tag_combination + unexpected_tag_combination

# %%
# Create Tickets
ticket_prompt_template = """
    You are a IT ticket generation emulator focusing on generating the actual message of users.
    
    Step 1: Generate {num_ticket} tickets, 
        (a) Each `content` should be 20 to 200 words
        (b) Make occasional minor typos in the `content`
        (c) Each ticket `content` should be written based on the topic in the followin table:
        {tag_combination}  

    Step 2: For the `owner_id` (use `id` column in the table), `owner_name` (use `name` column in the table), account_id (`account_id`)
            and allow one user to have multiple tickets:
        {user_table}

    Step 3: Randomly selected a `channel` from ['email','chat','web','sms','social','phone'] for each ticket.
    """

ticket_prompt = PromptTemplate(
    template = ticket_prompt_template,
    input_variables = ["num_ticket","num_expected_tag_msg","num_unexpected_tag_msg","expected_tags","unexpected_tags","ticket_table"],
    ).invoke({"num_ticket": num_ticket,
              "tag_combination": tag_combination, 
              "unexpected_tags": unexpected_tags, 
              "user_table": user_table,
            }).to_messages()

ticket_ls = llm.with_structured_output(TicketSamples).invoke(ticket_prompt).model_dump()['samples']
ticket_table = pd.DataFrame(ticket_ls)
# ticket_table['id'] = msg_table.index
ticket_table['role'] = "user"
ticket_table['status'] = "open"
ticket_table['urgency_score'] = [random.random() for _ in range(num_ticket)]
# ticket_table

# %%
for ticket in ticket_table['content']:
    print(ticket)
# Out:
# Hi there, I was trying to book a reservation for a dinner at your restaurant, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a table for two at 7 PM this Saturday. Thank you!
# Hello, I'm having trouble logging into my account. Every time I enter my credentials, it says 'incorrect password,' even though I'm sure it's correct. I've tried resetting it, but the email link doesn't seem to work. Could you please assist me in resolving this issue? Thank you.
# Hi, I noticed an unexpected charge on my latest bill. I believe there might be a mistake, as I didn't make any additional purchases. Could you please look into this and let me know what happened? If necessary, I would like to escalate this issue to ensure it's resolved promptly. Thank you for your assistance.
# Hello, I need to cancel my reservation for this weekend. Something came up, and I won't be able to make it. Could you please confirm the cancellation and let me know if there's anything else I need to do? Thank you for your understanding.
# Hi, I was supposed to attend a webinar yesterday, but I couldn't find the link to join. I checked my email and spam folder, but there was nothing. Could you please provide me with the recording or let me know when the next session will be? Thank you.
# Hello, I need to pause my subscription for a month due to personal reasons. Could you please guide me on how to do this? Also, I noticed an extra charge on my bill this month. Can you help me understand what it's for? Thank you.
# Hi, I'm having trouble accessing my account. Every time I try to log in, it says my account is locked. I haven't received any emails about this, so I'm not sure what's going on. Could you please help me resolve this issue? Thank you.
# Hello, I need to escalate an issue regarding my account. I've been trying to pause my subscription, but the option isn't available on the website. Could you please assist me with this? Thank you.
# Hi, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.
# Hello, I need help with my account login. Every time I try to log in, it says my password is incorrect. I've tried resetting it, but the link doesn't work. Could you please assist me with this? Thank you.
# Hi, I was trying to book a hotel room for my upcoming trip, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a room for me. Thank you!
# Hello, I have a question about the benefits included in my subscription. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.
# Hi, I was trying to book a flight for my vacation, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the flight. Thank you.
# Hello, I need help with my account login. Every time I try to log in, it says my password is incorrect. I've tried resetting it, but the link doesn't work. Could you please assist me with this? Thank you.
# Hi, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.
# Hello, I need help with my account login. Every time I try to log in, it says my password is incorrect. I've tried resetting it, but the link doesn't work. Could you please assist me with this? Thank you.
# Hi, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.
# Hello, I was trying to book a hotel room for my upcoming trip, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a room for me. Thank you!
# Hi, I need help with my account password. Every time I try to reset it, the link doesn't work. Could you please assist me with this? Thank you.
# Hello, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.
# Hi, I have a question about the pricing of your services. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.
# Hello, I was trying to book a hotel room for my upcoming trip, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a room for me. Thank you!
# Hi, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.
# Hello, I need help with my account password. Every time I try to reset it, the link doesn't work. Could you please assist me with this? Thank you.
# Hi, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.
# Hello, I noticed an unexpected charge on my latest bill. I believe there might be a mistake, as I didn't make any additional purchases. Could you please look into this and let me know what happened? If necessary, I would like to escalate this issue to ensure it's resolved promptly. Thank you for your assistance.
# Hi, I was trying to make a reservation for a dinner at your restaurant, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a table for two at 7 PM this Saturday. Thank you!
# Hello, I have a question about the pricing of your services. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.
# Hi, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.
# Hello, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.
# Hi, I noticed an unexpected charge on my latest bill. I believe there might be a mistake, as I didn't make any additional purchases. Could you please look into this and let me know what happened? If necessary, I would like to escalate this issue to ensure it's resolved promptly. Thank you for your assistance.
# Hello, I need to escalate an issue regarding my account. I've been trying to pause my subscription, but the option isn't available on the website. Could you please assist me with this? Thank you.
# Hi, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.
# Hello, I have a question about the pricing of your services. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.
# Hi, I was trying to book a hotel room for my upcoming trip, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a room for me. Thank you!
# Hello, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.
# Hi, I have a question about the pricing of your services. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.
# Hello, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.
# Hi, I need help with my account password. Every time I try to reset it, the link doesn't work. Could you please assist me with this? Thank you.
# Hello, I was trying to make a reservation for a dinner at your restaurant, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a table for two at 7 PM this Saturday. Thank you!
# Hi, I have a question about the stock price of your company. I noticed some fluctuations recently, and I'm not sure if they're part of the market trend. Could you please clarify this for me? Thank you.
# Hello, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.
# Hi, I have a question about the stock price of your company. I noticed some fluctuations recently, and I'm not sure if they're part of the market trend. Could you please clarify this for me? Thank you.
# Hello, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.
# Hi, I have a question about the stock price of your company. I noticed some fluctuations recently, and I'm not sure if they're part of the market trend. Could you please clarify this for me? Thank you.
# Hello, I was trying to make a reservation for a dinner at your restaurant, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a table for two at 7 PM this Saturday. Thank you!
# Hi, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.
# Hello, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.
# Hi, I have a question about the weather forecast for this weekend. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.
# Hello, I need help with my account password. Every time I try to reset it, the link doesn't work. Could you please assist me with this? Thank you.

# %%
ticket_table
# Out:
#    status                                            content owner_id  \
# 0    open  Hi there, I was trying to book a reservation f...   427e02
# 1    open  Hello, I'm having trouble logging into my acco...   c78831
# 2    open  Hi, I noticed an unexpected charge on my lates...   7bdf7c
# 3    open  Hello, I need to cancel my reservation for thi...   c482cf
# 4    open  Hi, I was supposed to attend a webinar yesterd...   7f693e
# 5    open  Hello, I need to pause my subscription for a m...   8da0ce
# 6    open  Hi, I'm having trouble accessing my account. E...   2a0c63
# 7    open  Hello, I need to escalate an issue regarding m...   e436cb
# 8    open  Hi, I was trying to book tickets for an event,...   5d03df
# 9    open  Hello, I need help with my account login. Ever...   947b40
# 10   open  Hi, I was trying to book a hotel room for my u...   f001f5
# 11   open  Hello, I have a question about the benefits in...   610877
# 12   open  Hi, I was trying to book a flight for my vacat...   a813af
# 13   open  Hello, I need help with my account login. Ever...   3026f6
# 14   open  Hi, I was trying to book tickets for an event,...   5142e4
# 15   open  Hello, I need help with my account login. Ever...   898e18
# 16   open  Hi, I need to cancel my subscription. I've tri...   5de55b
# 17   open  Hello, I was trying to book a hotel room for m...   3783ff
# 18   open  Hi, I need help with my account password. Ever...   2151a1
# 19   open  Hello, I was trying to book tickets for an eve...   a4ab87
# 20   open  Hi, I have a question about the pricing of you...   f556c0
# 21   open  Hello, I was trying to book a hotel room for m...   88382b
# 22   open  Hi, I need to cancel my subscription. I've tri...   888fb2
# 23   open  Hello, I need help with my account password. E...   f1f10d
# 24   open  Hi, I need to cancel my subscription. I've tri...   e6376d
# 25   open  Hello, I noticed an unexpected charge on my la...   427e02
# 26   open  Hi, I was trying to make a reservation for a d...   c78831
# 27   open  Hello, I have a question about the pricing of ...   7bdf7c
# 28   open  Hi, I was trying to book tickets for an event,...   c482cf
# 29   open  Hello, I need to cancel my subscription. I've ...   7f693e
# 30   open  Hi, I noticed an unexpected charge on my lates...   8da0ce
# 31   open  Hello, I need to escalate an issue regarding m...   2a0c63
# 32   open  Hi, I need to cancel my subscription. I've tri...   e436cb
# 33   open  Hello, I have a question about the pricing of ...   5d03df
# 34   open  Hi, I was trying to book a hotel room for my u...   947b40
# 35   open  Hello, I need to cancel my subscription. I've ...   f001f5
# 36   open  Hi, I have a question about the pricing of you...   610877
# 37   open  Hello, I was trying to book tickets for an eve...   a813af
# 38   open  Hi, I need help with my account password. Ever...   3026f6
# 39   open  Hello, I was trying to make a reservation for ...   5142e4
# 40   open  Hi, I have a question about the stock price of...   898e18
# 41   open  Hello, I need to cancel my subscription. I've ...   5de55b
# 42   open  Hi, I have a question about the stock price of...   3783ff
# 43   open  Hello, I was trying to book tickets for an eve...   2151a1
# 44   open  Hi, I have a question about the stock price of...   a4ab87
# 45   open  Hello, I was trying to make a reservation for ...   f556c0
# 46   open  Hi, I need to cancel my subscription. I've tri...   88382b
# 47   open  Hello, I was trying to book tickets for an eve...   888fb2
# 48   open  Hi, I have a question about the weather foreca...   f1f10d
# 49   open  Hello, I need help with my account password. E...   e6376d
#
#          owner_name channel                                              tags  \
# 0     Alice Johnson     web                              booking, reservation
# 1     Michael Smith   email                                             login
# 2        Emma Brown   phone                       billing, escalation, access
# 3        Liam Davis    chat              escalation, cancelation, reservation
# 4     Olivia Wilson  social                                        attendance
# 5     Noah Martinez     sms                                    pause, billing
# 6   Sophia Anderson     web                escalation, login, events, pricing
# 7      James Taylor   email                                 escalation, pause
# 8   Isabella Thomas    chat                               events, reservation
# 9       Ethan White   phone                                             login
# 10       Mia Harris     web              booking, billing, login, reservation
# 11      Lucas Clark   email                                          benefits
# 12     Amelia Lewis    chat                               booking, attendance
# 13  Benjamin Walker   phone                                             login
# 14   Charlotte Hall     web                           events, benefits, pause
# 15      Henry Allen   email                                             login
# 16        Ava Young    chat                             password, cancelation
# 17     William King   phone                     booking, billing, cancelation
# 18     Evelyn Scott     web                                          password
# 19   Alice Kingsley   email             events, booking, password, escalation
# 20        Bob Stone    chat                                   pricing, access
# 21      Cathy Bloom   phone                          pricing, access, booking
# 22       David Noir     web                         subscription, cancelation
# 23        Eva Green   email                            subscription, password
# 24      Frank Ocean    chat                  subscription, login, cancelation
# 25    Alice Johnson   phone                billing, login, escalation, access
# 26    Michael Smith     web                               access, reservation
# 27       Emma Brown   email                  pricing, access, login, benefits
# 28       Liam Davis    chat                         pricing, events, password
# 29    Olivia Wilson   phone               login, pricing, events, cancelation
# 30    Noah Martinez     web                subscription, cancelation, billing
# 31  Sophia Anderson   email                 pause, booking, login, escalation
# 32     James Taylor    chat           escalation, cancelation, billing, pause
# 33  Isabella Thomas   phone                                           pricing
# 34      Ethan White     web                     password, booking, attendance
# 35       Mia Harris   email                         pause, cancelation, login
# 36      Lucas Clark    chat                                   pricing, events
# 37     Amelia Lewis   phone                       events, attendance, pricing
# 38  Benjamin Walker     web                     password, subscription, login
# 39   Charlotte Hall   email                                       reservation
# 40      Henry Allen    chat                                       stock price
# 41        Ava Young   phone                         subscription, stock price
# 42     William King     web                              stock price, dietary
# 43     Evelyn Scott   email                                   events, dietary
# 44   Alice Kingsley    chat                              stock price, weather
# 45        Bob Stone   phone  reservation, pricing, health advice, stock price
# 46      Cathy Bloom     web                 subscription, attendance, dietary
# 47       David Noir   email           events, pricing, dietary, health advice
# 48        Eva Green    chat                            weather, health advice
# 49      Frank Ocean   phone             password, login, weather, stock price
#
#                               account_id  urgency_score  role
# 0   9d2e95e8-9d52-40ab-9983-3273c94d4579       0.755503  user
# 1   be5df8ee-09b2-429e-96f6-23891b32aab8       0.403607  user
# 2   53838228-26c5-43a1-85c1-1884d8631d34       0.491300  user
# 3   e6b9bf00-6f47-4980-9eaa-2016d0932c0a       0.177412  user
# 4   f284499e-eec1-4603-b567-1292769cb381       0.102007  user
# 5   05a7efa6-9f71-4d58-bcca-0e0fa9203449       0.503614  user
# 6   a797750f-fe84-410d-a92a-6ecdbd828328       0.961779  user
# 7   0785aa0f-5957-4166-ac93-ef3d0dfc5713       0.070531  user
# 8   4dc9019a-819d-43a7-b49c-572b7fa57202       0.630096  user
# 9   2164efce-3905-4eb2-9d33-787bbc46cf32       0.833758  user
# 10  2eeefb9a-3443-4432-935f-d74f0a0620de       0.450828  user
# 11  d8dd121f-a950-43c5-a064-0baee58734aa       0.269314  user
# 12  f40010c7-c75e-49bf-94aa-044052588961       0.480030  user
# 13  0d68f151-9424-409c-91de-f99065b15a3e       0.158322  user
# 14  277333e6-658e-4acf-a134-9a9d7bf96c77       0.286957  user
# 15  8820c399-359b-4294-9fe0-16788c75a586       0.699617  user
# 16  b22327a3-3e8a-43a0-a967-da834581daa5       0.888792  user
# 17  53565334-18a2-4438-9ff3-7e9a3b2a640b       0.829065  user
# 18  852abfc7-30fa-470e-b498-096835c63e90       0.589411  user
# 19  5e29ca38-ca1a-4ff6-ac7e-9e2be65a0dfc       0.758643  user
# 20  e3dd5b4b-e507-47f7-a4e7-b521e1ced93c       0.548814  user
# 21  520a78d9-40b8-408c-93e0-323b0057d64e       0.471464  user
# 22  eebfb9ee-4c2e-4241-b83f-d8ab628ffbb2       0.248378  user
# 23  15f83690-6903-4679-b6f6-4dd666b5dce0       0.079201  user
# 24  8eb13c63-e36c-4e03-ab86-2eb5e760781d       0.080662  user
# 25  9d2e95e8-9d52-40ab-9983-3273c94d4579       0.619999  user
# 26  be5df8ee-09b2-429e-96f6-23891b32aab8       0.497226  user
# 27  53838228-26c5-43a1-85c1-1884d8631d34       0.208673  user
# 28  e6b9bf00-6f47-4980-9eaa-2016d0932c0a       0.733377  user
# 29  f284499e-eec1-4603-b567-1292769cb381       0.962131  user
# 30  05a7efa6-9f71-4d58-bcca-0e0fa9203449       0.995997  user
# 31  a797750f-fe84-410d-a92a-6ecdbd828328       0.054919  user
# 32  0785aa0f-5957-4166-ac93-ef3d0dfc5713       0.587230  user
# 33  4dc9019a-819d-43a7-b49c-572b7fa57202       0.379800  user
# 34  2164efce-3905-4eb2-9d33-787bbc46cf32       0.802398  user
# 35  2eeefb9a-3443-4432-935f-d74f0a0620de       0.757992  user
# 36  d8dd121f-a950-43c5-a064-0baee58734aa       0.400146  user
# 37  f40010c7-c75e-49bf-94aa-044052588961       0.462886  user
# 38  0d68f151-9424-409c-91de-f99065b15a3e       0.827570  user
# 39  277333e6-658e-4acf-a134-9a9d7bf96c77       0.753188  user
# 40  8820c399-359b-4294-9fe0-16788c75a586       0.513223  user
# 41  b22327a3-3e8a-43a0-a967-da834581daa5       0.219579  user
# 42  53565334-18a2-4438-9ff3-7e9a3b2a640b       0.157175  user
# 43  852abfc7-30fa-470e-b498-096835c63e90       0.260020  user
# 44  5e29ca38-ca1a-4ff6-ac7e-9e2be65a0dfc       0.263812  user
# 45  e3dd5b4b-e507-47f7-a4e7-b521e1ced93c       0.639011  user
# 46  520a78d9-40b8-408c-93e0-323b0057d64e       0.601147  user
# 47  eebfb9ee-4c2e-4241-b83f-d8ab628ffbb2       0.835181  user
# 48  15f83690-6903-4679-b6f6-4dd666b5dce0       0.903001  user
# 49  8eb13c63-e36c-4e03-ab86-2eb5e760781d       0.842432  user

# %%
len(ticket_table)
# Out:
# 50

# %% [markdown]
# ## Load Samples into Database

# %%
with get_session(engine) as session:
    kb = []
    for article in cultpass_articles:
        knowledge = udahub.Knowledge(
            article_id=str(uuid.uuid4()),
            account_id=account_id,
            title=article["title"],
            content=article["content"],
            tags=article["tags"]
        )
        kb.append(knowledge)
    session.add_all(kb)

# %% [markdown]
# **Ticket**

# %%
user_table.columns
# Out:
# Index(['id', 'name', 'email', 'is_blocked', 'account_id'], dtype='object')

# %%
def add_user(user_info):
    """
    Adding a single user to the database.
    """
    with get_session(engine) as session:
        user = udahub.User(
            user_id=user_info["account_id"],
            account_id=account_id,
            external_user_id=user_info["id"],
            user_name=user_info["name"],
            is_blocked=user_info["is_blocked"],
            email_address=user_info["email"]
            )
        session.add_all([user])

# %%
for index, row in user_table.iterrows():
    add_user(row)

# %%
def add_ticket(ticket_info):
    """
    Adding a single ticket to the database
    """
    with get_session(engine) as session:
        user = session.query(udahub.User).filter_by(
            account_id=account_id,
            external_user_id=ticket_info["owner_id"],
        ).first()

        print(ticket_info)
        print(user)

        if not user:
            user = udahub.User(
                # user_id=str(uuid.uuid4()),
                user_id=ticket_info["account_id"],
                account_id=account_id,
                external_user_id=ticket_info["owner_id"],
                user_name=ticket_info["owner_name"],
                is_blocked=False,     # Data structure in data/models/udahub.py had been modified to include this flag for advanced agent capability
                email_address=None    # Data structure in data/models/udahub.py had been modified to include this flag for advanced agent capability
            )
        
        ticket = udahub.Ticket(
            ticket_id=str(uuid.uuid4()),
            account_id=account_id,
            user_id=user.user_id,
            channel=ticket_info["channel"],
        )
        metadata = udahub.TicketMetadata(
            ticket_id=ticket.ticket_id,
            status=ticket_info["status"],
            main_issue_type=None,
            tags=ticket_info["tags"],
            urgency_score=ticket_info["urgency_score"]
        )

        first_message = udahub.TicketMessage(
            message_id=str(uuid.uuid4()),
            ticket_id=ticket.ticket_id,
            role=ticket_info["role"],
            content=ticket_info["content"],
        )

        # print(user)
        session.add_all([user, ticket, metadata, first_message])

# %%
for index, row in ticket_table.iterrows():
    add_ticket(row)
# Out:
# status                                                        open
# content          Hi there, I was trying to book a reservation f...
# owner_id                                                    427e02
# owner_name                                           Alice Johnson
# channel                                                        web
# tags                                          booking, reservation
# account_id                    9d2e95e8-9d52-40ab-9983-3273c94d4579
# urgency_score                                             0.755503
# role                                                          user
# Name: 0, dtype: object
# <User(user_id='9d2e95e8-9d52-40ab-9983-3273c94d4579', user_name='Alice Johnson', external_user_id='427e02')>
# status                                                        open
# content          Hello, I'm having trouble logging into my acco...
# owner_id                                                    c78831
# owner_name                                           Michael Smith
# channel                                                      email
# tags                                                         login
# account_id                    be5df8ee-09b2-429e-96f6-23891b32aab8
# urgency_score                                             0.403607
# role                                                          user
# Name: 1, dtype: object
# <User(user_id='be5df8ee-09b2-429e-96f6-23891b32aab8', user_name='Michael Smith', external_user_id='c78831')>
# status                                                        open
# content          Hi, I noticed an unexpected charge on my lates...
# owner_id                                                    7bdf7c
# owner_name                                              Emma Brown
# channel                                                      phone
# tags                                   billing, escalation, access
# account_id                    53838228-26c5-43a1-85c1-1884d8631d34
# urgency_score                                               0.4913
# role                                                          user
# Name: 2, dtype: object
# <User(user_id='53838228-26c5-43a1-85c1-1884d8631d34', user_name='Emma Brown', external_user_id='7bdf7c')>
# status                                                        open
# content          Hello, I need to cancel my reservation for thi...
# owner_id                                                    c482cf
# owner_name                                              Liam Davis
# channel                                                       chat
# tags                          escalation, cancelation, reservation
# account_id                    e6b9bf00-6f47-4980-9eaa-2016d0932c0a
# urgency_score                                             0.177412
# role                                                          user
# Name: 3, dtype: object
# <User(user_id='e6b9bf00-6f47-4980-9eaa-2016d0932c0a', user_name='Liam Davis', external_user_id='c482cf')>
# status                                                        open
# content          Hi, I was supposed to attend a webinar yesterd...
# owner_id                                                    7f693e
# owner_name                                           Olivia Wilson
# channel                                                     social
# tags                                                    attendance
# account_id                    f284499e-eec1-4603-b567-1292769cb381
# urgency_score                                             0.102007
# role                                                          user
# Name: 4, dtype: object
# <User(user_id='f284499e-eec1-4603-b567-1292769cb381', user_name='Olivia Wilson', external_user_id='7f693e')>
# status                                                        open
# content          Hello, I need to pause my subscription for a m...
# owner_id                                                    8da0ce
# owner_name                                           Noah Martinez
# channel                                                        sms
# tags                                                pause, billing
# account_id                    05a7efa6-9f71-4d58-bcca-0e0fa9203449
# urgency_score                                             0.503614
# role                                                          user
# Name: 5, dtype: object
# <User(user_id='05a7efa6-9f71-4d58-bcca-0e0fa9203449', user_name='Noah Martinez', external_user_id='8da0ce')>
# status                                                        open
# content          Hi, I'm having trouble accessing my account. E...
# owner_id                                                    2a0c63
# owner_name                                         Sophia Anderson
# channel                                                        web
# tags                            escalation, login, events, pricing
# account_id                    a797750f-fe84-410d-a92a-6ecdbd828328
# urgency_score                                             0.961779
# role                                                          user
# Name: 6, dtype: object
# <User(user_id='a797750f-fe84-410d-a92a-6ecdbd828328', user_name='Sophia Anderson', external_user_id='2a0c63')>
# status                                                        open
# content          Hello, I need to escalate an issue regarding m...
# owner_id                                                    e436cb
# owner_name                                            James Taylor
# channel                                                      email
# tags                                             escalation, pause
# account_id                    0785aa0f-5957-4166-ac93-ef3d0dfc5713
# urgency_score                                             0.070531
# role                                                          user
# Name: 7, dtype: object
# <User(user_id='0785aa0f-5957-4166-ac93-ef3d0dfc5713', user_name='James Taylor', external_user_id='e436cb')>
# status                                                        open
# content          Hi, I was trying to book tickets for an event,...
# owner_id                                                    5d03df
# owner_name                                         Isabella Thomas
# channel                                                       chat
# tags                                           events, reservation
# account_id                    4dc9019a-819d-43a7-b49c-572b7fa57202
# urgency_score                                             0.630096
# role                                                          user
# Name: 8, dtype: object
# <User(user_id='4dc9019a-819d-43d7-b49c-572b7fa57202', user_name='Isabella Thomas', external_user_id='5d03df')>
# status                                                        open
# content          Hello, I need help with my account login. Ever...
# owner_id                                                    947b40
# owner_name                                             Ethan White
# channel                                                      phone
# tags                                                         login
# account_id                    2164efce-3905-4eb2-9d33-787bbc46cf32
# urgency_score                                             0.833758
# role                                                          user
# Name: 9, dtype: object
# <User(user_id='2164efce-3905-4eb2-9d33-787bbc46cf32', user_name='Ethan White', external_user_id='947b40')>
# status                                                        open
# content          Hi, I was trying to book a hotel room for my u...
# owner_id                                                    f001f5
# owner_name                                              Mia Harris
# channel                                                        web
# tags                          booking, billing, login, reservation
# account_id                    2eeefb9a-3443-4432-935f-d74f0a0620de
# urgency_score                                             0.450828
# role                                                          user
# Name: 10, dtype: object
# <User(user_id='2eeefb9a-3443-4432-935f-d74f0a0620de', user_name='Mia Harris', external_user_id='f001f5')>
# status                                                        open
# content          Hello, I have a question about the benefits in...
# owner_id                                                    610877
# owner_name                                             Lucas Clark
# channel                                                      email
# tags                                                      benefits
# account_id                    d8dd121f-a950-43c5-a064-0baee58734aa
# urgency_score                                             0.269314
# role                                                          user
# Name: 11, dtype: object
# <User(user_id='d8dd121f-a950-43c5-a064-0baee58734aa', user_name='Lucas Clark', external_user_id='610877')>
# status                                                        open
# content          Hi, I was trying to book a flight for my vacat...
# owner_id                                                    a813af
# owner_name                                            Amelia Lewis
# channel                                                       chat
# tags                                           booking, attendance
# account_id                    f40010c7-c75e-49bf-94aa-044052588961
# urgency_score                                              0.48003
# role                                                          user
# Name: 12, dtype: object
# <User(user_id='f40010c7-c75e-49bf-94aa-044052588961', user_name='Amelia Lewis', external_user_id='a813af')>
# status                                                        open
# content          Hello, I need help with my account login. Ever...
# owner_id                                                    3026f6
# owner_name                                         Benjamin Walker
# channel                                                      phone
# tags                                                         login
# account_id                    0d68f151-9424-409c-91de-f99065b15a3e
# urgency_score                                             0.158322
# role                                                          user
# Name: 13, dtype: object
# <User(user_id='0d68f151-9424-409c-91de-f99065b15a3e', user_name='Benjamin Walker', external_user_id='3026f6')>
# status                                                        open
# content          Hi, I was trying to book tickets for an event,...
# owner_id                                                    5142e4
# owner_name                                          Charlotte Hall
# channel                                                        web
# tags                                       events, benefits, pause
# account_id                    277333e6-658e-4acf-a134-9a9d7bf96c77
# urgency_score                                             0.286957
# role                                                          user
# Name: 14, dtype: object
# <User(user_id='277333e6-658e-4acf-a134-9a9d7bf96c77', user_name='Charlotte Hall', external_user_id='5142e4')>
# status                                                        open
# content          Hello, I need help with my account login. Ever...
# owner_id                                                    898e18
# owner_name                                             Henry Allen
# channel                                                      email
# tags                                                         login
# account_id                    8820c399-359b-4294-9fe0-16788c75a586
# urgency_score                                             0.699617
# role                                                          user
# Name: 15, dtype: object
# <User(user_id='8820c399-359b-4294-9fe0-16788c75a586', user_name='Henry Allen', external_user_id='898e18')>
# status                                                        open
# content          Hi, I need to cancel my subscription. I've tri...
# owner_id                                                    5de55b
# owner_name                                               Ava Young
# channel                                                       chat
# tags                                         password, cancelation
# account_id                    b22327a3-3e8a-43a0-a967-da834581daa5
# urgency_score                                             0.888792
# role                                                          user
# Name: 16, dtype: object
# <User(user_id='b22327a3-3e8a-43a0-a967-da834581daa5', user_name='Ava Young', external_user_id='5de55b')>
# status                                                        open
# content          Hello, I was trying to book a hotel room for m...
# owner_id                                                    3783ff
# owner_name                                            William King
# channel                                                      phone
# tags                                 booking, billing, cancelation
# account_id                    53565334-18a2-4438-9ff3-7e9a3b2a640b
# urgency_score                                             0.829065
# role                                                          user
# Name: 17, dtype: object
# <User(user_id='53565334-18a2-4438-9ff3-7e9a3b2a640b', user_name='William King', external_user_id='3783ff')>
# status                                                        open
# content          Hi, I need help with my account password. Ever...
# owner_id                                                    2151a1
# owner_name                                            Evelyn Scott
# channel                                                        web
# tags                                                      password
# account_id                    852abfc7-30fa-470e-b498-096835c63e90
# urgency_score                                             0.589411
# role                                                          user
# Name: 18, dtype: object
# <User(user_id='852abfc7-30fa-470e-b498-096835c63e90', user_name='Evelyn Scott', external_user_id='2151a1')>
# status                                                        open
# content          Hello, I was trying to book tickets for an eve...
# owner_id                                                    a4ab87
# owner_name                                          Alice Kingsley
# channel                                                      email
# tags                         events, booking, password, escalation
# account_id                    5e29ca38-ca1a-4ff6-ac7e-9e2be65a0dfc
# urgency_score                                             0.758643
# role                                                          user
# Name: 19, dtype: object
# <User(user_id='5e29ca38-ca1a-4ff6-ac7e-9e2be65a0dfc', user_name='Alice Kingsley', external_user_id='a4ab87')>
# status                                                        open
# content          Hi, I have a question about the pricing of you...
# owner_id                                                    f556c0
# owner_name                                               Bob Stone
# channel                                                       chat
# tags                                               pricing, access
# account_id                    e3dd5b4b-e507-47f7-a4e7-b521e1ced93c
# urgency_score                                             0.548814
# role                                                          user
# Name: 20, dtype: object
# <User(user_id='e3dd5b4b-e507-47f7-a4e7-b521e1ced93c', user_name='Bob Stone', external_user_id='f556c0')>
# status                                                        open
# content          Hello, I was trying to book a hotel room for m...
# owner_id                                                    88382b
# owner_name                                             Cathy Bloom
# channel                                                      phone
# tags                                      pricing, access, booking
# account_id                    520a78d9-40b8-408c-93e0-323b0057d64e
# urgency_score                                             0.471464
# role                                                          user
# Name: 21, dtype: object
# <User(user_id='520a78d9-40b8-408c-93e0-323b0057d64e', user_name='Cathy Bloom', external_user_id='88382b')>
# status                                                        open
# content          Hi, I need to cancel my subscription. I've tri...
# owner_id                                                    888fb2
# owner_name                                              David Noir
# channel                                                        web
# tags                                     subscription, cancelation
# account_id                    eebfb9ee-4c2e-4241-b83f-d8ab628ffbb2
# urgency_score                                             0.248378
# role                                                          user
# Name: 22, dtype: object
# <User(user_id='eebfb9ee-4c2e-4241-b83f-d8ab628ffbb2', user_name='David Noir', external_user_id='888fb2')>
# status                                                        open
# content          Hello, I need help with my account password. E...
# owner_id                                                    f1f10d
# owner_name                                               Eva Green
# channel                                                      email
# tags                                        subscription, password
# account_id                    15f83690-6903-4679-b6f6-4dd666b5dce0
# urgency_score                                             0.079201
# role                                                          user
# Name: 23, dtype: object
# <User(user_id='15f83690-6903-4679-b6f6-4dd666b5dce0', user_name='Eva Green', external_user_id='f1f10d')>
# status                                                        open
# content          Hi, I need to cancel my subscription. I've tri...
# owner_id                                                    e6376d
# owner_name                                             Frank Ocean
# channel                                                       chat
# tags                              subscription, login, cancelation
# account_id                    8eb13c63-e36c-4e03-ab86-2eb5e760781d
# urgency_score                                             0.080662
# role                                                          user
# Name: 24, dtype: object
# <User(user_id='8eb13c63-e36c-4e03-ab86-2eb5e760781d', user_name='Frank Ocean', external_user_id='e6376d')>
# status                                                        open
# content          Hello, I noticed an unexpected charge on my la...
# owner_id                                                    427e02
# owner_name                                           Alice Johnson
# channel                                                      phone
# tags                            billing, login, escalation, access
# account_id                    9d2e95e8-9d52-40ab-9983-3273c94d4579
# urgency_score                                             0.619999
# role                                                          user
# Name: 25, dtype: object
# <User(user_id='9d2e95e8-9d52-40ab-9983-3273c94d4579', user_name='Alice Johnson', external_user_id='427e02')>
# status                                                        open
# content          Hi, I was trying to make a reservation for a d...
# owner_id                                                    c78831
# owner_name                                           Michael Smith
# channel                                                        web
# tags                                           access, reservation
# account_id                    be5df8ee-09b2-429e-96f6-23891b32aab8
# urgency_score                                             0.497226
# role                                                          user
# Name: 26, dtype: object
# <User(user_id='be5df8ee-09b2-429e-96f6-23891b32aab8', user_name='Michael Smith', external_user_id='c78831')>
# status                                                        open
# content          Hello, I have a question about the pricing of ...
# owner_id                                                    7bdf7c
# owner_name                                              Emma Brown
# channel                                                      email
# tags                              pricing, access, login, benefits
# account_id                    53838228-26c5-43a1-85c1-1884d8631d34
# urgency_score                                             0.208673
# role                                                          user
# Name: 27, dtype: object
# <User(user_id='53838228-26c5-43a1-85c1-1884d8631d34', user_name='Emma Brown', external_user_id='7bdf7c')>
# status                                                        open
# content          Hi, I was trying to book tickets for an event,...
# owner_id                                                    c482cf
# owner_name                                              Liam Davis
# channel                                                       chat
# tags                                     pricing, events, password
# account_id                    e6b9bf00-6f47-4980-9eaa-2016d0932c0a
# urgency_score                                             0.733377
# role                                                          user
# Name: 28, dtype: object
# <User(user_id='e6b9bf00-6f47-4980-9eaa-2016d0932c0a', user_name='Liam Davis', external_user_id='c482cf')>
# status                                                        open
# content          Hello, I need to cancel my subscription. I've ...
# owner_id                                                    7f693e
# owner_name                                           Olivia Wilson
# channel                                                      phone
# tags                           login, pricing, events, cancelation
# account_id                    f284499e-eec1-4603-b567-1292769cb381
# urgency_score                                             0.962131
# role                                                          user
# Name: 29, dtype: object
# <User(user_id='f284499e-eec1-4603-b567-1292769cb381', user_name='Olivia Wilson', external_user_id='7f693e')>
# status                                                        open
# content          Hi, I noticed an unexpected charge on my lates...
# owner_id                                                    8da0ce
# owner_name                                           Noah Martinez
# channel                                                        web
# tags                            subscription, cancelation, billing
# account_id                    05a7efa6-9f71-4d58-bcca-0e0fa9203449
# urgency_score                                             0.995997
# role                                                          user
# Name: 30, dtype: object
# <User(user_id='05a7efa6-9f71-4d58-bcca-0e0fa9203449', user_name='Noah Martinez', external_user_id='8da0ce')>
# status                                                        open
# content          Hello, I need to escalate an issue regarding m...
# owner_id                                                    2a0c63
# owner_name                                         Sophia Anderson
# channel                                                      email
# tags                             pause, booking, login, escalation
# account_id                    a797750f-fe84-410d-a92a-6ecdbd828328
# urgency_score                                             0.054919
# role                                                          user
# Name: 31, dtype: object
# <User(user_id='a797750f-fe84-410d-a92a-6ecdbd828328', user_name='Sophia Anderson', external_user_id='2a0c63')>
# status                                                        open
# content          Hi, I need to cancel my subscription. I've tri...
# owner_id                                                    e436cb
# owner_name                                            James Taylor
# channel                                                       chat
# tags                       escalation, cancelation, billing, pause
# account_id                    0785aa0f-5957-4166-ac93-ef3d0dfc5713
# urgency_score                                              0.58723
# role                                                          user
# Name: 32, dtype: object
# <User(user_id='0785aa0f-5957-4166-ac93-ef3d0dfc5713', user_name='James Taylor', external_user_id='e436cb')>
# status                                                        open
# content          Hello, I have a question about the pricing of ...
# owner_id                                                    5d03df
# owner_name                                         Isabella Thomas
# channel                                                      phone
# tags                                                       pricing
# account_id                    4dc9019a-819d-43a7-b49c-572b7fa57202
# urgency_score                                               0.3798
# role                                                          user
# Name: 33, dtype: object
# <User(user_id='4dc9019a-819d-43d7-b49c-572b7fa57202', user_name='Isabella Thomas', external_user_id='5d03df')>
# status                                                        open
# content          Hi, I was trying to book a hotel room for my u...
# owner_id                                                    947b40
# owner_name                                             Ethan White
# channel                                                        web
# tags                                 password, booking, attendance
# account_id                    2164efce-3905-4eb2-9d33-787bbc46cf32
# urgency_score                                             0.802398
# role                                                          user
# Name: 34, dtype: object
# <User(user_id='2164efce-3905-4eb2-9d33-787bbc46cf32', user_name='Ethan White', external_user_id='947b40')>
# status                                                        open
# content          Hello, I need to cancel my subscription. I've ...
# owner_id                                                    f001f5
# owner_name                                              Mia Harris
# channel                                                      email
# tags                                     pause, cancelation, login
# account_id                    2eeefb9a-3443-4432-935f-d74f0a0620de
# urgency_score                                             0.757992
# role                                                          user
# Name: 35, dtype: object
# <User(user_id='2eeefb9a-3443-4432-935f-d74f0a0620de', user_name='Mia Harris', external_user_id='f001f5')>
# status                                                        open
# content          Hi, I have a question about the pricing of you...
# owner_id                                                    610877
# owner_name                                             Lucas Clark
# channel                                                       chat
# tags                                               pricing, events
# account_id                    d8dd121f-a950-43c5-a064-0baee58734aa
# urgency_score                                             0.400146
# role                                                          user
# Name: 36, dtype: object
# <User(user_id='d8dd121f-a950-43c5-a064-0baee58734aa', user_name='Lucas Clark', external_user_id='610877')>
# status                                                        open
# content          Hello, I was trying to book tickets for an eve...
# owner_id                                                    a813af
# owner_name                                            Amelia Lewis
# channel                                                      phone
# tags                                   events, attendance, pricing
# account_id                    f40010c7-c75e-49bf-94aa-044052588961
# urgency_score                                             0.462886
# role                                                          user
# Name: 37, dtype: object
# <User(user_id='f40010c7-c75e-49bf-94aa-044052588961', user_name='Amelia Lewis', external_user_id='a813af')>
# status                                                        open
# content          Hi, I need help with my account password. Ever...
# owner_id                                                    3026f6
# owner_name                                         Benjamin Walker
# channel                                                        web
# tags                                 password, subscription, login
# account_id                    0d68f151-9424-409c-91de-f99065b15a3e
# urgency_score                                              0.82757
# role                                                          user
# Name: 38, dtype: object
# <User(user_id='0d68f151-9424-409c-91de-f99065b15a3e', user_name='Benjamin Walker', external_user_id='3026f6')>
# status                                                        open
# content          Hello, I was trying to make a reservation for ...
# owner_id                                                    5142e4
# owner_name                                          Charlotte Hall
# channel                                                      email
# tags                                                   reservation
# account_id                    277333e6-658e-4acf-a134-9a9d7bf96c77
# urgency_score                                             0.753188
# role                                                          user
# Name: 39, dtype: object
# <User(user_id='277333e6-658e-4acf-a134-9a9d7bf96c77', user_name='Charlotte Hall', external_user_id='5142e4')>
# status                                                        open
# content          Hi, I have a question about the stock price of...
# owner_id                                                    898e18
# owner_name                                             Henry Allen
# channel                                                       chat
# tags                                                   stock price
# account_id                    8820c399-359b-4294-9fe0-16788c75a586
# urgency_score                                             0.513223
# role                                                          user
# Name: 40, dtype: object
# <User(user_id='8820c399-359b-4294-9fe0-16788c75a586', user_name='Henry Allen', external_user_id='898e18')>
# status                                                        open
# content          Hello, I need to cancel my subscription. I've ...
# owner_id                                                    5de55b
# owner_name                                               Ava Young
# channel                                                      phone
# tags                                     subscription, stock price
# account_id                    b22327a3-3e8a-43a0-a967-da834581daa5
# urgency_score                                             0.219579
# role                                                          user
# Name: 41, dtype: object
# <User(user_id='b22327a3-3e8a-43a0-a967-da834581daa5', user_name='Ava Young', external_user_id='5de55b')>
# status                                                        open
# content          Hi, I have a question about the stock price of...
# owner_id                                                    3783ff
# owner_name                                            William King
# channel                                                        web
# tags                                          stock price, dietary
# account_id                    53565334-18a2-4438-9ff3-7e9a3b2a640b
# urgency_score                                             0.157175
# role                                                          user
# Name: 42, dtype: object
# <User(user_id='53565334-18a2-4438-9ff3-7e9a3b2a640b', user_name='William King', external_user_id='3783ff')>
# status                                                        open
# content          Hello, I was trying to book tickets for an eve...
# owner_id                                                    2151a1
# owner_name                                            Evelyn Scott
# channel                                                      email
# tags                                               events, dietary
# account_id                    852abfc7-30fa-470e-b498-096835c63e90
# urgency_score                                              0.26002
# role                                                          user
# Name: 43, dtype: object
# <User(user_id='852abfc7-30fa-470e-b498-096835c63e90', user_name='Evelyn Scott', external_user_id='2151a1')>
# status                                                        open
# content          Hi, I have a question about the stock price of...
# owner_id                                                    a4ab87
# owner_name                                          Alice Kingsley
# channel                                                       chat
# tags                                          stock price, weather
# account_id                    5e29ca38-ca1a-4ff6-ac7e-9e2be65a0dfc
# urgency_score                                             0.263812
# role                                                          user
# Name: 44, dtype: object
# <User(user_id='5e29ca38-ca1a-4ff6-ac7e-9e2be65a0dfc', user_name='Alice Kingsley', external_user_id='a4ab87')>
# status                                                        open
# content          Hello, I was trying to make a reservation for ...
# owner_id                                                    f556c0
# owner_name                                               Bob Stone
# channel                                                      phone
# tags              reservation, pricing, health advice, stock price
# account_id                    e3dd5b4b-e507-47f7-a4e7-b521e1ced93c
# urgency_score                                             0.639011
# role                                                          user
# Name: 45, dtype: object
# <User(user_id='e3dd5b4b-e507-47f7-a4e7-b521e1ced93c', user_name='Bob Stone', external_user_id='f556c0')>
# status                                                        open
# content          Hi, I need to cancel my subscription. I've tri...
# owner_id                                                    88382b
# owner_name                                             Cathy Bloom
# channel                                                        web
# tags                             subscription, attendance, dietary
# account_id                    520a78d9-40b8-408c-93e0-323b0057d64e
# urgency_score                                             0.601147
# role                                                          user
# Name: 46, dtype: object
# <User(user_id='520a78d9-40b8-408c-93e0-323b0057d64e', user_name='Cathy Bloom', external_user_id='88382b')>
# status                                                        open
# content          Hello, I was trying to book tickets for an eve...
# owner_id                                                    888fb2
# owner_name                                              David Noir
# channel                                                      email
# tags                       events, pricing, dietary, health advice
# account_id                    eebfb9ee-4c2e-4241-b83f-d8ab628ffbb2
# urgency_score                                             0.835181
# role                                                          user
# Name: 47, dtype: object
# <User(user_id='eebfb9ee-4c2e-4241-b83f-d8ab628ffbb2', user_name='David Noir', external_user_id='888fb2')>
# status                                                        open
# content          Hi, I have a question about the weather foreca...
# owner_id                                                    f1f10d
# owner_name                                               Eva Green
# channel                                                       chat
# tags                                        weather, health advice
# account_id                    15f83690-6903-4679-b6f6-4dd666b5dce0
# urgency_score                                             0.903001
# role                                                          user
# Name: 48, dtype: object
# <User(user_id='15f83690-6903-4679-b6f6-4dd666b5dce0', user_name='Eva Green', external_user_id='f1f10d')>
# status                                                        open
# content          Hello, I need help with my account password. E...
# owner_id                                                    e6376d
# owner_name                                             Frank Ocean
# channel                                                      phone
# tags                         password, login, weather, stock price
# account_id                    8eb13c63-e36c-4e03-ab86-2eb5e760781d
# urgency_score                                             0.842432
# role                                                          user
# Name: 49, dtype: object
# <User(user_id='8eb13c63-e36c-4e03-ab86-2eb5e760781d', user_name='Frank Ocean', external_user_id='e6376d')>

# %% [markdown]
# # Tests

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    print(account)
# Out:
# <Account(account_id='cultpass', account_name='CultPass Card')>

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    for article in account.knowledge_articles:
        print(article)
# Out:
# <Knowledge(article_id='4deda255-6435-44e6-9cd5-6f9bafe96145', title='How to Reserve a Spot for an Event')>
# <Knowledge(article_id='0b9b9f1a-6a22-42c0-9ba4-a72446313982', title='What's Included in a CultPass Subscription')>
# <Knowledge(article_id='ceadf686-586d-43ca-b644-6234a828053c', title='How to Cancel or Pause a Subscription')>
# <Knowledge(article_id='6f1781ac-c4b1-482d-88c4-51812c1e056a', title='How to Handle Login Issues?')>

# %%
with get_session(engine) as session:
    users = session.query(udahub.User).all()
    for user in users:
        # Get all column names for this model
        inst = inspect(user)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(user, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'user_id': '9d2e95e8-9d52-40ab-9983-3273c94d4579', 'account_id': 'cultpass', 'external_user_id': '427e02', 'user_name': 'Alice Johnson', 'is_blocked': False, 'email_address': 'alice.johnson@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': 'be5df8ee-09b2-429e-96f6-23891b32aab8', 'account_id': 'cultpass', 'external_user_id': 'c78831', 'user_name': 'Michael Smith', 'is_blocked': True, 'email_address': 'michael.smith@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '53838228-26c5-43a1-85c1-1884d8631d34', 'account_id': 'cultpass', 'external_user_id': '7bdf7c', 'user_name': 'Emma Brown', 'is_blocked': False, 'email_address': 'emma.brown@ecospherenterprises.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': 'e6b9bf00-6f47-4980-9eaa-2016d0932c0a', 'account_id': 'cultpass', 'external_user_id': 'c482cf', 'user_name': 'Liam Davis', 'is_blocked': True, 'email_address': 'liam.davis@quantumleapdynamics.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': 'f284499e-eec1-4603-b567-1292769cb381', 'account_id': 'cultpass', 'external_user_id': '7f693e', 'user_name': 'Olivia Wilson', 'is_blocked': False, 'email_address': 'olivia.wilson@greenwavetechnologies.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '05a7efa6-9f71-4d58-bcca-0e0fa9203449', 'account_id': 'cultpass', 'external_user_id': '8da0ce', 'user_name': 'Noah Martinez', 'is_blocked': True, 'email_address': 'noah.martinez@skylineventures.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': 'a797750f-fe84-410d-a92a-6ecdbd828328', 'account_id': 'cultpass', 'external_user_id': '2a0c63', 'user_name': 'Sophia Anderson', 'is_blocked': False, 'email_address': 'sophia.anderson@apexinnovations.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '0785aa0f-5957-4166-ac93-ef3d0dfc5713', 'account_id': 'cultpass', 'external_user_id': 'e436cb', 'user_name': 'James Taylor', 'is_blocked': True, 'email_address': 'james.taylor@bluehorizonindustries.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '4dc9019a-819d-43d7-b49c-572b7fa57202', 'account_id': 'cultpass', 'external_user_id': '5d03df', 'user_name': 'Isabella Thomas', 'is_blocked': False, 'email_address': 'isabella.thomas@pinnaclepathways.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '2164efce-3905-4eb2-9d33-787bbc46cf32', 'account_id': 'cultpass', 'external_user_id': '947b40', 'user_name': 'Ethan White', 'is_blocked': True, 'email_address': 'ethan.white@synergysystemsgroup.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '2eeefb9a-3443-4432-935f-d74f0a0620de', 'account_id': 'cultpass', 'external_user_id': 'f001f5', 'user_name': 'Mia Harris', 'is_blocked': False, 'email_address': 'mia.harris@vanguardvisionaries.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': 'd8dd121f-a950-43c5-a064-0baee58734aa', 'account_id': 'cultpass', 'external_user_id': '610877', 'user_name': 'Lucas Clark', 'is_blocked': True, 'email_address': 'lucas.clark@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': 'f40010c7-c75e-49bf-94aa-044052588961', 'account_id': 'cultpass', 'external_user_id': 'a813af', 'user_name': 'Amelia Lewis', 'is_blocked': False, 'email_address': 'amelia.lewis@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '0d68f151-9424-409c-91de-f99065b15a3e', 'account_id': 'cultpass', 'external_user_id': '3026f6', 'user_name': 'Benjamin Walker', 'is_blocked': True, 'email_address': 'benjamin.walker@ecospherenterprises.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '277333e6-658e-4acf-a134-9a9d7bf96c77', 'account_id': 'cultpass', 'external_user_id': '5142e4', 'user_name': 'Charlotte Hall', 'is_blocked': False, 'email_address': 'charlotte.hall@quantumleapdynamics.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '8820c399-359b-4294-9fe0-16788c75a586', 'account_id': 'cultpass', 'external_user_id': '898e18', 'user_name': 'Henry Allen', 'is_blocked': True, 'email_address': 'henry.allen@greenwavetechnologies.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': 'b22327a3-3e8a-43a0-a967-da834581daa5', 'account_id': 'cultpass', 'external_user_id': '5de55b', 'user_name': 'Ava Young', 'is_blocked': False, 'email_address': 'ava.young@skylineventures.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '53565334-18a2-4438-9ff3-7e9a3b2a640b', 'account_id': 'cultpass', 'external_user_id': '3783ff', 'user_name': 'William King', 'is_blocked': True, 'email_address': 'william.king@apexinnovations.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '852abfc7-30fa-470e-b498-096835c63e90', 'account_id': 'cultpass', 'external_user_id': '2151a1', 'user_name': 'Evelyn Scott', 'is_blocked': False, 'email_address': 'evelyn.scott@bluehorizonindustries.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '5e29ca38-ca1a-4ff6-ac7e-9e2be65a0dfc', 'account_id': 'cultpass', 'external_user_id': 'a4ab87', 'user_name': 'Alice Kingsley', 'is_blocked': True, 'email_address': 'alice.kingsley@wonderland.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': 'e3dd5b4b-e507-47f7-a4e7-b521e1ced93c', 'account_id': 'cultpass', 'external_user_id': 'f556c0', 'user_name': 'Bob Stone', 'is_blocked': False, 'email_address': 'bob.stone@granite.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '520a78d9-40b8-408c-93e0-323b0057d64e', 'account_id': 'cultpass', 'external_user_id': '88382b', 'user_name': 'Cathy Bloom', 'is_blocked': False, 'email_address': 'cathy.bloom@florals.org', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': 'eebfb9ee-4c2e-4241-b83f-d8ab628ffbb2', 'account_id': 'cultpass', 'external_user_id': '888fb2', 'user_name': 'David Noir', 'is_blocked': True, 'email_address': 'david.noir@shadowmail.com', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '15f83690-6903-4679-b6f6-4dd666b5dce0', 'account_id': 'cultpass', 'external_user_id': 'f1f10d', 'user_name': 'Eva Green', 'is_blocked': False, 'email_address': 'eva.green@ecosoul.net', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'user_id': '8eb13c63-e36c-4e03-ab86-2eb5e760781d', 'account_id': 'cultpass', 'external_user_id': 'e6376d', 'user_name': 'Frank Ocean', 'is_blocked': False, 'email_address': 'frank.ocean@seawaves.io', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}

# %%
with get_session(engine) as session:
    tickets = session.query(udahub.Ticket).all()
    for ticket in tickets:
        # Get all column names for this model
        inst = inspect(ticket)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(ticket, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'ticket_id': '04988314-c6ec-41f3-b769-c070be049937', 'account_id': 'cultpass', 'user_id': '9d2e95e8-9d52-40ab-9983-3273c94d4579', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '191d8eec-a361-491e-b41c-d24af47067ce', 'account_id': 'cultpass', 'user_id': 'be5df8ee-09b2-429e-96f6-23891b32aab8', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'e02ed328-252f-4eaa-840c-0d1ce06518a2', 'account_id': 'cultpass', 'user_id': '53838228-26c5-43a1-85c1-1884d8631d34', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'd51540c9-be08-412b-9400-9ed93e1f3e04', 'account_id': 'cultpass', 'user_id': 'e6b9bf00-6f47-4980-9eaa-2016d0932c0a', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '2eac2f82-5c95-4378-a332-6991f25cc453', 'account_id': 'cultpass', 'user_id': 'f284499e-eec1-4603-b567-1292769cb381', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '4223581b-0ec2-4c77-873b-c396d4276bd9', 'account_id': 'cultpass', 'user_id': '05a7efa6-9f71-4d58-bcca-0e0fa9203449', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'fb135539-9fb8-4931-8030-b95aeb505394', 'account_id': 'cultpass', 'user_id': 'a797750f-fe84-410d-a92a-6ecdbd828328', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '7ddea533-a645-4bed-ab7e-c4f5bb446963', 'account_id': 'cultpass', 'user_id': '0785aa0f-5957-4166-ac93-ef3d0dfc5713', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'b8cb1740-fdc5-4d07-ba23-08ca7e35f3a6', 'account_id': 'cultpass', 'user_id': '4dc9019a-819d-43d7-b49c-572b7fa57202', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'cb2e7547-d2f6-40e3-8101-3fbd96f51b91', 'account_id': 'cultpass', 'user_id': '2164efce-3905-4eb2-9d33-787bbc46cf32', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'c98ba2d6-3ad4-4ad8-95c1-f8d7e8357d8c', 'account_id': 'cultpass', 'user_id': '2eeefb9a-3443-4432-935f-d74f0a0620de', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '81bbc7d5-abae-45b2-b835-6eb624e6d7a4', 'account_id': 'cultpass', 'user_id': 'd8dd121f-a950-43c5-a064-0baee58734aa', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '606ed5f8-5fe6-4a8d-96a2-248150ba1ac9', 'account_id': 'cultpass', 'user_id': 'f40010c7-c75e-49bf-94aa-044052588961', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '25b6ab7f-a492-413c-ab8e-fad55acfda31', 'account_id': 'cultpass', 'user_id': '0d68f151-9424-409c-91de-f99065b15a3e', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '5b700426-908f-4d03-a950-49a5a21f93bd', 'account_id': 'cultpass', 'user_id': '277333e6-658e-4acf-a134-9a9d7bf96c77', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'b5c0ec08-69b4-4d85-9b3a-be926851ca9e', 'account_id': 'cultpass', 'user_id': '8820c399-359b-4294-9fe0-16788c75a586', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'ac608554-4f0a-4db6-9e0f-c2008f431c50', 'account_id': 'cultpass', 'user_id': 'b22327a3-3e8a-43a0-a967-da834581daa5', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '5a67160d-ad9d-47c8-9e9e-7e9a1c6092ad', 'account_id': 'cultpass', 'user_id': '53565334-18a2-4438-9ff3-7e9a3b2a640b', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '443adaa5-99f7-47ad-b156-d2897ad96c8a', 'account_id': 'cultpass', 'user_id': '852abfc7-30fa-470e-b498-096835c63e90', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'd209dd85-3582-4a91-b3b2-3e6a598042f2', 'account_id': 'cultpass', 'user_id': '5e29ca38-ca1a-4ff6-ac7e-9e2be65a0dfc', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '4e986961-57b0-40ee-8d5b-91b357c853aa', 'account_id': 'cultpass', 'user_id': 'e3dd5b4b-e507-47f7-a4e7-b521e1ced93c', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '8b48fca1-9981-49fe-a5c5-1f2711832071', 'account_id': 'cultpass', 'user_id': '520a78d9-40b8-408c-93e0-323b0057d64e', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '4968f4ad-7cef-4c7e-ba53-ba9332fa6822', 'account_id': 'cultpass', 'user_id': 'eebfb9ee-4c2e-4241-b83f-d8ab628ffbb2', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '3045295f-f870-46b1-bddf-904f5f609d03', 'account_id': 'cultpass', 'user_id': '15f83690-6903-4679-b6f6-4dd666b5dce0', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '5b97fd76-fc2c-46cf-b5fe-1c15a00aba7e', 'account_id': 'cultpass', 'user_id': '8eb13c63-e36c-4e03-ab86-2eb5e760781d', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '2cb3eea6-56f5-4765-8370-fd9c003f398a', 'account_id': 'cultpass', 'user_id': '9d2e95e8-9d52-40ab-9983-3273c94d4579', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '6732f43a-240c-4f90-abd7-d5f1ff619c79', 'account_id': 'cultpass', 'user_id': 'be5df8ee-09b2-429e-96f6-23891b32aab8', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '750be6ed-61cf-4300-95b5-05d463cc4d2c', 'account_id': 'cultpass', 'user_id': '53838228-26c5-43a1-85c1-1884d8631d34', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '9bac57a2-ddbb-477f-b851-2f1c194ab0f7', 'account_id': 'cultpass', 'user_id': 'e6b9bf00-6f47-4980-9eaa-2016d0932c0a', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '1480424b-55eb-4cbf-aef8-061b062be369', 'account_id': 'cultpass', 'user_id': 'f284499e-eec1-4603-b567-1292769cb381', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'f7486ad4-54cb-4a58-b71f-cbdfde43cf60', 'account_id': 'cultpass', 'user_id': '05a7efa6-9f71-4d58-bcca-0e0fa9203449', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '4baea0f6-b493-410f-a710-93535cf2ed83', 'account_id': 'cultpass', 'user_id': 'a797750f-fe84-410d-a92a-6ecdbd828328', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '8260553e-6777-4142-a161-6c3c2ef6e2cd', 'account_id': 'cultpass', 'user_id': '0785aa0f-5957-4166-ac93-ef3d0dfc5713', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '6b17ae4a-7146-434d-b8ea-cc43aa1531fe', 'account_id': 'cultpass', 'user_id': '4dc9019a-819d-43d7-b49c-572b7fa57202', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '214e6f30-a4f5-400c-93a4-3a680e9563f6', 'account_id': 'cultpass', 'user_id': '2164efce-3905-4eb2-9d33-787bbc46cf32', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '51b3e999-360d-44d4-bf89-1f27b248aa03', 'account_id': 'cultpass', 'user_id': '2eeefb9a-3443-4432-935f-d74f0a0620de', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '044f0d4b-f885-4734-a9d3-b939e1eb8c98', 'account_id': 'cultpass', 'user_id': 'd8dd121f-a950-43c5-a064-0baee58734aa', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'a1581f17-4722-469a-8d9c-c1783e310e86', 'account_id': 'cultpass', 'user_id': 'f40010c7-c75e-49bf-94aa-044052588961', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '8c732cf6-52ba-41d7-91f4-80cb4031c78a', 'account_id': 'cultpass', 'user_id': '0d68f151-9424-409c-91de-f99065b15a3e', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'da974b97-ffad-46fe-99c6-8752ea2bf497', 'account_id': 'cultpass', 'user_id': '277333e6-658e-4acf-a134-9a9d7bf96c77', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '502ef53d-ed37-40fe-a469-9e78397a8318', 'account_id': 'cultpass', 'user_id': '8820c399-359b-4294-9fe0-16788c75a586', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'b7c94198-ec35-4b96-88ac-e64d1d364b0a', 'account_id': 'cultpass', 'user_id': 'b22327a3-3e8a-43a0-a967-da834581daa5', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'd8e78d4f-31d9-4bc1-afa2-c92c928d57f4', 'account_id': 'cultpass', 'user_id': '53565334-18a2-4438-9ff3-7e9a3b2a640b', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'bb2ca7e2-9068-4429-9447-9d2c966295f3', 'account_id': 'cultpass', 'user_id': '852abfc7-30fa-470e-b498-096835c63e90', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'e07690e9-b672-4afe-83d5-894e64459bdc', 'account_id': 'cultpass', 'user_id': '5e29ca38-ca1a-4ff6-ac7e-9e2be65a0dfc', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '5ff728d9-668b-4600-b976-7c3eb5fe7db7', 'account_id': 'cultpass', 'user_id': 'e3dd5b4b-e507-47f7-a4e7-b521e1ced93c', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '1b44ed80-aa05-4e3e-8a00-d16ccaa67c1b', 'account_id': 'cultpass', 'user_id': '520a78d9-40b8-408c-93e0-323b0057d64e', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '1523ecab-f2fa-46ce-85d4-458a2d1e7059', 'account_id': 'cultpass', 'user_id': 'eebfb9ee-4c2e-4241-b83f-d8ab628ffbb2', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '052f4dbb-2ae2-4208-9dc7-12bd39ad5a34', 'account_id': 'cultpass', 'user_id': '15f83690-6903-4679-b6f6-4dd666b5dce0', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'e7f71fe3-cf4e-4455-b034-15f5e531dd63', 'account_id': 'cultpass', 'user_id': '8eb13c63-e36c-4e03-ab86-2eb5e760781d', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}

# %%
with get_session(engine) as session:
    messages = session.query(udahub.TicketMessage).all()
    for message in messages:
        # Get all column names for this model
        inst = inspect(message)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(message, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'message_id': 'e8127004-81fc-4734-be0a-a59afea3a4eb', 'ticket_id': '04988314-c6ec-41f3-b769-c070be049937', 'role': <RoleEnum.user: 'user'>, 'content': "Hi there, I was trying to book a reservation for a dinner at your restaurant, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a table for two at 7 PM this Saturday. Thank you!", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '43b01b23-dbcb-4950-bf57-f3b2cd6d1bf0', 'ticket_id': '191d8eec-a361-491e-b41c-d24af47067ce', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble logging into my account. Every time I enter my credentials, it says 'incorrect password,' even though I'm sure it's correct. I've tried resetting it, but the email link doesn't seem to work. Could you please assist me in resolving this issue? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'e5ad615c-a8dc-44db-a84b-1828b3f23d48', 'ticket_id': 'e02ed328-252f-4eaa-840c-0d1ce06518a2', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I noticed an unexpected charge on my latest bill. I believe there might be a mistake, as I didn't make any additional purchases. Could you please look into this and let me know what happened? If necessary, I would like to escalate this issue to ensure it's resolved promptly. Thank you for your assistance.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '060adcfb-e8cc-4c2a-9115-6ec3a27d7af5', 'ticket_id': 'd51540c9-be08-412b-9400-9ed93e1f3e04', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to cancel my reservation for this weekend. Something came up, and I won't be able to make it. Could you please confirm the cancellation and let me know if there's anything else I need to do? Thank you for your understanding.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'fdd3c055-2ecb-4054-a667-4eb03a390f98', 'ticket_id': '2eac2f82-5c95-4378-a332-6991f25cc453', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I was supposed to attend a webinar yesterday, but I couldn't find the link to join. I checked my email and spam folder, but there was nothing. Could you please provide me with the recording or let me know when the next session will be? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '599e1e63-a14c-417d-b742-4aa4504668a8', 'ticket_id': '4223581b-0ec2-4c77-873b-c396d4276bd9', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to pause my subscription for a month due to personal reasons. Could you please guide me on how to do this? Also, I noticed an extra charge on my bill this month. Can you help me understand what it's for? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'e08fc301-8767-416c-aee8-d61ef7d8abab', 'ticket_id': 'fb135539-9fb8-4931-8030-b95aeb505394', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm having trouble accessing my account. Every time I try to log in, it says my account is locked. I haven't received any emails about this, so I'm not sure what's going on. Could you please help me resolve this issue? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '6398271a-2c74-465e-acf8-f903691e7492', 'ticket_id': '7ddea533-a645-4bed-ab7e-c4f5bb446963', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to escalate an issue regarding my account. I've been trying to pause my subscription, but the option isn't available on the website. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'f557346a-a379-44aa-b5a0-a49a06c59981', 'ticket_id': 'b8cb1740-fdc5-4d07-ba23-08ca7e35f3a6', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'cb91d11b-6bc0-4fc1-bdc3-fecc18eaba25', 'ticket_id': 'cb2e7547-d2f6-40e3-8101-3fbd96f51b91', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need help with my account login. Every time I try to log in, it says my password is incorrect. I've tried resetting it, but the link doesn't work. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '2035e2fc-06ca-4b14-b093-41eae8a20a5b', 'ticket_id': 'c98ba2d6-3ad4-4ad8-95c1-f8d7e8357d8c', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I was trying to book a hotel room for my upcoming trip, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a room for me. Thank you!", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'd300963c-648c-434d-858a-ca74cd30746a', 'ticket_id': '81bbc7d5-abae-45b2-b835-6eb624e6d7a4', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I have a question about the benefits included in my subscription. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '70d73973-2b57-4964-acd7-625237a0aa0f', 'ticket_id': '606ed5f8-5fe6-4a8d-96a2-248150ba1ac9', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I was trying to book a flight for my vacation, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the flight. Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '43c8c084-ee98-4d05-b3a2-37031134aa6e', 'ticket_id': '25b6ab7f-a492-413c-ab8e-fad55acfda31', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need help with my account login. Every time I try to log in, it says my password is incorrect. I've tried resetting it, but the link doesn't work. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'a44987f3-7254-48e6-8fa4-f3e058ab857d', 'ticket_id': '5b700426-908f-4d03-a950-49a5a21f93bd', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'e85e1c09-b039-4a95-b17b-a0a658619949', 'ticket_id': 'b5c0ec08-69b4-4d85-9b3a-be926851ca9e', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need help with my account login. Every time I try to log in, it says my password is incorrect. I've tried resetting it, but the link doesn't work. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'b05c3b9a-5257-4719-a8d6-08428d78de69', 'ticket_id': 'ac608554-4f0a-4db6-9e0f-c2008f431c50', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '88cbe10b-f53d-4489-a77e-2e726168eb20', 'ticket_id': '5a67160d-ad9d-47c8-9e9e-7e9a1c6092ad', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I was trying to book a hotel room for my upcoming trip, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a room for me. Thank you!", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '850e72f9-d3d9-456a-b503-2951128071ca', 'ticket_id': '443adaa5-99f7-47ad-b156-d2897ad96c8a', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I need help with my account password. Every time I try to reset it, the link doesn't work. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'bfaba3db-d10f-4be5-bfd7-2ed6f382ffa3', 'ticket_id': 'd209dd85-3582-4a91-b3b2-3e6a598042f2', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '510399ae-f24f-4d1d-96c6-6a0b2da8c2d6', 'ticket_id': '4e986961-57b0-40ee-8d5b-91b357c853aa', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I have a question about the pricing of your services. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '6b62633c-de16-4083-8f09-3731747614a3', 'ticket_id': '8b48fca1-9981-49fe-a5c5-1f2711832071', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I was trying to book a hotel room for my upcoming trip, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a room for me. Thank you!", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'ea2aa0ed-16f9-4cff-93ac-fef609623b9c', 'ticket_id': '4968f4ad-7cef-4c7e-ba53-ba9332fa6822', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '51c0e066-0978-434b-aff0-4deb4151d157', 'ticket_id': '3045295f-f870-46b1-bddf-904f5f609d03', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need help with my account password. Every time I try to reset it, the link doesn't work. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'c8b6ecb4-b314-41ea-92a7-b4290d0a4dbe', 'ticket_id': '5b97fd76-fc2c-46cf-b5fe-1c15a00aba7e', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '41853d4b-e50e-443c-86d6-9724984c284d', 'ticket_id': '2cb3eea6-56f5-4765-8370-fd9c003f398a', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I noticed an unexpected charge on my latest bill. I believe there might be a mistake, as I didn't make any additional purchases. Could you please look into this and let me know what happened? If necessary, I would like to escalate this issue to ensure it's resolved promptly. Thank you for your assistance.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '8d561e66-4b5f-45ca-ad77-2dcfbc9de177', 'ticket_id': '6732f43a-240c-4f90-abd7-d5f1ff619c79', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I was trying to make a reservation for a dinner at your restaurant, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a table for two at 7 PM this Saturday. Thank you!", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'c458ba41-a449-4c3d-a200-98be50faa2c9', 'ticket_id': '750be6ed-61cf-4300-95b5-05d463cc4d2c', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I have a question about the pricing of your services. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'cc4efa10-051f-4e0d-874c-d2944d8faf00', 'ticket_id': '9bac57a2-ddbb-477f-b851-2f1c194ab0f7', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '87b3dcd8-eb7e-4711-bc53-95e871e34ea1', 'ticket_id': '1480424b-55eb-4cbf-aef8-061b062be369', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '51910876-36a3-4ba6-a114-a67db8f01f7d', 'ticket_id': 'f7486ad4-54cb-4a58-b71f-cbdfde43cf60', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I noticed an unexpected charge on my latest bill. I believe there might be a mistake, as I didn't make any additional purchases. Could you please look into this and let me know what happened? If necessary, I would like to escalate this issue to ensure it's resolved promptly. Thank you for your assistance.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '52d2e595-7654-43e4-87de-3097868f099a', 'ticket_id': '4baea0f6-b493-410f-a710-93535cf2ed83', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to escalate an issue regarding my account. I've been trying to pause my subscription, but the option isn't available on the website. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '0a37b1e4-5ed7-49da-b3e8-5cdf123a4813', 'ticket_id': '8260553e-6777-4142-a161-6c3c2ef6e2cd', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '62c2a59d-ca87-404b-8f2f-a92f7c47be1d', 'ticket_id': '6b17ae4a-7146-434d-b8ea-cc43aa1531fe', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I have a question about the pricing of your services. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '8af7e42c-f075-47dc-b558-7b24e2d301c3', 'ticket_id': '214e6f30-a4f5-400c-93a4-3a680e9563f6', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I was trying to book a hotel room for my upcoming trip, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a room for me. Thank you!", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '273b9470-981b-411a-8c6e-8bb35598088a', 'ticket_id': '51b3e999-360d-44d4-bf89-1f27b248aa03', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '30d63658-4f80-41bf-aace-bb75e9f3a178', 'ticket_id': '044f0d4b-f885-4734-a9d3-b939e1eb8c98', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I have a question about the pricing of your services. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '85222463-35f0-4256-aafb-59cd221f1ba3', 'ticket_id': 'a1581f17-4722-469a-8d9c-c1783e310e86', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '0ba2e4ac-793c-42b9-a34e-ff1648f5aa5e', 'ticket_id': '8c732cf6-52ba-41d7-91f4-80cb4031c78a', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I need help with my account password. Every time I try to reset it, the link doesn't work. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'd6c15668-92b8-4e88-b0d9-5ea1bef5011f', 'ticket_id': 'da974b97-ffad-46fe-99c6-8752ea2bf497', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I was trying to make a reservation for a dinner at your restaurant, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a table for two at 7 PM this Saturday. Thank you!", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '37160317-09c1-4e67-8ae0-9c87e9ae5fa4', 'ticket_id': '502ef53d-ed37-40fe-a469-9e78397a8318', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I have a question about the stock price of your company. I noticed some fluctuations recently, and I'm not sure if they're part of the market trend. Could you please clarify this for me? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'da01f1c6-1ad1-427d-92ab-139cd7d9448d', 'ticket_id': 'b7c94198-ec35-4b96-88ac-e64d1d364b0a', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '55d3104a-7078-4ea6-8a91-5cac78c82ff9', 'ticket_id': 'd8e78d4f-31d9-4bc1-afa2-c92c928d57f4', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I have a question about the stock price of your company. I noticed some fluctuations recently, and I'm not sure if they're part of the market trend. Could you please clarify this for me? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'a4bff783-3447-4cfe-925b-d6b73277617e', 'ticket_id': 'bb2ca7e2-9068-4429-9447-9d2c966295f3', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': 'bfcae99e-d32b-4598-80a7-0fe6a142d60c', 'ticket_id': 'e07690e9-b672-4afe-83d5-894e64459bdc', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I have a question about the stock price of your company. I noticed some fluctuations recently, and I'm not sure if they're part of the market trend. Could you please clarify this for me? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '8f8d6568-3706-4b05-8327-fa35a0832c63', 'ticket_id': '5ff728d9-668b-4600-b976-7c3eb5fe7db7', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I was trying to make a reservation for a dinner at your restaurant, but the website keeps showing an error message. I've tried multiple times, but it just won't go through. Can you please help me with this? I would really appreciate it if you could reserve a table for two at 7 PM this Saturday. Thank you!", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '3d69ae3e-6e3c-4d59-b81b-5c158bd4b258', 'ticket_id': '1b44ed80-aa05-4e3e-8a00-d16ccaa67c1b', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I need to cancel my subscription. I've tried doing it through the website, but the option isn't available. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '2021811b-4787-4d86-bdc9-412d6a3ee87c', 'ticket_id': '1523ecab-f2fa-46ce-85d4-458a2d1e7059', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I was trying to book tickets for an event, but the website keeps crashing. I've tried different browsers, but nothing seems to work. Could you please help me with this? I don't want to miss out on the event. Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '5272b74e-eaa4-4b16-8497-d6d7fdb589c8', 'ticket_id': '052f4dbb-2ae2-4208-9dc7-12bd39ad5a34', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I have a question about the weather forecast for this weekend. I noticed some changes recently, and I'm not sure if they're part of the new plan. Could you please clarify this for me? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'message_id': '8aea50c4-a44a-4763-8a31-7143ca6a6098', 'ticket_id': 'e7f71fe3-cf4e-4455-b034-15f5e531dd63', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need help with my account password. Every time I try to reset it, the link doesn't work. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}

# %%
with get_session(engine) as session:
    metas = session.query(udahub.TicketMetadata).all()
    for meta in metas:
        # Get all column names for this model
        inst = inspect(meta)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(meta, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'ticket_id': '04988314-c6ec-41f3-b769-c070be049937', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, reservation', 'urgency_score': 0.7555034328629645, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '191d8eec-a361-491e-b41c-d24af47067ce', 'status': 'open', 'main_issue_type': None, 'tags': 'login', 'urgency_score': 0.4036073428065703, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'e02ed328-252f-4eaa-840c-0d1ce06518a2', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, escalation, access', 'urgency_score': 0.49130041666055513, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'd51540c9-be08-412b-9400-9ed93e1f3e04', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, cancelation, reservation', 'urgency_score': 0.17741222321052197, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '2eac2f82-5c95-4378-a332-6991f25cc453', 'status': 'open', 'main_issue_type': None, 'tags': 'attendance', 'urgency_score': 0.10200732377130162, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '4223581b-0ec2-4c77-873b-c396d4276bd9', 'status': 'open', 'main_issue_type': None, 'tags': 'pause, billing', 'urgency_score': 0.5036139965193229, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'fb135539-9fb8-4931-8030-b95aeb505394', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, login, events, pricing', 'urgency_score': 0.9617794888734655, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '7ddea533-a645-4bed-ab7e-c4f5bb446963', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, pause', 'urgency_score': 0.07053061925068826, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'b8cb1740-fdc5-4d07-ba23-08ca7e35f3a6', 'status': 'open', 'main_issue_type': None, 'tags': 'events, reservation', 'urgency_score': 0.6300959816759971, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'cb2e7547-d2f6-40e3-8101-3fbd96f51b91', 'status': 'open', 'main_issue_type': None, 'tags': 'login', 'urgency_score': 0.833758459049208, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'c98ba2d6-3ad4-4ad8-95c1-f8d7e8357d8c', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, billing, login, reservation', 'urgency_score': 0.45082769809615064, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '81bbc7d5-abae-45b2-b835-6eb624e6d7a4', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits', 'urgency_score': 0.26931431135479234, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '606ed5f8-5fe6-4a8d-96a2-248150ba1ac9', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, attendance', 'urgency_score': 0.4800304850558662, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '25b6ab7f-a492-413c-ab8e-fad55acfda31', 'status': 'open', 'main_issue_type': None, 'tags': 'login', 'urgency_score': 0.1583216070966823, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '5b700426-908f-4d03-a950-49a5a21f93bd', 'status': 'open', 'main_issue_type': None, 'tags': 'events, benefits, pause', 'urgency_score': 0.28695667474066977, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'b5c0ec08-69b4-4d85-9b3a-be926851ca9e', 'status': 'open', 'main_issue_type': None, 'tags': 'login', 'urgency_score': 0.6996171482003939, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'ac608554-4f0a-4db6-9e0f-c2008f431c50', 'status': 'open', 'main_issue_type': None, 'tags': 'password, cancelation', 'urgency_score': 0.8887918966502946, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '5a67160d-ad9d-47c8-9e9e-7e9a1c6092ad', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, billing, cancelation', 'urgency_score': 0.8290654954372001, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '443adaa5-99f7-47ad-b156-d2897ad96c8a', 'status': 'open', 'main_issue_type': None, 'tags': 'password', 'urgency_score': 0.5894113404471908, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'd209dd85-3582-4a91-b3b2-3e6a598042f2', 'status': 'open', 'main_issue_type': None, 'tags': 'events, booking, password, escalation', 'urgency_score': 0.7586428198184788, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '4e986961-57b0-40ee-8d5b-91b357c853aa', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, access', 'urgency_score': 0.5488143039373815, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '8b48fca1-9981-49fe-a5c5-1f2711832071', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, access, booking', 'urgency_score': 0.4714643072644462, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '4968f4ad-7cef-4c7e-ba53-ba9332fa6822', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, cancelation', 'urgency_score': 0.24837823056568842, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '3045295f-f870-46b1-bddf-904f5f609d03', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, password', 'urgency_score': 0.07920098954155386, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '5b97fd76-fc2c-46cf-b5fe-1c15a00aba7e', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, login, cancelation', 'urgency_score': 0.08066187688435744, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '2cb3eea6-56f5-4765-8370-fd9c003f398a', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, login, escalation, access', 'urgency_score': 0.6199986144728392, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '6732f43a-240c-4f90-abd7-d5f1ff619c79', 'status': 'open', 'main_issue_type': None, 'tags': 'access, reservation', 'urgency_score': 0.4972257462583246, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '750be6ed-61cf-4300-95b5-05d463cc4d2c', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, access, login, benefits', 'urgency_score': 0.20867332494623847, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '9bac57a2-ddbb-477f-b851-2f1c194ab0f7', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, events, password', 'urgency_score': 0.7333774204780514, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '1480424b-55eb-4cbf-aef8-061b062be369', 'status': 'open', 'main_issue_type': None, 'tags': 'login, pricing, events, cancelation', 'urgency_score': 0.9621311139242386, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'f7486ad4-54cb-4a58-b71f-cbdfde43cf60', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, cancelation, billing', 'urgency_score': 0.9959965305148201, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '4baea0f6-b493-410f-a710-93535cf2ed83', 'status': 'open', 'main_issue_type': None, 'tags': 'pause, booking, login, escalation', 'urgency_score': 0.05491949736298385, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '8260553e-6777-4142-a161-6c3c2ef6e2cd', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, cancelation, billing, pause', 'urgency_score': 0.5872302337603035, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '6b17ae4a-7146-434d-b8ea-cc43aa1531fe', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing', 'urgency_score': 0.37980041538221176, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '214e6f30-a4f5-400c-93a4-3a680e9563f6', 'status': 'open', 'main_issue_type': None, 'tags': 'password, booking, attendance', 'urgency_score': 0.8023979921537732, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '51b3e999-360d-44d4-bf89-1f27b248aa03', 'status': 'open', 'main_issue_type': None, 'tags': 'pause, cancelation, login', 'urgency_score': 0.7579917300055361, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '044f0d4b-f885-4734-a9d3-b939e1eb8c98', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, events', 'urgency_score': 0.4001457698713329, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'a1581f17-4722-469a-8d9c-c1783e310e86', 'status': 'open', 'main_issue_type': None, 'tags': 'events, attendance, pricing', 'urgency_score': 0.46288588232626093, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '8c732cf6-52ba-41d7-91f4-80cb4031c78a', 'status': 'open', 'main_issue_type': None, 'tags': 'password, subscription, login', 'urgency_score': 0.8275695005126608, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'da974b97-ffad-46fe-99c6-8752ea2bf497', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation', 'urgency_score': 0.7531879261192169, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '502ef53d-ed37-40fe-a469-9e78397a8318', 'status': 'open', 'main_issue_type': None, 'tags': 'stock price', 'urgency_score': 0.5132231654540281, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'b7c94198-ec35-4b96-88ac-e64d1d364b0a', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, stock price', 'urgency_score': 0.21957916123603272, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'd8e78d4f-31d9-4bc1-afa2-c92c928d57f4', 'status': 'open', 'main_issue_type': None, 'tags': 'stock price, dietary', 'urgency_score': 0.15717538488975258, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'bb2ca7e2-9068-4429-9447-9d2c966295f3', 'status': 'open', 'main_issue_type': None, 'tags': 'events, dietary', 'urgency_score': 0.2600199932885846, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'e07690e9-b672-4afe-83d5-894e64459bdc', 'status': 'open', 'main_issue_type': None, 'tags': 'stock price, weather', 'urgency_score': 0.26381209339856904, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '5ff728d9-668b-4600-b976-7c3eb5fe7db7', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, pricing, health advice, stock price', 'urgency_score': 0.6390107904040807, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '1b44ed80-aa05-4e3e-8a00-d16ccaa67c1b', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, attendance, dietary', 'urgency_score': 0.6011468020861513, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '1523ecab-f2fa-46ce-85d4-458a2d1e7059', 'status': 'open', 'main_issue_type': None, 'tags': 'events, pricing, dietary, health advice', 'urgency_score': 0.8351808196556199, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': '052f4dbb-2ae2-4208-9dc7-12bd39ad5a34', 'status': 'open', 'main_issue_type': None, 'tags': 'weather, health advice', 'urgency_score': 0.9030008589887083, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}
# {'ticket_id': 'e7f71fe3-cf4e-4455-b034-15f5e531dd63', 'status': 'open', 'main_issue_type': None, 'tags': 'password, login, weather, stock price', 'urgency_score': 0.8424324295899782, 'created_at': datetime.datetime(2026, 4, 19, 0, 41, 51), 'updated_at': datetime.datetime(2026, 4, 19, 0, 41, 51)}

# %%
with get_session(engine) as session:
    user = session.query(udahub.User).filter_by(
        account_id=account_id,
        external_user_id=ticket_table.iloc[2].to_dict()["owner_id"],
    ).first()
    
    ticket:udahub.Ticket = user.tickets[0]
    for message in ticket.messages:
        print(message)
# Out:
# <TicketMessage(message_id='e5ad615c-a8dc-44db-a84b-1828b3f23d48', role='user', content='Hi, I noticed an unexpected ch...')>
