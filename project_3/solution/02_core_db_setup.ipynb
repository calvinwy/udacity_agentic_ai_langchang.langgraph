# %%
import json
import uuid
from sqlalchemy import create_engine, inspect
from utils import reset_db, get_session, model_to_dict
from data.models import udahub

# %% [markdown]
# # Udahub Application

# %% [markdown]
# ## Core Database

# %% [markdown]
# **Init DB**

# %%
udahub_db = "data/core/udahub.db"
reset_db(udahub_db)
engine = create_engine(f"sqlite:///{udahub_db}", echo=False)
udahub.Base.metadata.create_all(bind=engine)
# Out:
# 2026-04-16 19:09:56,366 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-16 19:09:56,368 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Recreated data/core/udahub.db with fresh schema

# %% [markdown]
# **Account**

# %%
account_id = "cultpass"
account_name = "CultPass Card"

with get_session(engine) as session:
    account = udahub.Account(
        account_id=account_id,
        account_name=account_name,
    )
    session.add(account)

# %% [markdown]
# ---

# %% [markdown]
# ## Integrations

# %% [markdown]
# **Use LLM to Generate Sample Data**

# %%
import os
import pandas as pd
import random
from dotenv import load_dotenv
from typing import List
from pydantic import BaseModel, Field
from typing import List, Optional, Dict, Any, Literal, TypedDict, Annotated
from langgraph.prebuilt import create_react_agent
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import SystemMessage
from langchain_chroma import Chroma
from langchain_core.documents import Document

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# llm_base_url = "https://openai.vocareum.com/v1"

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0.0,
    # base_url=llm_base_url,
    api_key=OPENAI_API_KEY,
)

embeddings_fn = OpenAIEmbeddings(
    model="text-embedding-3-large",
    # base_url=llm_base_url,
    api_key=OPENAI_API_KEY,
)

# %% [markdown]
# **Data Generation Parameters**

# %%
num_articles = 20
num_account = 10
num_user = 25
num_ticket = 50
num_msg = num_ticket
num_expected_tag_msg = round(num_msg * 0.8)
num_unexpected_tag_msg = num_msg - num_expected_tag_msg
chromadb_directory = "vectorstore"
collection_name = "knowledge_vecotr_store"

# %% [markdown]
# ### Sampling Schema
#
# For LLM to produce the data samples

# %%
class ArticlesSchema(BaseModel):
    title: Annotated[str, Field(description="Title of the article.")]
    content: Annotated[str, Field(description="Content of the article.")]
    tags: Annotated[str, Field(description="Tags of the article")]

class ArticlesListSchema(BaseModel):
    samples: Annotated[List[ArticlesSchema], Field(description="List of CultpassArticles")]

class AccountSamples(BaseModel):
    """Structured response for account table"""
    company_name: List[str] = Field(description="List of first name and last name")

class UsersSchema(BaseModel):
    name: Annotated[str, Field(description="User's name with first and last name.")]
    email: Annotated[str, Field(description="User's email address.")]
    is_blocked: Annotated[bool, Field(description="User's blocking status.")]
    account_id: Annotated[str, Field(description="Company account ID")]

class UsersListSchema(BaseModel):
    samples: Annotated[List[UsersSchema], Field(description="List of users")]

class SingleTicket(BaseModel):
    """Structured response for a ticket"""
    status: Annotated[Literal['open','pending','closed'], Field(description="Status of the ticket")]
    content: Annotated[str, Field(description="The ticket body message content.")]
    owner_id: Annotated[str, Field(description="User ID")]
    owner_name: Annotated[str, Field(description="User's name")]
    channel: Annotated[Literal['email','chat','web','sms','social','phone'], Field(description="Ticket priority")]
    tags: Annotated[str, Field(description="List of tags used for creating this message")]
    account_id: Annotated[str, Field(description="Company account ID")]
    urgency_score: Annotated[float, Field(description="Urgency of the ticket")]

class TicketSamples(BaseModel):
    """Structured response of ticket list"""
    samples: List[SingleTicket]

# %% [markdown]
# ## Loading Default Data
#
# * Knowledge Base
# * Users Data

# %%
# Load Sample Articles
cultpass_articles = []
with open('data/external/cultpass_articles.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_articles.append(json.loads(line))

# Extract Tags from Samples
sample_tags = [ article['tags'].split(', ') for article in cultpass_articles ]
sample_tags = set([ item for subtags in sample_tags for item in subtags ])
sample_tags_str = ", ".join(sample_tags)

# Define Tags with Expected Knowledge and Tags without Expected Knowledge
# (This is for sampling ticket questions "with vs without knowledge to answer" using LLM)
expected_tags = sample_tags
unexpected_tags = ['weather', 'stock price', 'dietary', 'health advice']

# %%
sample_tags
# Out:
# {'access',
#  'attendance',
#  'benefits',
#  'billing',
#  'booking',
#  'cancelation',
#  'escalation',
#  'events',
#  'login',
#  'password',
#  'pause',
#  'pricing',
#  'reservation',
#  'subscription'}

# %%
# Load Users Data
cultpass_users = []
with open('data/external/cultpass_users.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_users.append(json.loads(line))

# %% [markdown]
# #### Generate Knowledge Articles

# %%
# Create Additional Knowledge Articles
num_cultpass_articles = len(cultpass_articles)
num_new_articles = num_articles - num_cultpass_articles
sample_articles_template = """
    You are an helpful expert creating sample of python sample article data based on given examples.  Do not provide any additional description or explanation.
    There is a mock-up project, it has the following description:

    You’ve joined a fast-growing AI startup building the next frontier in customer support automation. Your team is responsible for building UDA-Hub, 
    a Universal Decision Agent designed to plug into existing customer support systems (Zendesk, Intercom, Freshdesk, internal CRMs) and intelligently 
    resolve tickets. You need to generate sample knowledge articles in area including: {sample_tags}.  
    
    The knowledge areas given above will be used as tags for the generated articles.

    The first UDA-Hub customer Cultpass has the following sample articles to be used as knowledge to be used by the system:
    {samples}

    Cultpass is a online travel and leisure platform that provides a subscription-based card for travelers, offering access to airport lounges, travel discounts, 
    and exclusive experiences worldwide. Please create the new articles based on this context and the sample articles provided above.

    Provide {num_articles} more example like above and double check if all articles uses tags from {sample_tags}, if not try again.
    """

sample_articles_prompt = PromptTemplate(
    template = sample_articles_template,
    input_variables = ["samples","num_articles","sample_tags"],
    ).invoke({"samples": cultpass_articles,
              "num_articles": num_new_articles,
              "sample_tags": sample_tags}).to_messages()

new_cultpass_articles = llm.with_structured_output(ArticlesListSchema).invoke(sample_articles_prompt).model_dump()['samples']
cultpass_articles_ls = cultpass_articles + new_cultpass_articles

# Extracting Sample Tags for Each Sample
# new_sample_tags = [ article['tags'].split(', ') for article in cultpass_articles_ls ]
# new_sample_tags = set([ item for subtags in new_sample_tags for item in subtags ])
# new_sample_tags_str = ", ".join(new_sample_tags)

if len(cultpass_articles_ls) < 14:
    raise AssertionError("You should load the articles with at least 14 records")

# %%
cultpass_articles_ls
# Out:
# [{'title': 'How to Reserve a Spot for an Event',
#   'content': 'If a user asks how to reserve an event:\n\n- Guide them to the CultPass app\n- Instruct them to browse the experience catalog and tap \'Reserve\'\n- If it\'s a premium or limited event, check if reservation confirmation is required via email\n- Remind them to arrive at least 15 minutes early with their QR code visible\n\n**Suggested phrasing:**\n"You can reserve an experience by opening the CultPass app, selecting your desired event, and tapping \'Reserve\'. Be sure to arrive 15 minutes early with your QR code ready."',
#   'tags': 'reservation, events, booking, attendance'},
#  {'title': "What's Included in a CultPass Subscription",
#   'content': 'Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."',
#   'tags': 'subscription, benefits, pricing, access'},
#  {'title': 'How to Cancel or Pause a Subscription',
#   'content': 'Users can manage their subscription via the app > \'My Account\' > \'Manage Plan\'.\n\n- Cancel: Effective at the end of the billing cycle\n- Pause: Preserves user data, resumes automatically when reactivated\n- Do NOT offer refunds unless approved by support lead\n\n**Suggested phrasing:**\n"You can cancel or pause your subscription at any time via the \'My Account\' section in the CultPass app. Cancelation takes effect at the end of your billing cycle."',
#   'tags': 'cancelation, pause, subscription, billing'},
#  {'title': 'How to Handle Login Issues?',
#   'content': 'Most login issues are resolved with password reset:\n\n- Ask the user to tap \'Forgot Password\' on the login screen\n- Ensure they are using the correct registered email\n- If they did not receive the reset email, check spam folder or retry after 10 minutes\n- For persistent login issues, escalate to human support\n\n**Suggested phrasing:**\n"Try tapping \'Forgot Password\' on the login screen. Make sure you\'re using the email associated with your account. If the email doesn\'t arrive, check spam or try again in a few minutes."',
#   'tags': 'login, password, access, escalation'},
#  {'title': 'How to Book a Lounge Access',
#   'content': 'To book lounge access:\n\n- Open the CultPass app and navigate to the \'Lounge Access\' section\n- Select your desired airport and lounge\n- Tap \'Book Now\' and confirm your booking\n- Ensure you have your CultPass card ready upon arrival\n\n**Suggested phrasing:**\n"You can book lounge access by selecting your airport and lounge in the CultPass app and tapping \'Book Now\'. Remember to have your CultPass card ready when you arrive."',
#   'tags': 'booking, access, reservation'},
#  {'title': 'Understanding CultPass Pricing Tiers',
#   'content': 'CultPass offers multiple pricing tiers:\n\n- Basic: Access to standard lounges and experiences\n- Premium: Includes premium lounges and exclusive events\n- VIP: All-access pass with additional perks\n\n**Suggested phrasing:**\n"CultPass offers various pricing tiers to suit your needs, from basic access to VIP experiences. Choose the tier that best fits your travel style."',
#   'tags': 'pricing, benefits, subscription'},
#  {'title': 'How to Escalate a Support Ticket',
#   'content': 'If an issue cannot be resolved:\n\n- Advise the user to contact support via the app\n- Ensure they provide their ticket number and details\n- Escalate to a human agent if necessary\n\n**Suggested phrasing:**\n"If your issue persists, please contact support through the app with your ticket number. We will escalate it to a human agent if needed."',
#   'tags': 'escalation, support, access'},
#  {'title': 'Managing Event Attendance',
#   'content': 'To manage your attendance:\n\n- Open the CultPass app and go to \'My Events\'\n- View upcoming events and confirm attendance\n- Cancel if unable to attend to free up space for others\n\n**Suggested phrasing:**\n"Manage your event attendance in the \'My Events\' section of the CultPass app. Confirm or cancel as needed to keep your schedule up-to-date."',
#   'tags': 'attendance, events, booking'},
#  {'title': 'How to Reset Your Password',
#   'content': 'For password reset:\n\n- Tap \'Forgot Password\' on the login screen\n- Enter your registered email and follow the instructions\n- Check spam if the reset email isn\'t received\n\n**Suggested phrasing:**\n"Reset your password by tapping \'Forgot Password\' and following the instructions sent to your email. Check your spam folder if you don\'t see it."',
#   'tags': 'password, login, access'},
#  {'title': 'Benefits of CultPass Membership',
#   'content': 'CultPass membership includes:\n\n- Access to exclusive lounges and events\n- Travel discounts and offers\n- Priority customer support\n\n**Suggested phrasing:**\n"Enjoy exclusive lounges, events, and travel discounts with your CultPass membership. Plus, get priority support whenever you need it."',
#   'tags': 'benefits, subscription, access'},
#  {'title': 'How to Pause Your CultPass Membership',
#   'content': 'To pause your membership:\n\n- Go to \'My Account\' in the CultPass app\n- Select \'Manage Plan\' and choose \'Pause Membership\'\n- Membership will resume automatically when reactivated\n\n**Suggested phrasing:**\n"Pause your CultPass membership anytime in the \'My Account\' section. It will automatically resume when you\'re ready to travel again."',
#   'tags': 'pause, subscription, billing'},
#  {'title': 'Handling Billing Discrepancies',
#   'content': 'For billing issues:\n\n- Review your billing history in the app\n- Contact support with your billing details\n- Escalate if discrepancies persist\n\n**Suggested phrasing:**\n"Check your billing history in the app. If you notice discrepancies, contact support with your details for further assistance."',
#   'tags': 'billing, escalation, support'},
#  {'title': 'How to Access Exclusive Events',
#   'content': 'To access exclusive events:\n\n- Browse the \'Exclusive Events\' section in the app\n- Tap \'Reserve\' for your chosen event\n- Confirm your reservation and check for any additional fees\n\n**Suggested phrasing:**\n"Access exclusive events by reserving your spot in the app. Confirm your reservation and check for any additional fees."',
#   'tags': 'access, events, reservation'},
#  {'title': 'Understanding CultPass Cancelation Policy',
#   'content': 'Cancelation policy includes:\n\n- Cancel anytime via \'My Account\'\n- Effective at the end of the billing cycle\n- No refunds unless approved by support\n\n**Suggested phrasing:**\n"Cancel your CultPass membership anytime in \'My Account\'. It will take effect at the end of your billing cycle."',
#   'tags': 'cancelation, billing, subscription'},
#  {'title': 'How to Update Your Payment Method',
#   'content': 'To update payment details:\n\n- Go to \'My Account\' in the app\n- Select \'Payment Methods\' and update your information\n- Ensure your new payment method is valid\n\n**Suggested phrasing:**\n"Update your payment method in \'My Account\' under \'Payment Methods\'. Ensure your new details are valid to avoid service interruptions."',
#   'tags': 'billing, access, subscription'},
#  {'title': 'How to Handle Event Overbooking',
#   'content': 'If an event is overbooked:\n\n- Notify users via email or app notification\n- Offer alternative dates or events\n- Escalate to support if users are dissatisfied\n\n**Suggested phrasing:**\n"In case of overbooking, we\'ll notify you and offer alternatives. Contact support if you need further assistance."',
#   'tags': 'events, escalation, booking'},
#  {'title': 'How to Access Travel Discounts',
#   'content': 'To access travel discounts:\n\n- Browse the \'Travel Discounts\' section in the app\n- Select your desired offer and follow the instructions\n- Ensure you meet any eligibility criteria\n\n**Suggested phrasing:**\n"Access travel discounts by browsing the \'Travel Discounts\' section in the app. Follow the instructions to redeem your offers."',
#   'tags': 'access, benefits, pricing'},
#  {'title': 'How to Confirm Event Attendance',
#   'content': 'To confirm attendance:\n\n- Open \'My Events\' in the app\n- Select the event and tap \'Confirm Attendance\'\n- Ensure your QR code is ready for entry\n\n**Suggested phrasing:**\n"Confirm your attendance by selecting the event in \'My Events\' and tapping \'Confirm Attendance\'. Have your QR code ready for entry."',
#   'tags': 'attendance, events, reservation'},
#  {'title': 'How to Upgrade Your CultPass Plan',
#   'content': 'To upgrade your plan:\n\n- Go to \'My Account\' in the app\n- Select \'Manage Plan\' and choose your new tier\n- Confirm the upgrade and review any additional costs\n\n**Suggested phrasing:**\n"Upgrade your CultPass plan in \'My Account\' by selecting \'Manage Plan\'. Choose your new tier and confirm the upgrade."',
#   'tags': 'subscription, pricing, benefits'},
#  {'title': 'How to Handle Password Security',
#   'content': 'For password security:\n\n- Use a strong, unique password\n- Change your password regularly\n- Enable two-factor authentication if available\n\n**Suggested phrasing:**\n"Ensure your password is strong and unique. Change it regularly and enable two-factor authentication for added security."',
#   'tags': 'password, login, access'}]

# %% [markdown]
# Creating Vector Embedding for RAG

# %%
# Create vector store for knowledge articles
vector_store = Chroma(
    collection_name=collection_name,
    embedding_function=embeddings_fn,
    persist_directory=chromadb_directory,
)

cultpass_articles_docs = [ Document(page_content=article['title']+": "+article["content"],
                                      metadata={"tags": article['tags']},
                                      id=i) for i, article in enumerate(cultpass_articles_ls) ]
_ = vector_store.add_documents(documents=cultpass_articles_docs)

# %%
question = "Hi, I have a question regarding the billing for the events I attended last month. There seems to be a discrepancy in the charges, and I would like to understand the breakdown of the costs. Could you please provide a detailed billing statement? Thank you."
vector_store.similarity_search(question)
# Out:
# [Document(id='11', metadata={'tags': 'billing, escalation, support'}, page_content='Handling Billing Discrepancies: For billing issues:\n\n- Review your billing history in the app\n- Contact support with your billing details\n- Escalate if discrepancies persist\n\n**Suggested phrasing:**\n"Check your billing history in the app. If you notice discrepancies, contact support with your details for further assistance."'),
#  Document(id='17', metadata={'tags': 'attendance, events, reservation'}, page_content='How to Confirm Event Attendance: To confirm attendance:\n\n- Open \'My Events\' in the app\n- Select the event and tap \'Confirm Attendance\'\n- Ensure your QR code is ready for entry\n\n**Suggested phrasing:**\n"Confirm your attendance by selecting the event in \'My Events\' and tapping \'Confirm Attendance\'. Have your QR code ready for entry."'),
#  Document(id='12', metadata={'tags': 'access, events, reservation'}, page_content='How to Access Exclusive Events: To access exclusive events:\n\n- Browse the \'Exclusive Events\' section in the app\n- Tap \'Reserve\' for your chosen event\n- Confirm your reservation and check for any additional fees\n\n**Suggested phrasing:**\n"Access exclusive events by reserving your spot in the app. Confirm your reservation and check for any additional fees."'),
#  Document(id='7', metadata={'tags': 'attendance, events, booking'}, page_content='Managing Event Attendance: To manage your attendance:\n\n- Open the CultPass app and go to \'My Events\'\n- View upcoming events and confirm attendance\n- Cancel if unable to attend to free up space for others\n\n**Suggested phrasing:**\n"Manage your event attendance in the \'My Events\' section of the CultPass app. Confirm or cancel as needed to keep your schedule up-to-date."')]

# %% [markdown]
# #### Generate Users and Tickets

# %%
# Create Company List
account_prompt_template = """You are a company naming expert. Please come up with {num_account} company names."""

account_prompt = PromptTemplate(
    template = account_prompt_template,
    input_variables = ["num_account"],
    ).invoke({"num_account": num_account}).to_messages()

account = llm.with_structured_output(AccountSamples).invoke(account_prompt).model_dump()['company_name']
account_table = pd.DataFrame({"company_name": account})
# account_table['id'] = account_table.index
account_table['account_id'] = [ str(uuid.uuid4()) for i in range(num_account) ]
account_table_ls = account_table.to_dict(orient='records')
# account_table

# %%
# Create Additional Users
num_cultpass_users = len(cultpass_users)
num_new_users = num_user - num_cultpass_users
user_prompt_template = """
    You are a people naming expert. Please come up with {num_user} names with both first and last name.
    Randomly choose a company for each user from the account list and based on the name of the company,
    create an email address for this person.  Some companies should have more users than others.
    All users from the same company must have the same domain name on their email address.

    The `is_blocked` status should be randomly choosen as 'True' or 'False'

    List of account (companies): {account_table}"""

user_prompt = PromptTemplate(
    template = user_prompt_template,
    input_variables = ["num_user","account_table"],
    ).invoke({"num_user": num_new_users, "account_table": account_table}).to_messages()

user_ls = llm.with_structured_output(UsersListSchema).invoke(user_prompt).model_dump()['samples']
user_table = pd.DataFrame(user_ls)
user_table['id'] = [ str(uuid.uuid4().hex[:6]) for i in range(num_new_users) ]
user_table = user_table[['id', 'name', 'email', 'is_blocked','account_id']]
cultpass_users_table = pd.DataFrame(cultpass_users)
user_table = pd.concat([user_table, cultpass_users_table])
user_table['account_id'] = [ str(uuid.uuid4()) for i in range(num_user) ]     # account ID of LLM generated user should be replaced with true uuid4.

# %%
cultpass_users_table
# Out:
#        id            name                          email  is_blocked
# 0  a4ab87  Alice Kingsley  alice.kingsley@wonderland.com        True
# 1  f556c0       Bob Stone          bob.stone@granite.com       False
# 2  88382b     Cathy Bloom        cathy.bloom@florals.org       False
# 3  888fb2      David Noir      david.noir@shadowmail.com        True
# 4  f1f10d       Eva Green          eva.green@ecosoul.net       False
# 5  e6376d     Frank Ocean        frank.ocean@seawaves.io       False

# %%
user_table
# Out:
#         id                name                                       email  \
# 0   b79e00       Alice Johnson       alice.johnson@innovatechsolutions.com
# 1   646d4a       Michael Smith       michael.smith@innovatechsolutions.com
# 2   ca1575        Sophia Brown        sophia.brown@innovatechsolutions.com
# 3   f74ec5        James Wilson        james.wilson@ecospherenterprises.com
# 4   9caffd     Olivia Martinez     olivia.martinez@ecospherenterprises.com
# 5   fe4bdc          Liam Davis          liam.davis@quantumleapdynamics.com
# 6   b64567         Emma Garcia       emma.garcia@greenwavetechnologies.com
# 7   540bd1       Noah Martinez     noah.martinez@greenwavetechnologies.com
# 8   e3ac40       Ava Rodriguez           ava.rodriguez@skylineventures.com
# 9   b0cef0   William Hernandez       william.hernandez@apexinnovations.com
# 10  627c92      Isabella Lopez          isabella.lopez@apexinnovations.com
# 11  130a1c      Lucas Gonzalez    lucas.gonzalez@bluehorizonindustries.com
# 12  79bc59           Mia Perez              mia.perez@pinnaclepathways.com
# 13  2567ff         Ethan White         ethan.white@synergysystemsgroup.com
# 14  537d6b  Charlotte Thompson  charlotte.thompson@synergysystemsgroup.com
# 15  93733d     Amelia Anderson     amelia.anderson@vanguardvisionaries.com
# 16  6e11c3     Benjamin Thomas     benjamin.thomas@vanguardvisionaries.com
# 17  8ce159      Harper Jackson      harper.jackson@vanguardvisionaries.com
# 18  e39b9e          Elijah Lee          elijah.lee@vanguardvisionaries.com
# 0   a4ab87      Alice Kingsley               alice.kingsley@wonderland.com
# 1   f556c0           Bob Stone                       bob.stone@granite.com
# 2   88382b         Cathy Bloom                     cathy.bloom@florals.org
# 3   888fb2          David Noir                   david.noir@shadowmail.com
# 4   f1f10d           Eva Green                       eva.green@ecosoul.net
# 5   e6376d         Frank Ocean                     frank.ocean@seawaves.io
#
#     is_blocked                            account_id
# 0        False  32113a40-34df-4cbc-9024-25be5898048b
# 1         True  8275c78b-36d2-4f0c-aac8-302b3c336d6d
# 2        False  1056a2b6-7951-47ce-8221-d4212ccd5007
# 3         True  e19f67b9-c1b6-40fb-b81b-f71e79fcdbc0
# 4        False  7d8d38be-2a24-4d6e-81f3-83fb8c20bc94
# 5         True  009f1601-9011-4b70-afc3-47f22427c7d2
# 6        False  cedd8b50-27c3-42b9-9640-ef4caaac34a1
# 7         True  8e6d45fc-1adc-4fa9-b7ac-538a05087118
# 8        False  527cd545-a615-4087-883f-b8d6e5302fc8
# 9         True  88461f45-18ea-41de-9136-0a2e7c59d60c
# 10       False  1445d9f8-c5d8-4d7a-a7fe-f989540f2069
# 11        True  d246bceb-268d-496a-9710-e5f4e8ecb1a6
# 12       False  16d6cd19-9151-4423-9fc3-08e308bf645f
# 13        True  3d5297e8-bb62-4cdf-87ff-cfe260b96565
# 14       False  dd3e8873-4a1a-407c-b1a0-df8157fb0102
# 15        True  aa2375f0-da24-48a2-8477-190ffe9d03af
# 16       False  1e34fef3-95c2-43ee-a9dd-49ebea7f4270
# 17        True  ea5f991a-9b0d-4231-9f5d-e6a9e96a529f
# 18       False  5e4da015-4f37-43d6-87a0-dea542953dbe
# 0         True  227d464d-d29a-45ba-be2a-55b67b9a71d4
# 1        False  60568a02-bd4c-4fc5-a1e4-992e0e87e1fe
# 2        False  66f15ea6-da81-46f3-afb0-7c563e648949
# 3         True  571c686f-d98d-4914-9f3c-f3ab8c7316da
# 4        False  dc3685f0-11cb-4a75-9d82-6a2ea65086b4
# 5        False  90635f90-d290-4948-9c52-3e56932d2de9

# %%
# Random Combination of Tags
expected_list_min_expected_tag = 1
expected_list_max_expected_tag = 4
unexpected_list_min_expected_tag = 0
unexpected_list_max_expected_tag = 2
unexpected_list_min_unexpected_tag = 1
unexpected_list_max_unexpected_tag = 2

expected_tag_combination = [ random.sample(list(expected_tags), random.randint(expected_list_min_expected_tag,expected_list_max_expected_tag)) for i in range(num_expected_tag_msg) ]
unexpected_tag_combination = [ random.sample(list(expected_tags), random.randint(unexpected_list_min_expected_tag,unexpected_list_max_expected_tag)) +
                               random.sample(list(unexpected_tags), random.randint(unexpected_list_min_unexpected_tag,unexpected_list_max_unexpected_tag)) for i in range(num_unexpected_tag_msg) ]
tag_combination = expected_tag_combination + unexpected_tag_combination

# %%
# Create Tickets
ticket_prompt_template = """
    You are a IT ticket generation emulator focusing on generating the actual message of users.
    
    Step 1: Generate {num_ticket} tickets, 
        (a) Each `content` should be 20 to 200 words
        (b) Make occasional minor typos in the `content`
        (c) Each ticket `content` should be written based on the topic in the followin table:
        {tag_combination}  

    Step 2: For the `owner_id` (use `id` column in the table), `owner_name` (use `name` column in the table), account_id (`account_id`)
            and allow one user to have multiple tickets:
        {user_table}

    Step 3: Randomly selected a `channel` from ['email','chat','web','sms','social','phone'] for each ticket.
    """

ticket_prompt = PromptTemplate(
    template = ticket_prompt_template,
    input_variables = ["num_ticket","num_expected_tag_msg","num_unexpected_tag_msg","expected_tags","unexpected_tags","ticket_table"],
    ).invoke({"num_ticket": num_ticket,
              "tag_combination": tag_combination, 
              "unexpected_tags": unexpected_tags, 
              "user_table": user_table,
            }).to_messages()

ticket_ls = llm.with_structured_output(TicketSamples).invoke(ticket_prompt).model_dump()['samples']
ticket_table = pd.DataFrame(ticket_ls)
# ticket_table['id'] = msg_table.index
ticket_table['role'] = "user"
ticket_table['status'] = "open"
ticket_table['urgency_score'] = [random.random() for _ in range(num_ticket)]
# ticket_table

# %%
for ticket in ticket_table['content']:
    print(ticket)
# Out:
# Hi there, I am having trouble logging into my account. Every time I try to enter my credentials, it says that my password is incorrect. I have tried resetting it multiple times, but the issue persists. Could you please assist me in resolving this issue? Thank you!
# Hello, I need to pause my subscription temporarily due to personal reasons. I couldn't find the option on the website. Could you guide me on how to proceed with this?
# Good day, I am writing to inquire about the benefits included in my current plan. I would also like to escalate a previous issue that was not resolved to my satisfaction. Additionally, I am interested in upcoming events that might be relevant to my interests. Could you provide more information?
# Hi, I am trying to make a reservation for an event, but the system keeps logging me out. I also want to know if my subscription covers this event. Can you help me with this?
# Hello, I would like to make a reservation for a table at your restaurant for this weekend. Could you confirm the availability and the process to book it?
# Hi, I need to cancel my attendance for the upcoming conference due to unforeseen circumstances. Additionally, I have a billing query regarding the refund process. Could you assist me with these issues?
# Hello, I am interested in making a reservation for a group event. Could you provide me with the pricing details and any available packages?
# Hi, I would like to book a session for next week. However, I might need to pause my current plan temporarily. Also, could you inform me about the benefits included in my package?
# Hello, I need to cancel my subscription as I am no longer using the service. Could you guide me through the cancellation process?
# Hi, I am interested in attending the upcoming events. Could you provide me with the schedule and any registration details?
# Hello, I am trying to make a reservation, but the system keeps logging me out. Additionally, I would like to know more about the benefits included in my plan. Could you assist me with these issues?
# Hi, I forgot my password and am unable to access my account. Could you help me reset it?
# Hello, I am having trouble accessing my account. I also forgot my password and need assistance with resetting it. Additionally, I am interested in upcoming events. Could you provide more information?
# Hi, I am trying to book a session, but I am having trouble accessing the booking page. Could you assist me with this issue?
# Hello, I would like to escalate an issue regarding my subscription. Additionally, I am interested in booking a session for next week. Could you assist me with these matters?
# Hi, I need to escalate an issue regarding my account. Additionally, I would like to pause my current plan temporarily. Could you assist me with these matters?
# Hello, I am interested in subscribing to your service. Could you provide me with information about the benefits included in the subscription and the billing process?
# Hi, I would like to know more about the benefits included in my current plan. Could you provide me with detailed information?
# Hello, I need to cancel my subscription as I am no longer using the service. Could you guide me through the cancellation process?
# Hi, I have a billing query regarding my last invoice. Could you provide me with a detailed breakdown of the charges?
# Hello, I need to pause my subscription temporarily due to personal reasons. Could you guide me on how to proceed with this?
# Hi, I am having trouble logging into my account. Could you assist me with resetting my password?
# Hello, I have a billing query regarding my last invoice. Additionally, I would like to pause my current plan temporarily. Could you assist me with these matters?
# Hi, I am interested in the pricing details for your services. Additionally, I would like to escalate an issue regarding my last invoice. Could you assist me with these matters?
# Hello, I forgot my password and am unable to access my account. Additionally, I am interested in upcoming events. Could you provide more information?
# Hi, I am trying to make a reservation, but I am having trouble accessing the reservation page. Additionally, I have a billing query regarding my last invoice. Could you assist me with these matters?
# Hello, I need to pause my subscription temporarily due to personal reasons. Additionally, I would like to escalate an issue regarding my account. Could you assist me with these matters?
# Hi, I need to pause my subscription temporarily due to personal reasons. Could you guide me on how to proceed with this?
# Hello, I need to escalate an issue regarding my account. Additionally, I would like to cancel my subscription as I am no longer using the service. Could you assist me with these matters?
# Hi, I am having trouble logging into my account. Additionally, I would like to escalate an issue regarding my last invoice. Could you assist me with these matters?
# Hello, I am interested in booking a session for next week. Additionally, I have a billing query regarding my last invoice. Could you assist me with these matters?
# Hi, I need to escalate an issue regarding my account. Additionally, I am having trouble accessing my account. Could you assist me with these matters?
# Hello, I would like to make a reservation for a table at your restaurant for this weekend. Could you confirm the availability and the process to book it?
# Hi, I am interested in the pricing details for your services. Additionally, I am having trouble logging into my account. Could you assist me with these matters?
# Hello, I have a billing query regarding my last invoice. Could you provide me with a detailed breakdown of the charges?
# Hi, I am trying to make a reservation, but I am having trouble accessing the reservation page. Could you assist me with this issue?
# Hello, I am interested in subscribing to your service. Additionally, I would like to book a session for next week. Could you assist me with these matters?
# Hi, I need to cancel my subscription as I am no longer using the service. Additionally, I would like to know more about the benefits included in my plan. Could you assist me with these matters?
# Hello, I would like to know more about the benefits included in my current plan. Additionally, I am interested in upcoming events. Could you provide more information?
# Hi, I forgot my password and am unable to access my account. Additionally, I have a billing query regarding my last invoice. Could you assist me with these matters?
# Hello, I have a billing query regarding my last invoice. Additionally, I would like to know more about the dietary options available in your meal plans. Could you assist me with these matters?
# Hi, I am interested in the dietary options available in your meal plans. Could you provide me with detailed information?
# Hello, I am seeking health advice regarding my current condition. Could you provide me with guidance on how to proceed?
# Hi, I am having trouble logging into my account. Additionally, I am interested in the pricing details for your services. Could you assist me with these matters?
# Hello, I am interested in the pricing details for your services. Additionally, I would like to know more about the dietary options available in your meal plans. Could you assist me with these matters?
# Hi, I am interested in the dietary options available in your meal plans. Could you provide me with detailed information?
# Hello, I have a billing query regarding my last invoice. Additionally, I am seeking health advice regarding my current condition. Could you assist me with these matters?
# Hi, I am having trouble accessing my account. Additionally, I am interested in the pricing details for your services. Could you assist me with these matters?
# Hello, I am interested in attending the upcoming events. Additionally, I would like to know more about the dietary options available in your meal plans. Could you assist me with these matters?
# Hi, I am interested in the dietary options available in your meal plans. Could you provide me with detailed information?

# %%
ticket_table
# Out:
#    status                                            content owner_id  \
# 0    open  Hi there, I am having trouble logging into my ...   b79e00
# 1    open  Hello, I need to pause my subscription tempora...   646d4a
# 2    open  Good day, I am writing to inquire about the be...   ca1575
# 3    open  Hi, I am trying to make a reservation for an e...   f74ec5
# 4    open  Hello, I would like to make a reservation for ...   9caffd
# 5    open  Hi, I need to cancel my attendance for the upc...   fe4bdc
# 6    open  Hello, I am interested in making a reservation...   b64567
# 7    open  Hi, I would like to book a session for next we...   540bd1
# 8    open  Hello, I need to cancel my subscription as I a...   e3ac40
# 9    open  Hi, I am interested in attending the upcoming ...   b0cef0
# 10   open  Hello, I am trying to make a reservation, but ...   627c92
# 11   open  Hi, I forgot my password and am unable to acce...   130a1c
# 12   open  Hello, I am having trouble accessing my accoun...   79bc59
# 13   open  Hi, I am trying to book a session, but I am ha...   2567ff
# 14   open  Hello, I would like to escalate an issue regar...   537d6b
# 15   open  Hi, I need to escalate an issue regarding my a...   93733d
# 16   open  Hello, I am interested in subscribing to your ...   6e11c3
# 17   open  Hi, I would like to know more about the benefi...   8ce159
# 18   open  Hello, I need to cancel my subscription as I a...   e39b9e
# 19   open  Hi, I have a billing query regarding my last i...   a4ab87
# 20   open  Hello, I need to pause my subscription tempora...   f556c0
# 21   open  Hi, I am having trouble logging into my accoun...   88382b
# 22   open  Hello, I have a billing query regarding my las...   888fb2
# 23   open  Hi, I am interested in the pricing details for...   f1f10d
# 24   open  Hello, I forgot my password and am unable to a...   e6376d
# 25   open  Hi, I am trying to make a reservation, but I a...   b79e00
# 26   open  Hello, I need to pause my subscription tempora...   646d4a
# 27   open  Hi, I need to pause my subscription temporaril...   ca1575
# 28   open  Hello, I need to escalate an issue regarding m...   f74ec5
# 29   open  Hi, I am having trouble logging into my accoun...   9caffd
# 30   open  Hello, I am interested in booking a session fo...   fe4bdc
# 31   open  Hi, I need to escalate an issue regarding my a...   b64567
# 32   open  Hello, I would like to make a reservation for ...   540bd1
# 33   open  Hi, I am interested in the pricing details for...   e3ac40
# 34   open  Hello, I have a billing query regarding my las...   b0cef0
# 35   open  Hi, I am trying to make a reservation, but I a...   627c92
# 36   open  Hello, I am interested in subscribing to your ...   130a1c
# 37   open  Hi, I need to cancel my subscription as I am n...   79bc59
# 38   open  Hello, I would like to know more about the ben...   2567ff
# 39   open  Hi, I forgot my password and am unable to acce...   537d6b
# 40   open  Hello, I have a billing query regarding my las...   93733d
# 41   open  Hi, I am interested in the dietary options ava...   6e11c3
# 42   open  Hello, I am seeking health advice regarding my...   8ce159
# 43   open  Hi, I am having trouble logging into my accoun...   e39b9e
# 44   open  Hello, I am interested in the pricing details ...   a4ab87
# 45   open  Hi, I am interested in the dietary options ava...   f556c0
# 46   open  Hello, I have a billing query regarding my las...   88382b
# 47   open  Hi, I am having trouble accessing my account. ...   888fb2
# 48   open  Hello, I am interested in attending the upcomi...   f1f10d
# 49   open  Hi, I am interested in the dietary options ava...   e6376d
#
#             owner_name channel                               tags  \
# 0        Alice Johnson   email                              login
# 1        Michael Smith     web                              pause
# 2         Sophia Brown    chat       benefits, escalation, events
# 3         James Wilson   phone   reservation, login, subscription
# 4      Olivia Martinez  social                        reservation
# 5           Liam Davis     sms   cancelation, attendance, billing
# 6          Emma Garcia   email               reservation, pricing
# 7        Noah Martinez     web           booking, pause, benefits
# 8        Ava Rodriguez    chat                        cancelation
# 9    William Hernandez   phone                             events
# 10      Isabella Lopez  social       reservation, login, benefits
# 11      Lucas Gonzalez     sms                           password
# 12           Mia Perez   email           password, access, events
# 13         Ethan White     web                    access, booking
# 14  Charlotte Thompson    chat  escalation, subscription, booking
# 15     Amelia Anderson   phone                  escalation, pause
# 16     Benjamin Thomas  social    subscription, benefits, billing
# 17      Harper Jackson     sms                           benefits
# 18          Elijah Lee   email                        cancelation
# 19      Alice Kingsley     web                            billing
# 20           Bob Stone    chat                              pause
# 21         Cathy Bloom   phone                              login
# 22          David Noir  social                     billing, pause
# 23           Eva Green     sms       pricing, escalation, billing
# 24         Frank Ocean   email                   password, events
# 25       Alice Johnson     web               reservation, billing
# 26       Michael Smith    chat                  pause, escalation
# 27        Sophia Brown   phone                              pause
# 28        James Wilson  social            escalation, cancelation
# 29     Olivia Martinez     sms                  login, escalation
# 30          Liam Davis   email                   booking, billing
# 31         Emma Garcia     web                 escalation, access
# 32       Noah Martinez    chat                        reservation
# 33       Ava Rodriguez   phone                     pricing, login
# 34   William Hernandez  social                            billing
# 35      Isabella Lopez     sms                reservation, access
# 36      Lucas Gonzalez   email              subscription, booking
# 37           Mia Perez     web              cancelation, benefits
# 38         Ethan White    chat                   benefits, events
# 39  Charlotte Thompson   phone                  password, billing
# 40     Amelia Anderson  social                   billing, dietary
# 41     Benjamin Thomas     sms                            dietary
# 42      Harper Jackson   email                      health advice
# 43          Elijah Lee     web                     login, pricing
# 44      Alice Kingsley    chat                   pricing, dietary
# 45           Bob Stone   phone                            dietary
# 46         Cathy Bloom  social             billing, health advice
# 47          David Noir     sms                    access, pricing
# 48           Eva Green   email                    events, dietary
# 49         Frank Ocean     web                            dietary
#
#                               account_id  urgency_score  role
# 0   32113a40-34df-4cbc-9024-25be5898048b       0.814848  user
# 1   8275c78b-36d2-4f0c-aac8-302b3c336d6d       0.872332  user
# 2   1056a2b6-7951-47ce-8221-d4212ccd5007       0.681314  user
# 3   e19f67b9-c1b6-40fb-b81b-f71e79fcdbc0       0.765031  user
# 4   7d8d38be-2a24-4d6e-81f3-83fb8c20bc94       0.210087  user
# 5   009f1601-9011-4b70-afc3-47f22427c7d2       0.957181  user
# 6   cedd8b50-27c3-42b9-9640-ef4caaac34a1       0.761294  user
# 7   8e6d45fc-1adc-4fa9-b7ac-538a05087118       0.195634  user
# 8   527cd545-a615-4087-883f-b8d6e5302fc8       0.329183  user
# 9   88461f45-18ea-41de-9136-0a2e7c59d60c       0.135810  user
# 10  1445d9f8-c5d8-4d7a-a7fe-f989540f2069       0.951518  user
# 11  d246bceb-268d-496a-9710-e5f4e8ecb1a6       0.988945  user
# 12  16d6cd19-9151-4423-9fc3-08e308bf645f       0.121298  user
# 13  3d5297e8-bb62-4cdf-87ff-cfe260b96565       0.683029  user
# 14  dd3e8873-4a1a-407c-b1a0-df8157fb0102       0.648258  user
# 15  aa2375f0-da24-48a2-8477-190ffe9d03af       0.852557  user
# 16  1e34fef3-95c2-43ee-a9dd-49ebea7f4270       0.589932  user
# 17  ea5f991a-9b0d-4231-9f5d-e6a9e96a529f       0.653140  user
# 18  5e4da015-4f37-43d6-87a0-dea542953dbe       0.566834  user
# 19  227d464d-d29a-45ba-be2a-55b67b9a71d4       0.696232  user
# 20  60568a02-bd4c-4fc5-a1e4-992e0e87e1fe       0.046485  user
# 21  66f15ea6-da81-46f3-afb0-7c563e648949       0.380530  user
# 22  571c686f-d98d-4914-9f3c-f3ab8c7316da       0.126689  user
# 23  dc3685f0-11cb-4a75-9d82-6a2ea65086b4       0.855270  user
# 24  90635f90-d290-4948-9c52-3e56932d2de9       0.107440  user
# 25  32113a40-34df-4cbc-9024-25be5898048b       0.462366  user
# 26  8275c78b-36d2-4f0c-aac8-302b3c336d6d       0.516997  user
# 27  1056a2b6-7951-47ce-8221-d4212ccd5007       0.475801  user
# 28  e19f67b9-c1b6-40fb-b81b-f71e79fcdbc0       0.109533  user
# 29  7d8d38be-2a24-4d6e-81f3-83fb8c20bc94       0.326561  user
# 30  009f1601-9011-4b70-afc3-47f22427c7d2       0.126528  user
# 31  cedd8b50-27c3-42b9-9640-ef4caaac34a1       0.871381  user
# 32  8e6d45fc-1adc-4fa9-b7ac-538a05087118       0.581032  user
# 33  527cd545-a615-4087-883f-b8d6e5302fc8       0.962767  user
# 34  88461f45-18ea-41de-9136-0a2e7c59d60c       0.916671  user
# 35  1445d9f8-c5d8-4d7a-a7fe-f989540f2069       0.948650  user
# 36  d246bceb-268d-496a-9710-e5f4e8ecb1a6       0.674408  user
# 37  16d6cd19-9151-4423-9fc3-08e308bf645f       0.830423  user
# 38  3d5297e8-bb62-4cdf-87ff-cfe260b96565       0.147246  user
# 39  dd3e8873-4a1a-407c-b1a0-df8157fb0102       0.823100  user
# 40  aa2375f0-da24-48a2-8477-190ffe9d03af       0.864251  user
# 41  1e34fef3-95c2-43ee-a9dd-49ebea7f4270       0.464706  user
# 42  ea5f991a-9b0d-4231-9f5d-e6a9e96a529f       0.316810  user
# 43  5e4da015-4f37-43d6-87a0-dea542953dbe       0.654347  user
# 44  227d464d-d29a-45ba-be2a-55b67b9a71d4       0.642695  user
# 45  60568a02-bd4c-4fc5-a1e4-992e0e87e1fe       0.983696  user
# 46  66f15ea6-da81-46f3-afb0-7c563e648949       0.982974  user
# 47  571c686f-d98d-4914-9f3c-f3ab8c7316da       0.771125  user
# 48  dc3685f0-11cb-4a75-9d82-6a2ea65086b4       0.089928  user
# 49  90635f90-d290-4948-9c52-3e56932d2de9       0.547584  user

# %%
len(ticket_table)
# Out:
# 50

# %% [markdown]
# ## Load Samples into Database

# %%
with get_session(engine) as session:
    kb = []
    for article in cultpass_articles:
        knowledge = udahub.Knowledge(
            article_id=str(uuid.uuid4()),
            account_id=account_id,
            title=article["title"],
            content=article["content"],
            tags=article["tags"]
        )
        kb.append(knowledge)
    session.add_all(kb)

# %% [markdown]
# **Ticket**

# %%
user_table.columns
# Out:
# Index(['id', 'name', 'email', 'is_blocked', 'account_id'], dtype='object')

# %%
def add_user(user_info):
    """
    Adding a single user to the database.
    """
    with get_session(engine) as session:
        user = udahub.User(
            user_id=user_info["account_id"],
            account_id=account_id,
            external_user_id=user_info["id"],
            user_name=user_info["name"],
            is_blocked=user_info["is_blocked"],
            email_address=user_info["email"]
            )
        session.add_all([user])

# %%
for index, row in user_table.iterrows():
    add_user(row)

# %%
def add_ticket(ticket_info):
    """
    Adding a single ticket to the database
    """
    with get_session(engine) as session:
        user = session.query(udahub.User).filter_by(
            account_id=account_id,
            external_user_id=ticket_info["owner_id"],
        ).first()

        print(ticket_info)
        print(user)

        if not user:
            user = udahub.User(
                # user_id=str(uuid.uuid4()),
                user_id=ticket_info["account_id"],
                account_id=account_id,
                external_user_id=ticket_info["owner_id"],
                user_name=ticket_info["owner_name"],
                is_blocked=False,     # Data structure in data/models/udahub.py had been modified to include this flag for advanced agent capability
                email_address=None    # Data structure in data/models/udahub.py had been modified to include this flag for advanced agent capability
            )
        
        ticket = udahub.Ticket(
            ticket_id=str(uuid.uuid4()),
            account_id=account_id,
            user_id=user.user_id,
            channel=ticket_info["channel"],
        )
        metadata = udahub.TicketMetadata(
            ticket_id=ticket.ticket_id,
            status=ticket_info["status"],
            main_issue_type=None,
            tags=ticket_info["tags"],
            urgency_score=ticket_info["urgency_score"]
        )

        first_message = udahub.TicketMessage(
            message_id=str(uuid.uuid4()),
            ticket_id=ticket.ticket_id,
            role=ticket_info["role"],
            content=ticket_info["content"],
        )

        # print(user)
        session.add_all([user, ticket, metadata, first_message])

# %%
for index, row in ticket_table.iterrows():
    add_ticket(row)
# Out:
# status                                                        open
# content          Hi there, I am having trouble logging into my ...
# owner_id                                                    b79e00
# owner_name                                           Alice Johnson
# channel                                                      email
# tags                                                         login
# account_id                    32113a40-34df-4cbc-9024-25be5898048b
# urgency_score                                             0.814848
# role                                                          user
# Name: 0, dtype: object
# <User(user_id='32113a40-34df-4cbc-9024-25be5898048b', user_name='Alice Johnson', external_user_id='b79e00')>
# status                                                        open
# content          Hello, I need to pause my subscription tempora...
# owner_id                                                    646d4a
# owner_name                                           Michael Smith
# channel                                                        web
# tags                                                         pause
# account_id                    8275c78b-36d2-4f0c-aac8-302b3c336d6d
# urgency_score                                             0.872332
# role                                                          user
# Name: 1, dtype: object
# <User(user_id='8275c78b-36d2-4f0c-aac8-302b3c336d6d', user_name='Michael Smith', external_user_id='646d4a')>
# status                                                        open
# content          Good day, I am writing to inquire about the be...
# owner_id                                                    ca1575
# owner_name                                            Sophia Brown
# channel                                                       chat
# tags                                  benefits, escalation, events
# account_id                    1056a2b6-7951-47ce-8221-d4212ccd5007
# urgency_score                                             0.681314
# role                                                          user
# Name: 2, dtype: object
# <User(user_id='1056a2b6-7951-47ce-8221-d4212ccd5007', user_name='Sophia Brown', external_user_id='ca1575')>
# status                                                        open
# content          Hi, I am trying to make a reservation for an e...
# owner_id                                                    f74ec5
# owner_name                                            James Wilson
# channel                                                      phone
# tags                              reservation, login, subscription
# account_id                    e19f67b9-c1b6-40fb-b81b-f71e79fcdbc0
# urgency_score                                             0.765031
# role                                                          user
# Name: 3, dtype: object
# <User(user_id='e19f67b9-c1b6-40fb-b81b-f71e79fcdbc0', user_name='James Wilson', external_user_id='f74ec5')>
# status                                                        open
# content          Hello, I would like to make a reservation for ...
# owner_id                                                    9caffd
# owner_name                                         Olivia Martinez
# channel                                                     social
# tags                                                   reservation
# account_id                    7d8d38be-2a24-4d6e-81f3-83fb8c20bc94
# urgency_score                                             0.210087
# role                                                          user
# Name: 4, dtype: object
# <User(user_id='7d8d38be-2a24-4d6e-81f3-83fb8c20bc94', user_name='Olivia Martinez', external_user_id='9caffd')>
# status                                                        open
# content          Hi, I need to cancel my attendance for the upc...
# owner_id                                                    fe4bdc
# owner_name                                              Liam Davis
# channel                                                        sms
# tags                              cancelation, attendance, billing
# account_id                    009f1601-9011-4b70-afc3-47f22427c7d2
# urgency_score                                             0.957181
# role                                                          user
# Name: 5, dtype: object
# <User(user_id='009f1601-9011-4b70-afc3-47f22427c7d2', user_name='Liam Davis', external_user_id='fe4bdc')>
# status                                                        open
# content          Hello, I am interested in making a reservation...
# owner_id                                                    b64567
# owner_name                                             Emma Garcia
# channel                                                      email
# tags                                          reservation, pricing
# account_id                    cedd8b50-27c3-42b9-9640-ef4caaac34a1
# urgency_score                                             0.761294
# role                                                          user
# Name: 6, dtype: object
# <User(user_id='cedd8b50-27c3-42b9-9640-ef4caaac34a1', user_name='Emma Garcia', external_user_id='b64567')>
# status                                                        open
# content          Hi, I would like to book a session for next we...
# owner_id                                                    540bd1
# owner_name                                           Noah Martinez
# channel                                                        web
# tags                                      booking, pause, benefits
# account_id                    8e6d45fc-1adc-4fa9-b7ac-538a05087118
# urgency_score                                             0.195634
# role                                                          user
# Name: 7, dtype: object
# <User(user_id='8e6d45fc-1adc-4fa9-b7ac-538a05087118', user_name='Noah Martinez', external_user_id='540bd1')>
# status                                                        open
# content          Hello, I need to cancel my subscription as I a...
# owner_id                                                    e3ac40
# owner_name                                           Ava Rodriguez
# channel                                                       chat
# tags                                                   cancelation
# account_id                    527cd545-a615-4087-883f-b8d6e5302fc8
# urgency_score                                             0.329183
# role                                                          user
# Name: 8, dtype: object
# <User(user_id='527cd545-a615-4087-883f-b8d6e5302fc8', user_name='Ava Rodriguez', external_user_id='e3ac40')>
# status                                                        open
# content          Hi, I am interested in attending the upcoming ...
# owner_id                                                    b0cef0
# owner_name                                       William Hernandez
# channel                                                      phone
# tags                                                        events
# account_id                    88461f45-18ea-41de-9136-0a2e7c59d60c
# urgency_score                                              0.13581
# role                                                          user
# Name: 9, dtype: object
# <User(user_id='88461f45-18ea-41de-9136-0a2e7c59d60c', user_name='William Hernandez', external_user_id='b0cef0')>
# status                                                        open
# content          Hello, I am trying to make a reservation, but ...
# owner_id                                                    627c92
# owner_name                                          Isabella Lopez
# channel                                                     social
# tags                                  reservation, login, benefits
# account_id                    1445d9f8-c5d8-4d7a-a7fe-f989540f2069
# urgency_score                                             0.951518
# role                                                          user
# Name: 10, dtype: object
# <User(user_id='1445d9f8-c5d8-4d7a-a7fe-f989540f2069', user_name='Isabella Lopez', external_user_id='627c92')>
# status                                                        open
# content          Hi, I forgot my password and am unable to acce...
# owner_id                                                    130a1c
# owner_name                                          Lucas Gonzalez
# channel                                                        sms
# tags                                                      password
# account_id                    d246bceb-268d-496a-9710-e5f4e8ecb1a6
# urgency_score                                             0.988945
# role                                                          user
# Name: 11, dtype: object
# <User(user_id='d246bceb-268d-496a-9710-e5f4e8ecb1a6', user_name='Lucas Gonzalez', external_user_id='130a1c')>
# status                                                        open
# content          Hello, I am having trouble accessing my accoun...
# owner_id                                                    79bc59
# owner_name                                               Mia Perez
# channel                                                      email
# tags                                      password, access, events
# account_id                    16d6cd19-9151-4423-9fc3-08e308bf645f
# urgency_score                                             0.121298
# role                                                          user
# Name: 12, dtype: object
# <User(user_id='16d6cd19-9151-4423-9fc3-08e308bf645f', user_name='Mia Perez', external_user_id='79bc59')>
# status                                                        open
# content          Hi, I am trying to book a session, but I am ha...
# owner_id                                                    2567ff
# owner_name                                             Ethan White
# channel                                                        web
# tags                                               access, booking
# account_id                    3d5297e8-bb62-4cdf-87ff-cfe260b96565
# urgency_score                                             0.683029
# role                                                          user
# Name: 13, dtype: object
# <User(user_id='3d5297e8-bb62-4cdf-87ff-cfe260b96565', user_name='Ethan White', external_user_id='2567ff')>
# status                                                        open
# content          Hello, I would like to escalate an issue regar...
# owner_id                                                    537d6b
# owner_name                                      Charlotte Thompson
# channel                                                       chat
# tags                             escalation, subscription, booking
# account_id                    dd3e8873-4a1a-407c-b1a0-df8157fb0102
# urgency_score                                             0.648258
# role                                                          user
# Name: 14, dtype: object
# <User(user_id='dd3e8873-4a1a-407c-b1a0-df8157fb0102', user_name='Charlotte Thompson', external_user_id='537d6b')>
# status                                                        open
# content          Hi, I need to escalate an issue regarding my a...
# owner_id                                                    93733d
# owner_name                                         Amelia Anderson
# channel                                                      phone
# tags                                             escalation, pause
# account_id                    aa2375f0-da24-48a2-8477-190ffe9d03af
# urgency_score                                             0.852557
# role                                                          user
# Name: 15, dtype: object
# <User(user_id='aa2375f0-da24-48a2-8477-190ffe9d03af', user_name='Amelia Anderson', external_user_id='93733d')>
# status                                                        open
# content          Hello, I am interested in subscribing to your ...
# owner_id                                                    6e11c3
# owner_name                                         Benjamin Thomas
# channel                                                     social
# tags                               subscription, benefits, billing
# account_id                    1e34fef3-95c2-43ee-a9dd-49ebea7f4270
# urgency_score                                             0.589932
# role                                                          user
# Name: 16, dtype: object
# <User(user_id='1e34fef3-95c2-43ee-a9dd-49ebea7f4270', user_name='Benjamin Thomas', external_user_id='6e11c3')>
# status                                                        open
# content          Hi, I would like to know more about the benefi...
# owner_id                                                    8ce159
# owner_name                                          Harper Jackson
# channel                                                        sms
# tags                                                      benefits
# account_id                    ea5f991a-9b0d-4231-9f5d-e6a9e96a529f
# urgency_score                                              0.65314
# role                                                          user
# Name: 17, dtype: object
# <User(user_id='ea5f991a-9b0d-4231-9f5d-e6a9e96a529f', user_name='Harper Jackson', external_user_id='8ce159')>
# status                                                        open
# content          Hello, I need to cancel my subscription as I a...
# owner_id                                                    e39b9e
# owner_name                                              Elijah Lee
# channel                                                      email
# tags                                                   cancelation
# account_id                    5e4da015-4f37-43d6-87a0-dea542953dbe
# urgency_score                                             0.566834
# role                                                          user
# Name: 18, dtype: object
# <User(user_id='5e4da015-4f37-43d6-87a0-dea542953dbe', user_name='Elijah Lee', external_user_id='e39b9e')>
# status                                                        open
# content          Hi, I have a billing query regarding my last i...
# owner_id                                                    a4ab87
# owner_name                                          Alice Kingsley
# channel                                                        web
# tags                                                       billing
# account_id                    227d464d-d29a-45ba-be2a-55b67b9a71d4
# urgency_score                                             0.696232
# role                                                          user
# Name: 19, dtype: object
# <User(user_id='227d464d-d29a-45ba-be2a-55b67b9a71d4', user_name='Alice Kingsley', external_user_id='a4ab87')>
# status                                                        open
# content          Hello, I need to pause my subscription tempora...
# owner_id                                                    f556c0
# owner_name                                               Bob Stone
# channel                                                       chat
# tags                                                         pause
# account_id                    60568a02-bd4c-4fc5-a1e4-992e0e87e1fe
# urgency_score                                             0.046485
# role                                                          user
# Name: 20, dtype: object
# <User(user_id='60568a02-bd4c-4fc5-a1e4-992e0e87e1fe', user_name='Bob Stone', external_user_id='f556c0')>
# status                                                        open
# content          Hi, I am having trouble logging into my accoun...
# owner_id                                                    88382b
# owner_name                                             Cathy Bloom
# channel                                                      phone
# tags                                                         login
# account_id                    66f15ea6-da81-46f3-afb0-7c563e648949
# urgency_score                                              0.38053
# role                                                          user
# Name: 21, dtype: object
# <User(user_id='66f15ea6-da81-46f3-afb0-7c563e648949', user_name='Cathy Bloom', external_user_id='88382b')>
# status                                                        open
# content          Hello, I have a billing query regarding my las...
# owner_id                                                    888fb2
# owner_name                                              David Noir
# channel                                                     social
# tags                                                billing, pause
# account_id                    571c686f-d98d-4914-9f3c-f3ab8c7316da
# urgency_score                                             0.126689
# role                                                          user
# Name: 22, dtype: object
# <User(user_id='571c686f-d98d-4914-9f3c-f3ab8c7316da', user_name='David Noir', external_user_id='888fb2')>
# status                                                        open
# content          Hi, I am interested in the pricing details for...
# owner_id                                                    f1f10d
# owner_name                                               Eva Green
# channel                                                        sms
# tags                                  pricing, escalation, billing
# account_id                    dc3685f0-11cb-4a75-9d82-6a2ea65086b4
# urgency_score                                              0.85527
# role                                                          user
# Name: 23, dtype: object
# <User(user_id='dc3685f0-11cb-4a75-9d82-6a2ea65086b4', user_name='Eva Green', external_user_id='f1f10d')>
# status                                                        open
# content          Hello, I forgot my password and am unable to a...
# owner_id                                                    e6376d
# owner_name                                             Frank Ocean
# channel                                                      email
# tags                                              password, events
# account_id                    90635f90-d290-4948-9c52-3e56932d2de9
# urgency_score                                              0.10744
# role                                                          user
# Name: 24, dtype: object
# <User(user_id='90635f90-d290-4948-9c52-3e56932d2de9', user_name='Frank Ocean', external_user_id='e6376d')>
# status                                                        open
# content          Hi, I am trying to make a reservation, but I a...
# owner_id                                                    b79e00
# owner_name                                           Alice Johnson
# channel                                                        web
# tags                                          reservation, billing
# account_id                    32113a40-34df-4cbc-9024-25be5898048b
# urgency_score                                             0.462366
# role                                                          user
# Name: 25, dtype: object
# <User(user_id='32113a40-34df-4cbc-9024-25be5898048b', user_name='Alice Johnson', external_user_id='b79e00')>
# status                                                        open
# content          Hello, I need to pause my subscription tempora...
# owner_id                                                    646d4a
# owner_name                                           Michael Smith
# channel                                                       chat
# tags                                             pause, escalation
# account_id                    8275c78b-36d2-4f0c-aac8-302b3c336d6d
# urgency_score                                             0.516997
# role                                                          user
# Name: 26, dtype: object
# <User(user_id='8275c78b-36d2-4f0c-aac8-302b3c336d6d', user_name='Michael Smith', external_user_id='646d4a')>
# status                                                        open
# content          Hi, I need to pause my subscription temporaril...
# owner_id                                                    ca1575
# owner_name                                            Sophia Brown
# channel                                                      phone
# tags                                                         pause
# account_id                    1056a2b6-7951-47ce-8221-d4212ccd5007
# urgency_score                                             0.475801
# role                                                          user
# Name: 27, dtype: object
# <User(user_id='1056a2b6-7951-47ce-8221-d4212ccd5007', user_name='Sophia Brown', external_user_id='ca1575')>
# status                                                        open
# content          Hello, I need to escalate an issue regarding m...
# owner_id                                                    f74ec5
# owner_name                                            James Wilson
# channel                                                     social
# tags                                       escalation, cancelation
# account_id                    e19f67b9-c1b6-40fb-b81b-f71e79fcdbc0
# urgency_score                                             0.109533
# role                                                          user
# Name: 28, dtype: object
# <User(user_id='e19f67b9-c1b6-40fb-b81b-f71e79fcdbc0', user_name='James Wilson', external_user_id='f74ec5')>
# status                                                        open
# content          Hi, I am having trouble logging into my accoun...
# owner_id                                                    9caffd
# owner_name                                         Olivia Martinez
# channel                                                        sms
# tags                                             login, escalation
# account_id                    7d8d38be-2a24-4d6e-81f3-83fb8c20bc94
# urgency_score                                             0.326561
# role                                                          user
# Name: 29, dtype: object
# <User(user_id='7d8d38be-2a24-4d6e-81f3-83fb8c20bc94', user_name='Olivia Martinez', external_user_id='9caffd')>
# status                                                        open
# content          Hello, I am interested in booking a session fo...
# owner_id                                                    fe4bdc
# owner_name                                              Liam Davis
# channel                                                      email
# tags                                              booking, billing
# account_id                    009f1601-9011-4b70-afc3-47f22427c7d2
# urgency_score                                             0.126528
# role                                                          user
# Name: 30, dtype: object
# <User(user_id='009f1601-9011-4b70-afc3-47f22427c7d2', user_name='Liam Davis', external_user_id='fe4bdc')>
# status                                                        open
# content          Hi, I need to escalate an issue regarding my a...
# owner_id                                                    b64567
# owner_name                                             Emma Garcia
# channel                                                        web
# tags                                            escalation, access
# account_id                    cedd8b50-27c3-42b9-9640-ef4caaac34a1
# urgency_score                                             0.871381
# role                                                          user
# Name: 31, dtype: object
# <User(user_id='cedd8b50-27c3-42b9-9640-ef4caaac34a1', user_name='Emma Garcia', external_user_id='b64567')>
# status                                                        open
# content          Hello, I would like to make a reservation for ...
# owner_id                                                    540bd1
# owner_name                                           Noah Martinez
# channel                                                       chat
# tags                                                   reservation
# account_id                    8e6d45fc-1adc-4fa9-b7ac-538a05087118
# urgency_score                                             0.581032
# role                                                          user
# Name: 32, dtype: object
# <User(user_id='8e6d45fc-1adc-4fa9-b7ac-538a05087118', user_name='Noah Martinez', external_user_id='540bd1')>
# status                                                        open
# content          Hi, I am interested in the pricing details for...
# owner_id                                                    e3ac40
# owner_name                                           Ava Rodriguez
# channel                                                      phone
# tags                                                pricing, login
# account_id                    527cd545-a615-4087-883f-b8d6e5302fc8
# urgency_score                                             0.962767
# role                                                          user
# Name: 33, dtype: object
# <User(user_id='527cd545-a615-4087-883f-b8d6e5302fc8', user_name='Ava Rodriguez', external_user_id='e3ac40')>
# status                                                        open
# content          Hello, I have a billing query regarding my las...
# owner_id                                                    b0cef0
# owner_name                                       William Hernandez
# channel                                                     social
# tags                                                       billing
# account_id                    88461f45-18ea-41de-9136-0a2e7c59d60c
# urgency_score                                             0.916671
# role                                                          user
# Name: 34, dtype: object
# <User(user_id='88461f45-18ea-41de-9136-0a2e7c59d60c', user_name='William Hernandez', external_user_id='b0cef0')>
# status                                                        open
# content          Hi, I am trying to make a reservation, but I a...
# owner_id                                                    627c92
# owner_name                                          Isabella Lopez
# channel                                                        sms
# tags                                           reservation, access
# account_id                    1445d9f8-c5d8-4d7a-a7fe-f989540f2069
# urgency_score                                              0.94865
# role                                                          user
# Name: 35, dtype: object
# <User(user_id='1445d9f8-c5d8-4d7a-a7fe-f989540f2069', user_name='Isabella Lopez', external_user_id='627c92')>
# status                                                        open
# content          Hello, I am interested in subscribing to your ...
# owner_id                                                    130a1c
# owner_name                                          Lucas Gonzalez
# channel                                                      email
# tags                                         subscription, booking
# account_id                    d246bceb-268d-496a-9710-e5f4e8ecb1a6
# urgency_score                                             0.674408
# role                                                          user
# Name: 36, dtype: object
# <User(user_id='d246bceb-268d-496a-9710-e5f4e8ecb1a6', user_name='Lucas Gonzalez', external_user_id='130a1c')>
# status                                                        open
# content          Hi, I need to cancel my subscription as I am n...
# owner_id                                                    79bc59
# owner_name                                               Mia Perez
# channel                                                        web
# tags                                         cancelation, benefits
# account_id                    16d6cd19-9151-4423-9fc3-08e308bf645f
# urgency_score                                             0.830423
# role                                                          user
# Name: 37, dtype: object
# <User(user_id='16d6cd19-9151-4423-9fc3-08e308bf645f', user_name='Mia Perez', external_user_id='79bc59')>
# status                                                        open
# content          Hello, I would like to know more about the ben...
# owner_id                                                    2567ff
# owner_name                                             Ethan White
# channel                                                       chat
# tags                                              benefits, events
# account_id                    3d5297e8-bb62-4cdf-87ff-cfe260b96565
# urgency_score                                             0.147246
# role                                                          user
# Name: 38, dtype: object
# <User(user_id='3d5297e8-bb62-4cdf-87ff-cfe260b96565', user_name='Ethan White', external_user_id='2567ff')>
# status                                                        open
# content          Hi, I forgot my password and am unable to acce...
# owner_id                                                    537d6b
# owner_name                                      Charlotte Thompson
# channel                                                      phone
# tags                                             password, billing
# account_id                    dd3e8873-4a1a-407c-b1a0-df8157fb0102
# urgency_score                                               0.8231
# role                                                          user
# Name: 39, dtype: object
# <User(user_id='dd3e8873-4a1a-407c-b1a0-df8157fb0102', user_name='Charlotte Thompson', external_user_id='537d6b')>
# status                                                        open
# content          Hello, I have a billing query regarding my las...
# owner_id                                                    93733d
# owner_name                                         Amelia Anderson
# channel                                                     social
# tags                                              billing, dietary
# account_id                    aa2375f0-da24-48a2-8477-190ffe9d03af
# urgency_score                                             0.864251
# role                                                          user
# Name: 40, dtype: object
# <User(user_id='aa2375f0-da24-48a2-8477-190ffe9d03af', user_name='Amelia Anderson', external_user_id='93733d')>
# status                                                        open
# content          Hi, I am interested in the dietary options ava...
# owner_id                                                    6e11c3
# owner_name                                         Benjamin Thomas
# channel                                                        sms
# tags                                                       dietary
# account_id                    1e34fef3-95c2-43ee-a9dd-49ebea7f4270
# urgency_score                                             0.464706
# role                                                          user
# Name: 41, dtype: object
# <User(user_id='1e34fef3-95c2-43ee-a9dd-49ebea7f4270', user_name='Benjamin Thomas', external_user_id='6e11c3')>
# status                                                        open
# content          Hello, I am seeking health advice regarding my...
# owner_id                                                    8ce159
# owner_name                                          Harper Jackson
# channel                                                      email
# tags                                                 health advice
# account_id                    ea5f991a-9b0d-4231-9f5d-e6a9e96a529f
# urgency_score                                              0.31681
# role                                                          user
# Name: 42, dtype: object
# <User(user_id='ea5f991a-9b0d-4231-9f5d-e6a9e96a529f', user_name='Harper Jackson', external_user_id='8ce159')>
# status                                                        open
# content          Hi, I am having trouble logging into my accoun...
# owner_id                                                    e39b9e
# owner_name                                              Elijah Lee
# channel                                                        web
# tags                                                login, pricing
# account_id                    5e4da015-4f37-43d6-87a0-dea542953dbe
# urgency_score                                             0.654347
# role                                                          user
# Name: 43, dtype: object
# <User(user_id='5e4da015-4f37-43d6-87a0-dea542953dbe', user_name='Elijah Lee', external_user_id='e39b9e')>
# status                                                        open
# content          Hello, I am interested in the pricing details ...
# owner_id                                                    a4ab87
# owner_name                                          Alice Kingsley
# channel                                                       chat
# tags                                              pricing, dietary
# account_id                    227d464d-d29a-45ba-be2a-55b67b9a71d4
# urgency_score                                             0.642695
# role                                                          user
# Name: 44, dtype: object
# <User(user_id='227d464d-d29a-45ba-be2a-55b67b9a71d4', user_name='Alice Kingsley', external_user_id='a4ab87')>
# status                                                        open
# content          Hi, I am interested in the dietary options ava...
# owner_id                                                    f556c0
# owner_name                                               Bob Stone
# channel                                                      phone
# tags                                                       dietary
# account_id                    60568a02-bd4c-4fc5-a1e4-992e0e87e1fe
# urgency_score                                             0.983696
# role                                                          user
# Name: 45, dtype: object
# <User(user_id='60568a02-bd4c-4fc5-a1e4-992e0e87e1fe', user_name='Bob Stone', external_user_id='f556c0')>
# status                                                        open
# content          Hello, I have a billing query regarding my las...
# owner_id                                                    88382b
# owner_name                                             Cathy Bloom
# channel                                                     social
# tags                                        billing, health advice
# account_id                    66f15ea6-da81-46f3-afb0-7c563e648949
# urgency_score                                             0.982974
# role                                                          user
# Name: 46, dtype: object
# <User(user_id='66f15ea6-da81-46f3-afb0-7c563e648949', user_name='Cathy Bloom', external_user_id='88382b')>
# status                                                        open
# content          Hi, I am having trouble accessing my account. ...
# owner_id                                                    888fb2
# owner_name                                              David Noir
# channel                                                        sms
# tags                                               access, pricing
# account_id                    571c686f-d98d-4914-9f3c-f3ab8c7316da
# urgency_score                                             0.771125
# role                                                          user
# Name: 47, dtype: object
# <User(user_id='571c686f-d98d-4914-9f3c-f3ab8c7316da', user_name='David Noir', external_user_id='888fb2')>
# status                                                        open
# content          Hello, I am interested in attending the upcomi...
# owner_id                                                    f1f10d
# owner_name                                               Eva Green
# channel                                                      email
# tags                                               events, dietary
# account_id                    dc3685f0-11cb-4a75-9d82-6a2ea65086b4
# urgency_score                                             0.089928
# role                                                          user
# Name: 48, dtype: object
# <User(user_id='dc3685f0-11cb-4a75-9d82-6a2ea65086b4', user_name='Eva Green', external_user_id='f1f10d')>
# status                                                        open
# content          Hi, I am interested in the dietary options ava...
# owner_id                                                    e6376d
# owner_name                                             Frank Ocean
# channel                                                        web
# tags                                                       dietary
# account_id                    90635f90-d290-4948-9c52-3e56932d2de9
# urgency_score                                             0.547584
# role                                                          user
# Name: 49, dtype: object
# <User(user_id='90635f90-d290-4948-9c52-3e56932d2de9', user_name='Frank Ocean', external_user_id='e6376d')>

# %% [markdown]
# # Tests

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    print(account)
# Out:
# <Account(account_id='cultpass', account_name='CultPass Card')>

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    for article in account.knowledge_articles:
        print(article)
# Out:
# <Knowledge(article_id='2e521418-b3e2-4c4e-b8ac-5a967f9ed2e5', title='How to Reserve a Spot for an Event')>
# <Knowledge(article_id='895e5d17-1f98-4ac6-9900-807d01c7da36', title='What's Included in a CultPass Subscription')>
# <Knowledge(article_id='11d03f79-641b-44ee-b06f-18cfdef07faf', title='How to Cancel or Pause a Subscription')>
# <Knowledge(article_id='8df95dfa-950f-4204-8a2d-431dd6588256', title='How to Handle Login Issues?')>

# %%
with get_session(engine) as session:
    users = session.query(udahub.User).all()
    for user in users:
        # Get all column names for this model
        inst = inspect(user)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(user, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'user_id': '32113a40-34df-4cbc-9024-25be5898048b', 'account_id': 'cultpass', 'external_user_id': 'b79e00', 'user_name': 'Alice Johnson', 'is_blocked': False, 'email_address': 'alice.johnson@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '8275c78b-36d2-4f0c-aac8-302b3c336d6d', 'account_id': 'cultpass', 'external_user_id': '646d4a', 'user_name': 'Michael Smith', 'is_blocked': True, 'email_address': 'michael.smith@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '1056a2b6-7951-47ce-8221-d4212ccd5007', 'account_id': 'cultpass', 'external_user_id': 'ca1575', 'user_name': 'Sophia Brown', 'is_blocked': False, 'email_address': 'sophia.brown@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': 'e19f67b9-c1b6-40fb-b81b-f71e79fcdbc0', 'account_id': 'cultpass', 'external_user_id': 'f74ec5', 'user_name': 'James Wilson', 'is_blocked': True, 'email_address': 'james.wilson@ecospherenterprises.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '7d8d38be-2a24-4d6e-81f3-83fb8c20bc94', 'account_id': 'cultpass', 'external_user_id': '9caffd', 'user_name': 'Olivia Martinez', 'is_blocked': False, 'email_address': 'olivia.martinez@ecospherenterprises.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '009f1601-9011-4b70-afc3-47f22427c7d2', 'account_id': 'cultpass', 'external_user_id': 'fe4bdc', 'user_name': 'Liam Davis', 'is_blocked': True, 'email_address': 'liam.davis@quantumleapdynamics.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': 'cedd8b50-27c3-42b9-9640-ef4caaac34a1', 'account_id': 'cultpass', 'external_user_id': 'b64567', 'user_name': 'Emma Garcia', 'is_blocked': False, 'email_address': 'emma.garcia@greenwavetechnologies.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '8e6d45fc-1adc-4fa9-b7ac-538a05087118', 'account_id': 'cultpass', 'external_user_id': '540bd1', 'user_name': 'Noah Martinez', 'is_blocked': True, 'email_address': 'noah.martinez@greenwavetechnologies.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '527cd545-a615-4087-883f-b8d6e5302fc8', 'account_id': 'cultpass', 'external_user_id': 'e3ac40', 'user_name': 'Ava Rodriguez', 'is_blocked': False, 'email_address': 'ava.rodriguez@skylineventures.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '88461f45-18ea-41de-9136-0a2e7c59d60c', 'account_id': 'cultpass', 'external_user_id': 'b0cef0', 'user_name': 'William Hernandez', 'is_blocked': True, 'email_address': 'william.hernandez@apexinnovations.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '1445d9f8-c5d8-4d7a-a7fe-f989540f2069', 'account_id': 'cultpass', 'external_user_id': '627c92', 'user_name': 'Isabella Lopez', 'is_blocked': False, 'email_address': 'isabella.lopez@apexinnovations.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': 'd246bceb-268d-496a-9710-e5f4e8ecb1a6', 'account_id': 'cultpass', 'external_user_id': '130a1c', 'user_name': 'Lucas Gonzalez', 'is_blocked': True, 'email_address': 'lucas.gonzalez@bluehorizonindustries.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '16d6cd19-9151-4423-9fc3-08e308bf645f', 'account_id': 'cultpass', 'external_user_id': '79bc59', 'user_name': 'Mia Perez', 'is_blocked': False, 'email_address': 'mia.perez@pinnaclepathways.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '3d5297e8-bb62-4cdf-87ff-cfe260b96565', 'account_id': 'cultpass', 'external_user_id': '2567ff', 'user_name': 'Ethan White', 'is_blocked': True, 'email_address': 'ethan.white@synergysystemsgroup.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': 'dd3e8873-4a1a-407c-b1a0-df8157fb0102', 'account_id': 'cultpass', 'external_user_id': '537d6b', 'user_name': 'Charlotte Thompson', 'is_blocked': False, 'email_address': 'charlotte.thompson@synergysystemsgroup.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': 'aa2375f0-da24-48a2-8477-190ffe9d03af', 'account_id': 'cultpass', 'external_user_id': '93733d', 'user_name': 'Amelia Anderson', 'is_blocked': True, 'email_address': 'amelia.anderson@vanguardvisionaries.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '1e34fef3-95c2-43ee-a9dd-49ebea7f4270', 'account_id': 'cultpass', 'external_user_id': '6e11c3', 'user_name': 'Benjamin Thomas', 'is_blocked': False, 'email_address': 'benjamin.thomas@vanguardvisionaries.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': 'ea5f991a-9b0d-4231-9f5d-e6a9e96a529f', 'account_id': 'cultpass', 'external_user_id': '8ce159', 'user_name': 'Harper Jackson', 'is_blocked': True, 'email_address': 'harper.jackson@vanguardvisionaries.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '5e4da015-4f37-43d6-87a0-dea542953dbe', 'account_id': 'cultpass', 'external_user_id': 'e39b9e', 'user_name': 'Elijah Lee', 'is_blocked': False, 'email_address': 'elijah.lee@vanguardvisionaries.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '227d464d-d29a-45ba-be2a-55b67b9a71d4', 'account_id': 'cultpass', 'external_user_id': 'a4ab87', 'user_name': 'Alice Kingsley', 'is_blocked': True, 'email_address': 'alice.kingsley@wonderland.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '60568a02-bd4c-4fc5-a1e4-992e0e87e1fe', 'account_id': 'cultpass', 'external_user_id': 'f556c0', 'user_name': 'Bob Stone', 'is_blocked': False, 'email_address': 'bob.stone@granite.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '66f15ea6-da81-46f3-afb0-7c563e648949', 'account_id': 'cultpass', 'external_user_id': '88382b', 'user_name': 'Cathy Bloom', 'is_blocked': False, 'email_address': 'cathy.bloom@florals.org', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '571c686f-d98d-4914-9f3c-f3ab8c7316da', 'account_id': 'cultpass', 'external_user_id': '888fb2', 'user_name': 'David Noir', 'is_blocked': True, 'email_address': 'david.noir@shadowmail.com', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': 'dc3685f0-11cb-4a75-9d82-6a2ea65086b4', 'account_id': 'cultpass', 'external_user_id': 'f1f10d', 'user_name': 'Eva Green', 'is_blocked': False, 'email_address': 'eva.green@ecosoul.net', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'user_id': '90635f90-d290-4948-9c52-3e56932d2de9', 'account_id': 'cultpass', 'external_user_id': 'e6376d', 'user_name': 'Frank Ocean', 'is_blocked': False, 'email_address': 'frank.ocean@seawaves.io', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}

# %%
with get_session(engine) as session:
    tickets = session.query(udahub.Ticket).all()
    for ticket in tickets:
        # Get all column names for this model
        inst = inspect(ticket)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(ticket, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'ticket_id': 'dbd204e7-1d45-4e7d-9119-ece3b76540d3', 'account_id': 'cultpass', 'user_id': '32113a40-34df-4cbc-9024-25be5898048b', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'a801a91e-87a7-4b1a-83ac-2e33c13ffb66', 'account_id': 'cultpass', 'user_id': '8275c78b-36d2-4f0c-aac8-302b3c336d6d', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'ad417186-a413-43f2-8a1c-066277badf04', 'account_id': 'cultpass', 'user_id': '1056a2b6-7951-47ce-8221-d4212ccd5007', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '0bb0011b-bb17-4992-a50a-501cc3f51e7a', 'account_id': 'cultpass', 'user_id': 'e19f67b9-c1b6-40fb-b81b-f71e79fcdbc0', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'e51c6d71-c6b7-424f-905f-8ebcbc63a97e', 'account_id': 'cultpass', 'user_id': '7d8d38be-2a24-4d6e-81f3-83fb8c20bc94', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'abcf6f17-eed2-4b71-8128-cc3f06d982ce', 'account_id': 'cultpass', 'user_id': '009f1601-9011-4b70-afc3-47f22427c7d2', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '4a6a193d-4e9b-4d4d-b19a-f0dbff31d734', 'account_id': 'cultpass', 'user_id': 'cedd8b50-27c3-42b9-9640-ef4caaac34a1', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '22d3836f-70c7-4d3e-833f-914dd1bc7a4d', 'account_id': 'cultpass', 'user_id': '8e6d45fc-1adc-4fa9-b7ac-538a05087118', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '1d24c166-c471-4528-b464-6d5fdef1eefd', 'account_id': 'cultpass', 'user_id': '527cd545-a615-4087-883f-b8d6e5302fc8', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '1982de5f-9443-4527-9eaa-12c2b6e41d8d', 'account_id': 'cultpass', 'user_id': '88461f45-18ea-41de-9136-0a2e7c59d60c', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '1f632a17-7cb3-4c2e-a421-631d5e785d78', 'account_id': 'cultpass', 'user_id': '1445d9f8-c5d8-4d7a-a7fe-f989540f2069', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'c78a1435-54c9-468b-a8a8-63f594918d9c', 'account_id': 'cultpass', 'user_id': 'd246bceb-268d-496a-9710-e5f4e8ecb1a6', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'd459f3f8-611c-4f88-97ec-750744a315dd', 'account_id': 'cultpass', 'user_id': '16d6cd19-9151-4423-9fc3-08e308bf645f', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '8e55b3d7-9f58-43c4-bee6-c77c866ba1f9', 'account_id': 'cultpass', 'user_id': '3d5297e8-bb62-4cdf-87ff-cfe260b96565', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '0417f75c-78ef-4b99-aed1-5eb0a5555e81', 'account_id': 'cultpass', 'user_id': 'dd3e8873-4a1a-407c-b1a0-df8157fb0102', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '5c0bd939-f907-4a07-88b5-0a7f743e9b57', 'account_id': 'cultpass', 'user_id': 'aa2375f0-da24-48a2-8477-190ffe9d03af', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '2aa29ae9-3050-402d-a23d-afd50a7ddb32', 'account_id': 'cultpass', 'user_id': '1e34fef3-95c2-43ee-a9dd-49ebea7f4270', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'bbfe01c3-5f8e-4683-91bb-aa5c621559e4', 'account_id': 'cultpass', 'user_id': 'ea5f991a-9b0d-4231-9f5d-e6a9e96a529f', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'b1f7adbd-7ef4-4ee4-9d3a-ab7ecca33fa3', 'account_id': 'cultpass', 'user_id': '5e4da015-4f37-43d6-87a0-dea542953dbe', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '53d91a0e-e022-4d58-849a-1e0895a286e7', 'account_id': 'cultpass', 'user_id': '227d464d-d29a-45ba-be2a-55b67b9a71d4', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '7b9dab3f-3526-4448-a9f5-05dfe54c53ad', 'account_id': 'cultpass', 'user_id': '60568a02-bd4c-4fc5-a1e4-992e0e87e1fe', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'd82e8fec-5dd7-4461-b30b-64599a476eff', 'account_id': 'cultpass', 'user_id': '66f15ea6-da81-46f3-afb0-7c563e648949', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '22b96cc8-b79c-4e7a-a52a-5e67c0f9350b', 'account_id': 'cultpass', 'user_id': '571c686f-d98d-4914-9f3c-f3ab8c7316da', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'be175e65-ad7d-4a1d-ba0d-2466242f477e', 'account_id': 'cultpass', 'user_id': 'dc3685f0-11cb-4a75-9d82-6a2ea65086b4', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'a3b93bae-bb85-4b62-b763-29eaa64d08bd', 'account_id': 'cultpass', 'user_id': '90635f90-d290-4948-9c52-3e56932d2de9', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '0b7d72f7-4869-4477-a736-0fb526b773dd', 'account_id': 'cultpass', 'user_id': '32113a40-34df-4cbc-9024-25be5898048b', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '2273c9a9-b391-464a-b921-bc01a2f9bc6b', 'account_id': 'cultpass', 'user_id': '8275c78b-36d2-4f0c-aac8-302b3c336d6d', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'bed83b85-b4ce-476c-a253-f3a634f87bf9', 'account_id': 'cultpass', 'user_id': '1056a2b6-7951-47ce-8221-d4212ccd5007', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '1c667af7-73c2-4a37-80c2-a800c829b584', 'account_id': 'cultpass', 'user_id': 'e19f67b9-c1b6-40fb-b81b-f71e79fcdbc0', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'eece1b74-de0a-43f6-8cd2-bcda6d66f0ce', 'account_id': 'cultpass', 'user_id': '7d8d38be-2a24-4d6e-81f3-83fb8c20bc94', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '71020cc1-af98-4222-9abf-8ca57fee4781', 'account_id': 'cultpass', 'user_id': '009f1601-9011-4b70-afc3-47f22427c7d2', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '74dbc5ca-2e08-4bcb-bc17-a584956c802a', 'account_id': 'cultpass', 'user_id': 'cedd8b50-27c3-42b9-9640-ef4caaac34a1', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '73d651eb-68a7-44fa-b18c-3de165726e25', 'account_id': 'cultpass', 'user_id': '8e6d45fc-1adc-4fa9-b7ac-538a05087118', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '5a6d646e-742e-4474-817b-a48f4a907104', 'account_id': 'cultpass', 'user_id': '527cd545-a615-4087-883f-b8d6e5302fc8', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '338f268f-b189-4590-ac62-c5549fe818ce', 'account_id': 'cultpass', 'user_id': '88461f45-18ea-41de-9136-0a2e7c59d60c', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'bff6622f-1393-41bb-8a77-a9764b8ef3cd', 'account_id': 'cultpass', 'user_id': '1445d9f8-c5d8-4d7a-a7fe-f989540f2069', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '001a6588-66db-44ea-be6b-7970f725d3a5', 'account_id': 'cultpass', 'user_id': 'd246bceb-268d-496a-9710-e5f4e8ecb1a6', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'd89680b2-1199-477c-a8ae-d29757a4b8cd', 'account_id': 'cultpass', 'user_id': '16d6cd19-9151-4423-9fc3-08e308bf645f', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '1c3948ee-f061-4f08-b646-ee25d598b07b', 'account_id': 'cultpass', 'user_id': '3d5297e8-bb62-4cdf-87ff-cfe260b96565', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '54b72e50-f5b5-438a-b3e5-fa9ccac36336', 'account_id': 'cultpass', 'user_id': 'dd3e8873-4a1a-407c-b1a0-df8157fb0102', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '5edc25fc-c99c-4375-8dd2-98d6b4f09c68', 'account_id': 'cultpass', 'user_id': 'aa2375f0-da24-48a2-8477-190ffe9d03af', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'aa103a31-52b7-4934-9389-319972ed247b', 'account_id': 'cultpass', 'user_id': '1e34fef3-95c2-43ee-a9dd-49ebea7f4270', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '276240c2-c195-4ae1-a0e9-6a0d2bc1414c', 'account_id': 'cultpass', 'user_id': 'ea5f991a-9b0d-4231-9f5d-e6a9e96a529f', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '24ddf6db-2608-4da6-bd76-062d9598cc33', 'account_id': 'cultpass', 'user_id': '5e4da015-4f37-43d6-87a0-dea542953dbe', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '9c12e873-7f87-43f7-a32e-fb6fe314e9f4', 'account_id': 'cultpass', 'user_id': '227d464d-d29a-45ba-be2a-55b67b9a71d4', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '94b5ac89-a3cf-42a5-a527-548c3c5c9744', 'account_id': 'cultpass', 'user_id': '60568a02-bd4c-4fc5-a1e4-992e0e87e1fe', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'fb13cfa4-8b63-46eb-a744-360aeb34848b', 'account_id': 'cultpass', 'user_id': '66f15ea6-da81-46f3-afb0-7c563e648949', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'c41a8349-1e73-4f22-8eaf-5ce487733fad', 'account_id': 'cultpass', 'user_id': '571c686f-d98d-4914-9f3c-f3ab8c7316da', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '2bbe5087-97bf-454b-b8fb-8df81c356cd7', 'account_id': 'cultpass', 'user_id': 'dc3685f0-11cb-4a75-9d82-6a2ea65086b4', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '57044c9c-f7f5-45bd-8049-40b0a6812b4d', 'account_id': 'cultpass', 'user_id': '90635f90-d290-4948-9c52-3e56932d2de9', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}

# %%
with get_session(engine) as session:
    messages = session.query(udahub.TicketMessage).all()
    for message in messages:
        # Get all column names for this model
        inst = inspect(message)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(message, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'message_id': '9ba7e580-6e21-48f4-ba9f-15ad0031c494', 'ticket_id': 'dbd204e7-1d45-4e7d-9119-ece3b76540d3', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi there, I am having trouble logging into my account. Every time I try to enter my credentials, it says that my password is incorrect. I have tried resetting it multiple times, but the issue persists. Could you please assist me in resolving this issue? Thank you!', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '03b36e01-f7d0-42c1-99d0-f2fbb4b528cd', 'ticket_id': 'a801a91e-87a7-4b1a-83ac-2e33c13ffb66', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to pause my subscription temporarily due to personal reasons. I couldn't find the option on the website. Could you guide me on how to proceed with this?", 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'b0272c36-ff62-4e7f-b7ee-fcc7b433c988', 'ticket_id': 'ad417186-a413-43f2-8a1c-066277badf04', 'role': <RoleEnum.user: 'user'>, 'content': 'Good day, I am writing to inquire about the benefits included in my current plan. I would also like to escalate a previous issue that was not resolved to my satisfaction. Additionally, I am interested in upcoming events that might be relevant to my interests. Could you provide more information?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'a885d48f-609c-4005-8241-5200715fb6c9', 'ticket_id': '0bb0011b-bb17-4992-a50a-501cc3f51e7a', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am trying to make a reservation for an event, but the system keeps logging me out. I also want to know if my subscription covers this event. Can you help me with this?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '26bc30a1-25f5-49d7-af32-48a904bd463b', 'ticket_id': 'e51c6d71-c6b7-424f-905f-8ebcbc63a97e', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I would like to make a reservation for a table at your restaurant for this weekend. Could you confirm the availability and the process to book it?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '52e0ecb5-29e4-4c70-ac06-a4ee8b17edec', 'ticket_id': 'abcf6f17-eed2-4b71-8128-cc3f06d982ce', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to cancel my attendance for the upcoming conference due to unforeseen circumstances. Additionally, I have a billing query regarding the refund process. Could you assist me with these issues?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'a84f4310-5b53-4ad6-bf47-b0e522311753', 'ticket_id': '4a6a193d-4e9b-4d4d-b19a-f0dbff31d734', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am interested in making a reservation for a group event. Could you provide me with the pricing details and any available packages?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '75525e1c-6c9f-4128-899b-59d1bd53cfea', 'ticket_id': '22d3836f-70c7-4d3e-833f-914dd1bc7a4d', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I would like to book a session for next week. However, I might need to pause my current plan temporarily. Also, could you inform me about the benefits included in my package?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '88e94284-8872-4539-8e26-e70ad4419b0e', 'ticket_id': '1d24c166-c471-4528-b464-6d5fdef1eefd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to cancel my subscription as I am no longer using the service. Could you guide me through the cancellation process?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'e6e7c1e6-f5be-430a-95e6-6e3337f573a0', 'ticket_id': '1982de5f-9443-4527-9eaa-12c2b6e41d8d', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am interested in attending the upcoming events. Could you provide me with the schedule and any registration details?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '24dd949d-7bce-4011-8469-0c9dfc7a8031', 'ticket_id': '1f632a17-7cb3-4c2e-a421-631d5e785d78', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am trying to make a reservation, but the system keeps logging me out. Additionally, I would like to know more about the benefits included in my plan. Could you assist me with these issues?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '84bcdd7a-2852-4067-9d45-dcfac6b63375', 'ticket_id': 'c78a1435-54c9-468b-a8a8-63f594918d9c', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I forgot my password and am unable to access my account. Could you help me reset it?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'a17892cf-1efd-40fa-a3cb-a8b5daae6a4f', 'ticket_id': 'd459f3f8-611c-4f88-97ec-750744a315dd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble accessing my account. I also forgot my password and need assistance with resetting it. Additionally, I am interested in upcoming events. Could you provide more information?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'b65a4e78-10b8-4d01-91ee-f074c3cc15b7', 'ticket_id': '8e55b3d7-9f58-43c4-bee6-c77c866ba1f9', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am trying to book a session, but I am having trouble accessing the booking page. Could you assist me with this issue?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'f0e8fe63-7159-43f7-82ff-7da89c3942e8', 'ticket_id': '0417f75c-78ef-4b99-aed1-5eb0a5555e81', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I would like to escalate an issue regarding my subscription. Additionally, I am interested in booking a session for next week. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'f333eca2-189f-4391-95dd-0230a200f15d', 'ticket_id': '5c0bd939-f907-4a07-88b5-0a7f743e9b57', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to escalate an issue regarding my account. Additionally, I would like to pause my current plan temporarily. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '040d002d-5923-4fbf-b177-ee770fe63b8f', 'ticket_id': '2aa29ae9-3050-402d-a23d-afd50a7ddb32', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am interested in subscribing to your service. Could you provide me with information about the benefits included in the subscription and the billing process?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '15d2a963-9ae4-46f9-9e39-d1750493639a', 'ticket_id': 'bbfe01c3-5f8e-4683-91bb-aa5c621559e4', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I would like to know more about the benefits included in my current plan. Could you provide me with detailed information?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '45a65e06-781c-456c-9d9d-0de1a650d162', 'ticket_id': 'b1f7adbd-7ef4-4ee4-9d3a-ab7ecca33fa3', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to cancel my subscription as I am no longer using the service. Could you guide me through the cancellation process?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '66bb905c-562c-49eb-b73d-c4a26c272976', 'ticket_id': '53d91a0e-e022-4d58-849a-1e0895a286e7', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I have a billing query regarding my last invoice. Could you provide me with a detailed breakdown of the charges?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'c623f80f-1f96-4747-b8d8-23972b667973', 'ticket_id': '7b9dab3f-3526-4448-a9f5-05dfe54c53ad', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to pause my subscription temporarily due to personal reasons. Could you guide me on how to proceed with this?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '73b7ef17-6554-4ae4-8fce-fdb4c13a1c06', 'ticket_id': 'd82e8fec-5dd7-4461-b30b-64599a476eff', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am having trouble logging into my account. Could you assist me with resetting my password?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'd23d4656-7083-4e93-a15e-86b84680a04a', 'ticket_id': '22b96cc8-b79c-4e7a-a52a-5e67c0f9350b', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a billing query regarding my last invoice. Additionally, I would like to pause my current plan temporarily. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '45bdbdc8-e884-4376-b19f-f0f5648883bf', 'ticket_id': 'be175e65-ad7d-4a1d-ba0d-2466242f477e', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am interested in the pricing details for your services. Additionally, I would like to escalate an issue regarding my last invoice. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '2950dcf1-b48c-4329-9175-2befce954f49', 'ticket_id': 'a3b93bae-bb85-4b62-b763-29eaa64d08bd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I forgot my password and am unable to access my account. Additionally, I am interested in upcoming events. Could you provide more information?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '49167c6d-41b9-4cb0-9d5c-0e0402756a04', 'ticket_id': '0b7d72f7-4869-4477-a736-0fb526b773dd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am trying to make a reservation, but I am having trouble accessing the reservation page. Additionally, I have a billing query regarding my last invoice. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'a58caed1-72cf-4362-973f-feecd59f0a54', 'ticket_id': '2273c9a9-b391-464a-b921-bc01a2f9bc6b', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to pause my subscription temporarily due to personal reasons. Additionally, I would like to escalate an issue regarding my account. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '13c6a613-786c-4170-a7cd-038b297b5d07', 'ticket_id': 'bed83b85-b4ce-476c-a253-f3a634f87bf9', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to pause my subscription temporarily due to personal reasons. Could you guide me on how to proceed with this?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '791dccb7-7495-4fa4-976a-1fb7f61cae86', 'ticket_id': '1c667af7-73c2-4a37-80c2-a800c829b584', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to escalate an issue regarding my account. Additionally, I would like to cancel my subscription as I am no longer using the service. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '8252f2a4-d22d-4244-b7ac-928531b01177', 'ticket_id': 'eece1b74-de0a-43f6-8cd2-bcda6d66f0ce', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am having trouble logging into my account. Additionally, I would like to escalate an issue regarding my last invoice. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '830b25c4-3a7f-4dae-a6ee-68f636fc650f', 'ticket_id': '71020cc1-af98-4222-9abf-8ca57fee4781', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am interested in booking a session for next week. Additionally, I have a billing query regarding my last invoice. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '2f8126d2-0e33-4072-8e33-0ec78fc4d752', 'ticket_id': '74dbc5ca-2e08-4bcb-bc17-a584956c802a', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to escalate an issue regarding my account. Additionally, I am having trouble accessing my account. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '1221cef2-8f56-4416-9d6f-cdb595a12754', 'ticket_id': '73d651eb-68a7-44fa-b18c-3de165726e25', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I would like to make a reservation for a table at your restaurant for this weekend. Could you confirm the availability and the process to book it?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'a548fcda-4aee-4fac-b6a9-b666d1590373', 'ticket_id': '5a6d646e-742e-4474-817b-a48f4a907104', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am interested in the pricing details for your services. Additionally, I am having trouble logging into my account. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'fff151a3-4bba-44f7-8732-06983bb4e5bb', 'ticket_id': '338f268f-b189-4590-ac62-c5549fe818ce', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a billing query regarding my last invoice. Could you provide me with a detailed breakdown of the charges?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '3cb3bc5a-c6fb-453d-90b8-0141f13be772', 'ticket_id': 'bff6622f-1393-41bb-8a77-a9764b8ef3cd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am trying to make a reservation, but I am having trouble accessing the reservation page. Could you assist me with this issue?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '5a8bea3c-e684-43fc-8f8f-ef7801cd60db', 'ticket_id': '001a6588-66db-44ea-be6b-7970f725d3a5', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am interested in subscribing to your service. Additionally, I would like to book a session for next week. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'e2fb495e-5213-4999-b72c-8c2697532a6b', 'ticket_id': 'd89680b2-1199-477c-a8ae-d29757a4b8cd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to cancel my subscription as I am no longer using the service. Additionally, I would like to know more about the benefits included in my plan. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'd48b737b-d7db-4bd6-8a55-ea239818afac', 'ticket_id': '1c3948ee-f061-4f08-b646-ee25d598b07b', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I would like to know more about the benefits included in my current plan. Additionally, I am interested in upcoming events. Could you provide more information?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'd8f6254d-d192-4418-9fd0-1e2affb23da2', 'ticket_id': '54b72e50-f5b5-438a-b3e5-fa9ccac36336', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I forgot my password and am unable to access my account. Additionally, I have a billing query regarding my last invoice. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '2daaad59-20f7-4201-839b-f0ee99692010', 'ticket_id': '5edc25fc-c99c-4375-8dd2-98d6b4f09c68', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a billing query regarding my last invoice. Additionally, I would like to know more about the dietary options available in your meal plans. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '0e3690ae-7a7e-4811-9a69-e4b4fd276958', 'ticket_id': 'aa103a31-52b7-4934-9389-319972ed247b', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am interested in the dietary options available in your meal plans. Could you provide me with detailed information?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '25062c65-0591-40aa-8157-b9ce1a9ac28b', 'ticket_id': '276240c2-c195-4ae1-a0e9-6a0d2bc1414c', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am seeking health advice regarding my current condition. Could you provide me with guidance on how to proceed?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'd050d5b8-8339-46d5-ae33-08f68c9c9ace', 'ticket_id': '24ddf6db-2608-4da6-bd76-062d9598cc33', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am having trouble logging into my account. Additionally, I am interested in the pricing details for your services. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '7dd1cba6-0c1a-424f-838a-7c95024f623f', 'ticket_id': '9c12e873-7f87-43f7-a32e-fb6fe314e9f4', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am interested in the pricing details for your services. Additionally, I would like to know more about the dietary options available in your meal plans. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '6341eaae-9837-4883-be22-2fe03375cc1e', 'ticket_id': '94b5ac89-a3cf-42a5-a527-548c3c5c9744', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am interested in the dietary options available in your meal plans. Could you provide me with detailed information?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '8d7696a8-fd23-40ad-a4a8-a898dc840fd7', 'ticket_id': 'fb13cfa4-8b63-46eb-a744-360aeb34848b', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a billing query regarding my last invoice. Additionally, I am seeking health advice regarding my current condition. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': 'c534d21c-fe70-45c5-a837-f1b410924b52', 'ticket_id': 'c41a8349-1e73-4f22-8eaf-5ce487733fad', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am having trouble accessing my account. Additionally, I am interested in the pricing details for your services. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '6c92d90e-cf28-4137-a272-f8dc7b0ef9a7', 'ticket_id': '2bbe5087-97bf-454b-b8fb-8df81c356cd7', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am interested in attending the upcoming events. Additionally, I would like to know more about the dietary options available in your meal plans. Could you assist me with these matters?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'message_id': '551c0fc7-38b4-424e-9542-bfd0c5a08c96', 'ticket_id': '57044c9c-f7f5-45bd-8049-40b0a6812b4d', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am interested in the dietary options available in your meal plans. Could you provide me with detailed information?', 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}

# %%
with get_session(engine) as session:
    metas = session.query(udahub.TicketMetadata).all()
    for meta in metas:
        # Get all column names for this model
        inst = inspect(meta)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(meta, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'ticket_id': 'dbd204e7-1d45-4e7d-9119-ece3b76540d3', 'status': 'open', 'main_issue_type': None, 'tags': 'login', 'urgency_score': 0.8148480333847369, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'a801a91e-87a7-4b1a-83ac-2e33c13ffb66', 'status': 'open', 'main_issue_type': None, 'tags': 'pause', 'urgency_score': 0.8723317924164307, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'ad417186-a413-43f2-8a1c-066277badf04', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits, escalation, events', 'urgency_score': 0.6813140383187604, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '0bb0011b-bb17-4992-a50a-501cc3f51e7a', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, login, subscription', 'urgency_score': 0.7650306346680679, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'e51c6d71-c6b7-424f-905f-8ebcbc63a97e', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation', 'urgency_score': 0.21008673098615793, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'abcf6f17-eed2-4b71-8128-cc3f06d982ce', 'status': 'open', 'main_issue_type': None, 'tags': 'cancelation, attendance, billing', 'urgency_score': 0.9571808386535131, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '4a6a193d-4e9b-4d4d-b19a-f0dbff31d734', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, pricing', 'urgency_score': 0.761293922518536, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '22d3836f-70c7-4d3e-833f-914dd1bc7a4d', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, pause, benefits', 'urgency_score': 0.1956338494474843, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '1d24c166-c471-4528-b464-6d5fdef1eefd', 'status': 'open', 'main_issue_type': None, 'tags': 'cancelation', 'urgency_score': 0.32918317756752513, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '1982de5f-9443-4527-9eaa-12c2b6e41d8d', 'status': 'open', 'main_issue_type': None, 'tags': 'events', 'urgency_score': 0.13581015355738757, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '1f632a17-7cb3-4c2e-a421-631d5e785d78', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, login, benefits', 'urgency_score': 0.9515184841499618, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'c78a1435-54c9-468b-a8a8-63f594918d9c', 'status': 'open', 'main_issue_type': None, 'tags': 'password', 'urgency_score': 0.9889446030408745, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'd459f3f8-611c-4f88-97ec-750744a315dd', 'status': 'open', 'main_issue_type': None, 'tags': 'password, access, events', 'urgency_score': 0.12129820030661831, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '8e55b3d7-9f58-43c4-bee6-c77c866ba1f9', 'status': 'open', 'main_issue_type': None, 'tags': 'access, booking', 'urgency_score': 0.6830287508714972, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '0417f75c-78ef-4b99-aed1-5eb0a5555e81', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, subscription, booking', 'urgency_score': 0.6482581564030433, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '5c0bd939-f907-4a07-88b5-0a7f743e9b57', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, pause', 'urgency_score': 0.8525567060827385, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '2aa29ae9-3050-402d-a23d-afd50a7ddb32', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, benefits, billing', 'urgency_score': 0.5899323432490461, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'bbfe01c3-5f8e-4683-91bb-aa5c621559e4', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits', 'urgency_score': 0.6531396891732726, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'b1f7adbd-7ef4-4ee4-9d3a-ab7ecca33fa3', 'status': 'open', 'main_issue_type': None, 'tags': 'cancelation', 'urgency_score': 0.5668336354003474, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '53d91a0e-e022-4d58-849a-1e0895a286e7', 'status': 'open', 'main_issue_type': None, 'tags': 'billing', 'urgency_score': 0.696232438924386, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '7b9dab3f-3526-4448-a9f5-05dfe54c53ad', 'status': 'open', 'main_issue_type': None, 'tags': 'pause', 'urgency_score': 0.046485247089783854, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'd82e8fec-5dd7-4461-b30b-64599a476eff', 'status': 'open', 'main_issue_type': None, 'tags': 'login', 'urgency_score': 0.3805301593719148, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '22b96cc8-b79c-4e7a-a52a-5e67c0f9350b', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, pause', 'urgency_score': 0.12668863249978168, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'be175e65-ad7d-4a1d-ba0d-2466242f477e', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, escalation, billing', 'urgency_score': 0.8552696476828662, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'a3b93bae-bb85-4b62-b763-29eaa64d08bd', 'status': 'open', 'main_issue_type': None, 'tags': 'password, events', 'urgency_score': 0.10744009839036883, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '0b7d72f7-4869-4477-a736-0fb526b773dd', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, billing', 'urgency_score': 0.4623659988113318, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '2273c9a9-b391-464a-b921-bc01a2f9bc6b', 'status': 'open', 'main_issue_type': None, 'tags': 'pause, escalation', 'urgency_score': 0.5169974254706143, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'bed83b85-b4ce-476c-a253-f3a634f87bf9', 'status': 'open', 'main_issue_type': None, 'tags': 'pause', 'urgency_score': 0.4758005139483732, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '1c667af7-73c2-4a37-80c2-a800c829b584', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, cancelation', 'urgency_score': 0.10953273513090445, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'eece1b74-de0a-43f6-8cd2-bcda6d66f0ce', 'status': 'open', 'main_issue_type': None, 'tags': 'login, escalation', 'urgency_score': 0.3265606780962832, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '71020cc1-af98-4222-9abf-8ca57fee4781', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, billing', 'urgency_score': 0.12652770142112113, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '74dbc5ca-2e08-4bcb-bc17-a584956c802a', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, access', 'urgency_score': 0.8713811166935361, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '73d651eb-68a7-44fa-b18c-3de165726e25', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation', 'urgency_score': 0.5810324428609448, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '5a6d646e-742e-4474-817b-a48f4a907104', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, login', 'urgency_score': 0.9627672983301716, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '338f268f-b189-4590-ac62-c5549fe818ce', 'status': 'open', 'main_issue_type': None, 'tags': 'billing', 'urgency_score': 0.9166711177370781, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'bff6622f-1393-41bb-8a77-a9764b8ef3cd', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, access', 'urgency_score': 0.9486497226558895, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '001a6588-66db-44ea-be6b-7970f725d3a5', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, booking', 'urgency_score': 0.6744080343828989, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'd89680b2-1199-477c-a8ae-d29757a4b8cd', 'status': 'open', 'main_issue_type': None, 'tags': 'cancelation, benefits', 'urgency_score': 0.8304232940606021, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '1c3948ee-f061-4f08-b646-ee25d598b07b', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits, events', 'urgency_score': 0.14724552255737577, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '54b72e50-f5b5-438a-b3e5-fa9ccac36336', 'status': 'open', 'main_issue_type': None, 'tags': 'password, billing', 'urgency_score': 0.8231000553577122, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '5edc25fc-c99c-4375-8dd2-98d6b4f09c68', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, dietary', 'urgency_score': 0.8642510572730775, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'aa103a31-52b7-4934-9389-319972ed247b', 'status': 'open', 'main_issue_type': None, 'tags': 'dietary', 'urgency_score': 0.464705597440328, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '276240c2-c195-4ae1-a0e9-6a0d2bc1414c', 'status': 'open', 'main_issue_type': None, 'tags': 'health advice', 'urgency_score': 0.31681042603421017, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '24ddf6db-2608-4da6-bd76-062d9598cc33', 'status': 'open', 'main_issue_type': None, 'tags': 'login, pricing', 'urgency_score': 0.6543468895161967, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '9c12e873-7f87-43f7-a32e-fb6fe314e9f4', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, dietary', 'urgency_score': 0.6426949763690755, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '94b5ac89-a3cf-42a5-a527-548c3c5c9744', 'status': 'open', 'main_issue_type': None, 'tags': 'dietary', 'urgency_score': 0.9836960944922813, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'fb13cfa4-8b63-46eb-a744-360aeb34848b', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, health advice', 'urgency_score': 0.9829742218170832, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': 'c41a8349-1e73-4f22-8eaf-5ce487733fad', 'status': 'open', 'main_issue_type': None, 'tags': 'access, pricing', 'urgency_score': 0.7711250660409628, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '2bbe5087-97bf-454b-b8fb-8df81c356cd7', 'status': 'open', 'main_issue_type': None, 'tags': 'events, dietary', 'urgency_score': 0.08992844391370891, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}
# {'ticket_id': '57044c9c-f7f5-45bd-8049-40b0a6812b4d', 'status': 'open', 'main_issue_type': None, 'tags': 'dietary', 'urgency_score': 0.5475841041408942, 'created_at': datetime.datetime(2026, 4, 16, 17, 11, 19), 'updated_at': datetime.datetime(2026, 4, 16, 17, 11, 19)}

# %%
with get_session(engine) as session:
    user = session.query(udahub.User).filter_by(
        account_id=account_id,
        external_user_id=ticket_table.iloc[2].to_dict()["owner_id"],
    ).first()
    
    ticket:udahub.Ticket = user.tickets[0]
    for message in ticket.messages:
        print(message)
# Out:
# <TicketMessage(message_id='b0272c36-ff62-4e7f-b7ee-fcc7b433c988', role='user', content='Good day, I am writing to inqu...')>
