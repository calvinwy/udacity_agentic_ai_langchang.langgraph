# %%
import json
import uuid
from sqlalchemy import create_engine, inspect
from utils import reset_db, get_session, model_to_dict
from data.models import udahub

# %% [markdown]
# # Udahub Application

# %% [markdown]
# ## Core Database

# %% [markdown]
# **Init DB**

# %%
udahub_db = "data/core/udahub.db"
reset_db(udahub_db)
engine = create_engine(f"sqlite:///{udahub_db}", echo=False)
udahub.Base.metadata.create_all(bind=engine)
# Out:
# 2026-04-18 21:57:11,429 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-18 21:57:11,430 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Recreated data/core/udahub.db with fresh schema

# %% [markdown]
# **Account**

# %%
account_id = "cultpass"
account_name = "CultPass Card"

with get_session(engine) as session:
    account = udahub.Account(
        account_id=account_id,
        account_name=account_name,
    )
    session.add(account)

# %% [markdown]
# ---

# %% [markdown]
# ## Integrations

# %% [markdown]
# **Use LLM to Generate Sample Data**

# %%
import os
import pandas as pd
import random
from dotenv import load_dotenv
from typing import List
from pydantic import BaseModel, Field
from typing import List, Optional, Dict, Any, Literal, TypedDict, Annotated
from langgraph.prebuilt import create_react_agent
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import SystemMessage
from langchain_chroma import Chroma
from langchain_core.documents import Document

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# llm_base_url = "https://openai.vocareum.com/v1"

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0.0,
    # base_url=llm_base_url,
    api_key=OPENAI_API_KEY,
)

embeddings_fn = OpenAIEmbeddings(
    model="text-embedding-3-large",
    # base_url=llm_base_url,
    api_key=OPENAI_API_KEY,
)

# %% [markdown]
# **Data Generation Parameters**

# %%
num_articles = 20
num_account = 10
num_user = 25
num_ticket = 50
num_msg = num_ticket
num_expected_tag_msg = round(num_msg * 0.8)
num_unexpected_tag_msg = num_msg - num_expected_tag_msg
chromadb_directory = "vectorstore"
collection_name = "knowledge_vecotr_store"

# %% [markdown]
# ### Sampling Schema
#
# For LLM to produce the data samples

# %%
class ArticlesSchema(BaseModel):
    title: Annotated[str, Field(description="Title of the article.")]
    content: Annotated[str, Field(description="Content of the article.")]
    tags: Annotated[str, Field(description="Tags of the article")]

class ArticlesListSchema(BaseModel):
    samples: Annotated[List[ArticlesSchema], Field(description="List of CultpassArticles")]

class AccountSamples(BaseModel):
    """Structured response for account table"""
    company_name: List[str] = Field(description="List of first name and last name")

class UsersSchema(BaseModel):
    name: Annotated[str, Field(description="User's name with first and last name.")]
    email: Annotated[str, Field(description="User's email address.")]
    is_blocked: Annotated[bool, Field(description="User's blocking status.")]
    account_id: Annotated[str, Field(description="Company account ID")]

class UsersListSchema(BaseModel):
    samples: Annotated[List[UsersSchema], Field(description="List of users")]

class SingleTicket(BaseModel):
    """Structured response for a ticket"""
    status: Annotated[Literal['open','pending','closed'], Field(description="Status of the ticket")]
    content: Annotated[str, Field(description="The ticket body message content.")]
    owner_id: Annotated[str, Field(description="User ID")]
    owner_name: Annotated[str, Field(description="User's name")]
    channel: Annotated[Literal['email','chat','web','sms','social','phone'], Field(description="Ticket priority")]
    tags: Annotated[str, Field(description="List of tags used for creating this message")]
    account_id: Annotated[str, Field(description="Company account ID")]
    urgency_score: Annotated[float, Field(description="Urgency of the ticket")]

class TicketSamples(BaseModel):
    """Structured response of ticket list"""
    samples: List[SingleTicket]

# %% [markdown]
# ## Loading Default Data
#
# * Knowledge Base
# * Users Data

# %%
# Load Sample Articles
cultpass_articles = []
with open('data/external/cultpass_articles.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_articles.append(json.loads(line))

# Extract Tags from Samples
sample_tags = [ article['tags'].split(', ') for article in cultpass_articles ]
sample_tags = set([ item for subtags in sample_tags for item in subtags ])
sample_tags_str = ", ".join(sample_tags)

# Define Tags with Expected Knowledge and Tags without Expected Knowledge
# (This is for sampling ticket questions "with vs without knowledge to answer" using LLM)
expected_tags = sample_tags
unexpected_tags = ['weather', 'stock price', 'dietary', 'health advice']

# %%
sample_tags
# Out:
# {'access',
#  'attendance',
#  'benefits',
#  'billing',
#  'booking',
#  'cancelation',
#  'escalation',
#  'events',
#  'login',
#  'password',
#  'pause',
#  'pricing',
#  'reservation',
#  'subscription'}

# %%
# Load Users Data
cultpass_users = []
with open('data/external/cultpass_users.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_users.append(json.loads(line))

# %% [markdown]
# #### Generate Knowledge Articles

# %%
# Create Additional Knowledge Articles
num_cultpass_articles = len(cultpass_articles)
num_new_articles = num_articles - num_cultpass_articles
sample_articles_template = """
    You are an helpful expert creating sample of python sample article data based on given examples.  Do not provide any additional description or explanation.
    There is a mock-up project, it has the following description:

    You’ve joined a fast-growing AI startup building the next frontier in customer support automation. Your team is responsible for building UDA-Hub, 
    a Universal Decision Agent designed to plug into existing customer support systems (Zendesk, Intercom, Freshdesk, internal CRMs) and intelligently 
    resolve tickets. You need to generate sample knowledge articles in area including: {sample_tags}.  
    
    The knowledge areas given above will be used as tags for the generated articles.

    The first UDA-Hub customer Cultpass has the following sample articles to be used as knowledge to be used by the system:
    {samples}

    Cultpass is a online travel and leisure platform that provides a subscription-based card for travelers, offering access to airport lounges, travel discounts, 
    and exclusive experiences worldwide. Please create the new articles based on this context and the sample articles provided above.

    Provide {num_articles} more example like above and double check if all articles uses tags from {sample_tags}, if not try again.
    """

sample_articles_prompt = PromptTemplate(
    template = sample_articles_template,
    input_variables = ["samples","num_articles","sample_tags"],
    ).invoke({"samples": cultpass_articles,
              "num_articles": num_new_articles,
              "sample_tags": sample_tags}).to_messages()

new_cultpass_articles = llm.with_structured_output(ArticlesListSchema).invoke(sample_articles_prompt).model_dump()['samples']
cultpass_articles_ls = cultpass_articles + new_cultpass_articles

# Extracting Sample Tags for Each Sample
# new_sample_tags = [ article['tags'].split(', ') for article in cultpass_articles_ls ]
# new_sample_tags = set([ item for subtags in new_sample_tags for item in subtags ])
# new_sample_tags_str = ", ".join(new_sample_tags)

if len(cultpass_articles_ls) < 14:
    raise AssertionError("You should load the articles with at least 14 records")

# %%
cultpass_articles_ls
# Out:
# [{'title': 'How to Reserve a Spot for an Event',
#   'content': 'If a user asks how to reserve an event:\n\n- Guide them to the CultPass app\n- Instruct them to browse the experience catalog and tap \'Reserve\'\n- If it\'s a premium or limited event, check if reservation confirmation is required via email\n- Remind them to arrive at least 15 minutes early with their QR code visible\n\n**Suggested phrasing:**\n"You can reserve an experience by opening the CultPass app, selecting your desired event, and tapping \'Reserve\'. Be sure to arrive 15 minutes early with your QR code ready."',
#   'tags': 'reservation, events, booking, attendance'},
#  {'title': "What's Included in a CultPass Subscription",
#   'content': 'Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."',
#   'tags': 'subscription, benefits, pricing, access'},
#  {'title': 'How to Cancel or Pause a Subscription',
#   'content': 'Users can manage their subscription via the app > \'My Account\' > \'Manage Plan\'.\n\n- Cancel: Effective at the end of the billing cycle\n- Pause: Preserves user data, resumes automatically when reactivated\n- Do NOT offer refunds unless approved by support lead\n\n**Suggested phrasing:**\n"You can cancel or pause your subscription at any time via the \'My Account\' section in the CultPass app. Cancelation takes effect at the end of your billing cycle."',
#   'tags': 'cancelation, pause, subscription, billing'},
#  {'title': 'How to Handle Login Issues?',
#   'content': 'Most login issues are resolved with password reset:\n\n- Ask the user to tap \'Forgot Password\' on the login screen\n- Ensure they are using the correct registered email\n- If they did not receive the reset email, check spam folder or retry after 10 minutes\n- For persistent login issues, escalate to human support\n\n**Suggested phrasing:**\n"Try tapping \'Forgot Password\' on the login screen. Make sure you\'re using the email associated with your account. If the email doesn\'t arrive, check spam or try again in a few minutes."',
#   'tags': 'login, password, access, escalation'},
#  {'title': 'How to Access Airport Lounges with CultPass',
#   'content': 'To access airport lounges:\n\n- Open the CultPass app and navigate to \'Airport Lounges\'\n- Select your desired lounge and tap \'Access\'\n- Show the QR code at the lounge entrance\n\n**Suggested phrasing:**\n"Access airport lounges by selecting \'Airport Lounges\' in the CultPass app and showing your QR code at the entrance."',
#   'tags': 'access, benefits, reservation'},
#  {'title': 'Understanding CultPass Pricing Tiers',
#   'content': 'CultPass offers multiple pricing tiers:\n\n- Basic: Access to standard experiences\n- Premium: Includes premium events and additional benefits\n- VIP: Unlimited access to all experiences\n\n**Suggested phrasing:**\n"CultPass offers Basic, Premium, and VIP tiers, each providing different levels of access and benefits."',
#   'tags': 'pricing, benefits, subscription'},
#  {'title': 'How to Book a Cultural Experience',
#   'content': 'To book a cultural experience:\n\n- Open the CultPass app and browse the experience catalog\n- Tap \'Book Now\' on your chosen event\n- Confirm your booking details\n\n**Suggested phrasing:**\n"Book a cultural experience by selecting \'Book Now\' in the CultPass app and confirming your details."',
#   'tags': 'booking, events, reservation'},
#  {'title': 'Steps to Escalate a Support Ticket',
#   'content': 'If an issue persists:\n\n- Advise the user to tap \'Help\' in the app\n- Select \'Contact Support\' and describe the issue\n- Choose \'Escalate\' if the problem is unresolved\n\n**Suggested phrasing:**\n"For unresolved issues, escalate by selecting \'Contact Support\' and choosing \'Escalate\' in the app."',
#   'tags': 'escalation, support, access'},
#  {'title': 'How to Update Your CultPass Subscription',
#   'content': 'To update your subscription:\n\n- Go to \'My Account\' in the app\n- Tap \'Manage Plan\' and select \'Update Subscription\'\n- Choose your new plan and confirm\n\n**Suggested phrasing:**\n"Update your subscription by selecting \'Manage Plan\' in the app and choosing \'Update Subscription\'."',
#   'tags': 'subscription, billing, access'},
#  {'title': 'Handling Password Reset Requests',
#   'content': 'For password resets:\n\n- Direct users to tap \'Forgot Password\' on the login screen\n- Ensure they check their email for the reset link\n- Advise checking spam if the email isn\'t received\n\n**Suggested phrasing:**\n"Reset your password by tapping \'Forgot Password\' and checking your email for the reset link."',
#   'tags': 'password, login, access'},
#  {'title': 'How to Pause Your CultPass Subscription',
#   'content': 'To pause your subscription:\n\n- Navigate to \'My Account\' in the app\n- Select \'Manage Plan\' and tap \'Pause Subscription\'\n- Confirm your choice\n\n**Suggested phrasing:**\n"Pause your subscription by selecting \'Manage Plan\' and choosing \'Pause Subscription\' in the app."',
#   'tags': 'pause, subscription, billing'},
#  {'title': 'Benefits of CultPass Membership',
#   'content': 'CultPass membership includes:\n\n- Access to exclusive events\n- Discounts on travel and leisure\n- Priority support for members\n\n**Suggested phrasing:**\n"Enjoy exclusive events, travel discounts, and priority support with your CultPass membership."',
#   'tags': 'benefits, subscription, access'},
#  {'title': 'How to Cancel a Booking',
#   'content': 'To cancel a booking:\n\n- Open the CultPass app and go to \'My Bookings\'\n- Select the booking you wish to cancel\n- Tap \'Cancel Booking\' and confirm\n\n**Suggested phrasing:**\n"Cancel a booking by selecting \'My Bookings\' in the app and choosing \'Cancel Booking\'."',
#   'tags': 'cancelation, booking, reservation'},
#  {'title': 'Resolving Login Authentication Issues',
#   'content': 'For authentication issues:\n\n- Verify the user\'s email and password\n- Suggest resetting the password if needed\n- Escalate to support if the issue persists\n\n**Suggested phrasing:**\n"Ensure your email and password are correct. If issues persist, reset your password or contact support."',
#   'tags': 'login, password, escalation'},
#  {'title': 'How to Attend a CultPass Event',
#   'content': 'To attend an event:\n\n- Ensure your booking is confirmed in the app\n- Arrive at the venue 15 minutes early\n- Show your QR code at the entrance\n\n**Suggested phrasing:**\n"Attend an event by confirming your booking in the app and arriving 15 minutes early with your QR code."',
#   'tags': 'attendance, events, reservation'},
#  {'title': 'Understanding CultPass Billing Cycles',
#   'content': 'CultPass billing cycles:\n\n- Monthly billing on the same date each month\n- Charges appear as \'CultPass Subscription\' on statements\n- Contact support for billing inquiries\n\n**Suggested phrasing:**\n"Your CultPass subscription is billed monthly. For billing inquiries, contact support."',
#   'tags': 'billing, subscription, pricing'},
#  {'title': 'How to Access Exclusive Travel Discounts',
#   'content': 'To access travel discounts:\n\n- Open the CultPass app and navigate to \'Travel Discounts\'\n- Browse available offers and select \'Redeem\'\n- Follow the instructions to apply the discount\n\n**Suggested phrasing:**\n"Access travel discounts by selecting \'Travel Discounts\' in the CultPass app and choosing \'Redeem\'."',
#   'tags': 'access, benefits, pricing'},
#  {'title': 'Steps to Reactivate a Paused Subscription',
#   'content': 'To reactivate:\n\n- Go to \'My Account\' in the app\n- Tap \'Manage Plan\' and select \'Reactivate Subscription\'\n- Confirm your reactivation\n\n**Suggested phrasing:**\n"Reactivate your subscription by selecting \'Manage Plan\' and choosing \'Reactivate Subscription\' in the app."',
#   'tags': 'pause, subscription, billing'},
#  {'title': 'How to Handle Event Overbooking',
#   'content': 'For overbooked events:\n\n- Inform users of the overbooking\n- Offer alternative dates or events\n- Escalate to support if necessary\n\n**Suggested phrasing:**\n"If an event is overbooked, we\'ll offer alternative dates or events. Contact support for further assistance."',
#   'tags': 'escalation, events, booking'},
#  {'title': 'How to Change Your CultPass Account Email',
#   'content': 'To change your email:\n\n- Go to \'My Account\' in the app\n- Select \'Edit Profile\' and update your email\n- Confirm the change via the verification email\n\n**Suggested phrasing:**\n"Change your account email by selecting \'Edit Profile\' in the app and confirming the change via email."',
#   'tags': 'access, login, password'}]

# %% [markdown]
# Creating Vector Embedding for RAG

# %%
# Create vector store for knowledge articles
vector_store = Chroma(
    collection_name=collection_name,
    embedding_function=embeddings_fn,
    persist_directory=chromadb_directory,
)

cultpass_articles_docs = [ Document(page_content=article['title']+": "+article["content"],
                                      metadata={"tags": article['tags']},
                                      id=i) for i, article in enumerate(cultpass_articles_ls) ]
_ = vector_store.add_documents(documents=cultpass_articles_docs)

# %%
question = "Hi, I have a question regarding the billing for the events I attended last month. There seems to be a discrepancy in the charges, and I would like to understand the breakdown of the costs. Could you please provide a detailed billing statement? Thank you."
vector_store.similarity_search(question)
# Out:
# [Document(id='15', metadata={'tags': 'billing, subscription, pricing'}, page_content='Understanding CultPass Billing Cycles: CultPass billing cycles:\n\n- Monthly billing on the same date each month\n- Charges appear as \'CultPass Subscription\' on statements\n- Contact support for billing inquiries\n\n**Suggested phrasing:**\n"Your CultPass subscription is billed monthly. For billing inquiries, contact support."'),
#  Document(id='1', metadata={'tags': 'subscription, benefits, pricing, access'}, page_content='What\'s Included in a CultPass Subscription: Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."'),
#  Document(id='14', metadata={'tags': 'attendance, events, reservation'}, page_content='How to Attend a CultPass Event: To attend an event:\n\n- Ensure your booking is confirmed in the app\n- Arrive at the venue 15 minutes early\n- Show your QR code at the entrance\n\n**Suggested phrasing:**\n"Attend an event by confirming your booking in the app and arriving 15 minutes early with your QR code."'),
#  Document(id='18', metadata={'tags': 'escalation, events, booking'}, page_content='How to Handle Event Overbooking: For overbooked events:\n\n- Inform users of the overbooking\n- Offer alternative dates or events\n- Escalate to support if necessary\n\n**Suggested phrasing:**\n"If an event is overbooked, we\'ll offer alternative dates or events. Contact support for further assistance."')]

# %% [markdown]
# #### Generate Users and Tickets

# %%
# Create Company List
account_prompt_template = """You are a company naming expert. Please come up with {num_account} company names."""

account_prompt = PromptTemplate(
    template = account_prompt_template,
    input_variables = ["num_account"],
    ).invoke({"num_account": num_account}).to_messages()

account = llm.with_structured_output(AccountSamples).invoke(account_prompt).model_dump()['company_name']
account_table = pd.DataFrame({"company_name": account})
# account_table['id'] = account_table.index
account_table['account_id'] = [ str(uuid.uuid4()) for i in range(num_account) ]
account_table_ls = account_table.to_dict(orient='records')
# account_table

# %%
# Create Additional Users
num_cultpass_users = len(cultpass_users)
num_new_users = num_user - num_cultpass_users
user_prompt_template = """
    You are a people naming expert. Please come up with {num_user} names with both first and last name.
    Randomly choose a company for each user from the account list and based on the name of the company,
    create an email address for this person.  Some companies should have more users than others.
    All users from the same company must have the same domain name on their email address.

    The `is_blocked` status should be randomly choosen as 'True' or 'False'

    List of account (companies): {account_table}"""

user_prompt = PromptTemplate(
    template = user_prompt_template,
    input_variables = ["num_user","account_table"],
    ).invoke({"num_user": num_new_users, "account_table": account_table}).to_messages()

user_ls = llm.with_structured_output(UsersListSchema).invoke(user_prompt).model_dump()['samples']
user_table = pd.DataFrame(user_ls)
user_table['id'] = [ str(uuid.uuid4().hex[:6]) for i in range(num_new_users) ]
user_table = user_table[['id', 'name', 'email', 'is_blocked','account_id']]
cultpass_users_table = pd.DataFrame(cultpass_users)
user_table = pd.concat([user_table, cultpass_users_table])
user_table['account_id'] = [ str(uuid.uuid4()) for i in range(num_user) ]     # account ID of LLM generated user should be replaced with true uuid4.

# %%
cultpass_users_table
# Out:
#        id            name                          email  is_blocked
# 0  a4ab87  Alice Kingsley  alice.kingsley@wonderland.com        True
# 1  f556c0       Bob Stone          bob.stone@granite.com       False
# 2  88382b     Cathy Bloom        cathy.bloom@florals.org       False
# 3  888fb2      David Noir      david.noir@shadowmail.com        True
# 4  f1f10d       Eva Green          eva.green@ecosoul.net       False
# 5  e6376d     Frank Ocean        frank.ocean@seawaves.io       False

# %%
user_table
# Out:
#         id             name                                      email  \
# 0   f4bdd5    Liam Anderson      liam.anderson@innovatechsolutions.com
# 1   c72205  Olivia Martinez    olivia.martinez@innovatechsolutions.com
# 2   2a868e    Noah Thompson      noah.thompson@innovatechsolutions.com
# 3   7bd3a2     Emma Johnson       emma.johnson@ecospherenterprises.com
# 4   7b7e1e        Ava Brown          ava.brown@ecospherenterprises.com
# 5   1d9c28     Sophia Davis       sophia.davis@quantumleapdynamics.com
# 6   dde4a7  Isabella Wilson  isabella.wilson@greenwavetechnologies.com
# 7   0eb068        Mia Moore             mia.moore@pinnacleventures.com
# 8   b9ba01    Amelia Taylor         amelia.taylor@pinnacleventures.com
# 9   d0d184     Harper White    harper.white@bluehorizoninnovations.com
# 10  372fa0    Evelyn Harris        evelyn.harris@synergynexusgroup.com
# 11  9f57d8    Abigail Clark    abigail.clark@futureforgeindustries.com
# 12  7a6f3a       Ella Lewis           ella.lewis@apexvisionarylabs.com
# 13  8f32d0     Avery Walker     avery.walker@harmonyglobalpartners.com
# 14  d80ca4    Scarlett Hall    scarlett.hall@harmonyglobalpartners.com
# 15  ebe647       Luna Young       luna.young@harmonyglobalpartners.com
# 16  3580a0        Aria King        aria.king@harmonyglobalpartners.com
# 17  708e14     Chloe Wright     chloe.wright@harmonyglobalpartners.com
# 18  809ca6      Grace Scott      grace.scott@harmonyglobalpartners.com
# 0   a4ab87   Alice Kingsley              alice.kingsley@wonderland.com
# 1   f556c0        Bob Stone                      bob.stone@granite.com
# 2   88382b      Cathy Bloom                    cathy.bloom@florals.org
# 3   888fb2       David Noir                  david.noir@shadowmail.com
# 4   f1f10d        Eva Green                      eva.green@ecosoul.net
# 5   e6376d      Frank Ocean                    frank.ocean@seawaves.io
#
#     is_blocked                            account_id
# 0        False  e508a593-c0e2-4e92-9e5f-f4154394835f
# 1         True  650073c9-8c4c-4966-9974-470d3b355cbf
# 2        False  b2e51046-6fd6-46e7-acfe-a3201f48df11
# 3         True  35d5a4d0-5b32-4153-9176-c3836b55f8af
# 4        False  5166787c-329c-411a-9642-6eb9ffb5cb1c
# 5         True  73b346e4-d929-4b5b-9de7-5b5e3495aac4
# 6        False  332a7584-7ece-4a3c-9af9-fc171ca6c3d3
# 7         True  2bb563e9-c99a-40d5-8675-c87b619f2fac
# 8        False  b715b515-9285-4089-b437-adc4c8b7a24c
# 9         True  a1d9450a-755e-4fc5-933a-b9dc50b86403
# 10       False  5d2a35fc-08f2-47c7-bccc-fa8da7031b9c
# 11        True  f26ae613-18c5-46be-ba93-c406512501bb
# 12       False  2ab80818-6d73-4775-aff8-5bf7af1114f9
# 13        True  3595ed30-e71f-4a57-82bb-9d3ba6be28cc
# 14       False  72f856a5-5b82-484d-a58f-7ea2464422ab
# 15        True  a1d414fc-c9e7-484c-bf3d-257c09ff3cb4
# 16       False  588cf16f-76ea-4e15-a3ad-993218a9bc7d
# 17        True  559e868a-4fce-4b45-afe9-ec1b003a0023
# 18       False  92f05fbc-0a54-4586-80ea-195a1f1b567c
# 0         True  677292a8-6fa0-4a23-af23-2b49d7423276
# 1        False  f97eb195-a272-4154-bac2-edf6e7f51342
# 2        False  31be3fea-75b8-470e-adbc-089668438646
# 3         True  5edf5765-d45c-4f53-babf-02f12d9aec9d
# 4        False  e9ecd8a2-8915-4361-9abb-5fe1b1f1d31b
# 5        False  25505c86-5949-408f-9ffe-af0bcce57a71

# %%
# Random Combination of Tags
expected_list_min_expected_tag = 1
expected_list_max_expected_tag = 4
unexpected_list_min_expected_tag = 0
unexpected_list_max_expected_tag = 2
unexpected_list_min_unexpected_tag = 1
unexpected_list_max_unexpected_tag = 2

expected_tag_combination = [ random.sample(list(expected_tags), random.randint(expected_list_min_expected_tag,expected_list_max_expected_tag)) for i in range(num_expected_tag_msg) ]
unexpected_tag_combination = [ random.sample(list(expected_tags), random.randint(unexpected_list_min_expected_tag,unexpected_list_max_expected_tag)) +
                               random.sample(list(unexpected_tags), random.randint(unexpected_list_min_unexpected_tag,unexpected_list_max_unexpected_tag)) for i in range(num_unexpected_tag_msg) ]
tag_combination = expected_tag_combination + unexpected_tag_combination

# %%
# Create Tickets
ticket_prompt_template = """
    You are a IT ticket generation emulator focusing on generating the actual message of users.
    
    Step 1: Generate {num_ticket} tickets, 
        (a) Each `content` should be 20 to 200 words
        (b) Make occasional minor typos in the `content`
        (c) Each ticket `content` should be written based on the topic in the followin table:
        {tag_combination}  

    Step 2: For the `owner_id` (use `id` column in the table), `owner_name` (use `name` column in the table), account_id (`account_id`)
            and allow one user to have multiple tickets:
        {user_table}

    Step 3: Randomly selected a `channel` from ['email','chat','web','sms','social','phone'] for each ticket.
    """

ticket_prompt = PromptTemplate(
    template = ticket_prompt_template,
    input_variables = ["num_ticket","num_expected_tag_msg","num_unexpected_tag_msg","expected_tags","unexpected_tags","ticket_table"],
    ).invoke({"num_ticket": num_ticket,
              "tag_combination": tag_combination, 
              "unexpected_tags": unexpected_tags, 
              "user_table": user_table,
            }).to_messages()

ticket_ls = llm.with_structured_output(TicketSamples).invoke(ticket_prompt).model_dump()['samples']
ticket_table = pd.DataFrame(ticket_ls)
# ticket_table['id'] = msg_table.index
ticket_table['role'] = "user"
ticket_table['status'] = "open"
ticket_table['urgency_score'] = [random.random() for _ in range(num_ticket)]
# ticket_table

# %%
for ticket in ticket_table['content']:
    print(ticket)
# Out:
# Hi there, I was wondering if you could provide more information about the benefits package offered by your company. I've heard great things, but I want to make sure I understand all the details before making any decisions. Could you also let me know if there are any upcoming events where I can learn more? Thanks!
# Hello, I've been having some issues with my billing lately. It seems like there are some charges that I don't recognize, and I would like to pause my subscription until this is resolved. Can you please escalate this matter to the billing department? Thank you.
# Hi, I'm having trouble accessing my account. Every time I try to log in, it says my credentials are incorrect, even though I'm sure they're right. Could you please help me regain access?
# Hello, I need to book a meeting room for next week, but I'm having trouble with the online booking system. It keeps giving me an error message. Also, I forgot my password and can't reset it. Can you assist me with these issues?
# Hi, I've been trying to log in to my account to check my billing details, but it keeps saying my password is incorrect. I also need to make a reservation for an upcoming event. Can you help me with these issues?
# Hello, I need to book a conference room for a meeting next week, but the system isn't letting me. Also, I need to confirm my attendance for an event. Can you help me with these issues?
# Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?
# Hello, I'm having trouble logging into my account to confirm my attendance for an upcoming event. Can you help me resolve this issue?
# Hi, I'm interested in attending one of your events, but I'm not sure about the pricing. Can you provide more information on the cost and any discounts available?
# Hello, I need to cancel a booking I made for next week. The system isn't allowing me to do it online. Can you assist me with this?
# Hi, I need to cancel a reservation I made for an event next month. Also, I'm having trouble logging into my account to confirm my attendance. Can you help me with these issues?
# Hello, I'm trying to understand the pricing for your services, but it's a bit confusing. Also, I have some questions about my billing statement. Can you help me with these issues?
# Hi, I need to confirm my attendance for an upcoming event, but I'm having trouble with the system. Also, I have some questions about my billing statement. Can you help me with these issues?
# Hello, I'm interested in learning more about the benefits package offered by your company. Can you provide more information on this?
# Hi, I'm having trouble with my subscription. It seems like there are some issues with the pricing, and I would like to escalate this matter. Can you help me resolve this issue?
# Hello, I need to cancel my subscription, but I'm having trouble with the system. Also, I have some questions about the pricing. Can you help me with these issues?
# Hi, I forgot my password and can't reset it. Can you help me regain access to my account?
# Hello, I'm having trouble with my password and can't log in to my account. Also, I have some questions about the benefits package offered by your company. Can you help me with these issues?
# Hi, I have some questions about my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?
# Hello, I'm interested in booking a meeting room for next week, but I'm having trouble with the system. Also, I have some questions about the benefits package offered by your company. Can you help me with these issues?
# Hi, I need to cancel my subscription, but I'm having trouble with the system. Also, I have some questions about the benefits package offered by your company. Can you help me with these issues?
# Hello, I need to confirm my attendance for an upcoming event, but I'm having trouble with the system. Also, I have some questions about my billing statement. Can you help me with these issues?
# Hi, I'm having trouble with my password and can't log in to my account. Also, I have some questions about my subscription. Can you help me with these issues?
# Hello, I'm interested in learning more about the benefits package offered by your company. Can you provide more information on this?
# Hi, I'm having trouble logging into my account. Can you help me resolve this issue?
# Hello, I need to book a meeting room for next week, but I'm having trouble with the system. Also, I forgot my password and can't reset it. Can you assist me with these issues?
# Hi, I'm interested in attending one of your events, but I'm not sure about the pricing. Can you provide more information on the cost and any discounts available?
# Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?
# Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?
# Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?
# Hi, I'm interested in learning more about the benefits package offered by your company. Can you provide more information on this?
# Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?
# Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?
# Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?
# Hi, I'm interested in booking a meeting room for next week, but I'm having trouble with the system. Can you help me resolve this issue?
# Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?
# Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?
# Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?
# Hi, I'm interested in learning more about the benefits package offered by your company. Can you provide more information on this?
# Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?
# Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?
# Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?
# Hi, I'm interested in learning more about the benefits package offered by your company. Can you provide more information on this?
# Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?
# Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?
# Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?
# Hi, I'm interested in booking a meeting room for next week, but I'm having trouble with the system. Can you help me resolve this issue?
# Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?
# Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?
# Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?

# %%
ticket_table
# Out:
#    status                                            content owner_id  \
# 0    open  Hi there, I was wondering if you could provide...   f4bdd5
# 1    open  Hello, I've been having some issues with my bi...   c72205
# 2    open  Hi, I'm having trouble accessing my account. E...   2a868e
# 3    open  Hello, I need to book a meeting room for next ...   7bd3a2
# 4    open  Hi, I've been trying to log in to my account t...   7b7e1e
# 5    open  Hello, I need to book a conference room for a ...   1d9c28
# 6    open  Hi, I'm trying to understand the pricing struc...   dde4a7
# 7    open  Hello, I'm having trouble logging into my acco...   0eb068
# 8    open  Hi, I'm interested in attending one of your ev...   b9ba01
# 9    open  Hello, I need to cancel a booking I made for n...   d0d184
# 10   open  Hi, I need to cancel a reservation I made for ...   372fa0
# 11   open  Hello, I'm trying to understand the pricing fo...   9f57d8
# 12   open  Hi, I need to confirm my attendance for an upc...   7a6f3a
# 13   open  Hello, I'm interested in learning more about t...   8f32d0
# 14   open  Hi, I'm having trouble with my subscription. I...   d80ca4
# 15   open  Hello, I need to cancel my subscription, but I...   ebe647
# 16   open  Hi, I forgot my password and can't reset it. C...   3580a0
# 17   open  Hello, I'm having trouble with my password and...   708e14
# 18   open  Hi, I have some questions about my billing sta...   809ca6
# 19   open  Hello, I'm interested in booking a meeting roo...   a4ab87
# 20   open  Hi, I need to cancel my subscription, but I'm ...   f556c0
# 21   open  Hello, I need to confirm my attendance for an ...   88382b
# 22   open  Hi, I'm having trouble with my password and ca...   888fb2
# 23   open  Hello, I'm interested in learning more about t...   f1f10d
# 24   open  Hi, I'm having trouble logging into my account...   e6376d
# 25   open  Hello, I need to book a meeting room for next ...   f4bdd5
# 26   open  Hi, I'm interested in attending one of your ev...   c72205
# 27   open  Hello, I'm having trouble with my billing stat...   2a868e
# 28   open  Hi, I'm trying to understand the pricing struc...   7bd3a2
# 29   open  Hello, I'm having trouble with my password and...   7b7e1e
# 30   open  Hi, I'm interested in learning more about the ...   1d9c28
# 31   open  Hello, I'm having trouble with my billing stat...   dde4a7
# 32   open  Hi, I'm trying to understand the pricing struc...   0eb068
# 33   open  Hello, I'm having trouble with my password and...   b9ba01
# 34   open  Hi, I'm interested in booking a meeting room f...   d0d184
# 35   open  Hello, I'm having trouble with my billing stat...   372fa0
# 36   open  Hi, I'm trying to understand the pricing struc...   9f57d8
# 37   open  Hello, I'm having trouble with my password and...   7a6f3a
# 38   open  Hi, I'm interested in learning more about the ...   8f32d0
# 39   open  Hello, I'm having trouble with my billing stat...   d80ca4
# 40   open  Hi, I'm trying to understand the pricing struc...   ebe647
# 41   open  Hello, I'm having trouble with my password and...   3580a0
# 42   open  Hi, I'm interested in learning more about the ...   708e14
# 43   open  Hello, I'm having trouble with my billing stat...   809ca6
# 44   open  Hi, I'm trying to understand the pricing struc...   a4ab87
# 45   open  Hello, I'm having trouble with my password and...   f556c0
# 46   open  Hi, I'm interested in booking a meeting room f...   88382b
# 47   open  Hello, I'm having trouble with my billing stat...   888fb2
# 48   open  Hi, I'm trying to understand the pricing struc...   f1f10d
# 49   open  Hello, I'm having trouble with my password and...   e6376d
#
#          owner_name channel                               tags  \
# 0     Liam Anderson   email                   benefits, events
# 1   Olivia Martinez    chat         billing, pause, escalation
# 2     Noah Thompson     web                             access
# 3      Emma Johnson     sms                  booking, password
# 4         Ava Brown  social        billing, login, reservation
# 5      Sophia Davis   phone                attendance, booking
# 6   Isabella Wilson   email                            pricing
# 7         Mia Moore    chat                  login, attendance
# 8     Amelia Taylor     web                    pricing, events
# 9      Harper White     sms               booking, cancelation
# 10    Evelyn Harris  social    reservation, cancelation, login
# 11    Abigail Clark   phone                   pricing, billing
# 12       Ella Lewis   email                attendance, billing
# 13     Avery Walker    chat                           benefits
# 14    Scarlett Hall     web  subscription, pricing, escalation
# 15       Luna Young     sms               pricing, cancelation
# 16        Aria King  social                           password
# 17     Chloe Wright   phone                 password, benefits
# 18      Grace Scott   email                            billing
# 19   Alice Kingsley    chat                  booking, benefits
# 20        Bob Stone     web              cancelation, benefits
# 21      Cathy Bloom     sms                attendance, billing
# 22       David Noir  social             password, subscription
# 23        Eva Green   phone                           benefits
# 24      Frank Ocean   email                              login
# 25    Liam Anderson    chat                  booking, password
# 26  Olivia Martinez     web                    pricing, events
# 27    Noah Thompson     sms                            billing
# 28     Emma Johnson  social                            pricing
# 29        Ava Brown   phone                           password
# 30     Sophia Davis   email                           benefits
# 31  Isabella Wilson    chat                            billing
# 32        Mia Moore     web                            pricing
# 33    Amelia Taylor     sms                           password
# 34     Harper White  social                            booking
# 35    Evelyn Harris   phone                            billing
# 36    Abigail Clark   email                            pricing
# 37       Ella Lewis    chat                           password
# 38     Avery Walker     web                           benefits
# 39    Scarlett Hall     sms                            billing
# 40       Luna Young  social                            pricing
# 41        Aria King   phone                           password
# 42     Chloe Wright   email                           benefits
# 43      Grace Scott    chat                            billing
# 44   Alice Kingsley     web                            pricing
# 45        Bob Stone     sms                           password
# 46      Cathy Bloom  social                            booking
# 47       David Noir   phone                            billing
# 48        Eva Green   email                            pricing
# 49      Frank Ocean    chat                           password
#
#                               account_id  urgency_score  role
# 0   e508a593-c0e2-4e92-9e5f-f4154394835f       0.519548  user
# 1   650073c9-8c4c-4966-9974-470d3b355cbf       0.531055  user
# 2   b2e51046-6fd6-46e7-acfe-a3201f48df11       0.705149  user
# 3   35d5a4d0-5b32-4153-9176-c3836b55f8af       0.777741  user
# 4   5166787c-329c-411a-9642-6eb9ffb5cb1c       0.617994  user
# 5   73b346e4-d929-4b5b-9de7-5b5e3495aac4       0.354851  user
# 6   332a7584-7ece-4a3c-9af9-fc171ca6c3d3       0.093630  user
# 7   2bb563e9-c99a-40d5-8675-c87b619f2fac       0.979815  user
# 8   b715b515-9285-4089-b437-adc4c8b7a24c       0.964032  user
# 9   a1d9450a-755e-4fc5-933a-b9dc50b86403       0.816404  user
# 10  5d2a35fc-08f2-47c7-bccc-fa8da7031b9c       0.552185  user
# 11  f26ae613-18c5-46be-ba93-c406512501bb       0.201753  user
# 12  2ab80818-6d73-4775-aff8-5bf7af1114f9       0.797143  user
# 13  3595ed30-e71f-4a57-82bb-9d3ba6be28cc       0.515747  user
# 14  72f856a5-5b82-484d-a58f-7ea2464422ab       0.333878  user
# 15  a1d414fc-c9e7-484c-bf3d-257c09ff3cb4       0.599605  user
# 16  588cf16f-76ea-4e15-a3ad-993218a9bc7d       0.729061  user
# 17  559e868a-4fce-4b45-afe9-ec1b003a0023       0.150828  user
# 18  92f05fbc-0a54-4586-80ea-195a1f1b567c       0.710437  user
# 19  677292a8-6fa0-4a23-af23-2b49d7423276       0.669272  user
# 20  f97eb195-a272-4154-bac2-edf6e7f51342       0.927418  user
# 21  31be3fea-75b8-470e-adbc-089668438646       0.172920  user
# 22  5edf5765-d45c-4f53-babf-02f12d9aec9d       0.548975  user
# 23  e9ecd8a2-8915-4361-9abb-5fe1b1f1d31b       0.719167  user
# 24  25505c86-5949-408f-9ffe-af0bcce57a71       0.844022  user
# 25  e508a593-c0e2-4e92-9e5f-f4154394835f       0.639412  user
# 26  650073c9-8c4c-4966-9974-470d3b355cbf       0.299832  user
# 27  b2e51046-6fd6-46e7-acfe-a3201f48df11       0.324593  user
# 28  35d5a4d0-5b32-4153-9176-c3836b55f8af       0.063053  user
# 29  5166787c-329c-411a-9642-6eb9ffb5cb1c       0.159357  user
# 30  73b346e4-d929-4b5b-9de7-5b5e3495aac4       0.642070  user
# 31  332a7584-7ece-4a3c-9af9-fc171ca6c3d3       0.626463  user
# 32  2bb563e9-c99a-40d5-8675-c87b619f2fac       0.768503  user
# 33  b715b515-9285-4089-b437-adc4c8b7a24c       0.567801  user
# 34  a1d9450a-755e-4fc5-933a-b9dc50b86403       0.975452  user
# 35  5d2a35fc-08f2-47c7-bccc-fa8da7031b9c       0.597491  user
# 36  f26ae613-18c5-46be-ba93-c406512501bb       0.567802  user
# 37  2ab80818-6d73-4775-aff8-5bf7af1114f9       0.448522  user
# 38  3595ed30-e71f-4a57-82bb-9d3ba6be28cc       0.151473  user
# 39  72f856a5-5b82-484d-a58f-7ea2464422ab       0.062387  user
# 40  a1d414fc-c9e7-484c-bf3d-257c09ff3cb4       0.233094  user
# 41  588cf16f-76ea-4e15-a3ad-993218a9bc7d       0.262689  user
# 42  559e868a-4fce-4b45-afe9-ec1b003a0023       0.135529  user
# 43  92f05fbc-0a54-4586-80ea-195a1f1b567c       0.150859  user
# 44  677292a8-6fa0-4a23-af23-2b49d7423276       0.535460  user
# 45  f97eb195-a272-4154-bac2-edf6e7f51342       0.608508  user
# 46  31be3fea-75b8-470e-adbc-089668438646       0.075837  user
# 47  5edf5765-d45c-4f53-babf-02f12d9aec9d       0.481710  user
# 48  e9ecd8a2-8915-4361-9abb-5fe1b1f1d31b       0.973290  user
# 49  25505c86-5949-408f-9ffe-af0bcce57a71       0.268556  user

# %%
len(ticket_table)
# Out:
# 50

# %% [markdown]
# ## Load Samples into Database

# %%
with get_session(engine) as session:
    kb = []
    for article in cultpass_articles:
        knowledge = udahub.Knowledge(
            article_id=str(uuid.uuid4()),
            account_id=account_id,
            title=article["title"],
            content=article["content"],
            tags=article["tags"]
        )
        kb.append(knowledge)
    session.add_all(kb)

# %% [markdown]
# **Ticket**

# %%
user_table.columns
# Out:
# Index(['id', 'name', 'email', 'is_blocked', 'account_id'], dtype='object')

# %%
def add_user(user_info):
    """
    Adding a single user to the database.
    """
    with get_session(engine) as session:
        user = udahub.User(
            user_id=user_info["account_id"],
            account_id=account_id,
            external_user_id=user_info["id"],
            user_name=user_info["name"],
            is_blocked=user_info["is_blocked"],
            email_address=user_info["email"]
            )
        session.add_all([user])

# %%
for index, row in user_table.iterrows():
    add_user(row)

# %%
def add_ticket(ticket_info):
    """
    Adding a single ticket to the database
    """
    with get_session(engine) as session:
        user = session.query(udahub.User).filter_by(
            account_id=account_id,
            external_user_id=ticket_info["owner_id"],
        ).first()

        print(ticket_info)
        print(user)

        if not user:
            user = udahub.User(
                # user_id=str(uuid.uuid4()),
                user_id=ticket_info["account_id"],
                account_id=account_id,
                external_user_id=ticket_info["owner_id"],
                user_name=ticket_info["owner_name"],
                is_blocked=False,     # Data structure in data/models/udahub.py had been modified to include this flag for advanced agent capability
                email_address=None    # Data structure in data/models/udahub.py had been modified to include this flag for advanced agent capability
            )
        
        ticket = udahub.Ticket(
            ticket_id=str(uuid.uuid4()),
            account_id=account_id,
            user_id=user.user_id,
            channel=ticket_info["channel"],
        )
        metadata = udahub.TicketMetadata(
            ticket_id=ticket.ticket_id,
            status=ticket_info["status"],
            main_issue_type=None,
            tags=ticket_info["tags"],
            urgency_score=ticket_info["urgency_score"]
        )

        first_message = udahub.TicketMessage(
            message_id=str(uuid.uuid4()),
            ticket_id=ticket.ticket_id,
            role=ticket_info["role"],
            content=ticket_info["content"],
        )

        # print(user)
        session.add_all([user, ticket, metadata, first_message])

# %%
for index, row in ticket_table.iterrows():
    add_ticket(row)
# Out:
# status                                                        open
# content          Hi there, I was wondering if you could provide...
# owner_id                                                    f4bdd5
# owner_name                                           Liam Anderson
# channel                                                      email
# tags                                              benefits, events
# account_id                    e508a593-c0e2-4e92-9e5f-f4154394835f
# urgency_score                                             0.519548
# role                                                          user
# Name: 0, dtype: object
# <User(user_id='e508a593-c0e2-4e92-9e5f-f4154394835f', user_name='Liam Anderson', external_user_id='f4bdd5')>
# status                                                        open
# content          Hello, I've been having some issues with my bi...
# owner_id                                                    c72205
# owner_name                                         Olivia Martinez
# channel                                                       chat
# tags                                    billing, pause, escalation
# account_id                    650073c9-8c4c-4966-9974-470d3b355cbf
# urgency_score                                             0.531055
# role                                                          user
# Name: 1, dtype: object
# <User(user_id='650073c9-8c4c-4966-9974-470d3b355cbf', user_name='Olivia Martinez', external_user_id='c72205')>
# status                                                        open
# content          Hi, I'm having trouble accessing my account. E...
# owner_id                                                    2a868e
# owner_name                                           Noah Thompson
# channel                                                        web
# tags                                                        access
# account_id                    b2e51046-6fd6-46e7-acfe-a3201f48df11
# urgency_score                                             0.705149
# role                                                          user
# Name: 2, dtype: object
# <User(user_id='b2e51046-6fd6-46e7-acfe-a3201f48df11', user_name='Noah Thompson', external_user_id='2a868e')>
# status                                                        open
# content          Hello, I need to book a meeting room for next ...
# owner_id                                                    7bd3a2
# owner_name                                            Emma Johnson
# channel                                                        sms
# tags                                             booking, password
# account_id                    35d5a4d0-5b32-4153-9176-c3836b55f8af
# urgency_score                                             0.777741
# role                                                          user
# Name: 3, dtype: object
# <User(user_id='35d5a4d0-5b32-4153-9176-c3836b55f8af', user_name='Emma Johnson', external_user_id='7bd3a2')>
# status                                                        open
# content          Hi, I've been trying to log in to my account t...
# owner_id                                                    7b7e1e
# owner_name                                               Ava Brown
# channel                                                     social
# tags                                   billing, login, reservation
# account_id                    5166787c-329c-411a-9642-6eb9ffb5cb1c
# urgency_score                                             0.617994
# role                                                          user
# Name: 4, dtype: object
# <User(user_id='5166787c-329c-411a-9642-6eb9ffb5cb1c', user_name='Ava Brown', external_user_id='7b7e1e')>
# status                                                        open
# content          Hello, I need to book a conference room for a ...
# owner_id                                                    1d9c28
# owner_name                                            Sophia Davis
# channel                                                      phone
# tags                                           attendance, booking
# account_id                    73b346e4-d929-4b5b-9de7-5b5e3495aac4
# urgency_score                                             0.354851
# role                                                          user
# Name: 5, dtype: object
# <User(user_id='73b346e4-d929-4b5b-9de7-5b5e3495aac4', user_name='Sophia Davis', external_user_id='1d9c28')>
# status                                                        open
# content          Hi, I'm trying to understand the pricing struc...
# owner_id                                                    dde4a7
# owner_name                                         Isabella Wilson
# channel                                                      email
# tags                                                       pricing
# account_id                    332a7584-7ece-4a3c-9af9-fc171ca6c3d3
# urgency_score                                              0.09363
# role                                                          user
# Name: 6, dtype: object
# <User(user_id='332a7584-7ece-4a3c-9af9-fc171ca6c3d3', user_name='Isabella Wilson', external_user_id='dde4a7')>
# status                                                        open
# content          Hello, I'm having trouble logging into my acco...
# owner_id                                                    0eb068
# owner_name                                               Mia Moore
# channel                                                       chat
# tags                                             login, attendance
# account_id                    2bb563e9-c99a-40d5-8675-c87b619f2fac
# urgency_score                                             0.979815
# role                                                          user
# Name: 7, dtype: object
# <User(user_id='2bb563e9-c99a-40d5-8675-c87b619f2fac', user_name='Mia Moore', external_user_id='0eb068')>
# status                                                        open
# content          Hi, I'm interested in attending one of your ev...
# owner_id                                                    b9ba01
# owner_name                                           Amelia Taylor
# channel                                                        web
# tags                                               pricing, events
# account_id                    b715b515-9285-4089-b437-adc4c8b7a24c
# urgency_score                                             0.964032
# role                                                          user
# Name: 8, dtype: object
# <User(user_id='b715b515-9285-4089-b437-adc4c8b7a24c', user_name='Amelia Taylor', external_user_id='b9ba01')>
# status                                                        open
# content          Hello, I need to cancel a booking I made for n...
# owner_id                                                    d0d184
# owner_name                                            Harper White
# channel                                                        sms
# tags                                          booking, cancelation
# account_id                    a1d9450a-755e-4fc5-933a-b9dc50b86403
# urgency_score                                             0.816404
# role                                                          user
# Name: 9, dtype: object
# <User(user_id='a1d9450a-755e-4fc5-933a-b9dc50b86403', user_name='Harper White', external_user_id='d0d184')>
# status                                                        open
# content          Hi, I need to cancel a reservation I made for ...
# owner_id                                                    372fa0
# owner_name                                           Evelyn Harris
# channel                                                     social
# tags                               reservation, cancelation, login
# account_id                    5d2a35fc-08f2-47c7-bccc-fa8da7031b9c
# urgency_score                                             0.552185
# role                                                          user
# Name: 10, dtype: object
# <User(user_id='5d2a35fc-08f2-47c7-bccc-fa8da7031b9c', user_name='Evelyn Harris', external_user_id='372fa0')>
# status                                                        open
# content          Hello, I'm trying to understand the pricing fo...
# owner_id                                                    9f57d8
# owner_name                                           Abigail Clark
# channel                                                      phone
# tags                                              pricing, billing
# account_id                    f26ae613-18c5-46be-ba93-c406512501bb
# urgency_score                                             0.201753
# role                                                          user
# Name: 11, dtype: object
# <User(user_id='f26ae613-18c5-46be-ba93-c406512501bb', user_name='Abigail Clark', external_user_id='9f57d8')>
# status                                                        open
# content          Hi, I need to confirm my attendance for an upc...
# owner_id                                                    7a6f3a
# owner_name                                              Ella Lewis
# channel                                                      email
# tags                                           attendance, billing
# account_id                    2ab80818-6d73-4775-aff8-5bf7af1114f9
# urgency_score                                             0.797143
# role                                                          user
# Name: 12, dtype: object
# <User(user_id='2ab80818-6d73-4775-aff8-5bf7af1114f9', user_name='Ella Lewis', external_user_id='7a6f3a')>
# status                                                        open
# content          Hello, I'm interested in learning more about t...
# owner_id                                                    8f32d0
# owner_name                                            Avery Walker
# channel                                                       chat
# tags                                                      benefits
# account_id                    3595ed30-e71f-4a57-82bb-9d3ba6be28cc
# urgency_score                                             0.515747
# role                                                          user
# Name: 13, dtype: object
# <User(user_id='3595ed30-e71f-4a57-82bb-9d3ba6be28cc', user_name='Avery Walker', external_user_id='8f32d0')>
# status                                                        open
# content          Hi, I'm having trouble with my subscription. I...
# owner_id                                                    d80ca4
# owner_name                                           Scarlett Hall
# channel                                                        web
# tags                             subscription, pricing, escalation
# account_id                    72f856a5-5b82-484d-a58f-7ea2464422ab
# urgency_score                                             0.333878
# role                                                          user
# Name: 14, dtype: object
# <User(user_id='72f856a5-5b82-484d-a58f-7ea2464422ab', user_name='Scarlett Hall', external_user_id='d80ca4')>
# status                                                        open
# content          Hello, I need to cancel my subscription, but I...
# owner_id                                                    ebe647
# owner_name                                              Luna Young
# channel                                                        sms
# tags                                          pricing, cancelation
# account_id                    a1d414fc-c9e7-484c-bf3d-257c09ff3cb4
# urgency_score                                             0.599605
# role                                                          user
# Name: 15, dtype: object
# <User(user_id='a1d414fc-c9e7-484c-bf3d-257c09ff3cb4', user_name='Luna Young', external_user_id='ebe647')>
# status                                                        open
# content          Hi, I forgot my password and can't reset it. C...
# owner_id                                                    3580a0
# owner_name                                               Aria King
# channel                                                     social
# tags                                                      password
# account_id                    588cf16f-76ea-4e15-a3ad-993218a9bc7d
# urgency_score                                             0.729061
# role                                                          user
# Name: 16, dtype: object
# <User(user_id='588cf16f-76ea-4e15-a3ad-993218a9bc7d', user_name='Aria King', external_user_id='3580a0')>
# status                                                        open
# content          Hello, I'm having trouble with my password and...
# owner_id                                                    708e14
# owner_name                                            Chloe Wright
# channel                                                      phone
# tags                                            password, benefits
# account_id                    559e868a-4fce-4b45-afe9-ec1b003a0023
# urgency_score                                             0.150828
# role                                                          user
# Name: 17, dtype: object
# <User(user_id='559e868a-4fce-4b45-afe9-ec1b003a0023', user_name='Chloe Wright', external_user_id='708e14')>
# status                                                        open
# content          Hi, I have some questions about my billing sta...
# owner_id                                                    809ca6
# owner_name                                             Grace Scott
# channel                                                      email
# tags                                                       billing
# account_id                    92f05fbc-0a54-4586-80ea-195a1f1b567c
# urgency_score                                             0.710437
# role                                                          user
# Name: 18, dtype: object
# <User(user_id='92f05fbc-0a54-4586-80ea-195a1f1b567c', user_name='Grace Scott', external_user_id='809ca6')>
# status                                                        open
# content          Hello, I'm interested in booking a meeting roo...
# owner_id                                                    a4ab87
# owner_name                                          Alice Kingsley
# channel                                                       chat
# tags                                             booking, benefits
# account_id                    677292a8-6fa0-4a23-af23-2b49d7423276
# urgency_score                                             0.669272
# role                                                          user
# Name: 19, dtype: object
# <User(user_id='677292a8-6fa0-4a23-af23-2b49d7423276', user_name='Alice Kingsley', external_user_id='a4ab87')>
# status                                                        open
# content          Hi, I need to cancel my subscription, but I'm ...
# owner_id                                                    f556c0
# owner_name                                               Bob Stone
# channel                                                        web
# tags                                         cancelation, benefits
# account_id                    f97eb195-a272-4154-bac2-edf6e7f51342
# urgency_score                                             0.927418
# role                                                          user
# Name: 20, dtype: object
# <User(user_id='f97eb195-a272-4154-bac2-edf6e7f51342', user_name='Bob Stone', external_user_id='f556c0')>
# status                                                        open
# content          Hello, I need to confirm my attendance for an ...
# owner_id                                                    88382b
# owner_name                                             Cathy Bloom
# channel                                                        sms
# tags                                           attendance, billing
# account_id                    31be3fea-75b8-470e-adbc-089668438646
# urgency_score                                              0.17292
# role                                                          user
# Name: 21, dtype: object
# <User(user_id='31be3fea-75b8-470e-adbc-089668438646', user_name='Cathy Bloom', external_user_id='88382b')>
# status                                                        open
# content          Hi, I'm having trouble with my password and ca...
# owner_id                                                    888fb2
# owner_name                                              David Noir
# channel                                                     social
# tags                                        password, subscription
# account_id                    5edf5765-d45c-4f53-babf-02f12d9aec9d
# urgency_score                                             0.548975
# role                                                          user
# Name: 22, dtype: object
# <User(user_id='5edf5765-d45c-4f53-babf-02f12d9aec9d', user_name='David Noir', external_user_id='888fb2')>
# status                                                        open
# content          Hello, I'm interested in learning more about t...
# owner_id                                                    f1f10d
# owner_name                                               Eva Green
# channel                                                      phone
# tags                                                      benefits
# account_id                    e9ecd8a2-8915-4361-9abb-5fe1b1f1d31b
# urgency_score                                             0.719167
# role                                                          user
# Name: 23, dtype: object
# <User(user_id='e9ecd8a2-8915-4361-9abb-5fe1b1f1d31b', user_name='Eva Green', external_user_id='f1f10d')>
# status                                                        open
# content          Hi, I'm having trouble logging into my account...
# owner_id                                                    e6376d
# owner_name                                             Frank Ocean
# channel                                                      email
# tags                                                         login
# account_id                    25505c86-5949-408f-9ffe-af0bcce57a71
# urgency_score                                             0.844022
# role                                                          user
# Name: 24, dtype: object
# <User(user_id='25505c86-5949-408f-9ffe-af0bcce57a71', user_name='Frank Ocean', external_user_id='e6376d')>
# status                                                        open
# content          Hello, I need to book a meeting room for next ...
# owner_id                                                    f4bdd5
# owner_name                                           Liam Anderson
# channel                                                       chat
# tags                                             booking, password
# account_id                    e508a593-c0e2-4e92-9e5f-f4154394835f
# urgency_score                                             0.639412
# role                                                          user
# Name: 25, dtype: object
# <User(user_id='e508a593-c0e2-4e92-9e5f-f4154394835f', user_name='Liam Anderson', external_user_id='f4bdd5')>
# status                                                        open
# content          Hi, I'm interested in attending one of your ev...
# owner_id                                                    c72205
# owner_name                                         Olivia Martinez
# channel                                                        web
# tags                                               pricing, events
# account_id                    650073c9-8c4c-4966-9974-470d3b355cbf
# urgency_score                                             0.299832
# role                                                          user
# Name: 26, dtype: object
# <User(user_id='650073c9-8c4c-4966-9974-470d3b355cbf', user_name='Olivia Martinez', external_user_id='c72205')>
# status                                                        open
# content          Hello, I'm having trouble with my billing stat...
# owner_id                                                    2a868e
# owner_name                                           Noah Thompson
# channel                                                        sms
# tags                                                       billing
# account_id                    b2e51046-6fd6-46e7-acfe-a3201f48df11
# urgency_score                                             0.324593
# role                                                          user
# Name: 27, dtype: object
# <User(user_id='b2e51046-6fd6-46e7-acfe-a3201f48df11', user_name='Noah Thompson', external_user_id='2a868e')>
# status                                                        open
# content          Hi, I'm trying to understand the pricing struc...
# owner_id                                                    7bd3a2
# owner_name                                            Emma Johnson
# channel                                                     social
# tags                                                       pricing
# account_id                    35d5a4d0-5b32-4153-9176-c3836b55f8af
# urgency_score                                             0.063053
# role                                                          user
# Name: 28, dtype: object
# <User(user_id='35d5a4d0-5b32-4153-9176-c3836b55f8af', user_name='Emma Johnson', external_user_id='7bd3a2')>
# status                                                        open
# content          Hello, I'm having trouble with my password and...
# owner_id                                                    7b7e1e
# owner_name                                               Ava Brown
# channel                                                      phone
# tags                                                      password
# account_id                    5166787c-329c-411a-9642-6eb9ffb5cb1c
# urgency_score                                             0.159357
# role                                                          user
# Name: 29, dtype: object
# <User(user_id='5166787c-329c-411a-9642-6eb9ffb5cb1c', user_name='Ava Brown', external_user_id='7b7e1e')>
# status                                                        open
# content          Hi, I'm interested in learning more about the ...
# owner_id                                                    1d9c28
# owner_name                                            Sophia Davis
# channel                                                      email
# tags                                                      benefits
# account_id                    73b346e4-d929-4b5b-9de7-5b5e3495aac4
# urgency_score                                              0.64207
# role                                                          user
# Name: 30, dtype: object
# <User(user_id='73b346e4-d929-4b5b-9de7-5b5e3495aac4', user_name='Sophia Davis', external_user_id='1d9c28')>
# status                                                        open
# content          Hello, I'm having trouble with my billing stat...
# owner_id                                                    dde4a7
# owner_name                                         Isabella Wilson
# channel                                                       chat
# tags                                                       billing
# account_id                    332a7584-7ece-4a3c-9af9-fc171ca6c3d3
# urgency_score                                             0.626463
# role                                                          user
# Name: 31, dtype: object
# <User(user_id='332a7584-7ece-4a3c-9af9-fc171ca6c3d3', user_name='Isabella Wilson', external_user_id='dde4a7')>
# status                                                        open
# content          Hi, I'm trying to understand the pricing struc...
# owner_id                                                    0eb068
# owner_name                                               Mia Moore
# channel                                                        web
# tags                                                       pricing
# account_id                    2bb563e9-c99a-40d5-8675-c87b619f2fac
# urgency_score                                             0.768503
# role                                                          user
# Name: 32, dtype: object
# <User(user_id='2bb563e9-c99a-40d5-8675-c87b619f2fac', user_name='Mia Moore', external_user_id='0eb068')>
# status                                                        open
# content          Hello, I'm having trouble with my password and...
# owner_id                                                    b9ba01
# owner_name                                           Amelia Taylor
# channel                                                        sms
# tags                                                      password
# account_id                    b715b515-9285-4089-b437-adc4c8b7a24c
# urgency_score                                             0.567801
# role                                                          user
# Name: 33, dtype: object
# <User(user_id='b715b515-9285-4089-b437-adc4c8b7a24c', user_name='Amelia Taylor', external_user_id='b9ba01')>
# status                                                        open
# content          Hi, I'm interested in booking a meeting room f...
# owner_id                                                    d0d184
# owner_name                                            Harper White
# channel                                                     social
# tags                                                       booking
# account_id                    a1d9450a-755e-4fc5-933a-b9dc50b86403
# urgency_score                                             0.975452
# role                                                          user
# Name: 34, dtype: object
# <User(user_id='a1d9450a-755e-4fc5-933a-b9dc50b86403', user_name='Harper White', external_user_id='d0d184')>
# status                                                        open
# content          Hello, I'm having trouble with my billing stat...
# owner_id                                                    372fa0
# owner_name                                           Evelyn Harris
# channel                                                      phone
# tags                                                       billing
# account_id                    5d2a35fc-08f2-47c7-bccc-fa8da7031b9c
# urgency_score                                             0.597491
# role                                                          user
# Name: 35, dtype: object
# <User(user_id='5d2a35fc-08f2-47c7-bccc-fa8da7031b9c', user_name='Evelyn Harris', external_user_id='372fa0')>
# status                                                        open
# content          Hi, I'm trying to understand the pricing struc...
# owner_id                                                    9f57d8
# owner_name                                           Abigail Clark
# channel                                                      email
# tags                                                       pricing
# account_id                    f26ae613-18c5-46be-ba93-c406512501bb
# urgency_score                                             0.567802
# role                                                          user
# Name: 36, dtype: object
# <User(user_id='f26ae613-18c5-46be-ba93-c406512501bb', user_name='Abigail Clark', external_user_id='9f57d8')>
# status                                                        open
# content          Hello, I'm having trouble with my password and...
# owner_id                                                    7a6f3a
# owner_name                                              Ella Lewis
# channel                                                       chat
# tags                                                      password
# account_id                    2ab80818-6d73-4775-aff8-5bf7af1114f9
# urgency_score                                             0.448522
# role                                                          user
# Name: 37, dtype: object
# <User(user_id='2ab80818-6d73-4775-aff8-5bf7af1114f9', user_name='Ella Lewis', external_user_id='7a6f3a')>
# status                                                        open
# content          Hi, I'm interested in learning more about the ...
# owner_id                                                    8f32d0
# owner_name                                            Avery Walker
# channel                                                        web
# tags                                                      benefits
# account_id                    3595ed30-e71f-4a57-82bb-9d3ba6be28cc
# urgency_score                                             0.151473
# role                                                          user
# Name: 38, dtype: object
# <User(user_id='3595ed30-e71f-4a57-82bb-9d3ba6be28cc', user_name='Avery Walker', external_user_id='8f32d0')>
# status                                                        open
# content          Hello, I'm having trouble with my billing stat...
# owner_id                                                    d80ca4
# owner_name                                           Scarlett Hall
# channel                                                        sms
# tags                                                       billing
# account_id                    72f856a5-5b82-484d-a58f-7ea2464422ab
# urgency_score                                             0.062387
# role                                                          user
# Name: 39, dtype: object
# <User(user_id='72f856a5-5b82-484d-a58f-7ea2464422ab', user_name='Scarlett Hall', external_user_id='d80ca4')>
# status                                                        open
# content          Hi, I'm trying to understand the pricing struc...
# owner_id                                                    ebe647
# owner_name                                              Luna Young
# channel                                                     social
# tags                                                       pricing
# account_id                    a1d414fc-c9e7-484c-bf3d-257c09ff3cb4
# urgency_score                                             0.233094
# role                                                          user
# Name: 40, dtype: object
# <User(user_id='a1d414fc-c9e7-484c-bf3d-257c09ff3cb4', user_name='Luna Young', external_user_id='ebe647')>
# status                                                        open
# content          Hello, I'm having trouble with my password and...
# owner_id                                                    3580a0
# owner_name                                               Aria King
# channel                                                      phone
# tags                                                      password
# account_id                    588cf16f-76ea-4e15-a3ad-993218a9bc7d
# urgency_score                                             0.262689
# role                                                          user
# Name: 41, dtype: object
# <User(user_id='588cf16f-76ea-4e15-a3ad-993218a9bc7d', user_name='Aria King', external_user_id='3580a0')>
# status                                                        open
# content          Hi, I'm interested in learning more about the ...
# owner_id                                                    708e14
# owner_name                                            Chloe Wright
# channel                                                      email
# tags                                                      benefits
# account_id                    559e868a-4fce-4b45-afe9-ec1b003a0023
# urgency_score                                             0.135529
# role                                                          user
# Name: 42, dtype: object
# <User(user_id='559e868a-4fce-4b45-afe9-ec1b003a0023', user_name='Chloe Wright', external_user_id='708e14')>
# status                                                        open
# content          Hello, I'm having trouble with my billing stat...
# owner_id                                                    809ca6
# owner_name                                             Grace Scott
# channel                                                       chat
# tags                                                       billing
# account_id                    92f05fbc-0a54-4586-80ea-195a1f1b567c
# urgency_score                                             0.150859
# role                                                          user
# Name: 43, dtype: object
# <User(user_id='92f05fbc-0a54-4586-80ea-195a1f1b567c', user_name='Grace Scott', external_user_id='809ca6')>
# status                                                        open
# content          Hi, I'm trying to understand the pricing struc...
# owner_id                                                    a4ab87
# owner_name                                          Alice Kingsley
# channel                                                        web
# tags                                                       pricing
# account_id                    677292a8-6fa0-4a23-af23-2b49d7423276
# urgency_score                                              0.53546
# role                                                          user
# Name: 44, dtype: object
# <User(user_id='677292a8-6fa0-4a23-af23-2b49d7423276', user_name='Alice Kingsley', external_user_id='a4ab87')>
# status                                                        open
# content          Hello, I'm having trouble with my password and...
# owner_id                                                    f556c0
# owner_name                                               Bob Stone
# channel                                                        sms
# tags                                                      password
# account_id                    f97eb195-a272-4154-bac2-edf6e7f51342
# urgency_score                                             0.608508
# role                                                          user
# Name: 45, dtype: object
# <User(user_id='f97eb195-a272-4154-bac2-edf6e7f51342', user_name='Bob Stone', external_user_id='f556c0')>
# status                                                        open
# content          Hi, I'm interested in booking a meeting room f...
# owner_id                                                    88382b
# owner_name                                             Cathy Bloom
# channel                                                     social
# tags                                                       booking
# account_id                    31be3fea-75b8-470e-adbc-089668438646
# urgency_score                                             0.075837
# role                                                          user
# Name: 46, dtype: object
# <User(user_id='31be3fea-75b8-470e-adbc-089668438646', user_name='Cathy Bloom', external_user_id='88382b')>
# status                                                        open
# content          Hello, I'm having trouble with my billing stat...
# owner_id                                                    888fb2
# owner_name                                              David Noir
# channel                                                      phone
# tags                                                       billing
# account_id                    5edf5765-d45c-4f53-babf-02f12d9aec9d
# urgency_score                                              0.48171
# role                                                          user
# Name: 47, dtype: object
# <User(user_id='5edf5765-d45c-4f53-babf-02f12d9aec9d', user_name='David Noir', external_user_id='888fb2')>
# status                                                        open
# content          Hi, I'm trying to understand the pricing struc...
# owner_id                                                    f1f10d
# owner_name                                               Eva Green
# channel                                                      email
# tags                                                       pricing
# account_id                    e9ecd8a2-8915-4361-9abb-5fe1b1f1d31b
# urgency_score                                              0.97329
# role                                                          user
# Name: 48, dtype: object
# <User(user_id='e9ecd8a2-8915-4361-9abb-5fe1b1f1d31b', user_name='Eva Green', external_user_id='f1f10d')>
# status                                                        open
# content          Hello, I'm having trouble with my password and...
# owner_id                                                    e6376d
# owner_name                                             Frank Ocean
# channel                                                       chat
# tags                                                      password
# account_id                    25505c86-5949-408f-9ffe-af0bcce57a71
# urgency_score                                             0.268556
# role                                                          user
# Name: 49, dtype: object
# <User(user_id='25505c86-5949-408f-9ffe-af0bcce57a71', user_name='Frank Ocean', external_user_id='e6376d')>

# %% [markdown]
# # Tests

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    print(account)
# Out:
# <Account(account_id='cultpass', account_name='CultPass Card')>

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    for article in account.knowledge_articles:
        print(article)
# Out:
# <Knowledge(article_id='e1b81082-7f82-4cb5-a41f-4bd92f66e8d0', title='How to Reserve a Spot for an Event')>
# <Knowledge(article_id='5187b697-9b36-4b3e-9c20-25944fe2c8f0', title='What's Included in a CultPass Subscription')>
# <Knowledge(article_id='c9a1f1d8-52de-4858-b4ca-1673fae29c7d', title='How to Cancel or Pause a Subscription')>
# <Knowledge(article_id='441048b8-6f7a-4a17-89a2-c64c3f0aefc9', title='How to Handle Login Issues?')>

# %%
with get_session(engine) as session:
    users = session.query(udahub.User).all()
    for user in users:
        # Get all column names for this model
        inst = inspect(user)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(user, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'user_id': 'e508a593-c0e2-4e92-9e5f-f4154394835f', 'account_id': 'cultpass', 'external_user_id': 'f4bdd5', 'user_name': 'Liam Anderson', 'is_blocked': False, 'email_address': 'liam.anderson@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '650073c9-8c4c-4966-9974-470d3b355cbf', 'account_id': 'cultpass', 'external_user_id': 'c72205', 'user_name': 'Olivia Martinez', 'is_blocked': True, 'email_address': 'olivia.martinez@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': 'b2e51046-6fd6-46e7-acfe-a3201f48df11', 'account_id': 'cultpass', 'external_user_id': '2a868e', 'user_name': 'Noah Thompson', 'is_blocked': False, 'email_address': 'noah.thompson@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '35d5a4d0-5b32-4153-9176-c3836b55f8af', 'account_id': 'cultpass', 'external_user_id': '7bd3a2', 'user_name': 'Emma Johnson', 'is_blocked': True, 'email_address': 'emma.johnson@ecospherenterprises.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '5166787c-329c-411a-9642-6eb9ffb5cb1c', 'account_id': 'cultpass', 'external_user_id': '7b7e1e', 'user_name': 'Ava Brown', 'is_blocked': False, 'email_address': 'ava.brown@ecospherenterprises.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '73b346e4-d929-4b5b-9de7-5b5e3495aac4', 'account_id': 'cultpass', 'external_user_id': '1d9c28', 'user_name': 'Sophia Davis', 'is_blocked': True, 'email_address': 'sophia.davis@quantumleapdynamics.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '332a7584-7ece-4a3c-9af9-fc171ca6c3d3', 'account_id': 'cultpass', 'external_user_id': 'dde4a7', 'user_name': 'Isabella Wilson', 'is_blocked': False, 'email_address': 'isabella.wilson@greenwavetechnologies.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '2bb563e9-c99a-40d5-8675-c87b619f2fac', 'account_id': 'cultpass', 'external_user_id': '0eb068', 'user_name': 'Mia Moore', 'is_blocked': True, 'email_address': 'mia.moore@pinnacleventures.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': 'b715b515-9285-4089-b437-adc4c8b7a24c', 'account_id': 'cultpass', 'external_user_id': 'b9ba01', 'user_name': 'Amelia Taylor', 'is_blocked': False, 'email_address': 'amelia.taylor@pinnacleventures.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': 'a1d9450a-755e-4fc5-933a-b9dc50b86403', 'account_id': 'cultpass', 'external_user_id': 'd0d184', 'user_name': 'Harper White', 'is_blocked': True, 'email_address': 'harper.white@bluehorizoninnovations.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '5d2a35fc-08f2-47c7-bccc-fa8da7031b9c', 'account_id': 'cultpass', 'external_user_id': '372fa0', 'user_name': 'Evelyn Harris', 'is_blocked': False, 'email_address': 'evelyn.harris@synergynexusgroup.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': 'f26ae613-18c5-46be-ba93-c406512501bb', 'account_id': 'cultpass', 'external_user_id': '9f57d8', 'user_name': 'Abigail Clark', 'is_blocked': True, 'email_address': 'abigail.clark@futureforgeindustries.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '2ab80818-6d73-4775-aff8-5bf7af1114f9', 'account_id': 'cultpass', 'external_user_id': '7a6f3a', 'user_name': 'Ella Lewis', 'is_blocked': False, 'email_address': 'ella.lewis@apexvisionarylabs.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '3595ed30-e71f-4a57-82bb-9d3ba6be28cc', 'account_id': 'cultpass', 'external_user_id': '8f32d0', 'user_name': 'Avery Walker', 'is_blocked': True, 'email_address': 'avery.walker@harmonyglobalpartners.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '72f856a5-5b82-484d-a58f-7ea2464422ab', 'account_id': 'cultpass', 'external_user_id': 'd80ca4', 'user_name': 'Scarlett Hall', 'is_blocked': False, 'email_address': 'scarlett.hall@harmonyglobalpartners.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': 'a1d414fc-c9e7-484c-bf3d-257c09ff3cb4', 'account_id': 'cultpass', 'external_user_id': 'ebe647', 'user_name': 'Luna Young', 'is_blocked': True, 'email_address': 'luna.young@harmonyglobalpartners.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '588cf16f-76ea-4e15-a3ad-993218a9bc7d', 'account_id': 'cultpass', 'external_user_id': '3580a0', 'user_name': 'Aria King', 'is_blocked': False, 'email_address': 'aria.king@harmonyglobalpartners.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '559e868a-4fce-4b45-afe9-ec1b003a0023', 'account_id': 'cultpass', 'external_user_id': '708e14', 'user_name': 'Chloe Wright', 'is_blocked': True, 'email_address': 'chloe.wright@harmonyglobalpartners.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '92f05fbc-0a54-4586-80ea-195a1f1b567c', 'account_id': 'cultpass', 'external_user_id': '809ca6', 'user_name': 'Grace Scott', 'is_blocked': False, 'email_address': 'grace.scott@harmonyglobalpartners.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '677292a8-6fa0-4a23-af23-2b49d7423276', 'account_id': 'cultpass', 'external_user_id': 'a4ab87', 'user_name': 'Alice Kingsley', 'is_blocked': True, 'email_address': 'alice.kingsley@wonderland.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': 'f97eb195-a272-4154-bac2-edf6e7f51342', 'account_id': 'cultpass', 'external_user_id': 'f556c0', 'user_name': 'Bob Stone', 'is_blocked': False, 'email_address': 'bob.stone@granite.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '31be3fea-75b8-470e-adbc-089668438646', 'account_id': 'cultpass', 'external_user_id': '88382b', 'user_name': 'Cathy Bloom', 'is_blocked': False, 'email_address': 'cathy.bloom@florals.org', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '5edf5765-d45c-4f53-babf-02f12d9aec9d', 'account_id': 'cultpass', 'external_user_id': '888fb2', 'user_name': 'David Noir', 'is_blocked': True, 'email_address': 'david.noir@shadowmail.com', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': 'e9ecd8a2-8915-4361-9abb-5fe1b1f1d31b', 'account_id': 'cultpass', 'external_user_id': 'f1f10d', 'user_name': 'Eva Green', 'is_blocked': False, 'email_address': 'eva.green@ecosoul.net', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}
# {'user_id': '25505c86-5949-408f-9ffe-af0bcce57a71', 'account_id': 'cultpass', 'external_user_id': 'e6376d', 'user_name': 'Frank Ocean', 'is_blocked': False, 'email_address': 'frank.ocean@seawaves.io', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 3), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 3)}

# %%
with get_session(engine) as session:
    tickets = session.query(udahub.Ticket).all()
    for ticket in tickets:
        # Get all column names for this model
        inst = inspect(ticket)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(ticket, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'ticket_id': '63baf1dd-4a03-48ef-af6d-50d1acda37ce', 'account_id': 'cultpass', 'user_id': 'e508a593-c0e2-4e92-9e5f-f4154394835f', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '9abc0d19-2fcf-446e-92ce-506a96fe7d71', 'account_id': 'cultpass', 'user_id': '650073c9-8c4c-4966-9974-470d3b355cbf', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '7c08b1c1-a861-4f44-88ef-d5755d56476f', 'account_id': 'cultpass', 'user_id': 'b2e51046-6fd6-46e7-acfe-a3201f48df11', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'f52f9d01-1b6f-4756-83f3-0acef94df3ea', 'account_id': 'cultpass', 'user_id': '35d5a4d0-5b32-4153-9176-c3836b55f8af', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '043952d6-66f3-4b42-804e-e2ed95700e8f', 'account_id': 'cultpass', 'user_id': '5166787c-329c-411a-9642-6eb9ffb5cb1c', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '0250803f-ae20-4a70-b7e5-d51d060e2309', 'account_id': 'cultpass', 'user_id': '73b346e4-d929-4b5b-9de7-5b5e3495aac4', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'ce7f66b0-fabc-4fcb-b0e0-aa1978b6efdf', 'account_id': 'cultpass', 'user_id': '332a7584-7ece-4a3c-9af9-fc171ca6c3d3', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '7e42fee2-1d8e-4a13-b0d6-f491246bc115', 'account_id': 'cultpass', 'user_id': '2bb563e9-c99a-40d5-8675-c87b619f2fac', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '3ada43d2-9481-4c4c-bf5d-737864b9daeb', 'account_id': 'cultpass', 'user_id': 'b715b515-9285-4089-b437-adc4c8b7a24c', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'c522b03c-3b10-4303-9cdc-5c03923a5720', 'account_id': 'cultpass', 'user_id': 'a1d9450a-755e-4fc5-933a-b9dc50b86403', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'd1e63cac-ea52-4ab2-b94a-d4aa33b37eb4', 'account_id': 'cultpass', 'user_id': '5d2a35fc-08f2-47c7-bccc-fa8da7031b9c', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '7279357a-c07e-493a-b049-56d00f3a9cbb', 'account_id': 'cultpass', 'user_id': 'f26ae613-18c5-46be-ba93-c406512501bb', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '10da9fb6-2c69-4bc8-b167-cfe8e918b294', 'account_id': 'cultpass', 'user_id': '2ab80818-6d73-4775-aff8-5bf7af1114f9', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'baba08ae-bef9-4684-871e-fb118c78e5fd', 'account_id': 'cultpass', 'user_id': '3595ed30-e71f-4a57-82bb-9d3ba6be28cc', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '30ee1127-561d-4539-a5e0-b0d9358ef01d', 'account_id': 'cultpass', 'user_id': '72f856a5-5b82-484d-a58f-7ea2464422ab', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'baa370de-7eb7-4ca7-8d8a-05468c5be0d4', 'account_id': 'cultpass', 'user_id': 'a1d414fc-c9e7-484c-bf3d-257c09ff3cb4', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'ec456385-1868-4d17-9696-37d91a7b1704', 'account_id': 'cultpass', 'user_id': '588cf16f-76ea-4e15-a3ad-993218a9bc7d', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '935a9b38-95eb-4946-bc77-ac827b579369', 'account_id': 'cultpass', 'user_id': '559e868a-4fce-4b45-afe9-ec1b003a0023', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '6d7e0ff7-cd3b-4f7f-9e2e-cf659e58a541', 'account_id': 'cultpass', 'user_id': '92f05fbc-0a54-4586-80ea-195a1f1b567c', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '8fde2885-4410-411a-8cf3-0f770d0da2e0', 'account_id': 'cultpass', 'user_id': '677292a8-6fa0-4a23-af23-2b49d7423276', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '4a730ff9-c0d1-46cc-9d1c-f57efe643e6d', 'account_id': 'cultpass', 'user_id': 'f97eb195-a272-4154-bac2-edf6e7f51342', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'decb47c1-3014-4bb9-bca0-495a9bc4d6a5', 'account_id': 'cultpass', 'user_id': '31be3fea-75b8-470e-adbc-089668438646', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '19f63dbc-42a8-44cc-a6ff-84206ddfdda2', 'account_id': 'cultpass', 'user_id': '5edf5765-d45c-4f53-babf-02f12d9aec9d', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'd6dc9534-5ce6-42a3-993c-42d49d3aaae6', 'account_id': 'cultpass', 'user_id': 'e9ecd8a2-8915-4361-9abb-5fe1b1f1d31b', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '242aa04b-8823-49a9-9fb2-9cfb8e271ce7', 'account_id': 'cultpass', 'user_id': '25505c86-5949-408f-9ffe-af0bcce57a71', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'b32dbb63-94e9-4389-825f-4c3a52e99772', 'account_id': 'cultpass', 'user_id': 'e508a593-c0e2-4e92-9e5f-f4154394835f', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'a07d46a7-e617-4679-8949-99889f8b20e4', 'account_id': 'cultpass', 'user_id': '650073c9-8c4c-4966-9974-470d3b355cbf', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '30dce630-ba3f-4757-ba3c-45f40556618a', 'account_id': 'cultpass', 'user_id': 'b2e51046-6fd6-46e7-acfe-a3201f48df11', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'ea5158b6-9e2c-4204-adef-4f1294bfa480', 'account_id': 'cultpass', 'user_id': '35d5a4d0-5b32-4153-9176-c3836b55f8af', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'fbdafed4-9f71-475a-bc5f-f24ddb1ab4d1', 'account_id': 'cultpass', 'user_id': '5166787c-329c-411a-9642-6eb9ffb5cb1c', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '844e890c-05b1-41a6-8d9b-38e9bd3ee2ad', 'account_id': 'cultpass', 'user_id': '73b346e4-d929-4b5b-9de7-5b5e3495aac4', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '0c5d52b7-3816-4c1c-bc21-f0d9c3f04798', 'account_id': 'cultpass', 'user_id': '332a7584-7ece-4a3c-9af9-fc171ca6c3d3', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'f65dda97-ef51-4b31-8e86-152c4f6c32c7', 'account_id': 'cultpass', 'user_id': '2bb563e9-c99a-40d5-8675-c87b619f2fac', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'f3c1a1dc-1d32-4753-a0c8-2e59bee50a02', 'account_id': 'cultpass', 'user_id': 'b715b515-9285-4089-b437-adc4c8b7a24c', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '797f0697-4601-4737-8739-243d21b80e4e', 'account_id': 'cultpass', 'user_id': 'a1d9450a-755e-4fc5-933a-b9dc50b86403', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '4176a8d7-eba5-41de-bd2d-496d06270efb', 'account_id': 'cultpass', 'user_id': '5d2a35fc-08f2-47c7-bccc-fa8da7031b9c', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '4e72d3ad-2217-40ca-b871-f6eb29111a27', 'account_id': 'cultpass', 'user_id': 'f26ae613-18c5-46be-ba93-c406512501bb', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '225f7b4f-31e2-4f25-9a84-ae2b75976de4', 'account_id': 'cultpass', 'user_id': '2ab80818-6d73-4775-aff8-5bf7af1114f9', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '9a17c244-5d15-481e-9542-361bc56104b7', 'account_id': 'cultpass', 'user_id': '3595ed30-e71f-4a57-82bb-9d3ba6be28cc', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '31d722cc-c643-465f-976f-2a6dfca73655', 'account_id': 'cultpass', 'user_id': '72f856a5-5b82-484d-a58f-7ea2464422ab', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '17efcb6d-09ff-4e5d-befe-27793afa81b4', 'account_id': 'cultpass', 'user_id': 'a1d414fc-c9e7-484c-bf3d-257c09ff3cb4', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'be71103a-51db-4a11-8bed-b2e8caa6009e', 'account_id': 'cultpass', 'user_id': '588cf16f-76ea-4e15-a3ad-993218a9bc7d', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '75fe88d1-3caa-487c-8443-e75e546c73d0', 'account_id': 'cultpass', 'user_id': '559e868a-4fce-4b45-afe9-ec1b003a0023', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '87426525-9f6e-431e-8ee1-a33c53b224b6', 'account_id': 'cultpass', 'user_id': '92f05fbc-0a54-4586-80ea-195a1f1b567c', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'c2f08594-6065-40a9-af28-790c904e69b9', 'account_id': 'cultpass', 'user_id': '677292a8-6fa0-4a23-af23-2b49d7423276', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'c88d65b7-183c-460a-8ac4-9984b57ec43e', 'account_id': 'cultpass', 'user_id': 'f97eb195-a272-4154-bac2-edf6e7f51342', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '7c5971fd-2c6f-4611-968c-af6936cda678', 'account_id': 'cultpass', 'user_id': '31be3fea-75b8-470e-adbc-089668438646', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'a31d98b5-0595-484a-9e37-e202ae59c75d', 'account_id': 'cultpass', 'user_id': '5edf5765-d45c-4f53-babf-02f12d9aec9d', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '71a7c157-2470-4d7f-88d1-a3436b5147e6', 'account_id': 'cultpass', 'user_id': 'e9ecd8a2-8915-4361-9abb-5fe1b1f1d31b', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '75044d91-d661-45f7-9e23-45d003d8a0d2', 'account_id': 'cultpass', 'user_id': '25505c86-5949-408f-9ffe-af0bcce57a71', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}

# %%
with get_session(engine) as session:
    messages = session.query(udahub.TicketMessage).all()
    for message in messages:
        # Get all column names for this model
        inst = inspect(message)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(message, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'message_id': '702ab7a9-1252-4073-aeb5-7a4166cb3cbb', 'ticket_id': '63baf1dd-4a03-48ef-af6d-50d1acda37ce', 'role': <RoleEnum.user: 'user'>, 'content': "Hi there, I was wondering if you could provide more information about the benefits package offered by your company. I've heard great things, but I want to make sure I understand all the details before making any decisions. Could you also let me know if there are any upcoming events where I can learn more? Thanks!", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': '71491b9a-ea52-4f43-99bd-74f87a50b0a3', 'ticket_id': '9abc0d19-2fcf-446e-92ce-506a96fe7d71', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I've been having some issues with my billing lately. It seems like there are some charges that I don't recognize, and I would like to pause my subscription until this is resolved. Can you please escalate this matter to the billing department? Thank you.", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': '3a124ca6-7b8e-4453-931f-53b9172c357d', 'ticket_id': '7c08b1c1-a861-4f44-88ef-d5755d56476f', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm having trouble accessing my account. Every time I try to log in, it says my credentials are incorrect, even though I'm sure they're right. Could you please help me regain access?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': 'd1a99df0-4ff4-457d-9092-5eecd7945e9c', 'ticket_id': 'f52f9d01-1b6f-4756-83f3-0acef94df3ea', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to book a meeting room for next week, but I'm having trouble with the online booking system. It keeps giving me an error message. Also, I forgot my password and can't reset it. Can you assist me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': 'ccd0d736-b660-4084-ae84-b7c8355b2f5f', 'ticket_id': '043952d6-66f3-4b42-804e-e2ed95700e8f', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I've been trying to log in to my account to check my billing details, but it keeps saying my password is incorrect. I also need to make a reservation for an upcoming event. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': '05e2e3e1-6940-4e58-b5a2-f7f78296bde2', 'ticket_id': '0250803f-ae20-4a70-b7e5-d51d060e2309', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to book a conference room for a meeting next week, but the system isn't letting me. Also, I need to confirm my attendance for an event. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': 'daabf738-e0ce-4092-a662-d6ede99906c3', 'ticket_id': 'ce7f66b0-fabc-4fcb-b0e0-aa1978b6efdf', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': 'c490c4ae-ca0b-4423-87e3-b0f297fedcf1', 'ticket_id': '7e42fee2-1d8e-4a13-b0d6-f491246bc115', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble logging into my account to confirm my attendance for an upcoming event. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': '4e5f2b7d-782f-40b5-9bb3-70fb67898021', 'ticket_id': '3ada43d2-9481-4c4c-bf5d-737864b9daeb', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm interested in attending one of your events, but I'm not sure about the pricing. Can you provide more information on the cost and any discounts available?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': '3bbaa311-07d9-4d2a-a7e1-d67453782883', 'ticket_id': 'c522b03c-3b10-4303-9cdc-5c03923a5720', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to cancel a booking I made for next week. The system isn't allowing me to do it online. Can you assist me with this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': '23b0e4dd-4b24-472d-88ce-2ddaed27e36e', 'ticket_id': 'd1e63cac-ea52-4ab2-b94a-d4aa33b37eb4', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I need to cancel a reservation I made for an event next month. Also, I'm having trouble logging into my account to confirm my attendance. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': '98c8db47-a208-4948-b1ac-0a351560afd2', 'ticket_id': '7279357a-c07e-493a-b049-56d00f3a9cbb', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm trying to understand the pricing for your services, but it's a bit confusing. Also, I have some questions about my billing statement. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': '5c4901cd-a51a-4fad-ae3f-ff3ef61c7424', 'ticket_id': '10da9fb6-2c69-4bc8-b167-cfe8e918b294', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I need to confirm my attendance for an upcoming event, but I'm having trouble with the system. Also, I have some questions about my billing statement. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': '86e08c41-53d9-47d9-b801-bc3081c23857', 'ticket_id': 'baba08ae-bef9-4684-871e-fb118c78e5fd', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm interested in learning more about the benefits package offered by your company. Can you provide more information on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': 'b03044f9-03ab-4481-9d92-f24b4e873fcb', 'ticket_id': '30ee1127-561d-4539-a5e0-b0d9358ef01d', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm having trouble with my subscription. It seems like there are some issues with the pricing, and I would like to escalate this matter. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'message_id': '1c672a97-82e0-4df3-96ed-267b4d7a5248', 'ticket_id': 'baa370de-7eb7-4ca7-8d8a-05468c5be0d4', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to cancel my subscription, but I'm having trouble with the system. Also, I have some questions about the pricing. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '07d95f98-9612-4698-a5d3-a34bb9f2a120', 'ticket_id': 'ec456385-1868-4d17-9696-37d91a7b1704', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I forgot my password and can't reset it. Can you help me regain access to my account?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'b9dbc27f-a61a-4a8c-b316-a70d80d4d1f5', 'ticket_id': '935a9b38-95eb-4946-bc77-ac827b579369', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my password and can't log in to my account. Also, I have some questions about the benefits package offered by your company. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '80af1a2a-1028-4f77-86b6-d95678c3788c', 'ticket_id': '6d7e0ff7-cd3b-4f7f-9e2e-cf659e58a541', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I have some questions about my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'f4264bdb-fe22-4295-854e-b60878d4235d', 'ticket_id': '8fde2885-4410-411a-8cf3-0f770d0da2e0', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm interested in booking a meeting room for next week, but I'm having trouble with the system. Also, I have some questions about the benefits package offered by your company. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '6d09cb82-0469-4d53-894e-0d89cc6efadf', 'ticket_id': '4a730ff9-c0d1-46cc-9d1c-f57efe643e6d', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I need to cancel my subscription, but I'm having trouble with the system. Also, I have some questions about the benefits package offered by your company. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'cc66dd79-f64b-47d9-9f7d-12d8ab096201', 'ticket_id': 'decb47c1-3014-4bb9-bca0-495a9bc4d6a5', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to confirm my attendance for an upcoming event, but I'm having trouble with the system. Also, I have some questions about my billing statement. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '1d8f8d65-f839-453a-9566-919db44e39b8', 'ticket_id': '19f63dbc-42a8-44cc-a6ff-84206ddfdda2', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm having trouble with my password and can't log in to my account. Also, I have some questions about my subscription. Can you help me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '7aef6727-6ed3-4355-91d5-ce9301a642c5', 'ticket_id': 'd6dc9534-5ce6-42a3-993c-42d49d3aaae6', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm interested in learning more about the benefits package offered by your company. Can you provide more information on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '39793746-415e-4220-9e12-cae4ff4f315d', 'ticket_id': '242aa04b-8823-49a9-9fb2-9cfb8e271ce7', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm having trouble logging into my account. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '560a7307-130a-49cb-b838-b283cafa4b95', 'ticket_id': 'b32dbb63-94e9-4389-825f-4c3a52e99772', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I need to book a meeting room for next week, but I'm having trouble with the system. Also, I forgot my password and can't reset it. Can you assist me with these issues?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '800e94d4-f45c-44a1-b771-7e53d6470226', 'ticket_id': 'a07d46a7-e617-4679-8949-99889f8b20e4', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm interested in attending one of your events, but I'm not sure about the pricing. Can you provide more information on the cost and any discounts available?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'd466f06f-e1c8-42f6-8c39-fd1a2650314d', 'ticket_id': '30dce630-ba3f-4757-ba3c-45f40556618a', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'ce2aac70-6d49-49fd-9ca9-68889bea753d', 'ticket_id': 'ea5158b6-9e2c-4204-adef-4f1294bfa480', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '21d375f0-c823-4220-96c4-3ed37b42d57e', 'ticket_id': 'fbdafed4-9f71-475a-bc5f-f24ddb1ab4d1', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'e897bb95-43a0-4e4b-9a1e-16c32fef89e2', 'ticket_id': '844e890c-05b1-41a6-8d9b-38e9bd3ee2ad', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm interested in learning more about the benefits package offered by your company. Can you provide more information on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'dd863e78-d807-4c8f-b5e2-e174736e4a39', 'ticket_id': '0c5d52b7-3816-4c1c-bc21-f0d9c3f04798', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'ff2c4596-857c-42ea-985c-45d26654f17d', 'ticket_id': 'f65dda97-ef51-4b31-8e86-152c4f6c32c7', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'a69c4635-e959-4fbc-bce0-ecd6cf7dc778', 'ticket_id': 'f3c1a1dc-1d32-4753-a0c8-2e59bee50a02', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '30d38baf-6ef0-471c-9f3f-45551a690ddd', 'ticket_id': '797f0697-4601-4737-8739-243d21b80e4e', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm interested in booking a meeting room for next week, but I'm having trouble with the system. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '8d4b24c2-3fff-47b8-a981-4a96e2ed8754', 'ticket_id': '4176a8d7-eba5-41de-bd2d-496d06270efb', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'ff03934b-24df-49f8-8728-217337a6168c', 'ticket_id': '4e72d3ad-2217-40ca-b871-f6eb29111a27', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'a53ac12e-29fa-444c-a57e-02404e12fc05', 'ticket_id': '225f7b4f-31e2-4f25-9a84-ae2b75976de4', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '1732931c-63c6-405f-97ad-d1c288cdcd67', 'ticket_id': '9a17c244-5d15-481e-9542-361bc56104b7', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm interested in learning more about the benefits package offered by your company. Can you provide more information on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '96bcf0b7-1f54-452c-88b2-f48994888a72', 'ticket_id': '31d722cc-c643-465f-976f-2a6dfca73655', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '0315e326-110f-4d50-a878-8051bba60f52', 'ticket_id': '17efcb6d-09ff-4e5d-befe-27793afa81b4', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '8174b52d-43f1-4ba1-9d50-7711992cd602', 'ticket_id': 'be71103a-51db-4a11-8bed-b2e8caa6009e', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '1d8b900f-e82e-485e-9ed6-10b3e7e60f81', 'ticket_id': '75fe88d1-3caa-487c-8443-e75e546c73d0', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm interested in learning more about the benefits package offered by your company. Can you provide more information on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '7836e6d5-8b72-4750-b455-4ce8a7d5bb11', 'ticket_id': '87426525-9f6e-431e-8ee1-a33c53b224b6', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '1854efba-9106-44f2-a427-c57ba7b550f2', 'ticket_id': 'c2f08594-6065-40a9-af28-790c904e69b9', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'c19d6834-b3a1-4587-a725-b898716651ab', 'ticket_id': 'c88d65b7-183c-460a-8ac4-9984b57ec43e', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': 'f5dc5f63-5d78-4b43-8de5-fa7931deffb2', 'ticket_id': '7c5971fd-2c6f-4611-968c-af6936cda678', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm interested in booking a meeting room for next week, but I'm having trouble with the system. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '4ffcdb75-3568-4373-9476-0b93dc38f5c4', 'ticket_id': 'a31d98b5-0595-484a-9e37-e202ae59c75d', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my billing statement. It seems like there are some charges that I don't recognize. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '1b064c11-f80c-4b46-9434-f3e4b164295a', 'ticket_id': '71a7c157-2470-4d7f-88d1-a3436b5147e6', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I'm trying to understand the pricing structure for your services. It seems a bit confusing, and I want to make sure I'm getting the best deal. Can you provide more clarity on this?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'message_id': '7e23378b-79f9-42b2-a4a6-72f525ca2a91', 'ticket_id': '75044d91-d661-45f7-9e23-45d003d8a0d2', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I'm having trouble with my password and can't log in to my account. Can you help me resolve this issue?", 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}

# %%
with get_session(engine) as session:
    metas = session.query(udahub.TicketMetadata).all()
    for meta in metas:
        # Get all column names for this model
        inst = inspect(meta)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(meta, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'ticket_id': '63baf1dd-4a03-48ef-af6d-50d1acda37ce', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits, events', 'urgency_score': 0.5195484684346362, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '9abc0d19-2fcf-446e-92ce-506a96fe7d71', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, pause, escalation', 'urgency_score': 0.5310550603806578, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '7c08b1c1-a861-4f44-88ef-d5755d56476f', 'status': 'open', 'main_issue_type': None, 'tags': 'access', 'urgency_score': 0.7051492266640028, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'f52f9d01-1b6f-4756-83f3-0acef94df3ea', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, password', 'urgency_score': 0.7777411191801659, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '043952d6-66f3-4b42-804e-e2ed95700e8f', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, login, reservation', 'urgency_score': 0.6179937280422846, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '0250803f-ae20-4a70-b7e5-d51d060e2309', 'status': 'open', 'main_issue_type': None, 'tags': 'attendance, booking', 'urgency_score': 0.3548505314723145, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'ce7f66b0-fabc-4fcb-b0e0-aa1978b6efdf', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing', 'urgency_score': 0.09363033577965219, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '7e42fee2-1d8e-4a13-b0d6-f491246bc115', 'status': 'open', 'main_issue_type': None, 'tags': 'login, attendance', 'urgency_score': 0.9798152054416563, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '3ada43d2-9481-4c4c-bf5d-737864b9daeb', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, events', 'urgency_score': 0.9640318417204223, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'c522b03c-3b10-4303-9cdc-5c03923a5720', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, cancelation', 'urgency_score': 0.8164041488454662, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'd1e63cac-ea52-4ab2-b94a-d4aa33b37eb4', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, cancelation, login', 'urgency_score': 0.5521852066090321, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '7279357a-c07e-493a-b049-56d00f3a9cbb', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, billing', 'urgency_score': 0.20175335995027555, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '10da9fb6-2c69-4bc8-b167-cfe8e918b294', 'status': 'open', 'main_issue_type': None, 'tags': 'attendance, billing', 'urgency_score': 0.7971430768674755, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'baba08ae-bef9-4684-871e-fb118c78e5fd', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits', 'urgency_score': 0.5157465248955276, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': '30ee1127-561d-4539-a5e0-b0d9358ef01d', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, pricing, escalation', 'urgency_score': 0.3338784426742113, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 4), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 4)}
# {'ticket_id': 'baa370de-7eb7-4ca7-8d8a-05468c5be0d4', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, cancelation', 'urgency_score': 0.5996054973225581, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'ec456385-1868-4d17-9696-37d91a7b1704', 'status': 'open', 'main_issue_type': None, 'tags': 'password', 'urgency_score': 0.7290613702013894, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '935a9b38-95eb-4946-bc77-ac827b579369', 'status': 'open', 'main_issue_type': None, 'tags': 'password, benefits', 'urgency_score': 0.150827837789843, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '6d7e0ff7-cd3b-4f7f-9e2e-cf659e58a541', 'status': 'open', 'main_issue_type': None, 'tags': 'billing', 'urgency_score': 0.7104373830442426, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '8fde2885-4410-411a-8cf3-0f770d0da2e0', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, benefits', 'urgency_score': 0.6692724184855047, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '4a730ff9-c0d1-46cc-9d1c-f57efe643e6d', 'status': 'open', 'main_issue_type': None, 'tags': 'cancelation, benefits', 'urgency_score': 0.9274179521743936, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'decb47c1-3014-4bb9-bca0-495a9bc4d6a5', 'status': 'open', 'main_issue_type': None, 'tags': 'attendance, billing', 'urgency_score': 0.1729198286481538, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '19f63dbc-42a8-44cc-a6ff-84206ddfdda2', 'status': 'open', 'main_issue_type': None, 'tags': 'password, subscription', 'urgency_score': 0.5489753604305861, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'd6dc9534-5ce6-42a3-993c-42d49d3aaae6', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits', 'urgency_score': 0.7191672305740879, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '242aa04b-8823-49a9-9fb2-9cfb8e271ce7', 'status': 'open', 'main_issue_type': None, 'tags': 'login', 'urgency_score': 0.8440221289928597, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'b32dbb63-94e9-4389-825f-4c3a52e99772', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, password', 'urgency_score': 0.6394121714860129, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'a07d46a7-e617-4679-8949-99889f8b20e4', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, events', 'urgency_score': 0.29983169650329533, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '30dce630-ba3f-4757-ba3c-45f40556618a', 'status': 'open', 'main_issue_type': None, 'tags': 'billing', 'urgency_score': 0.3245928081885019, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'ea5158b6-9e2c-4204-adef-4f1294bfa480', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing', 'urgency_score': 0.06305332055515533, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'fbdafed4-9f71-475a-bc5f-f24ddb1ab4d1', 'status': 'open', 'main_issue_type': None, 'tags': 'password', 'urgency_score': 0.1593570530165177, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '844e890c-05b1-41a6-8d9b-38e9bd3ee2ad', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits', 'urgency_score': 0.642069676587569, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '0c5d52b7-3816-4c1c-bc21-f0d9c3f04798', 'status': 'open', 'main_issue_type': None, 'tags': 'billing', 'urgency_score': 0.6264627874362578, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'f65dda97-ef51-4b31-8e86-152c4f6c32c7', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing', 'urgency_score': 0.7685027120849381, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'f3c1a1dc-1d32-4753-a0c8-2e59bee50a02', 'status': 'open', 'main_issue_type': None, 'tags': 'password', 'urgency_score': 0.5678012781648908, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '797f0697-4601-4737-8739-243d21b80e4e', 'status': 'open', 'main_issue_type': None, 'tags': 'booking', 'urgency_score': 0.9754515442984288, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '4176a8d7-eba5-41de-bd2d-496d06270efb', 'status': 'open', 'main_issue_type': None, 'tags': 'billing', 'urgency_score': 0.5974908448880577, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '4e72d3ad-2217-40ca-b871-f6eb29111a27', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing', 'urgency_score': 0.5678024580914267, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '225f7b4f-31e2-4f25-9a84-ae2b75976de4', 'status': 'open', 'main_issue_type': None, 'tags': 'password', 'urgency_score': 0.44852157589735453, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '9a17c244-5d15-481e-9542-361bc56104b7', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits', 'urgency_score': 0.15147265996439163, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '31d722cc-c643-465f-976f-2a6dfca73655', 'status': 'open', 'main_issue_type': None, 'tags': 'billing', 'urgency_score': 0.06238699518257451, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '17efcb6d-09ff-4e5d-befe-27793afa81b4', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing', 'urgency_score': 0.23309441212878423, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'be71103a-51db-4a11-8bed-b2e8caa6009e', 'status': 'open', 'main_issue_type': None, 'tags': 'password', 'urgency_score': 0.26268877684321257, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '75fe88d1-3caa-487c-8443-e75e546c73d0', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits', 'urgency_score': 0.1355290729639057, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '87426525-9f6e-431e-8ee1-a33c53b224b6', 'status': 'open', 'main_issue_type': None, 'tags': 'billing', 'urgency_score': 0.1508589008110921, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'c2f08594-6065-40a9-af28-790c904e69b9', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing', 'urgency_score': 0.5354603105601271, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'c88d65b7-183c-460a-8ac4-9984b57ec43e', 'status': 'open', 'main_issue_type': None, 'tags': 'password', 'urgency_score': 0.6085076372826743, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '7c5971fd-2c6f-4611-968c-af6936cda678', 'status': 'open', 'main_issue_type': None, 'tags': 'booking', 'urgency_score': 0.07583724702809058, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': 'a31d98b5-0595-484a-9e37-e202ae59c75d', 'status': 'open', 'main_issue_type': None, 'tags': 'billing', 'urgency_score': 0.4817102677031393, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '71a7c157-2470-4d7f-88d1-a3436b5147e6', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing', 'urgency_score': 0.9732895043410966, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}
# {'ticket_id': '75044d91-d661-45f7-9e23-45d003d8a0d2', 'status': 'open', 'main_issue_type': None, 'tags': 'password', 'urgency_score': 0.2685559843751161, 'created_at': datetime.datetime(2026, 4, 18, 19, 59, 5), 'updated_at': datetime.datetime(2026, 4, 18, 19, 59, 5)}

# %%
with get_session(engine) as session:
    user = session.query(udahub.User).filter_by(
        account_id=account_id,
        external_user_id=ticket_table.iloc[2].to_dict()["owner_id"],
    ).first()
    
    ticket:udahub.Ticket = user.tickets[0]
    for message in ticket.messages:
        print(message)
# Out:
# <TicketMessage(message_id='3a124ca6-7b8e-4453-931f-53b9172c357d', role='user', content='Hi, I'm having trouble accessi...')>
