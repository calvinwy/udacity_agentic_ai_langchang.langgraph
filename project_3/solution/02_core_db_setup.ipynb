# %%
import json
import uuid
from sqlalchemy import create_engine, inspect
from utils import reset_db, get_session, model_to_dict
from data.models import udahub

# %% [markdown]
# # Udahub Application

# %% [markdown]
# ## Core Database

# %% [markdown]
# **Init DB**

# %%
udahub_db = "data/core/udahub.db"
reset_db(udahub_db)
engine = create_engine(f"sqlite:///{udahub_db}", echo=False)
udahub.Base.metadata.create_all(bind=engine)
# Out:
# 2026-04-12 01:03:49,488 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-04-12 01:03:49,488 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Recreated data/core/udahub.db with fresh schema

# %% [markdown]
# **Account**

# %%
account_id = "cultpass"
account_name = "CultPass Card"

with get_session(engine) as session:
    account = udahub.Account(
        account_id=account_id,
        account_name=account_name,
    )
    session.add(account)

# %% [markdown]
# ---

# %% [markdown]
# ## Integrations

# %% [markdown]
# **Use LLM to Generate Sample Data**

# %%
import os
import pandas as pd
import random
from dotenv import load_dotenv
from typing import List
from pydantic import BaseModel, Field
from typing import List, Optional, Dict, Any, Literal, TypedDict, Annotated
from langgraph.prebuilt import create_react_agent
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.prompts import PromptTemplate
from langchain_core.messages import SystemMessage
from langchain_chroma import Chroma
from langchain_core.documents import Document

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# llm_base_url = "https://openai.vocareum.com/v1"

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0.0,
    # base_url=llm_base_url,
    api_key=OPENAI_API_KEY,
)

embeddings_fn = OpenAIEmbeddings(
    model="text-embedding-3-large",
    # base_url=llm_base_url,
    api_key=OPENAI_API_KEY,
)

# %% [markdown]
# **Data Generation Parameters**

# %%
num_articles = 20
num_account = 10
num_user = 25
num_ticket = 50
num_msg = num_ticket
num_expected_tag_msg = round(num_msg * 0.8)
num_unexpected_tag_msg = num_msg - num_expected_tag_msg
chromadb_directory = "vectorstore"
collection_name = "knowledge_vecotr_store"

# %% [markdown]
# ### Sampling Schema
#
# For LLM to produce the data samples

# %%
class ArticlesSchema(BaseModel):
    title: Annotated[str, Field(description="Title of the article.")]
    content: Annotated[str, Field(description="Content of the article.")]
    tags: Annotated[str, Field(description="Tags of the article")]

class ArticlesListSchema(BaseModel):
    samples: Annotated[List[ArticlesSchema], Field(description="List of CultpassArticles")]

class AccountSamples(BaseModel):
    """Structured response for account table"""
    company_name: List[str] = Field(description="List of first name and last name")

class UsersSchema(BaseModel):
    name: Annotated[str, Field(description="User's name with first and last name.")]
    email: Annotated[str, Field(description="User's email address.")]
    is_blocked: Annotated[bool, Field(description="User's blocking status.")]
    account_id: Annotated[str, Field(description="Company account ID")]

class UsersListSchema(BaseModel):
    samples: Annotated[List[UsersSchema], Field(description="List of users")]

class SingleTicket(BaseModel):
    """Structured response for a ticket"""
    status: Annotated[Literal['open','pending','closed'], Field(description="Status of the ticket")]
    content: Annotated[str, Field(description="The ticket body message content.")]
    owner_id: Annotated[str, Field(description="User ID")]
    owner_name: Annotated[str, Field(description="User's name")]
    channel: Annotated[Literal['email','chat','web','sms','social','phone'], Field(description="Ticket priority")]
    tags: Annotated[str, Field(description="List of tags used for creating this message")]
    account_id: Annotated[str, Field(description="Company account ID")]
    urgency_score: Annotated[float, Field(description="Urgency of the ticket")]

class TicketSamples(BaseModel):
    """Structured response of ticket list"""
    samples: List[SingleTicket]

# %% [markdown]
# ## Loading Default Data
#
# * Knowledge Base
# * Users Data

# %%
# Load Sample Articles
cultpass_articles = []
with open('data/external/cultpass_articles.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_articles.append(json.loads(line))

# Extract Tags from Samples
sample_tags = [ article['tags'].split(', ') for article in cultpass_articles ]
sample_tags = set([ item for subtags in sample_tags for item in subtags ])
sample_tags_str = ", ".join(sample_tags)

# Define Tags with Expected Knowledge and Tags without Expected Knowledge
# (This is for sampling ticket questions "with vs without knowledge to answer" using LLM)
expected_tags = sample_tags
unexpected_tags = ['weather', 'stock price', 'dietary', 'health advice']

# %%
sample_tags
# Out:
# {'access',
#  'attendance',
#  'benefits',
#  'billing',
#  'booking',
#  'cancelation',
#  'escalation',
#  'events',
#  'login',
#  'password',
#  'pause',
#  'pricing',
#  'reservation',
#  'subscription'}

# %%
# Load Users Data
cultpass_users = []
with open('data/external/cultpass_users.jsonl', 'r', encoding='utf-8') as f:
    for line in f:
        cultpass_users.append(json.loads(line))

# %% [markdown]
# #### Generate Knowledge Articles

# %%
# Create Additional Knowledge Articles
num_cultpass_articles = len(cultpass_articles)
num_new_articles = num_articles - num_cultpass_articles
sample_articles_template = """
    You are an helpful expert creating sample of python sample article data based on given examples.  Do not provide any additional description or explanation.
    There is a mock-up project, it has the following description:

    You’ve joined a fast-growing AI startup building the next frontier in customer support automation. Your team is responsible for building UDA-Hub, 
    a Universal Decision Agent designed to plug into existing customer support systems (Zendesk, Intercom, Freshdesk, internal CRMs) and intelligently 
    resolve tickets. You need to generate sample knowledge articles in area including: {sample_tags}.  
    
    The knowledge areas given above will be used as tags for the generated articles.

    The first UDA-Hub customer Cultpass has the following sample articles to be used as knowledge to be used by the system:
    {samples}

    Cultpass is a online travel and leisure platform that provides a subscription-based card for travelers, offering access to airport lounges, travel discounts, 
    and exclusive experiences worldwide. Please create the new articles based on this context and the sample articles provided above.

    Provide {num_articles} more example like above and double check if all articles uses tags from {sample_tags}, if not try again.
    """

sample_articles_prompt = PromptTemplate(
    template = sample_articles_template,
    input_variables = ["samples","num_articles","sample_tags"],
    ).invoke({"samples": cultpass_articles,
              "num_articles": num_new_articles,
              "sample_tags": sample_tags}).to_messages()

new_cultpass_articles = llm.with_structured_output(ArticlesListSchema).invoke(sample_articles_prompt).model_dump()['samples']
cultpass_articles_ls = cultpass_articles + new_cultpass_articles

# Extracting Sample Tags for Each Sample
# new_sample_tags = [ article['tags'].split(', ') for article in cultpass_articles_ls ]
# new_sample_tags = set([ item for subtags in new_sample_tags for item in subtags ])
# new_sample_tags_str = ", ".join(new_sample_tags)

if len(cultpass_articles_ls) < 14:
    raise AssertionError("You should load the articles with at least 14 records")

# %%
cultpass_articles_ls
# Out:
# [{'title': 'How to Reserve a Spot for an Event',
#   'content': 'If a user asks how to reserve an event:\n\n- Guide them to the CultPass app\n- Instruct them to browse the experience catalog and tap \'Reserve\'\n- If it\'s a premium or limited event, check if reservation confirmation is required via email\n- Remind them to arrive at least 15 minutes early with their QR code visible\n\n**Suggested phrasing:**\n"You can reserve an experience by opening the CultPass app, selecting your desired event, and tapping \'Reserve\'. Be sure to arrive 15 minutes early with your QR code ready."',
#   'tags': 'reservation, events, booking, attendance'},
#  {'title': "What's Included in a CultPass Subscription",
#   'content': 'Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."',
#   'tags': 'subscription, benefits, pricing, access'},
#  {'title': 'How to Cancel or Pause a Subscription',
#   'content': 'Users can manage their subscription via the app > \'My Account\' > \'Manage Plan\'.\n\n- Cancel: Effective at the end of the billing cycle\n- Pause: Preserves user data, resumes automatically when reactivated\n- Do NOT offer refunds unless approved by support lead\n\n**Suggested phrasing:**\n"You can cancel or pause your subscription at any time via the \'My Account\' section in the CultPass app. Cancelation takes effect at the end of your billing cycle."',
#   'tags': 'cancelation, pause, subscription, billing'},
#  {'title': 'How to Handle Login Issues?',
#   'content': 'Most login issues are resolved with password reset:\n\n- Ask the user to tap \'Forgot Password\' on the login screen\n- Ensure they are using the correct registered email\n- If they did not receive the reset email, check spam folder or retry after 10 minutes\n- For persistent login issues, escalate to human support\n\n**Suggested phrasing:**\n"Try tapping \'Forgot Password\' on the login screen. Make sure you\'re using the email associated with your account. If the email doesn\'t arrive, check spam or try again in a few minutes."',
#   'tags': 'login, password, access, escalation'},
#  {'title': 'How to Access Airport Lounges with CultPass',
#   'content': 'To access airport lounges:\n\n- Open the CultPass app and navigate to \'Airport Lounges\'\n- Select your desired lounge and tap \'Access\'\n- Show the QR code at the lounge entrance\n\n**Suggested phrasing:**\n"Access airport lounges by selecting \'Airport Lounges\' in the CultPass app and showing your QR code at the entrance."',
#   'tags': 'access, benefits, reservation'},
#  {'title': 'Booking Exclusive Travel Experiences',
#   'content': 'To book exclusive travel experiences:\n\n- Open the CultPass app and browse the \'Exclusive Experiences\' section\n- Select an experience and tap \'Book Now\'\n- Confirm your booking details and receive a confirmation email\n\n**Suggested phrasing:**\n"Book exclusive travel experiences by browsing the \'Exclusive Experiences\' section in the CultPass app and tapping \'Book Now\'."',
#   'tags': 'booking, events, reservation'},
#  {'title': 'Understanding CultPass Pricing Tiers',
#   'content': 'CultPass offers multiple pricing tiers:\n\n- Basic: Access to standard experiences\n- Premium: Includes premium experiences and airport lounges\n- VIP: All-inclusive access with additional perks\n\n**Suggested phrasing:**\n"CultPass offers Basic, Premium, and VIP pricing tiers, each with unique benefits and access levels."',
#   'tags': 'pricing, benefits, subscription'},
#  {'title': 'How to Update Payment Information',
#   'content': 'To update payment information:\n\n- Go to \'My Account\' in the CultPass app\n- Select \'Payment Methods\' and update your card details\n- Ensure your billing address is correct\n\n**Suggested phrasing:**\n"Update your payment information by navigating to \'My Account\' and selecting \'Payment Methods\' in the CultPass app."',
#   'tags': 'billing, access, subscription'},
#  {'title': 'Resolving Event Attendance Issues',
#   'content': 'If you encounter issues attending an event:\n\n- Check your reservation status in the CultPass app\n- Ensure you have the correct date and time\n- Contact support if issues persist\n\n**Suggested phrasing:**\n"Verify your reservation status and event details in the CultPass app. Contact support for further assistance."',
#   'tags': 'attendance, events, reservation'},
#  {'title': 'How to Escalate a Support Ticket',
#   'content': 'To escalate a support ticket:\n\n- Open the CultPass app and go to \'Support\'\n- Select your ticket and tap \'Escalate\'\n- Provide additional details if necessary\n\n**Suggested phrasing:**\n"Escalate a support ticket by selecting \'Support\' in the CultPass app and tapping \'Escalate\' on your ticket."',
#   'tags': 'escalation, access, support'},
#  {'title': 'Managing Multiple CultPass Accounts',
#   'content': 'To manage multiple accounts:\n\n- Log out of your current account in the CultPass app\n- Tap \'Switch Account\' and enter the credentials for the other account\n- Ensure each account has a unique email\n\n**Suggested phrasing:**\n"Switch between multiple CultPass accounts by logging out and tapping \'Switch Account\' in the app."',
#   'tags': 'login, access, password'},
#  {'title': 'How to Pause Your CultPass Subscription',
#   'content': 'To pause your subscription:\n\n- Navigate to \'My Account\' in the CultPass app\n- Select \'Manage Plan\' and choose \'Pause Subscription\'\n- Confirm your choice and review the pause terms\n\n**Suggested phrasing:**\n"Pause your CultPass subscription by selecting \'Manage Plan\' and choosing \'Pause Subscription\' in the app."',
#   'tags': 'pause, subscription, billing'},
#  {'title': 'Troubleshooting Password Reset Issues',
#   'content': 'If you encounter issues resetting your password:\n\n- Ensure you are using the correct email\n- Check your spam folder for the reset email\n- Retry the reset process after 10 minutes\n\n**Suggested phrasing:**\n"Ensure you\'re using the correct email and check your spam folder if you don\'t receive the reset email."',
#   'tags': 'password, login, escalation'},
#  {'title': 'How to Cancel a Booking',
#   'content': 'To cancel a booking:\n\n- Open the CultPass app and go to \'My Bookings\'\n- Select the booking you wish to cancel and tap \'Cancel\'\n- Confirm the cancellation and review any applicable fees\n\n**Suggested phrasing:**\n"Cancel a booking by selecting \'My Bookings\' in the CultPass app and tapping \'Cancel\' on the desired booking."',
#   'tags': 'cancelation, booking, reservation'},
#  {'title': 'Understanding CultPass Benefits',
#   'content': 'CultPass offers a range of benefits:\n\n- Access to exclusive events and experiences\n- Discounts on travel and accommodations\n- Priority support and assistance\n\n**Suggested phrasing:**\n"Enjoy exclusive events, travel discounts, and priority support with your CultPass subscription."',
#   'tags': 'benefits, subscription, access'},
#  {'title': 'How to Change Your CultPass Plan',
#   'content': 'To change your plan:\n\n- Go to \'My Account\' in the CultPass app\n- Select \'Manage Plan\' and choose a new plan\n- Confirm your selection and review the new plan details\n\n**Suggested phrasing:**\n"Change your CultPass plan by selecting \'Manage Plan\' in the app and choosing a new plan."',
#   'tags': 'subscription, billing, access'},
#  {'title': 'Handling Event Overbooking',
#   'content': 'If an event is overbooked:\n\n- Check for alternative dates or times in the CultPass app\n- Contact support for assistance with rebooking\n- Consider attending a different event\n\n**Suggested phrasing:**\n"If an event is overbooked, check for alternative dates or contact support for rebooking assistance."',
#   'tags': 'booking, events, escalation'},
#  {'title': 'How to Verify Your CultPass Account',
#   'content': 'To verify your account:\n\n- Open the CultPass app and go to \'My Account\'\n- Tap \'Verify Account\' and follow the on-screen instructions\n- Ensure your email and phone number are correct\n\n**Suggested phrasing:**\n"Verify your CultPass account by selecting \'My Account\' and tapping \'Verify Account\' in the app."',
#   'tags': 'access, login, verification'},
#  {'title': 'Resolving Billing Discrepancies',
#   'content': 'If you notice billing discrepancies:\n\n- Review your billing history in the CultPass app\n- Ensure your payment method is up-to-date\n- Contact support for further investigation\n\n**Suggested phrasing:**\n"Review your billing history in the CultPass app and contact support if discrepancies persist."',
#   'tags': 'billing, escalation, subscription'},
#  {'title': 'How to Attend Virtual Events',
#   'content': 'To attend virtual events:\n\n- Open the CultPass app and navigate to \'Virtual Events\'\n- Select an event and tap \'Join Now\'\n- Ensure you have a stable internet connection\n\n**Suggested phrasing:**\n"Attend virtual events by selecting \'Virtual Events\' in the CultPass app and tapping \'Join Now\'."',
#   'tags': 'attendance, events, access'}]

# %% [markdown]
# Creating Vector Embedding for RAG

# %%
# Create vector store for knowledge articles
vector_store = Chroma(
    collection_name=collection_name,
    embedding_function=embeddings_fn,
    persist_directory=chromadb_directory,
)

cultpass_articles_docs = [ Document(page_content=article['title']+": "+article["content"],
                                      metadata={"tags": article['tags']},
                                      id=i) for i, article in enumerate(cultpass_articles_ls) ]
_ = vector_store.add_documents(documents=cultpass_articles_docs)

# %%
question = "Hi, I have a question regarding the billing for the events I attended last month. There seems to be a discrepancy in the charges, and I would like to understand the breakdown of the costs. Could you please provide a detailed billing statement? Thank you."
vector_store.similarity_search(question)
# Out:
# [Document(id='18', metadata={'tags': 'billing, escalation, subscription'}, page_content='Resolving Billing Discrepancies: If you notice billing discrepancies:\n\n- Review your billing history in the CultPass app\n- Ensure your payment method is up-to-date\n- Contact support for further investigation\n\n**Suggested phrasing:**\n"Review your billing history in the CultPass app and contact support if discrepancies persist."'),
#  Document(id='8', metadata={'tags': 'attendance, events, reservation'}, page_content='Resolving Event Attendance Issues: If you encounter issues attending an event:\n\n- Check your reservation status in the CultPass app\n- Ensure you have the correct date and time\n- Contact support if issues persist\n\n**Suggested phrasing:**\n"Verify your reservation status and event details in the CultPass app. Contact support for further assistance."'),
#  Document(id='1', metadata={'tags': 'subscription, benefits, pricing, access'}, page_content='What\'s Included in a CultPass Subscription: Each user is entitled to 4 cultural experiences per month, which may include:\n- Art exhibitions\n- Museum entries\n- Music concerts\n- Film screenings and more\n\nSome premium experiences may require an additional fee (visible in the app).\n\n**Suggested phrasing:**\n"Your CultPass subscription includes 4 curated experiences each month. You can choose from museums, concerts, film events and more. Premium events may have an extra cost, which is shown during reservation."'),
#  Document(id='16', metadata={'tags': 'booking, events, escalation'}, page_content='Handling Event Overbooking: If an event is overbooked:\n\n- Check for alternative dates or times in the CultPass app\n- Contact support for assistance with rebooking\n- Consider attending a different event\n\n**Suggested phrasing:**\n"If an event is overbooked, check for alternative dates or contact support for rebooking assistance."')]

# %% [markdown]
# #### Generate Users and Tickets

# %%
# Create Company List
account_prompt_template = """You are a company naming expert. Please come up with {num_account} company names."""

account_prompt = PromptTemplate(
    template = account_prompt_template,
    input_variables = ["num_account"],
    ).invoke({"num_account": num_account}).to_messages()

account = llm.with_structured_output(AccountSamples).invoke(account_prompt).model_dump()['company_name']
account_table = pd.DataFrame({"company_name": account})
# account_table['id'] = account_table.index
account_table['account_id'] = [ str(uuid.uuid4()) for i in range(num_account) ]
account_table_ls = account_table.to_dict(orient='records')
# account_table

# %%
# Create Additional Users
num_cultpass_users = len(cultpass_users)
num_new_users = num_user - num_cultpass_users
user_prompt_template = """
    You are a people naming expert. Please come up with {num_user} names with both first and last name.
    Randomly choose a company for each user from the account list and based on the name of the company,
    create an email address for this person.  Some companies should have more users than others.
    All users from the same company must have the same domain name on their email address.

    The `is_blocked` status should be randomly choosen as 'True' or 'False'

    List of account (companies): {account_table}"""

user_prompt = PromptTemplate(
    template = user_prompt_template,
    input_variables = ["num_user","account_table"],
    ).invoke({"num_user": num_new_users, "account_table": account_table}).to_messages()

user_ls = llm.with_structured_output(UsersListSchema).invoke(user_prompt).model_dump()['samples']
user_table = pd.DataFrame(user_ls)
user_table['id'] = [ str(uuid.uuid4().hex[:6]) for i in range(num_new_users) ]
user_table = user_table[['id', 'name', 'email', 'is_blocked','account_id']]
cultpass_users_table = pd.DataFrame(cultpass_users)
user_table = pd.concat([user_table, cultpass_users_table])
user_table['account_id'] = [ str(uuid.uuid4()) for i in range(num_user) ]     # account ID of LLM generated user should be replaced with true uuid4.

# %%
cultpass_users_table
# Out:
#        id            name                          email  is_blocked
# 0  a4ab87  Alice Kingsley  alice.kingsley@wonderland.com        True
# 1  f556c0       Bob Stone          bob.stone@granite.com       False
# 2  88382b     Cathy Bloom        cathy.bloom@florals.org       False
# 3  888fb2      David Noir      david.noir@shadowmail.com        True
# 4  f1f10d       Eva Green          eva.green@ecosoul.net       False
# 5  e6376d     Frank Ocean        frank.ocean@seawaves.io       False

# %%
user_table
# Out:
#         id             name                                     email  \
# 0   cf5b19    Alice Johnson     alice.johnson@innovatechsolutions.com
# 1   b6cde6        Bob Smith         bob.smith@innovatechsolutions.com
# 2   441882    Charlie Brown     charlie.brown@ecospherenterprises.com
# 3   7079d5     Diana Prince      diana.prince@quantumleapdynamics.com
# 4   41caaf       Ethan Hunt      ethan.hunt@greenwavetechnologies.com
# 5   693372  Fiona Gallagher       fiona.gallagher@skylineventures.com
# 6   a95423   George Clooney        george.clooney@apexinnovations.com
# 7   c0b2de   Hannah Montana  hannah.montana@bluehorizonindustries.com
# 8   3dab96      Ian Fleming          ian.fleming@pinnaclepathways.com
# 9   b598ab     Jack Sparrow      jack.sparrow@synergysystemsgroup.com
# 10  7a44b4  Karen Carpenter   karen.carpenter@vanguardvisionaries.com
# 11  028e46      Liam Neeson       liam.neeson@innovatechsolutions.com
# 12  3ca997      Mia Wallace       mia.wallace@ecospherenterprises.com
# 13  64f053    Noah Centineo     noah.centineo@quantumleapdynamics.com
# 14  236aa2     Olivia Wilde    olivia.wilde@greenwavetechnologies.com
# 15  cb9e2c        Paul Rudd             paul.rudd@skylineventures.com
# 16  c249c9     Quincy Jones          quincy.jones@apexinnovations.com
# 17  6f8e8d     Rachel Green    rachel.green@bluehorizonindustries.com
# 18  605e61     Steve Rogers         steve.rogers@pinnaclepathways.com
# 0   a4ab87   Alice Kingsley             alice.kingsley@wonderland.com
# 1   f556c0        Bob Stone                     bob.stone@granite.com
# 2   88382b      Cathy Bloom                   cathy.bloom@florals.org
# 3   888fb2       David Noir                 david.noir@shadowmail.com
# 4   f1f10d        Eva Green                     eva.green@ecosoul.net
# 5   e6376d      Frank Ocean                   frank.ocean@seawaves.io
#
#     is_blocked                            account_id
# 0        False  77cfa871-1900-4bd3-9333-8b06bc1e5662
# 1         True  1bf1aeb8-1ce3-4801-9fbc-0f2eb7784274
# 2        False  3f930443-5c74-4793-b7d1-be34b82db34e
# 3         True  0f11272b-a7f5-406b-9363-0a4da00f067b
# 4        False  9031f988-019d-43f3-aca3-dcf3b3f03c32
# 5         True  29ff37fc-03b6-4484-ab06-8c98b23cbf48
# 6        False  5265e089-2852-4f46-aed5-8f52214cdc5c
# 7         True  16e66a8a-3e40-42d3-9630-839e9676b96e
# 8        False  2a8ab9b7-9e86-4586-a9e5-98ce1e69773f
# 9         True  b3516eaa-2340-4f2d-b4f1-80cf899c766c
# 10       False  726974bd-2174-4fac-a8f6-4317c7f06f26
# 11        True  3d4a0fc5-f878-4a44-9a4f-e847710f41e7
# 12       False  0f4bc6b9-f6d4-489e-ab45-7c39d6495657
# 13        True  4cc18ddf-1097-4aa1-aea3-f9453f7bf3d3
# 14       False  0a4666e8-f1a5-46e4-8493-bf6e7ab97dba
# 15        True  3586ee90-86ae-4af4-aa83-e91c13cee421
# 16       False  911c1f5c-8f91-45ce-968e-2d4305295ede
# 17        True  2f4a7498-4dbe-4823-8916-7374c66c2892
# 18       False  4189813d-bd85-44f2-b47b-06385f93a9d7
# 0         True  4f7f5397-bbf0-4bdd-8c8e-cbb63a794113
# 1        False  77a5d472-51a2-425a-954d-e7f3e1f54815
# 2        False  6e3fc254-65d3-447e-ae74-52c5a1777177
# 3         True  b2bccfbb-d74e-4140-9cde-998bda55f9a5
# 4        False  efe6fde1-0780-4c5e-9e54-d4dfcd7b14f6
# 5        False  504f0364-be45-41f7-b252-9721031d559d

# %%
# Random Combination of Tags
expected_list_min_expected_tag = 1
expected_list_max_expected_tag = 4
unexpected_list_min_expected_tag = 0
unexpected_list_max_expected_tag = 2
unexpected_list_min_unexpected_tag = 1
unexpected_list_max_unexpected_tag = 2

expected_tag_combination = [ random.sample(list(expected_tags), random.randint(expected_list_min_expected_tag,expected_list_max_expected_tag)) for i in range(num_expected_tag_msg) ]
unexpected_tag_combination = [ random.sample(list(expected_tags), random.randint(unexpected_list_min_expected_tag,unexpected_list_max_expected_tag)) +
                               random.sample(list(unexpected_tags), random.randint(unexpected_list_min_unexpected_tag,unexpected_list_max_unexpected_tag)) for i in range(num_unexpected_tag_msg) ]
tag_combination = expected_tag_combination + unexpected_tag_combination

# %%
# Create Tickets
ticket_prompt_template = """
    You are a IT ticket generation emulator focusing on generating the actual message of users.
    
    Step 1: Generate {num_ticket} tickets, 
        (a) Each `content` should be 20 to 200 words
        (b) Make occasional minor typos in the `content`
        (c) Each ticket `content` should be written based on the topic in the followin table:
        {tag_combination}  

    Step 2: For the `owner_id` (use `id` column in the table), `owner_name` (use `name` column in the table), account_id (`account_id`)
            and allow one user to have multiple tickets:
        {user_table}

    Step 3: Randomly selected a `channel` from ['email','chat','web','sms','social','phone'] for each ticket.
    """

ticket_prompt = PromptTemplate(
    template = ticket_prompt_template,
    input_variables = ["num_ticket","num_expected_tag_msg","num_unexpected_tag_msg","expected_tags","unexpected_tags","ticket_table"],
    ).invoke({"num_ticket": num_ticket,
              "tag_combination": tag_combination, 
              "unexpected_tags": unexpected_tags, 
              "user_table": user_table,
            }).to_messages()

ticket_ls = llm.with_structured_output(TicketSamples).invoke(ticket_prompt).model_dump()['samples']
ticket_table = pd.DataFrame(ticket_ls)
# ticket_table['id'] = msg_table.index
ticket_table['role'] = "user"
ticket_table['status'] = "open"
ticket_table['urgency_score'] = [random.random() for _ in range(num_ticket)]
# ticket_table

# %%
for ticket in ticket_table['content']:
    print(ticket)
# Out:
# Hello, I am trying to book tickets for the upcoming tech conference, but the system keeps showing an error message. I have tried multiple times, but it seems like the booking process is not going through. Could you please assist me with this issue? I would appreciate it if you could resolve this as soon as possible since the event is approaching fast. Thank you!
# Hi, I am unable to log into my account. I have tried resetting my password, but I am not receiving the reset email. Could you please help me regain access to my account? I need to check my attendance records for the past month. Thank you for your assistance.
# Hello, I need to cancel my booking for the upcoming event due to unforeseen circumstances. I tried doing it through the website, but it seems like the cancelation option is not working. Could you please assist me with this? I would also like to know if there are any cancelation fees involved. Thank you.
# Hi, I am having trouble accessing my reservation details. I need to cancel my reservation, but I can't seem to find the option to do so. Could you please help me with this? I would appreciate a quick response as the reservation date is approaching. Thank you.
# Hello, I am unable to reset my password. I have tried multiple times, but the reset link is not working. I need to escalate this issue as I am unable to access my account. Could you please assist me with this? Thank you for your prompt attention to this matter.
# Hi, I am trying to book a session for the upcoming workshop, but I am facing issues with the payment process. It seems like there is a billing error. Could you please help me resolve this? I also need to confirm my attendance for the event. Thank you.
# Hello, I am having trouble with my subscription. I need to update my billing information, but the system is not allowing me to do so. I also have questions about the pricing of the subscription plans. Could you please assist me with this? Thank you.
# Hi, I need to cancel my subscription to the event series. I am also interested in knowing if there are any benefits for early cancelation. Could you please provide me with the necessary information? Thank you for your assistance.
# Hello, I am unable to log into my account. I need to cancel an upcoming event, but I can't access the cancelation option. Could you please help me with this issue? Thank you for your prompt response.
# Hi, I need to cancel my participation in the upcoming event. I tried doing it through the website, but it seems like the cancelation option is not working. Could you please assist me with this? Thank you.
# Hello, I have a question regarding my subscription. I need to know if there are any changes to the subscription plans. Could you please provide me with the necessary information? Thank you.
# Hi, I am unable to reset my password. I also need to access my event details, but I can't seem to log into my account. Could you please help me with this issue? Thank you for your assistance.
# Hello, I am having trouble with my billing. I need to pause my subscription for a month, but I can't find the option to do so. Could you please assist me with this? I also need to confirm my attendance for the upcoming event. Thank you.
# Hi, I am interested in subscribing to the event series. I need to know if there are any attendance requirements for the subscription. Could you please provide me with the necessary information? Thank you.
# Hello, I am having trouble with my password. I also need to know if there are any pricing changes for the reservation plans. Could you please assist me with this? Thank you for your prompt response.
# Hi, I am unable to access my reservation details. I also need to reset my password, but I am not receiving the reset email. Could you please help me with this issue? Thank you for your assistance.
# Hello, I need to escalate an issue with my event reservation. I am unable to access the reservation details, and the event date is approaching. Could you please assist me with this? Thank you for your prompt attention to this matter.
# Hi, I am unable to log into my account. I need to access my event benefits, but I can't seem to find the option to do so. Could you please help me with this issue? Thank you for your assistance.
# Hello, I have a question regarding the pricing of the event series. I also need to pause my subscription for a month. Could you please provide me with the necessary information? Thank you.
# Hi, I am unable to log into my account. I need to book a session for the upcoming workshop, but I can't seem to access the booking option. Could you please help me with this issue? Thank you for your assistance.
# Hello, I am having trouble with my billing. I need to update my reservation details, but the system is not allowing me to do so. I also have questions about the pricing of the reservation plans. Could you please assist me with this? Thank you.
# Hi, I am unable to log into my account. I need to reset my password, but I am not receiving the reset email. Could you please help me with this issue? Thank you for your assistance.
# Hello, I am having trouble with my booking. I need to access my reservation details, but the system is not allowing me to do so. I also have questions about the pricing of the booking plans. Could you please assist me with this? Thank you.
# Hi, I need to update my reservation details. I also have questions about the pricing of the reservation plans. Could you please provide me with the necessary information? Thank you for your assistance.
# Hello, I am having trouble with my billing. I need to escalate an issue with my event participation. Could you please assist me with this? Thank you for your prompt attention to this matter.
# Hi, I am unable to log into my account. I need to cancel my participation in the upcoming event, but I can't seem to find the cancelation option. Could you please help me with this issue? Thank you for your assistance.
# Hello, I have a question regarding the benefits of my subscription. I also need to pause my billing for a month. Could you please provide me with the necessary information? Thank you.
# Hi, I am interested in subscribing to the event series. I need to know if there are any booking requirements for the subscription. Could you please provide me with the necessary information? Thank you.
# Hello, I am having trouble with my subscription. I need to update my billing information, but the system is not allowing me to do so. I also have questions about the pricing of the subscription plans. Could you please assist me with this? Thank you.
# Hi, I need to update my reservation details. I also have questions about the benefits of the reservation plans. Could you please provide me with the necessary information? Thank you for your assistance.
# Hello, I am having trouble with my billing. I need to know if there are any benefits for early payment. Could you please provide me with the necessary information? Thank you.
# Hi, I am trying to book tickets for the upcoming tech conference, but the system keeps showing an error message. I have tried multiple times, but it seems like the booking process is not going through. Could you please assist me with this issue? I would appreciate it if you could resolve this as soon as possible since the event is approaching fast. Thank you!
# Hello, I need to escalate an issue with my event participation. I am unable to access the cancelation option, and the event date is approaching. Could you please assist me with this? Thank you for your prompt attention to this matter.
# Hi, I need to escalate an issue with my account. I am unable to access my event details, and the event date is approaching. Could you please assist me with this? Thank you for your prompt attention to this matter.
# Hello, I am having trouble with my booking. I need to access my reservation details, but the system is not allowing me to do so. I also have questions about the pricing of the booking plans. Could you please assist me with this? Thank you.
# Hi, I am having trouble with my password. I need to pause my subscription for a month, but I can't find the option to do so. Could you please assist me with this? I also have questions about the pricing of the subscription plans. Thank you.
# Hello, I need to update my reservation details. I also have questions about the cancelation policy for the subscription plans. Could you please provide me with the necessary information? Thank you for your assistance.
# Hi, I am unable to access my reservation details. I need to cancel my reservation, but I can't seem to find the option to do so. Could you please help me with this? I would appreciate a quick response as the reservation date is approaching. Thank you.
# Hello, I need to pause my subscription for a month. I also have questions about the escalation process for my account. Could you please provide me with the necessary information? Thank you.
# Hi, I am unable to log into my account. I need to pause my subscription for a month, but I can't find the option to do so. Could you please assist me with this? I also have questions about the pricing of the subscription plans. Thank you.
# Hello, I am having trouble with my password. I also need some health advice regarding my account. Could you please assist me with this? Thank you for your prompt response.
# Hi, I have a question regarding the stock price of the event series. I also need to know if there are any weather-related updates for the event. Could you please provide me with the necessary information? Thank you.
# Hello, I have a question regarding the stock price of the event series. I also need some dietary advice for the event. Could you please provide me with the necessary information? Thank you.
# Hi, I need to pause my subscription for a month. I also have questions about the login process for my account. Could you please provide me with the necessary information? Thank you.
# Hello, I am having trouble with my password. I also need some health advice regarding my account. Could you please assist me with this? Thank you for your prompt response.
# Hi, I have a question regarding the pricing of the event series. I also need some dietary advice for the event. Could you please provide me with the necessary information? Thank you.
# Hello, I am having trouble with my billing. I need to cancel my participation in the upcoming event, but I can't seem to find the cancelation option. I also have questions about the dietary requirements for the event. Could you please assist me with this? Thank you.
# Hi, I need to escalate an issue with my account. I am unable to access my event details, and the event date is approaching. Could you please assist me with this? Thank you for your prompt attention to this matter.
# Hello, I am having trouble with my password. I also need to know if there are any weather-related updates for the event. Could you please assist me with this? Thank you for your prompt response.
# Hi, I need to update my reservation details. I also have questions about the stock price of the event series. Could you please provide me with the necessary information? Thank you for your assistance.

# %%
ticket_table
# Out:
#    status                                            content owner_id  \
# 0    open  Hello, I am trying to book tickets for the upc...   cf5b19
# 1    open  Hi, I am unable to log into my account. I have...   b6cde6
# 2    open  Hello, I need to cancel my booking for the upc...   441882
# 3    open  Hi, I am having trouble accessing my reservati...   7079d5
# 4    open  Hello, I am unable to reset my password. I hav...   41caaf
# 5    open  Hi, I am trying to book a session for the upco...   693372
# 6    open  Hello, I am having trouble with my subscriptio...   a95423
# 7    open  Hi, I need to cancel my subscription to the ev...   c0b2de
# 8    open  Hello, I am unable to log into my account. I n...   3dab96
# 9    open  Hi, I need to cancel my participation in the u...   b598ab
# 10   open  Hello, I have a question regarding my subscrip...   7a44b4
# 11   open  Hi, I am unable to reset my password. I also n...   028e46
# 12   open  Hello, I am having trouble with my billing. I ...   3ca997
# 13   open  Hi, I am interested in subscribing to the even...   64f053
# 14   open  Hello, I am having trouble with my password. I...   236aa2
# 15   open  Hi, I am unable to access my reservation detai...   cb9e2c
# 16   open  Hello, I need to escalate an issue with my eve...   c249c9
# 17   open  Hi, I am unable to log into my account. I need...   6f8e8d
# 18   open  Hello, I have a question regarding the pricing...   605e61
# 19   open  Hi, I am unable to log into my account. I need...   a4ab87
# 20   open  Hello, I am having trouble with my billing. I ...   f556c0
# 21   open  Hi, I am unable to log into my account. I need...   88382b
# 22   open  Hello, I am having trouble with my booking. I ...   888fb2
# 23   open  Hi, I need to update my reservation details. I...   f1f10d
# 24   open  Hello, I am having trouble with my billing. I ...   e6376d
# 25   open  Hi, I am unable to log into my account. I need...   cf5b19
# 26   open  Hello, I have a question regarding the benefit...   b6cde6
# 27   open  Hi, I am interested in subscribing to the even...   441882
# 28   open  Hello, I am having trouble with my subscriptio...   7079d5
# 29   open  Hi, I need to update my reservation details. I...   41caaf
# 30   open  Hello, I am having trouble with my billing. I ...   693372
# 31   open  Hi, I am trying to book tickets for the upcomi...   a95423
# 32   open  Hello, I need to escalate an issue with my eve...   c0b2de
# 33   open  Hi, I need to escalate an issue with my accoun...   3dab96
# 34   open  Hello, I am having trouble with my booking. I ...   b598ab
# 35   open  Hi, I am having trouble with my password. I ne...   7a44b4
# 36   open  Hello, I need to update my reservation details...   028e46
# 37   open  Hi, I am unable to access my reservation detai...   3ca997
# 38   open  Hello, I need to pause my subscription for a m...   64f053
# 39   open  Hi, I am unable to log into my account. I need...   236aa2
# 40   open  Hello, I am having trouble with my password. I...   cb9e2c
# 41   open  Hi, I have a question regarding the stock pric...   c249c9
# 42   open  Hello, I have a question regarding the stock p...   6f8e8d
# 43   open  Hi, I need to pause my subscription for a mont...   605e61
# 44   open  Hello, I am having trouble with my password. I...   a4ab87
# 45   open  Hi, I have a question regarding the pricing of...   f556c0
# 46   open  Hello, I am having trouble with my billing. I ...   88382b
# 47   open  Hi, I need to escalate an issue with my accoun...   888fb2
# 48   open  Hello, I am having trouble with my password. I...   f1f10d
# 49   open  Hi, I need to update my reservation details. I...   e6376d
#
#          owner_name channel                                           tags  \
# 0     Alice Johnson     web                                         events
# 1         Bob Smith   email                           password, attendance
# 2     Charlie Brown    chat                   booking, cancelation, events
# 3      Diana Prince   phone               cancelation, reservation, access
# 4        Ethan Hunt     sms                           password, escalation
# 5   Fiona Gallagher  social                   booking, attendance, billing
# 6    George Clooney     web       password, subscription, billing, pricing
# 7    Hannah Montana   email                  cancelation, events, benefits
# 8       Ian Fleming    chat                             cancelation, login
# 9      Jack Sparrow   phone                            events, cancelation
# 10  Karen Carpenter     sms                                   subscription
# 11      Liam Neeson  social                       password, access, events
# 12      Mia Wallace     web       billing, attendance, subscription, pause
# 13    Noah Centineo   email               events, attendance, subscription
# 14     Olivia Wilde    chat                 password, pricing, reservation
# 15        Paul Rudd   phone           reservation, login, password, events
# 16     Quincy Jones     sms                events, reservation, escalation
# 17     Rachel Green  social                        login, events, benefits
# 18     Steve Rogers     web                         pricing, pause, events
# 19   Alice Kingsley   email                                 booking, login
# 20        Bob Stone    chat    billing, reservation, pricing, subscription
# 21      Cathy Bloom   phone                                login, password
# 22       David Noir     sms                access, pause, pricing, booking
# 23        Eva Green  social                           reservation, pricing
# 24      Frank Ocean     web                    billing, events, escalation
# 25    Alice Johnson   email       escalation, login, cancelation, benefits
# 26        Bob Smith    chat             benefits, password, pause, billing
# 27    Charlie Brown   phone                          subscription, booking
# 28     Diana Prince     sms                 subscription, pricing, billing
# 29       Ethan Hunt  social                reservation, benefits, password
# 30  Fiona Gallagher     web                              billing, benefits
# 31   George Clooney   email                                         events
# 32   Hannah Montana    chat              escalation, cancelation, benefits
# 33      Ian Fleming   phone                                     escalation
# 34     Jack Sparrow     sms           cancelation, access, booking, events
# 35  Karen Carpenter  social                       password, pause, pricing
# 36      Liam Neeson     web  reservation, cancelation, subscription, pause
# 37      Mia Wallace   email        access, reservation, cancelation, login
# 38    Noah Centineo    chat                     pause, escalation, booking
# 39     Olivia Wilde   phone                          login, pause, pricing
# 40        Paul Rudd     sms                        password, health advice
# 41     Quincy Jones  social                           stock price, weather
# 42     Rachel Green     web                           stock price, dietary
# 43     Steve Rogers   email           pause, login, health advice, weather
# 44   Alice Kingsley    chat    pause, password, health advice, stock price
# 45        Bob Stone   phone         pricing, login, dietary, health advice
# 46      Cathy Bloom     sms         billing, cancelation, dietary, weather
# 47       David Noir  social                   escalation, weather, dietary
# 48        Eva Green     web                              password, weather
# 49      Frank Ocean   email              reservation, stock price, weather
#
#                               account_id  urgency_score  role
# 0   77cfa871-1900-4bd3-9333-8b06bc1e5662       0.190220  user
# 1   1bf1aeb8-1ce3-4801-9fbc-0f2eb7784274       0.767425  user
# 2   3f930443-5c74-4793-b7d1-be34b82db34e       0.036948  user
# 3   0f11272b-a7f5-406b-9363-0a4da00f067b       0.553602  user
# 4   9031f988-019d-43f3-aca3-dcf3b3f03c32       0.120607  user
# 5   29ff37fc-03b6-4484-ab06-8c98b23cbf48       0.113121  user
# 6   5265e089-2852-4f46-aed5-8f52214cdc5c       0.580548  user
# 7   16e66a8a-3e40-42d3-9630-839e9676b96e       0.530235  user
# 8   2a8ab9b7-9e86-4586-a9e5-98ce1e69773f       0.165864  user
# 9   b3516eaa-2340-4f2d-b4f1-80cf899c766c       0.170734  user
# 10  726974bd-2174-4fac-a8f6-4317c7f06f26       0.047982  user
# 11  3d4a0fc5-f878-4a44-9a4f-e847710f41e7       0.989161  user
# 12  0f4bc6b9-f6d4-489e-ab45-7c39d6495657       0.647771  user
# 13  4cc18ddf-1097-4aa1-aea3-f9453f7bf3d3       0.828865  user
# 14  0a4666e8-f1a5-46e4-8493-bf6e7ab97dba       0.762799  user
# 15  3586ee90-86ae-4af4-aa83-e91c13cee421       0.503771  user
# 16  911c1f5c-8f91-45ce-968e-2d4305295ede       0.756000  user
# 17  2f4a7498-4dbe-4823-8916-7374c66c2892       0.458037  user
# 18  4189813d-bd85-44f2-b47b-06385f93a9d7       0.064509  user
# 19  4f7f5397-bbf0-4bdd-8c8e-cbb63a794113       0.728555  user
# 20  77a5d472-51a2-425a-954d-e7f3e1f54815       0.660905  user
# 21  6e3fc254-65d3-447e-ae74-52c5a1777177       0.385307  user
# 22  b2bccfbb-d74e-4140-9cde-998bda55f9a5       0.636274  user
# 23  efe6fde1-0780-4c5e-9e54-d4dfcd7b14f6       0.411202  user
# 24  504f0364-be45-41f7-b252-9721031d559d       0.289010  user
# 25  77cfa871-1900-4bd3-9333-8b06bc1e5662       0.428919  user
# 26  1bf1aeb8-1ce3-4801-9fbc-0f2eb7784274       0.328394  user
# 27  3f930443-5c74-4793-b7d1-be34b82db34e       0.349909  user
# 28  0f11272b-a7f5-406b-9363-0a4da00f067b       0.179406  user
# 29  9031f988-019d-43f3-aca3-dcf3b3f03c32       0.997842  user
# 30  29ff37fc-03b6-4484-ab06-8c98b23cbf48       0.858822  user
# 31  5265e089-2852-4f46-aed5-8f52214cdc5c       0.337131  user
# 32  16e66a8a-3e40-42d3-9630-839e9676b96e       0.599275  user
# 33  2a8ab9b7-9e86-4586-a9e5-98ce1e69773f       0.126171  user
# 34  b3516eaa-2340-4f2d-b4f1-80cf899c766c       0.030209  user
# 35  726974bd-2174-4fac-a8f6-4317c7f06f26       0.980542  user
# 36  3d4a0fc5-f878-4a44-9a4f-e847710f41e7       0.007194  user
# 37  0f4bc6b9-f6d4-489e-ab45-7c39d6495657       0.999822  user
# 38  4cc18ddf-1097-4aa1-aea3-f9453f7bf3d3       0.612529  user
# 39  0a4666e8-f1a5-46e4-8493-bf6e7ab97dba       0.088595  user
# 40  3586ee90-86ae-4af4-aa83-e91c13cee421       0.256066  user
# 41  911c1f5c-8f91-45ce-968e-2d4305295ede       0.138485  user
# 42  2f4a7498-4dbe-4823-8916-7374c66c2892       0.708379  user
# 43  4189813d-bd85-44f2-b47b-06385f93a9d7       0.893407  user
# 44  4f7f5397-bbf0-4bdd-8c8e-cbb63a794113       0.482443  user
# 45  77a5d472-51a2-425a-954d-e7f3e1f54815       0.151200  user
# 46  6e3fc254-65d3-447e-ae74-52c5a1777177       0.504861  user
# 47  b2bccfbb-d74e-4140-9cde-998bda55f9a5       0.755893  user
# 48  efe6fde1-0780-4c5e-9e54-d4dfcd7b14f6       0.535150  user
# 49  504f0364-be45-41f7-b252-9721031d559d       0.362538  user

# %%
len(ticket_table)
# Out:
# 50

# %% [markdown]
# ## Load Samples into Database

# %%
with get_session(engine) as session:
    kb = []
    for article in cultpass_articles:
        knowledge = udahub.Knowledge(
            article_id=str(uuid.uuid4()),
            account_id=account_id,
            title=article["title"],
            content=article["content"],
            tags=article["tags"]
        )
        kb.append(knowledge)
    session.add_all(kb)

# %% [markdown]
# **Ticket**

# %%
user_table.columns
# Out:
# Index(['id', 'name', 'email', 'is_blocked', 'account_id'], dtype='object')

# %%
def add_user(user_info):
    """
    Adding a single user to the database.
    """
    with get_session(engine) as session:
        user = udahub.User(
            user_id=user_info["account_id"],
            account_id=account_id,
            external_user_id=user_info["id"],
            user_name=user_info["name"],
            is_blocked=user_info["is_blocked"],
            email_address=user_info["email"]
            )
        session.add_all([user])

# %%
for index, row in user_table.iterrows():
    add_user(row)

# %%
def add_ticket(ticket_info):
    """
    Adding a single ticket to the database
    """
    with get_session(engine) as session:
        user = session.query(udahub.User).filter_by(
            account_id=account_id,
            external_user_id=ticket_info["owner_id"],
        ).first()

        print(ticket_info)
        print(user)

        if not user:
            user = udahub.User(
                # user_id=str(uuid.uuid4()),
                user_id=ticket_info["account_id"],
                account_id=account_id,
                external_user_id=ticket_info["owner_id"],
                user_name=ticket_info["owner_name"],
                is_blocked=False,     # Data structure in data/models/udahub.py had been modified to include this flag for advanced agent capability
                email_address=None    # Data structure in data/models/udahub.py had been modified to include this flag for advanced agent capability
            )
        
        ticket = udahub.Ticket(
            ticket_id=str(uuid.uuid4()),
            account_id=account_id,
            user_id=user.user_id,
            channel=ticket_info["channel"],
        )
        metadata = udahub.TicketMetadata(
            ticket_id=ticket.ticket_id,
            status=ticket_info["status"],
            main_issue_type=None,
            tags=ticket_info["tags"],
            urgency_score=ticket_info["urgency_score"]
        )

        first_message = udahub.TicketMessage(
            message_id=str(uuid.uuid4()),
            ticket_id=ticket.ticket_id,
            role=ticket_info["role"],
            content=ticket_info["content"],
        )

        # print(user)
        session.add_all([user, ticket, metadata, first_message])

# %%
for index, row in ticket_table.iterrows():
    add_ticket(row)
# Out:
# status                                                        open
# content          Hello, I am trying to book tickets for the upc...
# owner_id                                                    cf5b19
# owner_name                                           Alice Johnson
# channel                                                        web
# tags                                                        events
# account_id                    77cfa871-1900-4bd3-9333-8b06bc1e5662
# urgency_score                                              0.19022
# role                                                          user
# Name: 0, dtype: object
# <User(user_id='77cfa871-1900-4bd3-9333-8b06bc1e5662', user_name='Alice Johnson', external_user_id='cf5b19')>
# status                                                        open
# content          Hi, I am unable to log into my account. I have...
# owner_id                                                    b6cde6
# owner_name                                               Bob Smith
# channel                                                      email
# tags                                          password, attendance
# account_id                    1bf1aeb8-1ce3-4801-9fbc-0f2eb7784274
# urgency_score                                             0.767425
# role                                                          user
# Name: 1, dtype: object
# <User(user_id='1bf1aeb8-1ce3-4801-9fbc-0f2eb7784274', user_name='Bob Smith', external_user_id='b6cde6')>
# status                                                        open
# content          Hello, I need to cancel my booking for the upc...
# owner_id                                                    441882
# owner_name                                           Charlie Brown
# channel                                                       chat
# tags                                  booking, cancelation, events
# account_id                    3f930443-5c74-4793-b7d1-be34b82db34e
# urgency_score                                             0.036948
# role                                                          user
# Name: 2, dtype: object
# <User(user_id='3f930443-5c74-4793-b7d1-be34b82db34e', user_name='Charlie Brown', external_user_id='441882')>
# status                                                        open
# content          Hi, I am having trouble accessing my reservati...
# owner_id                                                    7079d5
# owner_name                                            Diana Prince
# channel                                                      phone
# tags                              cancelation, reservation, access
# account_id                    0f11272b-a7f5-406b-9363-0a4da00f067b
# urgency_score                                             0.553602
# role                                                          user
# Name: 3, dtype: object
# <User(user_id='0f11272b-a7f5-406b-9363-0a4da00f067b', user_name='Diana Prince', external_user_id='7079d5')>
# status                                                        open
# content          Hello, I am unable to reset my password. I hav...
# owner_id                                                    41caaf
# owner_name                                              Ethan Hunt
# channel                                                        sms
# tags                                          password, escalation
# account_id                    9031f988-019d-43f3-aca3-dcf3b3f03c32
# urgency_score                                             0.120607
# role                                                          user
# Name: 4, dtype: object
# <User(user_id='9031f988-019d-43f3-aca3-dcf3b3f03c32', user_name='Ethan Hunt', external_user_id='41caaf')>
# status                                                        open
# content          Hi, I am trying to book a session for the upco...
# owner_id                                                    693372
# owner_name                                         Fiona Gallagher
# channel                                                     social
# tags                                  booking, attendance, billing
# account_id                    29ff37fc-03b6-4484-ab06-8c98b23cbf48
# urgency_score                                             0.113121
# role                                                          user
# Name: 5, dtype: object
# <User(user_id='29ff37fc-03b6-4484-ab06-8c98b23cbf48', user_name='Fiona Gallagher', external_user_id='693372')>
# status                                                        open
# content          Hello, I am having trouble with my subscriptio...
# owner_id                                                    a95423
# owner_name                                          George Clooney
# channel                                                        web
# tags                      password, subscription, billing, pricing
# account_id                    5265e089-2852-4f46-aed5-8f52214cdc5c
# urgency_score                                             0.580548
# role                                                          user
# Name: 6, dtype: object
# <User(user_id='5265e089-2852-4f46-aed5-8f52214cdc5c', user_name='George Clooney', external_user_id='a95423')>
# status                                                        open
# content          Hi, I need to cancel my subscription to the ev...
# owner_id                                                    c0b2de
# owner_name                                          Hannah Montana
# channel                                                      email
# tags                                 cancelation, events, benefits
# account_id                    16e66a8a-3e40-42d3-9630-839e9676b96e
# urgency_score                                             0.530235
# role                                                          user
# Name: 7, dtype: object
# <User(user_id='16e66a8a-3e40-42d3-9630-839e9676b96e', user_name='Hannah Montana', external_user_id='c0b2de')>
# status                                                        open
# content          Hello, I am unable to log into my account. I n...
# owner_id                                                    3dab96
# owner_name                                             Ian Fleming
# channel                                                       chat
# tags                                            cancelation, login
# account_id                    2a8ab9b7-9e86-4586-a9e5-98ce1e69773f
# urgency_score                                             0.165864
# role                                                          user
# Name: 8, dtype: object
# <User(user_id='2a8ab9b7-9e86-4586-a9e5-98ce1e69773f', user_name='Ian Fleming', external_user_id='3dab96')>
# status                                                        open
# content          Hi, I need to cancel my participation in the u...
# owner_id                                                    b598ab
# owner_name                                            Jack Sparrow
# channel                                                      phone
# tags                                           events, cancelation
# account_id                    b3516eaa-2340-4f2d-b4f1-80cf899c766c
# urgency_score                                             0.170734
# role                                                          user
# Name: 9, dtype: object
# <User(user_id='b3516eaa-2340-4f2d-b4f1-80cf899c766c', user_name='Jack Sparrow', external_user_id='b598ab')>
# status                                                        open
# content          Hello, I have a question regarding my subscrip...
# owner_id                                                    7a44b4
# owner_name                                         Karen Carpenter
# channel                                                        sms
# tags                                                  subscription
# account_id                    726974bd-2174-4fac-a8f6-4317c7f06f26
# urgency_score                                             0.047982
# role                                                          user
# Name: 10, dtype: object
# <User(user_id='726974bd-2174-4fac-a8f6-4317c7f06f26', user_name='Karen Carpenter', external_user_id='7a44b4')>
# status                                                        open
# content          Hi, I am unable to reset my password. I also n...
# owner_id                                                    028e46
# owner_name                                             Liam Neeson
# channel                                                     social
# tags                                      password, access, events
# account_id                    3d4a0fc5-f878-4a44-9a4f-e847710f41e7
# urgency_score                                             0.989161
# role                                                          user
# Name: 11, dtype: object
# <User(user_id='3d4a0fc5-f878-4a44-9a4f-e847710f41e7', user_name='Liam Neeson', external_user_id='028e46')>
# status                                                        open
# content          Hello, I am having trouble with my billing. I ...
# owner_id                                                    3ca997
# owner_name                                             Mia Wallace
# channel                                                        web
# tags                      billing, attendance, subscription, pause
# account_id                    0f4bc6b9-f6d4-489e-ab45-7c39d6495657
# urgency_score                                             0.647771
# role                                                          user
# Name: 12, dtype: object
# <User(user_id='0f4bc6b9-f6d4-489e-ab45-7c39d6495657', user_name='Mia Wallace', external_user_id='3ca997')>
# status                                                        open
# content          Hi, I am interested in subscribing to the even...
# owner_id                                                    64f053
# owner_name                                           Noah Centineo
# channel                                                      email
# tags                              events, attendance, subscription
# account_id                    4cc18ddf-1097-4aa1-aea3-f9453f7bf3d3
# urgency_score                                             0.828865
# role                                                          user
# Name: 13, dtype: object
# <User(user_id='4cc18ddf-1097-4aa1-aea3-f9453f7bf3d3', user_name='Noah Centineo', external_user_id='64f053')>
# status                                                        open
# content          Hello, I am having trouble with my password. I...
# owner_id                                                    236aa2
# owner_name                                            Olivia Wilde
# channel                                                       chat
# tags                                password, pricing, reservation
# account_id                    0a4666e8-f1a5-46e4-8493-bf6e7ab97dba
# urgency_score                                             0.762799
# role                                                          user
# Name: 14, dtype: object
# <User(user_id='0a4666e8-f1a5-46e4-8493-bf6e7ab97dba', user_name='Olivia Wilde', external_user_id='236aa2')>
# status                                                        open
# content          Hi, I am unable to access my reservation detai...
# owner_id                                                    cb9e2c
# owner_name                                               Paul Rudd
# channel                                                      phone
# tags                          reservation, login, password, events
# account_id                    3586ee90-86ae-4af4-aa83-e91c13cee421
# urgency_score                                             0.503771
# role                                                          user
# Name: 15, dtype: object
# <User(user_id='3586ee90-86ae-4af4-aa83-e91c13cee421', user_name='Paul Rudd', external_user_id='cb9e2c')>
# status                                                        open
# content          Hello, I need to escalate an issue with my eve...
# owner_id                                                    c249c9
# owner_name                                            Quincy Jones
# channel                                                        sms
# tags                               events, reservation, escalation
# account_id                    911c1f5c-8f91-45ce-968e-2d4305295ede
# urgency_score                                                0.756
# role                                                          user
# Name: 16, dtype: object
# <User(user_id='911c1f5c-8f91-45ce-968e-2d4305295ede', user_name='Quincy Jones', external_user_id='c249c9')>
# status                                                        open
# content          Hi, I am unable to log into my account. I need...
# owner_id                                                    6f8e8d
# owner_name                                            Rachel Green
# channel                                                     social
# tags                                       login, events, benefits
# account_id                    2f4a7498-4dbe-4823-8916-7374c66c2892
# urgency_score                                             0.458037
# role                                                          user
# Name: 17, dtype: object
# <User(user_id='2f4a7498-4dbe-4823-8916-7374c66c2892', user_name='Rachel Green', external_user_id='6f8e8d')>
# status                                                        open
# content          Hello, I have a question regarding the pricing...
# owner_id                                                    605e61
# owner_name                                            Steve Rogers
# channel                                                        web
# tags                                        pricing, pause, events
# account_id                    4189813d-bd85-44f2-b47b-06385f93a9d7
# urgency_score                                             0.064509
# role                                                          user
# Name: 18, dtype: object
# <User(user_id='4189813d-bd85-44f2-b47b-06385f93a9d7', user_name='Steve Rogers', external_user_id='605e61')>
# status                                                        open
# content          Hi, I am unable to log into my account. I need...
# owner_id                                                    a4ab87
# owner_name                                          Alice Kingsley
# channel                                                      email
# tags                                                booking, login
# account_id                    4f7f5397-bbf0-4bdd-8c8e-cbb63a794113
# urgency_score                                             0.728555
# role                                                          user
# Name: 19, dtype: object
# <User(user_id='4f7f5397-bbf0-4bdd-8c8e-cbb63a794113', user_name='Alice Kingsley', external_user_id='a4ab87')>
# status                                                        open
# content          Hello, I am having trouble with my billing. I ...
# owner_id                                                    f556c0
# owner_name                                               Bob Stone
# channel                                                       chat
# tags                   billing, reservation, pricing, subscription
# account_id                    77a5d472-51a2-425a-954d-e7f3e1f54815
# urgency_score                                             0.660905
# role                                                          user
# Name: 20, dtype: object
# <User(user_id='77a5d472-51a2-425a-954d-e7f3e1f54815', user_name='Bob Stone', external_user_id='f556c0')>
# status                                                        open
# content          Hi, I am unable to log into my account. I need...
# owner_id                                                    88382b
# owner_name                                             Cathy Bloom
# channel                                                      phone
# tags                                               login, password
# account_id                    6e3fc254-65d3-447e-ae74-52c5a1777177
# urgency_score                                             0.385307
# role                                                          user
# Name: 21, dtype: object
# <User(user_id='6e3fc254-65d3-447e-ae74-52c5a1777177', user_name='Cathy Bloom', external_user_id='88382b')>
# status                                                        open
# content          Hello, I am having trouble with my booking. I ...
# owner_id                                                    888fb2
# owner_name                                              David Noir
# channel                                                        sms
# tags                               access, pause, pricing, booking
# account_id                    b2bccfbb-d74e-4140-9cde-998bda55f9a5
# urgency_score                                             0.636274
# role                                                          user
# Name: 22, dtype: object
# <User(user_id='b2bccfbb-d74e-4140-9cde-998bda55f9a5', user_name='David Noir', external_user_id='888fb2')>
# status                                                        open
# content          Hi, I need to update my reservation details. I...
# owner_id                                                    f1f10d
# owner_name                                               Eva Green
# channel                                                     social
# tags                                          reservation, pricing
# account_id                    efe6fde1-0780-4c5e-9e54-d4dfcd7b14f6
# urgency_score                                             0.411202
# role                                                          user
# Name: 23, dtype: object
# <User(user_id='efe6fde1-0780-4c5e-9e54-d4dfcd7b14f6', user_name='Eva Green', external_user_id='f1f10d')>
# status                                                        open
# content          Hello, I am having trouble with my billing. I ...
# owner_id                                                    e6376d
# owner_name                                             Frank Ocean
# channel                                                        web
# tags                                   billing, events, escalation
# account_id                    504f0364-be45-41f7-b252-9721031d559d
# urgency_score                                              0.28901
# role                                                          user
# Name: 24, dtype: object
# <User(user_id='504f0364-be45-41f7-b252-9721031d559d', user_name='Frank Ocean', external_user_id='e6376d')>
# status                                                        open
# content          Hi, I am unable to log into my account. I need...
# owner_id                                                    cf5b19
# owner_name                                           Alice Johnson
# channel                                                      email
# tags                      escalation, login, cancelation, benefits
# account_id                    77cfa871-1900-4bd3-9333-8b06bc1e5662
# urgency_score                                             0.428919
# role                                                          user
# Name: 25, dtype: object
# <User(user_id='77cfa871-1900-4bd3-9333-8b06bc1e5662', user_name='Alice Johnson', external_user_id='cf5b19')>
# status                                                        open
# content          Hello, I have a question regarding the benefit...
# owner_id                                                    b6cde6
# owner_name                                               Bob Smith
# channel                                                       chat
# tags                            benefits, password, pause, billing
# account_id                    1bf1aeb8-1ce3-4801-9fbc-0f2eb7784274
# urgency_score                                             0.328394
# role                                                          user
# Name: 26, dtype: object
# <User(user_id='1bf1aeb8-1ce3-4801-9fbc-0f2eb7784274', user_name='Bob Smith', external_user_id='b6cde6')>
# status                                                        open
# content          Hi, I am interested in subscribing to the even...
# owner_id                                                    441882
# owner_name                                           Charlie Brown
# channel                                                      phone
# tags                                         subscription, booking
# account_id                    3f930443-5c74-4793-b7d1-be34b82db34e
# urgency_score                                             0.349909
# role                                                          user
# Name: 27, dtype: object
# <User(user_id='3f930443-5c74-4793-b7d1-be34b82db34e', user_name='Charlie Brown', external_user_id='441882')>
# status                                                        open
# content          Hello, I am having trouble with my subscriptio...
# owner_id                                                    7079d5
# owner_name                                            Diana Prince
# channel                                                        sms
# tags                                subscription, pricing, billing
# account_id                    0f11272b-a7f5-406b-9363-0a4da00f067b
# urgency_score                                             0.179406
# role                                                          user
# Name: 28, dtype: object
# <User(user_id='0f11272b-a7f5-406b-9363-0a4da00f067b', user_name='Diana Prince', external_user_id='7079d5')>
# status                                                        open
# content          Hi, I need to update my reservation details. I...
# owner_id                                                    41caaf
# owner_name                                              Ethan Hunt
# channel                                                     social
# tags                               reservation, benefits, password
# account_id                    9031f988-019d-43f3-aca3-dcf3b3f03c32
# urgency_score                                             0.997842
# role                                                          user
# Name: 29, dtype: object
# <User(user_id='9031f988-019d-43f3-aca3-dcf3b3f03c32', user_name='Ethan Hunt', external_user_id='41caaf')>
# status                                                        open
# content          Hello, I am having trouble with my billing. I ...
# owner_id                                                    693372
# owner_name                                         Fiona Gallagher
# channel                                                        web
# tags                                             billing, benefits
# account_id                    29ff37fc-03b6-4484-ab06-8c98b23cbf48
# urgency_score                                             0.858822
# role                                                          user
# Name: 30, dtype: object
# <User(user_id='29ff37fc-03b6-4484-ab06-8c98b23cbf48', user_name='Fiona Gallagher', external_user_id='693372')>
# status                                                        open
# content          Hi, I am trying to book tickets for the upcomi...
# owner_id                                                    a95423
# owner_name                                          George Clooney
# channel                                                      email
# tags                                                        events
# account_id                    5265e089-2852-4f46-aed5-8f52214cdc5c
# urgency_score                                             0.337131
# role                                                          user
# Name: 31, dtype: object
# <User(user_id='5265e089-2852-4f46-aed5-8f52214cdc5c', user_name='George Clooney', external_user_id='a95423')>
# status                                                        open
# content          Hello, I need to escalate an issue with my eve...
# owner_id                                                    c0b2de
# owner_name                                          Hannah Montana
# channel                                                       chat
# tags                             escalation, cancelation, benefits
# account_id                    16e66a8a-3e40-42d3-9630-839e9676b96e
# urgency_score                                             0.599275
# role                                                          user
# Name: 32, dtype: object
# <User(user_id='16e66a8a-3e40-42d3-9630-839e9676b96e', user_name='Hannah Montana', external_user_id='c0b2de')>
# status                                                        open
# content          Hi, I need to escalate an issue with my accoun...
# owner_id                                                    3dab96
# owner_name                                             Ian Fleming
# channel                                                      phone
# tags                                                    escalation
# account_id                    2a8ab9b7-9e86-4586-a9e5-98ce1e69773f
# urgency_score                                             0.126171
# role                                                          user
# Name: 33, dtype: object
# <User(user_id='2a8ab9b7-9e86-4586-a9e5-98ce1e69773f', user_name='Ian Fleming', external_user_id='3dab96')>
# status                                                        open
# content          Hello, I am having trouble with my booking. I ...
# owner_id                                                    b598ab
# owner_name                                            Jack Sparrow
# channel                                                        sms
# tags                          cancelation, access, booking, events
# account_id                    b3516eaa-2340-4f2d-b4f1-80cf899c766c
# urgency_score                                             0.030209
# role                                                          user
# Name: 34, dtype: object
# <User(user_id='b3516eaa-2340-4f2d-b4f1-80cf899c766c', user_name='Jack Sparrow', external_user_id='b598ab')>
# status                                                        open
# content          Hi, I am having trouble with my password. I ne...
# owner_id                                                    7a44b4
# owner_name                                         Karen Carpenter
# channel                                                     social
# tags                                      password, pause, pricing
# account_id                    726974bd-2174-4fac-a8f6-4317c7f06f26
# urgency_score                                             0.980542
# role                                                          user
# Name: 35, dtype: object
# <User(user_id='726974bd-2174-4fac-a8f6-4317c7f06f26', user_name='Karen Carpenter', external_user_id='7a44b4')>
# status                                                        open
# content          Hello, I need to update my reservation details...
# owner_id                                                    028e46
# owner_name                                             Liam Neeson
# channel                                                        web
# tags                 reservation, cancelation, subscription, pause
# account_id                    3d4a0fc5-f878-4a44-9a4f-e847710f41e7
# urgency_score                                             0.007194
# role                                                          user
# Name: 36, dtype: object
# <User(user_id='3d4a0fc5-f878-4a44-9a4f-e847710f41e7', user_name='Liam Neeson', external_user_id='028e46')>
# status                                                        open
# content          Hi, I am unable to access my reservation detai...
# owner_id                                                    3ca997
# owner_name                                             Mia Wallace
# channel                                                      email
# tags                       access, reservation, cancelation, login
# account_id                    0f4bc6b9-f6d4-489e-ab45-7c39d6495657
# urgency_score                                             0.999822
# role                                                          user
# Name: 37, dtype: object
# <User(user_id='0f4bc6b9-f6d4-489e-ab45-7c39d6495657', user_name='Mia Wallace', external_user_id='3ca997')>
# status                                                        open
# content          Hello, I need to pause my subscription for a m...
# owner_id                                                    64f053
# owner_name                                           Noah Centineo
# channel                                                       chat
# tags                                    pause, escalation, booking
# account_id                    4cc18ddf-1097-4aa1-aea3-f9453f7bf3d3
# urgency_score                                             0.612529
# role                                                          user
# Name: 38, dtype: object
# <User(user_id='4cc18ddf-1097-4aa1-aea3-f9453f7bf3d3', user_name='Noah Centineo', external_user_id='64f053')>
# status                                                        open
# content          Hi, I am unable to log into my account. I need...
# owner_id                                                    236aa2
# owner_name                                            Olivia Wilde
# channel                                                      phone
# tags                                         login, pause, pricing
# account_id                    0a4666e8-f1a5-46e4-8493-bf6e7ab97dba
# urgency_score                                             0.088595
# role                                                          user
# Name: 39, dtype: object
# <User(user_id='0a4666e8-f1a5-46e4-8493-bf6e7ab97dba', user_name='Olivia Wilde', external_user_id='236aa2')>
# status                                                        open
# content          Hello, I am having trouble with my password. I...
# owner_id                                                    cb9e2c
# owner_name                                               Paul Rudd
# channel                                                        sms
# tags                                       password, health advice
# account_id                    3586ee90-86ae-4af4-aa83-e91c13cee421
# urgency_score                                             0.256066
# role                                                          user
# Name: 40, dtype: object
# <User(user_id='3586ee90-86ae-4af4-aa83-e91c13cee421', user_name='Paul Rudd', external_user_id='cb9e2c')>
# status                                                        open
# content          Hi, I have a question regarding the stock pric...
# owner_id                                                    c249c9
# owner_name                                            Quincy Jones
# channel                                                     social
# tags                                          stock price, weather
# account_id                    911c1f5c-8f91-45ce-968e-2d4305295ede
# urgency_score                                             0.138485
# role                                                          user
# Name: 41, dtype: object
# <User(user_id='911c1f5c-8f91-45ce-968e-2d4305295ede', user_name='Quincy Jones', external_user_id='c249c9')>
# status                                                        open
# content          Hello, I have a question regarding the stock p...
# owner_id                                                    6f8e8d
# owner_name                                            Rachel Green
# channel                                                        web
# tags                                          stock price, dietary
# account_id                    2f4a7498-4dbe-4823-8916-7374c66c2892
# urgency_score                                             0.708379
# role                                                          user
# Name: 42, dtype: object
# <User(user_id='2f4a7498-4dbe-4823-8916-7374c66c2892', user_name='Rachel Green', external_user_id='6f8e8d')>
# status                                                        open
# content          Hi, I need to pause my subscription for a mont...
# owner_id                                                    605e61
# owner_name                                            Steve Rogers
# channel                                                      email
# tags                          pause, login, health advice, weather
# account_id                    4189813d-bd85-44f2-b47b-06385f93a9d7
# urgency_score                                             0.893407
# role                                                          user
# Name: 43, dtype: object
# <User(user_id='4189813d-bd85-44f2-b47b-06385f93a9d7', user_name='Steve Rogers', external_user_id='605e61')>
# status                                                        open
# content          Hello, I am having trouble with my password. I...
# owner_id                                                    a4ab87
# owner_name                                          Alice Kingsley
# channel                                                       chat
# tags                   pause, password, health advice, stock price
# account_id                    4f7f5397-bbf0-4bdd-8c8e-cbb63a794113
# urgency_score                                             0.482443
# role                                                          user
# Name: 44, dtype: object
# <User(user_id='4f7f5397-bbf0-4bdd-8c8e-cbb63a794113', user_name='Alice Kingsley', external_user_id='a4ab87')>
# status                                                        open
# content          Hi, I have a question regarding the pricing of...
# owner_id                                                    f556c0
# owner_name                                               Bob Stone
# channel                                                      phone
# tags                        pricing, login, dietary, health advice
# account_id                    77a5d472-51a2-425a-954d-e7f3e1f54815
# urgency_score                                               0.1512
# role                                                          user
# Name: 45, dtype: object
# <User(user_id='77a5d472-51a2-425a-954d-e7f3e1f54815', user_name='Bob Stone', external_user_id='f556c0')>
# status                                                        open
# content          Hello, I am having trouble with my billing. I ...
# owner_id                                                    88382b
# owner_name                                             Cathy Bloom
# channel                                                        sms
# tags                        billing, cancelation, dietary, weather
# account_id                    6e3fc254-65d3-447e-ae74-52c5a1777177
# urgency_score                                             0.504861
# role                                                          user
# Name: 46, dtype: object
# <User(user_id='6e3fc254-65d3-447e-ae74-52c5a1777177', user_name='Cathy Bloom', external_user_id='88382b')>
# status                                                        open
# content          Hi, I need to escalate an issue with my accoun...
# owner_id                                                    888fb2
# owner_name                                              David Noir
# channel                                                     social
# tags                                  escalation, weather, dietary
# account_id                    b2bccfbb-d74e-4140-9cde-998bda55f9a5
# urgency_score                                             0.755893
# role                                                          user
# Name: 47, dtype: object
# <User(user_id='b2bccfbb-d74e-4140-9cde-998bda55f9a5', user_name='David Noir', external_user_id='888fb2')>
# status                                                        open
# content          Hello, I am having trouble with my password. I...
# owner_id                                                    f1f10d
# owner_name                                               Eva Green
# channel                                                        web
# tags                                             password, weather
# account_id                    efe6fde1-0780-4c5e-9e54-d4dfcd7b14f6
# urgency_score                                              0.53515
# role                                                          user
# Name: 48, dtype: object
# <User(user_id='efe6fde1-0780-4c5e-9e54-d4dfcd7b14f6', user_name='Eva Green', external_user_id='f1f10d')>
# status                                                        open
# content          Hi, I need to update my reservation details. I...
# owner_id                                                    e6376d
# owner_name                                             Frank Ocean
# channel                                                      email
# tags                             reservation, stock price, weather
# account_id                    504f0364-be45-41f7-b252-9721031d559d
# urgency_score                                             0.362538
# role                                                          user
# Name: 49, dtype: object
# <User(user_id='504f0364-be45-41f7-b252-9721031d559d', user_name='Frank Ocean', external_user_id='e6376d')>

# %% [markdown]
# # Tests

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    print(account)
# Out:
# <Account(account_id='cultpass', account_name='CultPass Card')>

# %%
with get_session(engine) as session:
    account = session.query(udahub.Account).filter_by(
        account_id=account_id
    ).first()
    for article in account.knowledge_articles:
        print(article)
# Out:
# <Knowledge(article_id='2d9a9fee-69b8-4b0b-abf3-3d1b5e7b5a8a', title='How to Reserve a Spot for an Event')>
# <Knowledge(article_id='3891ac20-2fc3-426d-802a-9643a9c00f28', title='What's Included in a CultPass Subscription')>
# <Knowledge(article_id='256bd263-3fdb-456e-97cf-b8baa2798db6', title='How to Cancel or Pause a Subscription')>
# <Knowledge(article_id='f264f2ef-48c6-4196-8086-5f9570b683c1', title='How to Handle Login Issues?')>

# %%
with get_session(engine) as session:
    users = session.query(udahub.User).all()
    for user in users:
        # Get all column names for this model
        inst = inspect(user)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(user, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'user_id': '77cfa871-1900-4bd3-9333-8b06bc1e5662', 'account_id': 'cultpass', 'external_user_id': 'cf5b19', 'user_name': 'Alice Johnson', 'is_blocked': False, 'email_address': 'alice.johnson@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '1bf1aeb8-1ce3-4801-9fbc-0f2eb7784274', 'account_id': 'cultpass', 'external_user_id': 'b6cde6', 'user_name': 'Bob Smith', 'is_blocked': True, 'email_address': 'bob.smith@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '3f930443-5c74-4793-b7d1-be34b82db34e', 'account_id': 'cultpass', 'external_user_id': '441882', 'user_name': 'Charlie Brown', 'is_blocked': False, 'email_address': 'charlie.brown@ecospherenterprises.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '0f11272b-a7f5-406b-9363-0a4da00f067b', 'account_id': 'cultpass', 'external_user_id': '7079d5', 'user_name': 'Diana Prince', 'is_blocked': True, 'email_address': 'diana.prince@quantumleapdynamics.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '9031f988-019d-43f3-aca3-dcf3b3f03c32', 'account_id': 'cultpass', 'external_user_id': '41caaf', 'user_name': 'Ethan Hunt', 'is_blocked': False, 'email_address': 'ethan.hunt@greenwavetechnologies.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '29ff37fc-03b6-4484-ab06-8c98b23cbf48', 'account_id': 'cultpass', 'external_user_id': '693372', 'user_name': 'Fiona Gallagher', 'is_blocked': True, 'email_address': 'fiona.gallagher@skylineventures.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '5265e089-2852-4f46-aed5-8f52214cdc5c', 'account_id': 'cultpass', 'external_user_id': 'a95423', 'user_name': 'George Clooney', 'is_blocked': False, 'email_address': 'george.clooney@apexinnovations.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '16e66a8a-3e40-42d3-9630-839e9676b96e', 'account_id': 'cultpass', 'external_user_id': 'c0b2de', 'user_name': 'Hannah Montana', 'is_blocked': True, 'email_address': 'hannah.montana@bluehorizonindustries.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '2a8ab9b7-9e86-4586-a9e5-98ce1e69773f', 'account_id': 'cultpass', 'external_user_id': '3dab96', 'user_name': 'Ian Fleming', 'is_blocked': False, 'email_address': 'ian.fleming@pinnaclepathways.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': 'b3516eaa-2340-4f2d-b4f1-80cf899c766c', 'account_id': 'cultpass', 'external_user_id': 'b598ab', 'user_name': 'Jack Sparrow', 'is_blocked': True, 'email_address': 'jack.sparrow@synergysystemsgroup.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '726974bd-2174-4fac-a8f6-4317c7f06f26', 'account_id': 'cultpass', 'external_user_id': '7a44b4', 'user_name': 'Karen Carpenter', 'is_blocked': False, 'email_address': 'karen.carpenter@vanguardvisionaries.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '3d4a0fc5-f878-4a44-9a4f-e847710f41e7', 'account_id': 'cultpass', 'external_user_id': '028e46', 'user_name': 'Liam Neeson', 'is_blocked': True, 'email_address': 'liam.neeson@innovatechsolutions.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '0f4bc6b9-f6d4-489e-ab45-7c39d6495657', 'account_id': 'cultpass', 'external_user_id': '3ca997', 'user_name': 'Mia Wallace', 'is_blocked': False, 'email_address': 'mia.wallace@ecospherenterprises.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '4cc18ddf-1097-4aa1-aea3-f9453f7bf3d3', 'account_id': 'cultpass', 'external_user_id': '64f053', 'user_name': 'Noah Centineo', 'is_blocked': True, 'email_address': 'noah.centineo@quantumleapdynamics.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '0a4666e8-f1a5-46e4-8493-bf6e7ab97dba', 'account_id': 'cultpass', 'external_user_id': '236aa2', 'user_name': 'Olivia Wilde', 'is_blocked': False, 'email_address': 'olivia.wilde@greenwavetechnologies.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '3586ee90-86ae-4af4-aa83-e91c13cee421', 'account_id': 'cultpass', 'external_user_id': 'cb9e2c', 'user_name': 'Paul Rudd', 'is_blocked': True, 'email_address': 'paul.rudd@skylineventures.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '911c1f5c-8f91-45ce-968e-2d4305295ede', 'account_id': 'cultpass', 'external_user_id': 'c249c9', 'user_name': 'Quincy Jones', 'is_blocked': False, 'email_address': 'quincy.jones@apexinnovations.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '2f4a7498-4dbe-4823-8916-7374c66c2892', 'account_id': 'cultpass', 'external_user_id': '6f8e8d', 'user_name': 'Rachel Green', 'is_blocked': True, 'email_address': 'rachel.green@bluehorizonindustries.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '4189813d-bd85-44f2-b47b-06385f93a9d7', 'account_id': 'cultpass', 'external_user_id': '605e61', 'user_name': 'Steve Rogers', 'is_blocked': False, 'email_address': 'steve.rogers@pinnaclepathways.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '4f7f5397-bbf0-4bdd-8c8e-cbb63a794113', 'account_id': 'cultpass', 'external_user_id': 'a4ab87', 'user_name': 'Alice Kingsley', 'is_blocked': True, 'email_address': 'alice.kingsley@wonderland.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '77a5d472-51a2-425a-954d-e7f3e1f54815', 'account_id': 'cultpass', 'external_user_id': 'f556c0', 'user_name': 'Bob Stone', 'is_blocked': False, 'email_address': 'bob.stone@granite.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '6e3fc254-65d3-447e-ae74-52c5a1777177', 'account_id': 'cultpass', 'external_user_id': '88382b', 'user_name': 'Cathy Bloom', 'is_blocked': False, 'email_address': 'cathy.bloom@florals.org', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': 'b2bccfbb-d74e-4140-9cde-998bda55f9a5', 'account_id': 'cultpass', 'external_user_id': '888fb2', 'user_name': 'David Noir', 'is_blocked': True, 'email_address': 'david.noir@shadowmail.com', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': 'efe6fde1-0780-4c5e-9e54-d4dfcd7b14f6', 'account_id': 'cultpass', 'external_user_id': 'f1f10d', 'user_name': 'Eva Green', 'is_blocked': False, 'email_address': 'eva.green@ecosoul.net', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'user_id': '504f0364-be45-41f7-b252-9721031d559d', 'account_id': 'cultpass', 'external_user_id': 'e6376d', 'user_name': 'Frank Ocean', 'is_blocked': False, 'email_address': 'frank.ocean@seawaves.io', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}

# %%
with get_session(engine) as session:
    tickets = session.query(udahub.Ticket).all()
    for ticket in tickets:
        # Get all column names for this model
        inst = inspect(ticket)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(ticket, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'ticket_id': '5c06102f-26c1-4258-a1a2-07e33c73c9b2', 'account_id': 'cultpass', 'user_id': '77cfa871-1900-4bd3-9333-8b06bc1e5662', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '80766888-1ff1-4a92-9cc2-b660af014e9e', 'account_id': 'cultpass', 'user_id': '1bf1aeb8-1ce3-4801-9fbc-0f2eb7784274', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'c53e4c91-0198-4a84-b19b-6702c0e8ab6e', 'account_id': 'cultpass', 'user_id': '3f930443-5c74-4793-b7d1-be34b82db34e', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'c195b99c-e0fe-4c2a-8a2c-972867b24c5b', 'account_id': 'cultpass', 'user_id': '0f11272b-a7f5-406b-9363-0a4da00f067b', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'a8bad12f-0609-4f76-bf7c-56be035fa9a9', 'account_id': 'cultpass', 'user_id': '9031f988-019d-43f3-aca3-dcf3b3f03c32', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '5c41d278-bfc3-4002-a25a-4424a01fdd0d', 'account_id': 'cultpass', 'user_id': '29ff37fc-03b6-4484-ab06-8c98b23cbf48', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '350c1ee5-22dc-4bdb-a1ef-4a888302bdbf', 'account_id': 'cultpass', 'user_id': '5265e089-2852-4f46-aed5-8f52214cdc5c', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '3068ffd9-022a-4f76-9c23-d9bbfa69cdd6', 'account_id': 'cultpass', 'user_id': '16e66a8a-3e40-42d3-9630-839e9676b96e', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'fc721c85-3f4b-430f-91aa-25fec399ff3d', 'account_id': 'cultpass', 'user_id': '2a8ab9b7-9e86-4586-a9e5-98ce1e69773f', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'e6b7d5c3-f861-4008-b9e8-ff2fabc8f72d', 'account_id': 'cultpass', 'user_id': 'b3516eaa-2340-4f2d-b4f1-80cf899c766c', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '55871fbc-c444-4468-8e62-5b72bffd4192', 'account_id': 'cultpass', 'user_id': '726974bd-2174-4fac-a8f6-4317c7f06f26', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '7719b82e-7b14-471f-9ad1-68f4c0993fb9', 'account_id': 'cultpass', 'user_id': '3d4a0fc5-f878-4a44-9a4f-e847710f41e7', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'e7e2dd71-26f3-4665-9ed9-9e54b22f5726', 'account_id': 'cultpass', 'user_id': '0f4bc6b9-f6d4-489e-ab45-7c39d6495657', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '56f569dc-3d99-4f63-ba21-c425c90608f6', 'account_id': 'cultpass', 'user_id': '4cc18ddf-1097-4aa1-aea3-f9453f7bf3d3', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '6b80e942-19ae-4a04-8c61-caec4e964ec5', 'account_id': 'cultpass', 'user_id': '0a4666e8-f1a5-46e4-8493-bf6e7ab97dba', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '9d9befb2-f315-4cd7-95e6-4060371b9239', 'account_id': 'cultpass', 'user_id': '3586ee90-86ae-4af4-aa83-e91c13cee421', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '0b392162-3c70-4992-86fb-306ea959abe0', 'account_id': 'cultpass', 'user_id': '911c1f5c-8f91-45ce-968e-2d4305295ede', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '841277fd-6789-430e-9fb4-b9d214c7778a', 'account_id': 'cultpass', 'user_id': '2f4a7498-4dbe-4823-8916-7374c66c2892', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'cbc78360-f0c0-43e9-bf08-39fde29709c6', 'account_id': 'cultpass', 'user_id': '4189813d-bd85-44f2-b47b-06385f93a9d7', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '549ba0e8-69fa-43a7-845a-c1c5f7c8a0fb', 'account_id': 'cultpass', 'user_id': '4f7f5397-bbf0-4bdd-8c8e-cbb63a794113', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '1091835c-f077-4470-849f-58760fba18d9', 'account_id': 'cultpass', 'user_id': '77a5d472-51a2-425a-954d-e7f3e1f54815', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'af63f586-902d-4edb-b626-5cf1172c760d', 'account_id': 'cultpass', 'user_id': '6e3fc254-65d3-447e-ae74-52c5a1777177', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '1f037a5b-b3cc-4ee7-b86a-5bb36671196e', 'account_id': 'cultpass', 'user_id': 'b2bccfbb-d74e-4140-9cde-998bda55f9a5', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '31683328-7315-495b-b752-061dbf9c5fe1', 'account_id': 'cultpass', 'user_id': 'efe6fde1-0780-4c5e-9e54-d4dfcd7b14f6', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '843ea3b1-d7c7-4dc6-a6ec-d7c29cc462d2', 'account_id': 'cultpass', 'user_id': '504f0364-be45-41f7-b252-9721031d559d', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '59ce23e9-07c6-4f9c-a2e6-b103b3958533', 'account_id': 'cultpass', 'user_id': '77cfa871-1900-4bd3-9333-8b06bc1e5662', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '07f1e546-3f84-4173-976e-65297a37097a', 'account_id': 'cultpass', 'user_id': '1bf1aeb8-1ce3-4801-9fbc-0f2eb7784274', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'ef07bd97-2acd-4bff-bfe4-9c1475bf477d', 'account_id': 'cultpass', 'user_id': '3f930443-5c74-4793-b7d1-be34b82db34e', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '2dd65338-32be-4230-a947-0ebaf2db41f5', 'account_id': 'cultpass', 'user_id': '0f11272b-a7f5-406b-9363-0a4da00f067b', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'd542bbfc-bb9d-489a-865c-9ea318fee3b6', 'account_id': 'cultpass', 'user_id': '9031f988-019d-43f3-aca3-dcf3b3f03c32', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'f73000b3-c95a-48e9-875e-1c363a22d61a', 'account_id': 'cultpass', 'user_id': '29ff37fc-03b6-4484-ab06-8c98b23cbf48', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '737a4faf-ebe0-4e71-969d-57a618cef107', 'account_id': 'cultpass', 'user_id': '5265e089-2852-4f46-aed5-8f52214cdc5c', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '09a1369f-7240-4319-9400-072e076039bd', 'account_id': 'cultpass', 'user_id': '16e66a8a-3e40-42d3-9630-839e9676b96e', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '5c80413c-61a2-4475-8b31-cbc946b275a3', 'account_id': 'cultpass', 'user_id': '2a8ab9b7-9e86-4586-a9e5-98ce1e69773f', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'afe9d57f-6ed5-4c5a-80fa-1e4bc71766d5', 'account_id': 'cultpass', 'user_id': 'b3516eaa-2340-4f2d-b4f1-80cf899c766c', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '60bff384-da5a-4180-b535-817afd21e13a', 'account_id': 'cultpass', 'user_id': '726974bd-2174-4fac-a8f6-4317c7f06f26', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'af545c63-ea04-4e28-8977-159b32747728', 'account_id': 'cultpass', 'user_id': '3d4a0fc5-f878-4a44-9a4f-e847710f41e7', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '80574bf3-fa35-4fde-8a0a-19370fc890a9', 'account_id': 'cultpass', 'user_id': '0f4bc6b9-f6d4-489e-ab45-7c39d6495657', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '276c1507-b2ab-42db-bde3-3328ab224443', 'account_id': 'cultpass', 'user_id': '4cc18ddf-1097-4aa1-aea3-f9453f7bf3d3', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'a132fa72-9bec-4358-9a12-b70b1f940004', 'account_id': 'cultpass', 'user_id': '0a4666e8-f1a5-46e4-8493-bf6e7ab97dba', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '7927954a-2c62-4f85-9a24-b53096987c37', 'account_id': 'cultpass', 'user_id': '3586ee90-86ae-4af4-aa83-e91c13cee421', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'a021d79c-d377-4e10-bf2b-b9200c79436f', 'account_id': 'cultpass', 'user_id': '911c1f5c-8f91-45ce-968e-2d4305295ede', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'f8fb2fc3-8f7d-47a0-8fbd-ba277c7ead81', 'account_id': 'cultpass', 'user_id': '2f4a7498-4dbe-4823-8916-7374c66c2892', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '55dceef0-ecad-40d0-bb05-46c5761e5714', 'account_id': 'cultpass', 'user_id': '4189813d-bd85-44f2-b47b-06385f93a9d7', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'edfb4a12-aba9-4241-b643-68d739151f86', 'account_id': 'cultpass', 'user_id': '4f7f5397-bbf0-4bdd-8c8e-cbb63a794113', 'channel': 'chat', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '6aa1ed52-bd08-4cfa-9198-7a0a85a92287', 'account_id': 'cultpass', 'user_id': '77a5d472-51a2-425a-954d-e7f3e1f54815', 'channel': 'phone', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'e6369808-ff87-4b8d-a4d7-3775e3e7b8b9', 'account_id': 'cultpass', 'user_id': '6e3fc254-65d3-447e-ae74-52c5a1777177', 'channel': 'sms', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '1b93732c-160a-4329-97c3-0b63c7bf147d', 'account_id': 'cultpass', 'user_id': 'b2bccfbb-d74e-4140-9cde-998bda55f9a5', 'channel': 'social', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'f61af362-735e-4b82-a2a5-f16830660511', 'account_id': 'cultpass', 'user_id': 'efe6fde1-0780-4c5e-9e54-d4dfcd7b14f6', 'channel': 'web', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '7a2a1db8-f3c5-46d0-9eca-d1a780fb37cf', 'account_id': 'cultpass', 'user_id': '504f0364-be45-41f7-b252-9721031d559d', 'channel': 'email', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}

# %%
with get_session(engine) as session:
    messages = session.query(udahub.TicketMessage).all()
    for message in messages:
        # Get all column names for this model
        inst = inspect(message)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(message, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'message_id': '9deca7f4-f0a6-4b45-be30-8df04c2b8c4d', 'ticket_id': '5c06102f-26c1-4258-a1a2-07e33c73c9b2', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am trying to book tickets for the upcoming tech conference, but the system keeps showing an error message. I have tried multiple times, but it seems like the booking process is not going through. Could you please assist me with this issue? I would appreciate it if you could resolve this as soon as possible since the event is approaching fast. Thank you!', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '77baa030-7777-4501-b1bf-873c52e4fbda', 'ticket_id': '80766888-1ff1-4a92-9cc2-b660af014e9e', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am unable to log into my account. I have tried resetting my password, but I am not receiving the reset email. Could you please help me regain access to my account? I need to check my attendance records for the past month. Thank you for your assistance.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '49b00eac-637f-4931-b322-bb54b2b2b24c', 'ticket_id': 'c53e4c91-0198-4a84-b19b-6702c0e8ab6e', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to cancel my booking for the upcoming event due to unforeseen circumstances. I tried doing it through the website, but it seems like the cancelation option is not working. Could you please assist me with this? I would also like to know if there are any cancelation fees involved. Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'a6579532-e8c8-40b8-85cc-0b9e5a782759', 'ticket_id': 'c195b99c-e0fe-4c2a-8a2c-972867b24c5b', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I am having trouble accessing my reservation details. I need to cancel my reservation, but I can't seem to find the option to do so. Could you please help me with this? I would appreciate a quick response as the reservation date is approaching. Thank you.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '8873d5e9-52ad-40f7-a1b4-59ac5ffa8844', 'ticket_id': 'a8bad12f-0609-4f76-bf7c-56be035fa9a9', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am unable to reset my password. I have tried multiple times, but the reset link is not working. I need to escalate this issue as I am unable to access my account. Could you please assist me with this? Thank you for your prompt attention to this matter.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'becec3b3-8d64-4305-96a9-d444a1cd9c8a', 'ticket_id': '5c41d278-bfc3-4002-a25a-4424a01fdd0d', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am trying to book a session for the upcoming workshop, but I am facing issues with the payment process. It seems like there is a billing error. Could you please help me resolve this? I also need to confirm my attendance for the event. Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '762d0980-265a-4de1-b895-2de5badd6503', 'ticket_id': '350c1ee5-22dc-4bdb-a1ef-4a888302bdbf', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my subscription. I need to update my billing information, but the system is not allowing me to do so. I also have questions about the pricing of the subscription plans. Could you please assist me with this? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '6fcc1102-d392-4858-b4ea-1663adb11e30', 'ticket_id': '3068ffd9-022a-4f76-9c23-d9bbfa69cdd6', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to cancel my subscription to the event series. I am also interested in knowing if there are any benefits for early cancelation. Could you please provide me with the necessary information? Thank you for your assistance.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'b75426bb-fd91-4424-b8f4-7cd0d229929e', 'ticket_id': 'fc721c85-3f4b-430f-91aa-25fec399ff3d', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I am unable to log into my account. I need to cancel an upcoming event, but I can't access the cancelation option. Could you please help me with this issue? Thank you for your prompt response.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'cf12694d-9eea-4cec-83dc-798de0c49e25', 'ticket_id': 'e6b7d5c3-f861-4008-b9e8-ff2fabc8f72d', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to cancel my participation in the upcoming event. I tried doing it through the website, but it seems like the cancelation option is not working. Could you please assist me with this? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'c681ac2f-3683-49af-8728-ff71d8b1f55d', 'ticket_id': '55871fbc-c444-4468-8e62-5b72bffd4192', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a question regarding my subscription. I need to know if there are any changes to the subscription plans. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'a038b114-fe55-4b74-8dc8-49c7e3a10b8c', 'ticket_id': '7719b82e-7b14-471f-9ad1-68f4c0993fb9', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I am unable to reset my password. I also need to access my event details, but I can't seem to log into my account. Could you please help me with this issue? Thank you for your assistance.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '1135f08e-467d-4528-a2cf-a3dc0da4f456', 'ticket_id': 'e7e2dd71-26f3-4665-9ed9-9e54b22f5726', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I am having trouble with my billing. I need to pause my subscription for a month, but I can't find the option to do so. Could you please assist me with this? I also need to confirm my attendance for the upcoming event. Thank you.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '6f7d647f-545f-41c7-ac2f-6b7b1a4cf97d', 'ticket_id': '56f569dc-3d99-4f63-ba21-c425c90608f6', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am interested in subscribing to the event series. I need to know if there are any attendance requirements for the subscription. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '59b08bb3-fe2e-496f-a361-55cf7560b045', 'ticket_id': '6b80e942-19ae-4a04-8c61-caec4e964ec5', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my password. I also need to know if there are any pricing changes for the reservation plans. Could you please assist me with this? Thank you for your prompt response.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '95016112-63cc-4671-9f17-9a947fbdd19a', 'ticket_id': '9d9befb2-f315-4cd7-95e6-4060371b9239', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am unable to access my reservation details. I also need to reset my password, but I am not receiving the reset email. Could you please help me with this issue? Thank you for your assistance.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'a1ddbc09-06bb-41f0-a514-bc5d6f860c34', 'ticket_id': '0b392162-3c70-4992-86fb-306ea959abe0', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to escalate an issue with my event reservation. I am unable to access the reservation details, and the event date is approaching. Could you please assist me with this? Thank you for your prompt attention to this matter.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '30fdd4b0-8047-4452-9f03-5d11d369cbff', 'ticket_id': '841277fd-6789-430e-9fb4-b9d214c7778a', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I am unable to log into my account. I need to access my event benefits, but I can't seem to find the option to do so. Could you please help me with this issue? Thank you for your assistance.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'c6f69027-bcab-410e-b1e5-9a00586bb19b', 'ticket_id': 'cbc78360-f0c0-43e9-bf08-39fde29709c6', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a question regarding the pricing of the event series. I also need to pause my subscription for a month. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '7e3025d6-3c2a-4851-b8fd-74ded41d801c', 'ticket_id': '549ba0e8-69fa-43a7-845a-c1c5f7c8a0fb', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I am unable to log into my account. I need to book a session for the upcoming workshop, but I can't seem to access the booking option. Could you please help me with this issue? Thank you for your assistance.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'ddebe12c-b7de-4737-9b7c-7463a804eeff', 'ticket_id': '1091835c-f077-4470-849f-58760fba18d9', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my billing. I need to update my reservation details, but the system is not allowing me to do so. I also have questions about the pricing of the reservation plans. Could you please assist me with this? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '3713e1be-2ca2-412a-a828-8de17c9defc3', 'ticket_id': 'af63f586-902d-4edb-b626-5cf1172c760d', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am unable to log into my account. I need to reset my password, but I am not receiving the reset email. Could you please help me with this issue? Thank you for your assistance.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '7e8ec281-b7d0-4446-befb-dc006907f462', 'ticket_id': '1f037a5b-b3cc-4ee7-b86a-5bb36671196e', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my booking. I need to access my reservation details, but the system is not allowing me to do so. I also have questions about the pricing of the booking plans. Could you please assist me with this? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '42292b8b-39cf-46fb-a1f9-b77d6e131ef6', 'ticket_id': '31683328-7315-495b-b752-061dbf9c5fe1', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to update my reservation details. I also have questions about the pricing of the reservation plans. Could you please provide me with the necessary information? Thank you for your assistance.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '53c666ec-9b1a-4c44-aad6-a32ea050bb75', 'ticket_id': '843ea3b1-d7c7-4dc6-a6ec-d7c29cc462d2', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my billing. I need to escalate an issue with my event participation. Could you please assist me with this? Thank you for your prompt attention to this matter.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '20372983-a256-4c9a-86b8-70aaad08d883', 'ticket_id': '59ce23e9-07c6-4f9c-a2e6-b103b3958533', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I am unable to log into my account. I need to cancel my participation in the upcoming event, but I can't seem to find the cancelation option. Could you please help me with this issue? Thank you for your assistance.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '08dc7c75-67ac-4d46-868e-1625b7bc4d6a', 'ticket_id': '07f1e546-3f84-4173-976e-65297a37097a', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a question regarding the benefits of my subscription. I also need to pause my billing for a month. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '12e1cc90-1d76-4bf0-8c70-34984120ee3c', 'ticket_id': 'ef07bd97-2acd-4bff-bfe4-9c1475bf477d', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am interested in subscribing to the event series. I need to know if there are any booking requirements for the subscription. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '916949fe-6d9c-4b23-9929-5f5b2af916e5', 'ticket_id': '2dd65338-32be-4230-a947-0ebaf2db41f5', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my subscription. I need to update my billing information, but the system is not allowing me to do so. I also have questions about the pricing of the subscription plans. Could you please assist me with this? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'cef558e5-fcdf-48fb-9f46-9c7f8b9a6614', 'ticket_id': 'd542bbfc-bb9d-489a-865c-9ea318fee3b6', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to update my reservation details. I also have questions about the benefits of the reservation plans. Could you please provide me with the necessary information? Thank you for your assistance.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '8d7a26ea-e1e3-4b72-9706-e85ea6011e85', 'ticket_id': 'f73000b3-c95a-48e9-875e-1c363a22d61a', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my billing. I need to know if there are any benefits for early payment. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'a91a6a76-a503-46eb-9574-a28f35831bac', 'ticket_id': '737a4faf-ebe0-4e71-969d-57a618cef107', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I am trying to book tickets for the upcoming tech conference, but the system keeps showing an error message. I have tried multiple times, but it seems like the booking process is not going through. Could you please assist me with this issue? I would appreciate it if you could resolve this as soon as possible since the event is approaching fast. Thank you!', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '8f04c297-62e7-45df-9250-73344571f46f', 'ticket_id': '09a1369f-7240-4319-9400-072e076039bd', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to escalate an issue with my event participation. I am unable to access the cancelation option, and the event date is approaching. Could you please assist me with this? Thank you for your prompt attention to this matter.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '2cea8ba3-c128-4e19-a31f-5e0f0bbfe447', 'ticket_id': '5c80413c-61a2-4475-8b31-cbc946b275a3', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to escalate an issue with my account. I am unable to access my event details, and the event date is approaching. Could you please assist me with this? Thank you for your prompt attention to this matter.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '593e7763-35f3-4368-abc5-8a3a4a7c3891', 'ticket_id': 'afe9d57f-6ed5-4c5a-80fa-1e4bc71766d5', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my booking. I need to access my reservation details, but the system is not allowing me to do so. I also have questions about the pricing of the booking plans. Could you please assist me with this? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'c3d0865d-5a1f-44e8-b629-dffb437750a0', 'ticket_id': '60bff384-da5a-4180-b535-817afd21e13a', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I am having trouble with my password. I need to pause my subscription for a month, but I can't find the option to do so. Could you please assist me with this? I also have questions about the pricing of the subscription plans. Thank you.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'f421454c-4fd2-407b-8e5b-29f14c5620be', 'ticket_id': 'af545c63-ea04-4e28-8977-159b32747728', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to update my reservation details. I also have questions about the cancelation policy for the subscription plans. Could you please provide me with the necessary information? Thank you for your assistance.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'd396b3bc-239b-4ab3-aa83-426531fcaafa', 'ticket_id': '80574bf3-fa35-4fde-8a0a-19370fc890a9', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I am unable to access my reservation details. I need to cancel my reservation, but I can't seem to find the option to do so. Could you please help me with this? I would appreciate a quick response as the reservation date is approaching. Thank you.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'b5978394-5d6b-45f2-ab0d-907268f49244', 'ticket_id': '276c1507-b2ab-42db-bde3-3328ab224443', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I need to pause my subscription for a month. I also have questions about the escalation process for my account. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'c7d0b7a7-086f-4fd6-afd3-86ca9b93c6cf', 'ticket_id': 'a132fa72-9bec-4358-9a12-b70b1f940004', 'role': <RoleEnum.user: 'user'>, 'content': "Hi, I am unable to log into my account. I need to pause my subscription for a month, but I can't find the option to do so. Could you please assist me with this? I also have questions about the pricing of the subscription plans. Thank you.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '08e2af76-2ffe-4dd4-9da4-4c86d98f1496', 'ticket_id': '7927954a-2c62-4f85-9a24-b53096987c37', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my password. I also need some health advice regarding my account. Could you please assist me with this? Thank you for your prompt response.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '4c25978e-2f04-4d43-b723-82286b6bf16b', 'ticket_id': 'a021d79c-d377-4e10-bf2b-b9200c79436f', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I have a question regarding the stock price of the event series. I also need to know if there are any weather-related updates for the event. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '0e1edd84-2a5b-49f0-a617-0ab7813c8f3d', 'ticket_id': 'f8fb2fc3-8f7d-47a0-8fbd-ba277c7ead81', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I have a question regarding the stock price of the event series. I also need some dietary advice for the event. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '3174ed49-e343-4f33-ad7b-3bb70500fee9', 'ticket_id': '55dceef0-ecad-40d0-bb05-46c5761e5714', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to pause my subscription for a month. I also have questions about the login process for my account. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'ef5cdf91-6ad9-4978-ad8e-6cb430350c7c', 'ticket_id': 'edfb4a12-aba9-4241-b643-68d739151f86', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my password. I also need some health advice regarding my account. Could you please assist me with this? Thank you for your prompt response.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '26efb289-f56e-4fe3-9be2-98d10ba27ea8', 'ticket_id': '6aa1ed52-bd08-4cfa-9198-7a0a85a92287', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I have a question regarding the pricing of the event series. I also need some dietary advice for the event. Could you please provide me with the necessary information? Thank you.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': 'fbb0669b-2f34-4ace-a095-080aec7fb2b2', 'ticket_id': 'e6369808-ff87-4b8d-a4d7-3775e3e7b8b9', 'role': <RoleEnum.user: 'user'>, 'content': "Hello, I am having trouble with my billing. I need to cancel my participation in the upcoming event, but I can't seem to find the cancelation option. I also have questions about the dietary requirements for the event. Could you please assist me with this? Thank you.", 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '5bd39016-46ed-4790-96a7-5cd2573d1107', 'ticket_id': '1b93732c-160a-4329-97c3-0b63c7bf147d', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to escalate an issue with my account. I am unable to access my event details, and the event date is approaching. Could you please assist me with this? Thank you for your prompt attention to this matter.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '897a21aa-b904-4459-ad78-2f8e3fd0b293', 'ticket_id': 'f61af362-735e-4b82-a2a5-f16830660511', 'role': <RoleEnum.user: 'user'>, 'content': 'Hello, I am having trouble with my password. I also need to know if there are any weather-related updates for the event. Could you please assist me with this? Thank you for your prompt response.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'message_id': '376293af-e7cc-4c62-89b6-cc4750fd8356', 'ticket_id': '7a2a1db8-f3c5-46d0-9eca-d1a780fb37cf', 'role': <RoleEnum.user: 'user'>, 'content': 'Hi, I need to update my reservation details. I also have questions about the stock price of the event series. Could you please provide me with the necessary information? Thank you for your assistance.', 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}

# %%
with get_session(engine) as session:
    metas = session.query(udahub.TicketMetadata).all()
    for meta in metas:
        # Get all column names for this model
        inst = inspect(meta)
        # Create a dictionary of {column_name: value}
        columns_data = {c.key: getattr(meta, c.key) for c in inst.mapper.column_attrs}
        print(columns_data)
# Out:
# {'ticket_id': '5c06102f-26c1-4258-a1a2-07e33c73c9b2', 'status': 'open', 'main_issue_type': None, 'tags': 'events', 'urgency_score': 0.19021991081010958, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '80766888-1ff1-4a92-9cc2-b660af014e9e', 'status': 'open', 'main_issue_type': None, 'tags': 'password, attendance', 'urgency_score': 0.767424703160575, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'c53e4c91-0198-4a84-b19b-6702c0e8ab6e', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, cancelation, events', 'urgency_score': 0.03694807653083454, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'c195b99c-e0fe-4c2a-8a2c-972867b24c5b', 'status': 'open', 'main_issue_type': None, 'tags': 'cancelation, reservation, access', 'urgency_score': 0.5536022750107589, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'a8bad12f-0609-4f76-bf7c-56be035fa9a9', 'status': 'open', 'main_issue_type': None, 'tags': 'password, escalation', 'urgency_score': 0.12060732593703327, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '5c41d278-bfc3-4002-a25a-4424a01fdd0d', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, attendance, billing', 'urgency_score': 0.11312088559532374, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '350c1ee5-22dc-4bdb-a1ef-4a888302bdbf', 'status': 'open', 'main_issue_type': None, 'tags': 'password, subscription, billing, pricing', 'urgency_score': 0.5805481159182141, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '3068ffd9-022a-4f76-9c23-d9bbfa69cdd6', 'status': 'open', 'main_issue_type': None, 'tags': 'cancelation, events, benefits', 'urgency_score': 0.5302350763062134, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'fc721c85-3f4b-430f-91aa-25fec399ff3d', 'status': 'open', 'main_issue_type': None, 'tags': 'cancelation, login', 'urgency_score': 0.16586394177275798, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'e6b7d5c3-f861-4008-b9e8-ff2fabc8f72d', 'status': 'open', 'main_issue_type': None, 'tags': 'events, cancelation', 'urgency_score': 0.1707336141195791, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '55871fbc-c444-4468-8e62-5b72bffd4192', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription', 'urgency_score': 0.047981509177063675, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '7719b82e-7b14-471f-9ad1-68f4c0993fb9', 'status': 'open', 'main_issue_type': None, 'tags': 'password, access, events', 'urgency_score': 0.9891606352712405, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'e7e2dd71-26f3-4665-9ed9-9e54b22f5726', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, attendance, subscription, pause', 'urgency_score': 0.6477711288939668, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '56f569dc-3d99-4f63-ba21-c425c90608f6', 'status': 'open', 'main_issue_type': None, 'tags': 'events, attendance, subscription', 'urgency_score': 0.8288652578446385, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '6b80e942-19ae-4a04-8c61-caec4e964ec5', 'status': 'open', 'main_issue_type': None, 'tags': 'password, pricing, reservation', 'urgency_score': 0.7627991712891818, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '9d9befb2-f315-4cd7-95e6-4060371b9239', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, login, password, events', 'urgency_score': 0.5037705238334501, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '0b392162-3c70-4992-86fb-306ea959abe0', 'status': 'open', 'main_issue_type': None, 'tags': 'events, reservation, escalation', 'urgency_score': 0.7560004943134815, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '841277fd-6789-430e-9fb4-b9d214c7778a', 'status': 'open', 'main_issue_type': None, 'tags': 'login, events, benefits', 'urgency_score': 0.45803678382016955, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'cbc78360-f0c0-43e9-bf08-39fde29709c6', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, pause, events', 'urgency_score': 0.06450944038843898, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '549ba0e8-69fa-43a7-845a-c1c5f7c8a0fb', 'status': 'open', 'main_issue_type': None, 'tags': 'booking, login', 'urgency_score': 0.7285553776171472, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '1091835c-f077-4470-849f-58760fba18d9', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, reservation, pricing, subscription', 'urgency_score': 0.6609046684369928, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'af63f586-902d-4edb-b626-5cf1172c760d', 'status': 'open', 'main_issue_type': None, 'tags': 'login, password', 'urgency_score': 0.38530702536043115, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '1f037a5b-b3cc-4ee7-b86a-5bb36671196e', 'status': 'open', 'main_issue_type': None, 'tags': 'access, pause, pricing, booking', 'urgency_score': 0.636273795915449, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '31683328-7315-495b-b752-061dbf9c5fe1', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, pricing', 'urgency_score': 0.4112024974549665, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '843ea3b1-d7c7-4dc6-a6ec-d7c29cc462d2', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, events, escalation', 'urgency_score': 0.2890096999050218, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '59ce23e9-07c6-4f9c-a2e6-b103b3958533', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, login, cancelation, benefits', 'urgency_score': 0.42891882651818136, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '07f1e546-3f84-4173-976e-65297a37097a', 'status': 'open', 'main_issue_type': None, 'tags': 'benefits, password, pause, billing', 'urgency_score': 0.3283943333984377, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'ef07bd97-2acd-4bff-bfe4-9c1475bf477d', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, booking', 'urgency_score': 0.34990879012282405, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '2dd65338-32be-4230-a947-0ebaf2db41f5', 'status': 'open', 'main_issue_type': None, 'tags': 'subscription, pricing, billing', 'urgency_score': 0.17940617752198473, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'd542bbfc-bb9d-489a-865c-9ea318fee3b6', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, benefits, password', 'urgency_score': 0.9978416234005176, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'f73000b3-c95a-48e9-875e-1c363a22d61a', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, benefits', 'urgency_score': 0.8588216451346256, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '737a4faf-ebe0-4e71-969d-57a618cef107', 'status': 'open', 'main_issue_type': None, 'tags': 'events', 'urgency_score': 0.3371305709646908, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '09a1369f-7240-4319-9400-072e076039bd', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, cancelation, benefits', 'urgency_score': 0.5992745900436415, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '5c80413c-61a2-4475-8b31-cbc946b275a3', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation', 'urgency_score': 0.12617095239267662, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'afe9d57f-6ed5-4c5a-80fa-1e4bc71766d5', 'status': 'open', 'main_issue_type': None, 'tags': 'cancelation, access, booking, events', 'urgency_score': 0.03020912017889288, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '60bff384-da5a-4180-b535-817afd21e13a', 'status': 'open', 'main_issue_type': None, 'tags': 'password, pause, pricing', 'urgency_score': 0.9805417653876983, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'af545c63-ea04-4e28-8977-159b32747728', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, cancelation, subscription, pause', 'urgency_score': 0.00719400745069243, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '80574bf3-fa35-4fde-8a0a-19370fc890a9', 'status': 'open', 'main_issue_type': None, 'tags': 'access, reservation, cancelation, login', 'urgency_score': 0.999822047099618, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '276c1507-b2ab-42db-bde3-3328ab224443', 'status': 'open', 'main_issue_type': None, 'tags': 'pause, escalation, booking', 'urgency_score': 0.6125287889830704, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'a132fa72-9bec-4358-9a12-b70b1f940004', 'status': 'open', 'main_issue_type': None, 'tags': 'login, pause, pricing', 'urgency_score': 0.08859530010031913, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '7927954a-2c62-4f85-9a24-b53096987c37', 'status': 'open', 'main_issue_type': None, 'tags': 'password, health advice', 'urgency_score': 0.2560659761380436, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'a021d79c-d377-4e10-bf2b-b9200c79436f', 'status': 'open', 'main_issue_type': None, 'tags': 'stock price, weather', 'urgency_score': 0.13848452405594203, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'f8fb2fc3-8f7d-47a0-8fbd-ba277c7ead81', 'status': 'open', 'main_issue_type': None, 'tags': 'stock price, dietary', 'urgency_score': 0.7083792551552924, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '55dceef0-ecad-40d0-bb05-46c5761e5714', 'status': 'open', 'main_issue_type': None, 'tags': 'pause, login, health advice, weather', 'urgency_score': 0.8934069253410132, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'edfb4a12-aba9-4241-b643-68d739151f86', 'status': 'open', 'main_issue_type': None, 'tags': 'pause, password, health advice, stock price', 'urgency_score': 0.48244281530832456, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '6aa1ed52-bd08-4cfa-9198-7a0a85a92287', 'status': 'open', 'main_issue_type': None, 'tags': 'pricing, login, dietary, health advice', 'urgency_score': 0.151200000793134, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'e6369808-ff87-4b8d-a4d7-3775e3e7b8b9', 'status': 'open', 'main_issue_type': None, 'tags': 'billing, cancelation, dietary, weather', 'urgency_score': 0.5048605275887338, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '1b93732c-160a-4329-97c3-0b63c7bf147d', 'status': 'open', 'main_issue_type': None, 'tags': 'escalation, weather, dietary', 'urgency_score': 0.7558926164948114, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': 'f61af362-735e-4b82-a2a5-f16830660511', 'status': 'open', 'main_issue_type': None, 'tags': 'password, weather', 'urgency_score': 0.5351498440220754, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}
# {'ticket_id': '7a2a1db8-f3c5-46d0-9eca-d1a780fb37cf', 'status': 'open', 'main_issue_type': None, 'tags': 'reservation, stock price, weather', 'urgency_score': 0.36253826847304804, 'created_at': datetime.datetime(2026, 4, 11, 23, 4, 45), 'updated_at': datetime.datetime(2026, 4, 11, 23, 4, 45)}

# %%
with get_session(engine) as session:
    user = session.query(udahub.User).filter_by(
        account_id=account_id,
        external_user_id=ticket_table.iloc[2].to_dict()["owner_id"],
    ).first()
    
    ticket:udahub.Ticket = user.tickets[0]
    for message in ticket.messages:
        print(message)
# Out:
# <TicketMessage(message_id='49b00eac-637f-4931-b322-bb54b2b2b24c', role='user', content='Hello, I need to cancel my boo...')>
