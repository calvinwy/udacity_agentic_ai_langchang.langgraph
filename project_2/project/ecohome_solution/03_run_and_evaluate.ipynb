# %% [markdown]
# # EcoHome Energy Advisor - Agent Run & Evaluation
#
# In this notebook, you'll run the Energy Advisor agent with various real-world scenarios and see how it helps customers optimize their energy usage.
#
# ## Learning Objectives
# - Create the agent's instructions
# - Run the Energy Advisor with different types of questions
# - Evaluate response quality and accuracy
# - Measure tool usage effectiveness
# - Identify areas for improvement
# - Implement evaluation metrics
#
# ## Evaluation Criteria
# - **Accuracy**: Correct information and calculations
# - **Relevance**: Responses address the user's question
# - **Completeness**: Comprehensive answers with actionable advice
# - **Tool Usage**: Appropriate use of available tools
# - **Reasoning**: Clear explanation of recommendations

# %% [markdown]
# ## 1. Import and Initialize

# %%
from datetime import datetime
from agent import Agent

# %%
## TODO: Create the agent's instructions

ECOHOME_SYSTEM_PROMPT = f"""
    You are an home energy expert, you are given a set of tools to assess the energy situation of our customer.
    You will be supporting the customer and providing advises on the following topics [with the corresponding tools]:

        (1) Weather Integration: Use weather forecasts to predict solar generation and optimize device scheduling
        (2) Dynamic Pricing: Consider time-of-day electricity prices for cost optimization
        (3) Historical Analysis: Query past energy usage patterns for personalized advice
        (4) RAG Pipeline: Retrieve relevant energy-saving tips and best practices
        (5) Multi-device Optimization: Handle EVs, HVAC, appliances, and solar systems
        (6) Cost Calculations: Provide specific savings estimates and ROI analysis
        (7) Other Energy Advices or Questions of Multiple Categories: Perform an analysis of the question and use any combination of the tools to try and figure out the answer
    
    After obtaining all required data from the tools, try to answer the question in a polite and helpful manner within 200 words.  Explain your logic.
    """

# %%
ecohome_agent = Agent(
    instructions=ECOHOME_SYSTEM_PROMPT,
)

# %%
response = ecohome_agent.invoke(
    question="When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
    context="Location: San Francisco, CA"
)

# %%
print(response["messages"][-1].content)
# Out:
# To minimize costs and maximize solar power for charging your electric car tomorrow in San Francisco, consider the following:
#
# 1. **Solar Power Maximization**: The highest solar irradiance is expected between 11 AM and 2 PM, with a peak at 2 PM (310 W/m²). Charging during this time will maximize the use of solar energy.
#
# 2. **Cost Minimization**: Electricity prices are lowest during the Off-Peak period, which is from midnight to 6 AM and again from 11 PM to midnight, at $0.096 per kWh. The Mid-Peak rate is $0.132 per kWh, and the Peak rate is $0.192 per kWh from 2 PM to 8 PM.
#
# **Recommendation**: To balance both solar power usage and cost, consider starting your charge around 11 AM to take advantage of solar power, and if possible, continue charging into the early afternoon. If you need to charge more, consider doing so during the Off-Peak hours (midnight to 6 AM) to benefit from the lowest rates. This strategy will help you optimize both cost and renewable energy usage.

# %%
print("TOOLS:")
for msg in response["messages"]:
    obj = msg.model_dump()
    if obj.get("tool_call_id"):
        print("-", msg.name)
# Out:
# TOOLS:
# - get_weather_forecast
# - get_electricity_prices

# %%
response['messages']
# Out:
# [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='17b9dd9f-81fa-42e3-9794-02bfbc4da7b4'),
#  HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', additional_kwargs={}, response_metadata={}, id='a58008cf-834a-4a40-be85-35b6cfaa653a'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 1079, 'total_tokens': 1133, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3aTEsovBh1rSEZMtTlBZnW9rUmR', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--e2c2cfdf-5e5a-4cf4-8d9d-5deb77b49393-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_eEWCrnbpNlrpjR9GgMfZfC5Y', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {}, 'id': 'call_ai2LDn1z7ncVt3SnaNXZ9Hbd', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1079, 'output_tokens': 54, 'total_tokens': 1133, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='{"location": "San Francisco", "forecast_days": 1, "current": {"temperature_c": 10.3, "condition": "partly_cloudy", "humidity": 92, "wind_speed": 10.6}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.9, "condition": "cloudy", "solar_irradiance": 222.5, "humidity": 84, "wind_speed": 12.5}, {"hour": 14, "temperature_c": 11.2, "condition": "cloudy", "solar_irradiance": 310.0, "humidity": 80, "wind_speed": 13.0}, {"hour": 15, "temperature_c": 10.7, "condition": "cloudy", "solar_irradiance": 161.5, "humidity": 86, "wind_speed": 11.5}, {"hour": 16, "temperature_c": 10.8, "condition": "partly_cloudy", "solar_irradiance": 109.2, "humidity": 93, "wind_speed": 10.2}, {"hour": 17, "temperature_c": 9.8, "condition": "partly_cloudy", "solar_irradiance": 16.5, "humidity": 92, "wind_speed": 10.5}, {"hour": 18, "temperature_c": 9.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.5}, {"hour": 19, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 9.8}, {"hour": 20, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.1}, {"hour": 21, "temperature_c": 7.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 9.4}, {"hour": 22, "temperature_c": 7.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 9.4}, {"hour": 23, "temperature_c": 7.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.1}]}', name='get_weather_forecast', id='192995d6-8419-4a1d-9993-79661f64f1d5', tool_call_id='call_eEWCrnbpNlrpjR9GgMfZfC5Y'),
#  ToolMessage(content='{"date": "2025-11-29", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='9ce97ff6-f2cd-4d8b-9d46-e5166f4b30de', tool_call_id='call_ai2LDn1z7ncVt3SnaNXZ9Hbd'),
#  AIMessage(content='To minimize costs and maximize solar power for charging your electric car tomorrow in San Francisco, consider the following:\n\n1. **Solar Power Maximization**: The highest solar irradiance is expected between 11 AM and 2 PM, with a peak at 2 PM (310 W/m²). Charging during this time will maximize the use of solar energy.\n\n2. **Cost Minimization**: Electricity prices are lowest during the Off-Peak period, which is from midnight to 6 AM and again from 11 PM to midnight, at $0.096 per kWh. The Mid-Peak rate is $0.132 per kWh, and the Peak rate is $0.192 per kWh from 2 PM to 8 PM.\n\n**Recommendation**: To balance both solar power usage and cost, consider starting your charge around 11 AM to take advantage of solar power, and if possible, continue charging into the early afternoon. If you need to charge more, consider doing so during the Off-Peak hours (midnight to 6 AM) to benefit from the lowest rates. This strategy will help you optimize both cost and renewable energy usage.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 238, 'prompt_tokens': 3237, 'total_tokens': 3475, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3aVgbDOpGwZFht9D13EQ43cgquY', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--98a951ec-9945-4df8-973a-4ac645d23921-0', usage_metadata={'input_tokens': 3237, 'output_tokens': 238, 'total_tokens': 3475, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %% [markdown]
# ## 2. Define Test Cases

# %%
# TODO: Define comprehensive test cases for the Energy Advisor
# Create 10 test cases covering different scenarios:
# - EV charging optimization
# - Thermostat settings
# - Appliance scheduling
# - Solar power maximization
# - Cost savings calculations

# %%
test_cases = [
    {
        "id": "ev_charging_1",
        "question": "When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "The response should contain time recommendation, cost analysis and solar consideration",
    },
    {
        "id": "ev_charging_2",
        "question": "To minimize cost of charing my vehicle using solar energy, how does the time range differs comparing summer to winter?",
        "expected_tools": ["get_weather_forecast", "query_solar_generation"],
        "expected_response": "The response to provide insights about time range difference between summer and winter.",
    },
    {
        "id": "thermostat_setting",
        "question": "What is the optimal thermostat_setting I should be setting to next week in my living room?",
        "expected_tools": ["query_energy_usage", "get_weather_forecast"],
        "expected_response": "The response should contain time recommendation and thermostat temperature setting.",
    },
    {
        "id": "appliance_scheduling",
        "question": "When is the best time this week to do my laundry to save money?",
        "expected_tools": ["get_electricity_prices","query_energy_usage","get_recent_energy_summary"],
        "expected_response": "The response should include a date and time for doing laundry.",
    },
    {
        "id": "energy_price_estimation",
        "question": "By not turning on my appliance, I save 100kwh a day, how much money do I save for a year?",
        "expected_tools": ["calculate_energy_savings"],
        "expected_response": "The response should include the number of hours, the energy consumed, and the price.",
    },
    {
        "id": "costs_savings_calculation",
        "question": "How do I optimize my electric bill with my appliances using my usage data from the last 2 weeks?",
        "expected_tools": ["query_energy_usage","get_electricity_prices"],
        "expected_response": "The result should provide suggestions on suggestions on how to arrange the appliances usage.",
    },
    {
        "id": "general_tips",
        "question": "Can you give me 5 general ways to save energy for my home?",
        "expected_tools": ["search_energy_tips"],
        "expected_response": "There should be 5 points related to energy saving given.",
    },
    {
        "id": "solar_saving",
        "question": "Can you estimate the total solar saving for the whole week next week?",
        "expected_tools": ["get_weather_forecast", "query_solar_generation"],
        "expected_response": "The response should be a total saving amount.",
    },
    {
        "id": "general_consumption",
        "question": "How much does it cost for my energy consumption in the last 2 weeks?",
        "expected_tools": ["query_energy_usage", "get_electricity_prices"],
        "expected_response": "The response should e a total cost amount.",
    },
    {
        "id": "energy_consumption",
        "question": "What is my energy consumption for the last 2 hours?",
        "expected_tools": ["get_recent_energy_summary"],
        "expected_response": "The response should contain the energy consumption of last 2 hours.",
    },
    

]

if len(test_cases) < 10:
    raise ValueError("You MUST have at least 10 test cases")

# %% [markdown]
# ## 3. Run Agent Tests

# %%
CONTEXT = "Location: San Francisco, CA"

# %%
# Run the agent tests
# For each test case, call the agent and collect the response
# Store results for evaluation

print("=== Running Agent Tests ===")
test_results = []

for i, test_case in enumerate(test_cases):
    print(f"\nTest {i+1}: {test_case['id']}")
    print(f"Question: {test_case['question']}")
    print("-" * 50)
    
    try:
        # Call the agent
        response = ecohome_agent.invoke(
            question=test_case['question'],
            context=CONTEXT
        )
        
        # Store the result
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': response,
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat()
        }
        test_results.append(result)
                
    except Exception as e:
        print(f"Error: {e}")
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': f"Error: {str(e)}",
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat(),
            'error': str(e)
        }
        test_results.append(result)

print(f"\nCompleted {len(test_results)} tests")
# Out:
# === Running Agent Tests ===
#
# Test 1: ev_charging_1
# Question: When should I charge my electric car tomorrow to minimize cost and maximize solar power?
# --------------------------------------------------
#
# Test 2: ev_charging_2
# Question: To minimize cost of charing my vehicle using solar energy, how does the time range differs comparing summer to winter?
# --------------------------------------------------
#
# Test 3: thermostat_setting
# Question: What is the optimal thermostat_setting I should be setting to next week in my living room?
# --------------------------------------------------
#
# Test 4: appliance_scheduling
# Question: When is the best time this week to do my laundry to save money?
# --------------------------------------------------
#
# Test 5: energy_price_estimation
# Question: By not turning on my appliance, I save 100kwh a day, how much money do I save for a year?
# --------------------------------------------------
#
# Test 6: costs_savings_calculation
# Question: How do I optimize my electric bill with my appliances using my usage data from the last 2 weeks?
# --------------------------------------------------
#
# Test 7: general_tips
# Question: Can you give me 5 general ways to save energy for my home?
# --------------------------------------------------
#
# Test 8: solar_saving
# Question: Can you estimate the total solar saving for the whole week next week?
# --------------------------------------------------
#
# Test 9: general_consumption
# Question: How much does it cost for my energy consumption in the last 2 weeks?
# --------------------------------------------------
#
# Test 10: energy_consumption
# Question: What is my energy consumption for the last 2 hours?
# --------------------------------------------------
#
# Completed 10 tests

# %%
test_results
# Out:
# [{'test_id': 'ev_charging_1',
#   'question': 'When should I charge my electric car tomorrow to minimize cost and maximize solar power?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='3ccf1dff-42c3-4019-b8e3-ba71e5742654'),
#     HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', additional_kwargs={}, response_metadata={}, id='d8af9fe2-f4ae-415a-be1f-2eeec303192f'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 1079, 'total_tokens': 1133, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3aZe6HcJufIYfySEzTR8SpUauFf', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--f7b47ef4-a6a6-4767-8dca-8519a42ab8d0-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_wNQsfUbvBE7ALECMueqdY8qB', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {}, 'id': 'call_rAeZ3w74nCZsKcdGZlgC6b0y', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1079, 'output_tokens': 54, 'total_tokens': 1133, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 1, "current": {"temperature_c": 10.3, "condition": "partly_cloudy", "humidity": 92, "wind_speed": 10.6}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.9, "condition": "cloudy", "solar_irradiance": 222.5, "humidity": 84, "wind_speed": 12.5}, {"hour": 14, "temperature_c": 11.2, "condition": "cloudy", "solar_irradiance": 310.0, "humidity": 80, "wind_speed": 13.0}, {"hour": 15, "temperature_c": 10.7, "condition": "cloudy", "solar_irradiance": 161.5, "humidity": 86, "wind_speed": 11.5}, {"hour": 16, "temperature_c": 10.8, "condition": "partly_cloudy", "solar_irradiance": 109.2, "humidity": 93, "wind_speed": 10.2}, {"hour": 17, "temperature_c": 9.8, "condition": "partly_cloudy", "solar_irradiance": 16.5, "humidity": 92, "wind_speed": 10.5}, {"hour": 18, "temperature_c": 9.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.5}, {"hour": 19, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 9.8}, {"hour": 20, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.1}, {"hour": 21, "temperature_c": 7.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 9.4}, {"hour": 22, "temperature_c": 7.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 9.4}, {"hour": 23, "temperature_c": 7.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.1}]}', name='get_weather_forecast', id='445fc60e-994c-4bc3-bff2-782bd5734054', tool_call_id='call_wNQsfUbvBE7ALECMueqdY8qB'),
#     ToolMessage(content='{"date": "2025-11-29", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='83cc5496-024d-4b2b-b337-6cd04a0fd00c', tool_call_id='call_rAeZ3w74nCZsKcdGZlgC6b0y'),
#     AIMessage(content='To minimize costs and maximize solar power for charging your electric car tomorrow in San Francisco, consider the following:\n\n1. **Solar Power Maximization**: The highest solar irradiance is expected between 11 AM and 2 PM, with a peak at 2 PM (310 W/m²). Charging during this time will maximize the use of solar energy.\n\n2. **Cost Minimization**: Electricity prices are lowest during the Off-Peak period, which is from midnight to 6 AM and again from 11 PM to midnight, at $0.096 per kWh. The Mid-Peak rate is $0.132 per kWh, and the Peak rate is $0.192 per kWh from 2 PM to 7 PM.\n\n**Recommendation**: To balance cost and solar utilization, start charging your car around 11 AM to take advantage of solar power, and continue until 2 PM. If you need additional charging, consider doing so during the Off-Peak hours (midnight to 6 AM) to minimize costs. This strategy will help you leverage solar energy while keeping electricity expenses low.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 229, 'prompt_tokens': 3237, 'total_tokens': 3466, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2816}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3ab8WV0SVzboRlZUgu8KCGaAnoy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--4a8a79d7-b3e4-48fa-a8aa-d80ab5b751a5-0', usage_metadata={'input_tokens': 3237, 'output_tokens': 229, 'total_tokens': 3466, 'input_token_details': {'audio': 0, 'cache_read': 2816}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'The response should contain time recommendation, cost analysis and solar consideration',
#   'timestamp': '2025-11-29T01:59:04.386448'},
#  {'test_id': 'ev_charging_2',
#   'question': 'To minimize cost of charing my vehicle using solar energy, how does the time range differs comparing summer to winter?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='ec764784-7734-4f9f-a556-db0c99fe34ed'),
#     HumanMessage(content='To minimize cost of charing my vehicle using solar energy, how does the time range differs comparing summer to winter?', additional_kwargs={}, response_metadata={}, id='f4a6e962-934c-4442-84f1-b8a77bce19a6'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 1086, 'total_tokens': 1140, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_e819e3438b', 'id': 'chatcmpl-Ch3aiUqFKOzmtB039EkFn7PkXWNpw', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--b54c5b55-4515-47c7-845e-3754455c891c-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_CGe15sCiuM6rr3aSNROLYr3K', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {}, 'id': 'call_tLXZDvqQlo73UY3QmV82G5Lh', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1086, 'output_tokens': 54, 'total_tokens': 1140, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 7, "current": {"temperature_c": 10.3, "condition": "partly_cloudy", "humidity": 92, "wind_speed": 10.6}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.9, "condition": "cloudy", "solar_irradiance": 222.5, "humidity": 84, "wind_speed": 12.5}, {"hour": 14, "temperature_c": 11.2, "condition": "cloudy", "solar_irradiance": 310.0, "humidity": 80, "wind_speed": 13.0}, {"hour": 15, "temperature_c": 10.7, "condition": "cloudy", "solar_irradiance": 161.5, "humidity": 86, "wind_speed": 11.5}, {"hour": 16, "temperature_c": 10.8, "condition": "partly_cloudy", "solar_irradiance": 109.2, "humidity": 93, "wind_speed": 10.2}, {"hour": 17, "temperature_c": 9.8, "condition": "partly_cloudy", "solar_irradiance": 16.5, "humidity": 92, "wind_speed": 10.5}, {"hour": 18, "temperature_c": 9.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.5}, {"hour": 19, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 9.8}, {"hour": 20, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.1}, {"hour": 21, "temperature_c": 7.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 9.4}, {"hour": 22, "temperature_c": 7.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 9.4}, {"hour": 23, "temperature_c": 7.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.1}, {"hour": 0, "temperature_c": 7.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 85, "wind_speed": 9.5}, {"hour": 1, "temperature_c": 7.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.3}, {"hour": 2, "temperature_c": 7.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.8}, {"hour": 3, "temperature_c": 6.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 83, "wind_speed": 8.4}, {"hour": 4, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 10.0}, {"hour": 5, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 10.2}, {"hour": 6, "temperature_c": 6.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, ...
#     ToolMessage(content='{"date": "2025-11-29", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='37f12e9c-20ef-43f6-8187-d903e168c2d5', tool_call_id='call_tLXZDvqQlo73UY3QmV82G5Lh'),
#     AIMessage(content='In San Francisco, the solar irradiance varies significantly between summer and winter, affecting the optimal time for charging your electric vehicle (EV) using solar energy. During summer, solar irradiance peaks between 11 AM and 3 PM, with the highest values around noon. This is when solar panels generate the most electricity, making it the best time to charge your EV.\n\nIn winter, the solar window is shorter, with peak irradiance occurring between 10 AM and 2 PM. The intensity is generally lower compared to summer, so you may need to adjust your charging schedule to maximize solar usage.\n\nConsidering dynamic pricing, electricity rates are highest during peak hours (2 PM to 8 PM). Therefore, aligning your EV charging with solar peak times not only maximizes solar usage but also avoids high electricity costs.\n\nIn summary, aim to charge your EV between 11 AM and 3 PM in summer and 10 AM to 2 PM in winter to optimize solar energy use and minimize costs. Adjusting your schedule to these time frames will help you take advantage of both solar generation and lower electricity rates.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 222, 'prompt_tokens': 10490, 'total_tokens': 10712, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3akdWzT7rLA52chwaRMYAVrEdrA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--8fe6ff83-2e02-4a9f-9bfc-d5737f03842d-0', usage_metadata={'input_tokens': 10490, 'output_tokens': 222, 'total_tokens': 10712, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'query_solar_generation'],
#   'expected_response': 'The response to provide insights about time range difference between summer and winter.',
#   'timestamp': '2025-11-29T01:59:10.319536'},
#  {'test_id': 'thermostat_setting',
#   'question': 'What is the optimal thermostat_setting I should be setting to next week in my living room?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='e8781f66-5944-4df5-95e3-a1af70f380dc'),
#     HumanMessage(content='What is the optimal thermostat_setting I should be setting to next week in my living room?', additional_kwargs={}, response_metadata={}, id='db87f855-e47e-4907-b325-f20cd4a54fd5'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1081, 'total_tokens': 1104, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3aocm8bMKMDnCfFPAEeFDyh57bO', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--3c59d36c-a682-4604-a434-45155c5d7013-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_vG5wlAfTXr3xMiKyZ8dL0N6I', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1081, 'output_tokens': 23, 'total_tokens': 1104, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 7, "current": {"temperature_c": 10.3, "condition": "partly_cloudy", "humidity": 92, "wind_speed": 10.6}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.9, "condition": "cloudy", "solar_irradiance": 222.5, "humidity": 84, "wind_speed": 12.5}, {"hour": 14, "temperature_c": 11.2, "condition": "cloudy", "solar_irradiance": 310.0, "humidity": 80, "wind_speed": 13.0}, {"hour": 15, "temperature_c": 10.7, "condition": "cloudy", "solar_irradiance": 161.5, "humidity": 86, "wind_speed": 11.5}, {"hour": 16, "temperature_c": 10.8, "condition": "partly_cloudy", "solar_irradiance": 109.2, "humidity": 93, "wind_speed": 10.2}, {"hour": 17, "temperature_c": 9.8, "condition": "partly_cloudy", "solar_irradiance": 16.5, "humidity": 92, "wind_speed": 10.5}, {"hour": 18, "temperature_c": 9.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.5}, {"hour": 19, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 9.8}, {"hour": 20, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.1}, {"hour": 21, "temperature_c": 7.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 9.4}, {"hour": 22, "temperature_c": 7.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 9.4}, {"hour": 23, "temperature_c": 7.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.1}, {"hour": 0, "temperature_c": 7.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 85, "wind_speed": 9.5}, {"hour": 1, "temperature_c": 7.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.3}, {"hour": 2, "temperature_c": 7.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.8}, {"hour": 3, "temperature_c": 6.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 83, "wind_speed": 8.4}, {"hour": 4, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 10.0}, {"hour": 5, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 10.2}, {"hour": 6, "temperature_c": 6.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, ...
#     AIMessage(content='Next week in San Francisco, the weather forecast indicates a range of temperatures from around 6.3°C (43.3°F) in the early morning to about 18.2°C (64.8°F) during the day. Given these conditions, an optimal thermostat setting for your living room would be around 20°C (68°F) during the day when temperatures are higher and around 18°C (64°F) at night when it cools down. \n\nThis setting balances comfort and energy efficiency, ensuring your living room remains warm without excessive heating costs. Additionally, consider using a programmable thermostat to automatically adjust the temperature based on your schedule, which can further enhance energy savings. \n\nBy maintaining these settings, you can ensure a comfortable environment while optimizing energy usage, especially during the cooler nights.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 9619, 'total_tokens': 9781, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3aqTZ1Iev4g5HTOOF6ftgTGTVXU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--54b0b837-f4bd-42a0-b9a2-ef9513b4b5ec-0', usage_metadata={'input_tokens': 9619, 'output_tokens': 162, 'total_tokens': 9781, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['query_energy_usage', 'get_weather_forecast'],
#   'expected_response': 'The response should contain time recommendation and thermostat temperature setting.',
#   'timestamp': '2025-11-29T01:59:14.928630'},
#  {'test_id': 'appliance_scheduling',
#   'question': 'When is the best time this week to do my laundry to save money?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='9d98d42a-c1ff-4058-87ce-9eff137bc566'),
#     HumanMessage(content='When is the best time this week to do my laundry to save money?', additional_kwargs={}, response_metadata={}, id='84f00bfd-491c-48bf-a1a0-955e49609e99'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 1078, 'total_tokens': 1132, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3at8wXI0RWIGAKDAsC8GfVqFcNe', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--7455f3cf-9be2-4113-bbfa-cbe58e36c9aa-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_s978E1fz3vQgqC8J3QBm1hfh', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {}, 'id': 'call_mU5AXzHCQYeqTQkTQgai4p2S', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1078, 'output_tokens': 54, 'total_tokens': 1132, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 7, "current": {"temperature_c": 10.3, "condition": "partly_cloudy", "humidity": 92, "wind_speed": 10.6}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.9, "condition": "cloudy", "solar_irradiance": 222.5, "humidity": 84, "wind_speed": 12.5}, {"hour": 14, "temperature_c": 11.2, "condition": "cloudy", "solar_irradiance": 310.0, "humidity": 80, "wind_speed": 13.0}, {"hour": 15, "temperature_c": 10.7, "condition": "cloudy", "solar_irradiance": 161.5, "humidity": 86, "wind_speed": 11.5}, {"hour": 16, "temperature_c": 10.8, "condition": "partly_cloudy", "solar_irradiance": 109.2, "humidity": 93, "wind_speed": 10.2}, {"hour": 17, "temperature_c": 9.8, "condition": "partly_cloudy", "solar_irradiance": 16.5, "humidity": 92, "wind_speed": 10.5}, {"hour": 18, "temperature_c": 9.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.5}, {"hour": 19, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 9.8}, {"hour": 20, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.1}, {"hour": 21, "temperature_c": 7.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 9.4}, {"hour": 22, "temperature_c": 7.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 9.4}, {"hour": 23, "temperature_c": 7.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.1}, {"hour": 0, "temperature_c": 7.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 85, "wind_speed": 9.5}, {"hour": 1, "temperature_c": 7.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.3}, {"hour": 2, "temperature_c": 7.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.8}, {"hour": 3, "temperature_c": 6.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 83, "wind_speed": 8.4}, {"hour": 4, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 10.0}, {"hour": 5, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 10.2}, {"hour": 6, "temperature_c": 6.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, ...
#     ToolMessage(content='{"date": "2025-11-29", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='be2bc9aa-119b-49a4-9952-8ba9d2bab934', tool_call_id='call_mU5AXzHCQYeqTQkTQgai4p2S'),
#     AIMessage(content='To save money on your laundry this week in San Francisco, it\'s best to run your washing machine during the "Off-Peak" hours when electricity rates are lower. According to the current electricity pricing, the "Off-Peak" period is from 12:00 AM to 6:00 AM and again from 11:00 PM to 12:00 AM, with a rate of $0.096 per kWh. \n\nAdditionally, the weather forecast indicates that the solar irradiance is low during these hours, meaning you won\'t miss out on potential solar energy savings by doing laundry at night. \n\nBy scheduling your laundry during these off-peak hours, you can take advantage of the lower electricity rates and reduce your energy costs. This approach not only saves money but also helps in balancing the grid demand, contributing to a more sustainable energy system.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 174, 'prompt_tokens': 10482, 'total_tokens': 10656, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3avx68QFhsqYamRQwIVJFkODp92', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--9d4e76cb-2396-4564-bc08-80b74abd090d-0', usage_metadata={'input_tokens': 10482, 'output_tokens': 174, 'total_tokens': 10656, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices',
#    'query_energy_usage',
#    'get_recent_energy_summary'],
#   'expected_response': 'The response should include a date and time for doing laundry.',
#   'timestamp': '2025-11-29T01:59:20.349353'},
#  {'test_id': 'energy_price_estimation',
#   'question': 'By not turning on my appliance, I save 100kwh a day, how much money do I save for a year?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='e7d03320-e0fb-4de4-894e-a908f15f528c'),
#     HumanMessage(content='By not turning on my appliance, I save 100kwh a day, how much money do I save for a year?', additional_kwargs={}, response_metadata={}, id='5088a5f1-b6b8-403a-9306-d7258a617870'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 1089, 'total_tokens': 1102, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3ayxtBGtNfWPIAaWeGRiENE01Pc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--5bdce41e-e13b-445c-90e0-c4e9ee049f40-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_p84TZCjo7GTfNTZivdgwVydQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1089, 'output_tokens': 13, 'total_tokens': 1102, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2025-11-29", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='1acbc700-3c65-44b4-88ba-72e3212f95c4', tool_call_id='call_p84TZCjo7GTfNTZivdgwVydQ'),
#     AIMessage(content='To calculate your annual savings from not using your appliance, we need to consider the electricity rate. Based on the current time-of-use pricing for your area, the average rate is approximately $0.132 per kWh during mid-peak hours, which is a reasonable estimate for this calculation.\n\nIf you save 100 kWh per day, your daily savings would be:\n\n\\[ 100 \\, \\text{kWh} \\times 0.132 \\, \\text{USD/kWh} = 13.2 \\, \\text{USD/day} \\]\n\nFor a year, assuming you save this amount every day:\n\n\\[ 13.2 \\, \\text{USD/day} \\times 365 \\, \\text{days/year} = 4,818 \\, \\text{USD/year} \\]\n\nTherefore, by not turning on your appliance, you could save approximately $4,818 annually. This calculation assumes a consistent rate and usage pattern throughout the year. Adjustments may be needed if your usage or rates vary significantly.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 212, 'prompt_tokens': 1950, 'total_tokens': 2162, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3azMy8o6EzhrVcNC6wgnatObstc', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--e3ff3055-96d8-4d83-8167-40341c1c814d-0', usage_metadata={'input_tokens': 1950, 'output_tokens': 212, 'total_tokens': 2162, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['calculate_energy_savings'],
#   'expected_response': 'The response should include the number of hours, the energy consumed, and the price.',
#   'timestamp': '2025-11-29T01:59:24.554118'},
#  {'test_id': 'costs_savings_calculation',
#   'question': 'How do I optimize my electric bill with my appliances using my usage data from the last 2 weeks?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='66aba59b-af29-4ce5-9ccd-6e02bd196f05'),
#     HumanMessage(content='How do I optimize my electric bill with my appliances using my usage data from the last 2 weeks?', additional_kwargs={}, response_metadata={}, id='1944eeb8-03ea-4f34-bb91-e38d2e7aaba3'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 68, 'prompt_tokens': 1084, 'total_tokens': 1152, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3b30dpEUp0mfuL1D8EASvAwvb5C', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--a844b409-4f8f-4f2b-abfd-18b50e4c4a79-0', tool_calls=[{'name': 'query_energy_usage', 'args': {'start_date': '2023-10-01', 'end_date': '2023-10-14', 'device_type': 'appliance'}, 'id': 'call_dksHnAY8Ma4wPAK2mFCfasoi', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {}, 'id': 'call_TjW5jBLIO1U918JmssiPtria', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1084, 'output_tokens': 68, 'total_tokens': 1152, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"start_date": "2023-10-01", "end_date": "2023-10-14", "device_type": "appliance", "total_records": 0, "total_consumption_kwh": 0, "total_cost_usd": 0, "records": []}', name='query_energy_usage', id='ca6eb3a6-c71f-4ff4-aaa6-4870e5bdebb6', tool_call_id='call_dksHnAY8Ma4wPAK2mFCfasoi'),
#     ToolMessage(content='{"date": "2025-11-29", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='bacaa48f-b671-46da-9d65-2f83d5001e2f', tool_call_id='call_TjW5jBLIO1U918JmssiPtria'),
#     AIMessage(content='To optimize your electric bill using your appliances, consider the following strategies based on the electricity pricing and your usage data:\n\n1. **Time-of-Use Pricing**: The electricity rates vary throughout the day. Off-Peak hours (12 AM - 6 AM and 11 PM - 12 AM) have the lowest rates at $0.096 per kWh. Mid-Peak hours (6 AM - 2 PM and 8 PM - 11 PM) are slightly higher at $0.132 per kWh. Peak hours (2 PM - 8 PM) are the most expensive at $0.192 per kWh with an additional demand charge of $8.00.\n\n2. **Shift Usage to Off-Peak Hours**: Since your appliance usage data from the last two weeks shows no specific consumption records, a general recommendation is to run energy-intensive appliances like dishwashers, washing machines, and dryers during Off-Peak hours to take advantage of the lower rates.\n\n3. **Avoid Peak Hours**: Try to minimize the use of high-energy appliances during Peak hours to avoid the higher rates and demand charges.\n\nBy strategically scheduling your appliance usage, you can significantly reduce your electric bill. If you have specific appliances in mind, consider their energy consumption and adjust their operation times accordingly.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 267, 'prompt_tokens': 2064, 'total_tokens': 2331, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3b4hCaNIXz1Yn12ZZzSMKXgGz3G', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--265706a1-78ea-45b3-b659-bb531ea8f9f3-0', usage_metadata={'input_tokens': 2064, 'output_tokens': 267, 'total_tokens': 2331, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['query_energy_usage', 'get_electricity_prices'],
#   'expected_response': 'The result should provide suggestions on suggestions on how to arrange the appliances usage.',
#   'timestamp': '2025-11-29T01:59:29.386687'},
#  {'test_id': 'general_tips',
#   'question': 'Can you give me 5 general ways to save energy for my home?',
# ...
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 7, "current": {"temperature_c": 10.3, "condition": "partly_cloudy", "humidity": 92, "wind_speed": 10.6}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.9, "condition": "cloudy", "solar_irradiance": 222.5, "humidity": 84, "wind_speed": 12.5}, {"hour": 14, "temperature_c": 11.2, "condition": "cloudy", "solar_irradiance": 310.0, "humidity": 80, "wind_speed": 13.0}, {"hour": 15, "temperature_c": 10.7, "condition": "cloudy", "solar_irradiance": 161.5, "humidity": 86, "wind_speed": 11.5}, {"hour": 16, "temperature_c": 10.8, "condition": "partly_cloudy", "solar_irradiance": 109.2, "humidity": 93, "wind_speed": 10.2}, {"hour": 17, "temperature_c": 9.8, "condition": "partly_cloudy", "solar_irradiance": 16.5, "humidity": 92, "wind_speed": 10.5}, {"hour": 18, "temperature_c": 9.0, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.5}, {"hour": 19, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 9.8}, {"hour": 20, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 10.1}, {"hour": 21, "temperature_c": 7.6, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 9.4}, {"hour": 22, "temperature_c": 7.3, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 9.4}, {"hour": 23, "temperature_c": 7.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.1}, {"hour": 0, "temperature_c": 7.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 85, "wind_speed": 9.5}, {"hour": 1, "temperature_c": 7.0, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.3}, {"hour": 2, "temperature_c": 7.1, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.8}, {"hour": 3, "temperature_c": 6.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 83, "wind_speed": 8.4}, {"hour": 4, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 10.0}, {"hour": 5, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 10.2}, {"hour": 6, "temperature_c": 6.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, ...
#     AIMessage(content="To estimate the total solar savings for the upcoming week in San Francisco, I analyzed the solar irradiance data from the weather forecast. Solar irradiance is a measure of how much solar power is available at a given time, and it directly impacts the potential solar energy generation.\n\nHere's a summary of the solar irradiance forecast for the week:\n\n- The forecast shows varying levels of solar irradiance throughout the week, with peak values reaching up to 514 W/m² during midday hours.\n- The solar irradiance is generally higher during the middle of the day (10 AM to 3 PM), which is typical for solar energy generation.\n\nTo calculate the total solar savings, you would need to know the efficiency and capacity of your solar panels. Assuming an average solar panel efficiency of 15-20% and a typical system size, you can estimate the energy generated by multiplying the solar irradiance by the panel area and efficiency.\n\nFor a more precise calculation, you can use the hourly solar irradiance data to compute the total energy generated each day and sum it up for the week. This will give you an estimate of the total solar energy savings for the week. If you provide your solar panel specifications, I can help with a more detailed calculation.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 249, 'prompt_tokens': 9615, 'total_tokens': 9864, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3bEblkONQ9KzA7A2PEocjaZxpwG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--2619c9f3-50ff-4e2d-8315-ad2724584d9c-0', usage_metadata={'input_tokens': 9615, 'output_tokens': 249, 'total_tokens': 9864, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'query_solar_generation'],
#   'expected_response': 'The response should be a total saving amount.',
#   'timestamp': '2025-11-29T01:59:40.251473'},
#  {'test_id': 'general_consumption',
#   'question': 'How much does it cost for my energy consumption in the last 2 weeks?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='3195f2e4-a700-4fc1-9339-0625558f9f46'),
#     HumanMessage(content='How much does it cost for my energy consumption in the last 2 weeks?', additional_kwargs={}, response_metadata={}, id='8abf274a-86d4-4fdc-bdfc-d599021fcd21'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 69, 'prompt_tokens': 1079, 'total_tokens': 1148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3bI1iFvErFGY5hR2nZZ9XfiXgQb', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--754b898a-26bf-47ea-9a73-98c7bc1b3f2f-0', tool_calls=[{'name': 'query_energy_usage', 'args': {'start_date': '2023-10-01', 'end_date': '2023-10-14'}, 'id': 'call_nFhEOvXJ78ndRG6yr9vOQ3A9', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {'date': '2023-10-14'}, 'id': 'call_xN32l5JQhMjYZIZbUmmt2DfF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1079, 'output_tokens': 69, 'total_tokens': 1148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"start_date": "2023-10-01", "end_date": "2023-10-14", "device_type": null, "total_records": 0, "total_consumption_kwh": 0, "total_cost_usd": 0, "records": []}', name='query_energy_usage', id='a0299975-4ac4-47c7-be8d-57d41fd55097', tool_call_id='call_nFhEOvXJ78ndRG6yr9vOQ3A9'),
#     ToolMessage(content='{"date": "2023-10-14", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='939dca1d-9ef6-4405-9a3e-4c935c0c7e55', tool_call_id='call_xN32l5JQhMjYZIZbUmmt2DfF'),
#     AIMessage(content='It seems that there is no recorded energy consumption data for your household from October 1 to October 14, 2023. This could be due to a lack of data entry or a technical issue with the data retrieval system. \n\nHowever, I can provide you with the current electricity pricing structure for your area, which follows a time-of-use model. The rates are as follows:\n\n- Off-Peak (12 AM - 6 AM, 11 PM - 12 AM): $0.096 per kWh\n- Mid-Peak (6 AM - 2 PM, 8 PM - 11 PM): $0.132 per kWh\n- Peak (2 PM - 8 PM): $0.192 per kWh with a demand charge of $8.00 per kW\n\nTo estimate your costs, you would need to multiply your energy consumption during each period by the respective rates. If you have any specific data or need further assistance, please let me know!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 203, 'prompt_tokens': 2058, 'total_tokens': 2261, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3bK3PrstSmPttRunQtjnUOBMdQv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--96ace1cd-3191-4cc6-8bbc-c1a5c0781f8d-0', usage_metadata={'input_tokens': 2058, 'output_tokens': 203, 'total_tokens': 2261, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['query_energy_usage', 'get_electricity_prices'],
#   'expected_response': 'The response should e a total cost amount.',
#   'timestamp': '2025-11-29T01:59:45.033540'},
#  {'test_id': 'energy_consumption',
#   'question': 'What is my energy consumption for the last 2 hours?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='2ef0b266-d8a9-4b8a-9abd-557061912985'),
#     HumanMessage(content='What is my energy consumption for the last 2 hours?', additional_kwargs={}, response_metadata={}, id='9d282282-a38d-4cb4-95b3-7810b2852e91'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 1075, 'total_tokens': 1091, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3bNV0yIfxQFjzPHKguHm9JluaIG', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--4760fa5f-398d-4346-bfd1-2db01be7e519-0', tool_calls=[{'name': 'get_recent_energy_summary', 'args': {'hours': 2}, 'id': 'call_Mt6oelvg5IWBevK8H4aMy6Fw', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1075, 'output_tokens': 16, 'total_tokens': 1091, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"time_period_hours": 2, "usage": {"total_consumption_kwh": 0, "total_cost_usd": 0, "device_breakdown": {}}, "generation": {"total_generation_kwh": 0, "average_weather": "unknown"}}', name='get_recent_energy_summary', id='35a18a9a-e223-480f-bbd1-5adf4f3efdd9', tool_call_id='call_Mt6oelvg5IWBevK8H4aMy6Fw'),
#     AIMessage(content='In the last 2 hours, your energy consumption was 0 kWh, with a total cost of $0. It seems there was no energy usage recorded during this period, and there was also no solar generation. This could be due to a lack of data or minimal activity in your home during these hours. If you have any specific devices or activities that you suspect might have been consuming energy, it might be worth checking their settings or usage patterns. If you need further assistance or a more detailed analysis, feel free to ask!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 108, 'prompt_tokens': 1161, 'total_tokens': 1269, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_689bad8e9a', 'id': 'chatcmpl-Ch3bO9dFdfeXQbFQ0zsUyZvngW5JW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--539a48de-0b80-4cb8-b06d-4ada8e691bd9-0', usage_metadata={'input_tokens': 1161, 'output_tokens': 108, 'total_tokens': 1269, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_recent_energy_summary'],
#   'expected_response': 'The response should contain the energy consumption of last 2 hours.',
#   'timestamp': '2025-11-29T01:59:48.619004'}]

# %%
from langchain_core.messages import BaseMessage, HumanMessage, AIMessage, SystemMessage, ToolMessage

tool_calls = []
for result in test_results:
    msg_list = result["response"]["messages"]
    tool_call = [msg.name for msg in msg_list if isinstance(msg, ToolMessage)]
    tool_calls.append(tool_call)

tool_calls_all = set([item for sublist in tool_calls for item in sublist])

# %%
tool_calls
# Out:
# [['get_weather_forecast', 'get_electricity_prices'],
#  ['get_weather_forecast', 'get_electricity_prices'],
#  ['get_weather_forecast'],
#  ['get_weather_forecast', 'get_electricity_prices'],
#  ['get_electricity_prices'],
#  ['query_energy_usage', 'get_electricity_prices'],
#  ['search_energy_tips'],
#  ['get_weather_forecast'],
#  ['query_energy_usage', 'get_electricity_prices'],
#  ['get_recent_energy_summary']]

# %%
tool_calls_all
# Out:
# {'get_electricity_prices',
#  'get_recent_energy_summary',
#  'get_weather_forecast',
#  'query_energy_usage',
#  'search_energy_tips'}

# %%
from langchain_core.messages import BaseMessage, HumanMessage, AIMessage, SystemMessage, ToolMessage

tool_calls = []
for result in test_results:
    msg_list = result["response"]["messages"]
    tool_call = [msg.name for msg in msg_list if isinstance(msg, ToolMessage)]
    tool_calls.append(tool_call)

tool_calls
# Out:
# [['get_weather_forecast', 'get_electricity_prices'],
#  ['get_weather_forecast', 'get_electricity_prices'],
#  ['get_weather_forecast'],
#  ['get_weather_forecast', 'get_electricity_prices'],
#  ['get_electricity_prices'],
#  ['query_energy_usage', 'get_electricity_prices'],
#  ['search_energy_tips'],
#  ['get_weather_forecast'],
#  ['query_energy_usage', 'get_electricity_prices'],
#  ['get_recent_energy_summary']]

# %% [markdown]
# ## 4. Evaluate Responses

# %%
# Set up all required libraries
from langchain_openai import ChatOpenAI
from langchain_core.messages import BaseMessage, HumanMessage, AIMessage, SystemMessage, ToolMessage
# from langgraph.graph.message import MessagesState
from langchain_core.prompts import PromptTemplate
from typing import List, Dict
from tools import TOOL_KIT
from pydantic import BaseModel, Field

# %%
class QualityEvalSchema(BaseModel):
    accuracy: float = Field(description="Accuracy of final_response with respect to the customer's question and espected response description.")
    relevance: float = Field(description="Relevancy of final_response with respect to the customer's question and espected response description.")
    completeness: float = Field(description="Completeness of final_response with respect to the customer's question and espected response description.")
    usefulness: float = Field(description="Usefulness of final_response with respect to the customer's question.")
    quality_evaluation_description: str = Field(description="Description of the analysis logic of other metrics")

class ToolEvalSchema(BaseModel):
    tool_appropriateness: float = Field(description="Appropriateness of the tools selected based on the given tools.")
    tool_completness: float = Field(description="Metric measuring whether all the necessary tools were used.")
    tool_evaluation_description: str = Field(description="The reasoning and description of the analysis of coming up with the metrics.")

# %%
# Set up LLM Judge for Evaluation
# (LangChain is used instead of LangGraph, because analysis are independant and only simple single step LLM evaluation is required)
from dotenv import load_dotenv
import os

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
llm_base_url = "https://openai.vocareum.com/v1"

# Create LLM Evaluation Agent
llm = ChatOpenAI(
    model="gpt-4o",             # using a more sophisticated model for evaluation purpose
    temperature=0.0,
    api_key = OPENAI_API_KEY,
    base_url = llm_base_url,
)

qual_structured_llm = llm.with_structured_output(QualityEvalSchema)
tool_structured_llm = llm.with_structured_output(ToolEvalSchema)

# %%
# TODO: Implement evaluation functions
# Create functions to evaluate:
# - Final Response
# - Tool usage

# %%
# TODO: Create a response evaluator
def evaluate_response(question, final_response, expected_response):
    """Evaluate a single response against expected response"""

    template = PromptTemplate(
        input_variables=["question", "final_response", "expected_response"],
        template="""You're a judging evaluator for the response given by an energy advisor.

        Given the response from the energy advisor with the expected response description provide the following:
        - accuracy: Out of a score of 100, how accurate is the advisor response provided with respect to the customer's question and the espected response description? 
        - relevance: Out of a score of 100, how relevant the advisor response provided with respect to the customer's question and the espected response description?
        - completeness: Out of a score of 100, how complete the advisor response provided with respect to the customer's question and the espected response description?
        - usefulness: Out of a score of 100, how useful the advisor response provided with respect to the customer's question?  (Consider whether customer can take any action based on this anwser)
        - quality_evaluation_description: Provide a detail description to justify your metrics provided above within 200 to 500 words.

        Customer's question: 
        {question}
        
        Energy advisor response: 
        {final_response}

        Expected response description: 
        {expected_response}
        """
    )

    messages = template.invoke(
            {
                "question": question, 
                "final_response": final_response, 
                "expected_response": expected_response
            }
        ).to_messages()

    ai_message = qual_structured_llm.invoke(messages)
    return ai_message

# %%
# TODO: Create a tool udage evaluator
def evaluate_tool_usage(messages: list, expected_tools: str):
    """Evaluate if the right tools were used"""
    
    template = PromptTemplate(
        input_variables=["messages", "expected_tools"],
        template="""You're a judging evaluator for the tools used by an energy advisor AI agent to answer the user's question.

        Given the message history from the energy advisor AI agent please evaluat the selection of tool(s) used by the following:
        - tool_appropriateness: Out of a score of 100, how appropriate the tool selected to answer the customer's question?
        - tool_completeness: Out of a score of 100, evaluate whether all necessary tools were used?
        - tool_evaluation_description: Provide a detail description to justify your metrics provided above within 200 to 500 words.

        Available toolset for the energy advisor AI agent: 
        {TOOL_KIT}
        
        Expected tools to use: 
        {expected_tools}
        """
    ) 


    tool_info: List[Dict[str, str]] = [
        {"name": tool.name, "description": tool.description}
        for tool in TOOL_KIT
    ]

    prompt_message = template.invoke(
            {"TOOL_KIT": str(tool_info), "expected_tools": expected_tools}
        ).to_messages()

    ai_message = tool_structured_llm.invoke(messages + prompt_message)
    return ai_message

# %%
def results_reporting(metrics: List[List[tuple]]):
    """Produce a report for the evaluation"""

    template = PromptTemplate(
        input_variables=["metrics"],
        template="""You are an expert report writer by looking at the provided metrics for the AI energy advisor you need to write a report from a list of test samples.
        Your task is listed as follow:
            - Calculate overall scores and metrics across all samples
            - Identify strengths and weaknesses
            - Provide recommendations for improvement
        
        Metrics:
        {metrics}

        The report must have a proper structure with the following sections names with a total of less than 300 words:
            - Overall Score
            - Strength and Weaknesses
            - Recommendations
        """
        )
    
    prompt_message = template.invoke({"metrics": metrics})
    report = llm.invoke(prompt_message)
    return report

# %%
# TODO: Generate a comprehensive evaluation report
# Calculate overall scores and metrics
# Identify strengths and weaknesses
# Provide recommendations for improvement

def generate_evaluation_report(test_results: List[Dict]):

    metrics = []

    for result in test_results:
        # Qualitative Evaluation using LLM
        quality_metric = evaluate_response(
            question = result.get('question',''),
            final_response = result.get('response', None).get('messages', None)[-1].content,
            expected_response = result.get('expected_response', None),
            )
        
        # Tool Evaluation using LLM
        tool_metric = evaluate_tool_usage(
            messages = result.get('response', None).get('messages', None),
            expected_tools = result.get('expected_tools', None),
            )

        # Join Metrics
        metrics.append( list(quality_metric) + list(tool_metric) )
        
    report = results_reporting(metrics)
    print(report.content)

    return metrics, report

# %%
metrics, report = generate_evaluation_report(test_results)
# Out:
# ### Overall Score
#
# The AI energy advisor demonstrates strong performance across various metrics, with an average accuracy of 85.5%, relevance of 89.0%, completeness of 81.5%, and usefulness of 86.0%. Tool appropriateness and completeness are rated at 88.0% and 82.5%, respectively. These scores indicate a generally effective system, though there is room for improvement in certain areas.
#
# ### Strengths and Weaknesses
#
# **Strengths:**
# - **Accuracy and Relevance:** The advisor consistently provides accurate and relevant responses, particularly in scenarios involving specific queries about energy usage and savings.
# - **Tool Appropriateness:** The selection of tools is generally well-suited to the tasks, ensuring that the responses are based on relevant data.
# - **Usefulness:** The advice given is often actionable, allowing users to make informed decisions about energy consumption and savings.
#
# **Weaknesses:**
# - **Completeness:** Some responses lack full completeness, often missing specific details or additional insights that could enhance the user's understanding.
# - **Tool Completeness:** In several instances, the advisor did not utilize all available tools, which could have provided a more comprehensive analysis.
# - **Specificity:** Certain responses could benefit from more detailed information, such as specific time frames or personalized advice based on user data.
#
# ### Recommendations
#
# To enhance the AI energy advisor's performance, the following recommendations are proposed:
# 1. **Enhance Completeness:** Ensure that responses are comprehensive by including all relevant details and insights. This could involve using additional tools to provide a more thorough analysis.
# 2. **Improve Tool Utilization:** Encourage the use of all relevant tools, especially those that can provide historical data or personalized insights, to enhance the depth and accuracy of responses.
# 3. **Increase Specificity:** Provide more detailed and personalized advice by incorporating user-specific data and scenarios. This will improve the relevance and usefulness of the responses, making them more actionable for users.

# %% [markdown]
# ---
