# %% [markdown]
# # EcoHome Energy Advisor - Agent Run & Evaluation
#
# In this notebook, you'll run the Energy Advisor agent with various real-world scenarios and see how it helps customers optimize their energy usage.
#
# ## Learning Objectives
# - Create the agent's instructions
# - Run the Energy Advisor with different types of questions
# - Evaluate response quality and accuracy
# - Measure tool usage effectiveness
# - Identify areas for improvement
# - Implement evaluation metrics
#
# ## Evaluation Criteria
# - **Accuracy**: Correct information and calculations
# - **Relevance**: Responses address the user's question
# - **Completeness**: Comprehensive answers with actionable advice
# - **Tool Usage**: Appropriate use of available tools
# - **Reasoning**: Clear explanation of recommendations

# %% [markdown]
# ## 1. Import and Initialize

# %%
from datetime import datetime
from agent import Agent

# %%
## TODO: Create the agent's instructions

ECOHOME_SYSTEM_PROMPT = f"""
    You are an home energy expert, you are given a set of tools to assess the energy situation of our customer.
    You will be supporting the customer and providing advises on the following topics [with the corresponding tools]:

        (1) Weather Integration: Use weather forecasts to predict solar generation and optimize device scheduling
        (2) Dynamic Pricing: Consider time-of-day electricity prices for cost optimization
        (3) Historical Analysis: Query past energy usage patterns for personalized advice
        (4) RAG Pipeline: Retrieve relevant energy-saving tips and best practices
        (5) Multi-device Optimization: Handle EVs, HVAC, appliances, and solar systems
        (6) Cost Calculations: Provide specific savings estimates and ROI analysis
        (7) Other Energy Advices or Questions of Multiple Categories: Perform an analysis of the question and use any combination of the tools to try and figure out the answer
    
    After obtaining all required data from the tools, try to answer the question in a polite and helpful manner within 200 words.  Explain your logic.
    """

# %%
ecohome_agent = Agent(
    instructions=ECOHOME_SYSTEM_PROMPT,
)

# %%
response = ecohome_agent.invoke(
    question="When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
    context="Location: San Francisco, CA"
)

# %%
print(response["messages"][-1].content)
# Out:
# To minimize costs and maximize solar power for charging your electric vehicle (EV) tomorrow in San Francisco, consider the following:
#
# 1. **Solar Generation**: Solar power generation is expected to peak between 11 AM and 3 PM, with the highest solar irradiance at 2 PM (377.8 W/m²). This is when your solar panels will produce the most energy.
#
# 2. **Electricity Pricing**: The electricity rates are lowest during the off-peak hours (midnight to 6 AM) at $0.096 per kWh. The rates increase to $0.132 during mid-peak hours (6 AM to 8 AM) and peak at $0.192 from 2 PM to 7 PM.
#
# ### Recommendation:
# - **Charge your EV between 11 AM and 3 PM** when solar generation is at its peak. This will allow you to utilize the solar energy produced, reducing your reliance on grid electricity and minimizing costs.
# - If you need to charge overnight, consider starting your charge after midnight to take advantage of the lower off-peak rates.
#
# By following this strategy, you can effectively reduce your energy costs while maximizing the use of renewable solar energy.

# %%
print("TOOLS:")
for msg in response["messages"]:
    obj = msg.model_dump()
    if obj.get("tool_call_id"):
        print("-", msg.name)
# Out:
# TOOLS:
# - get_weather_forecast
# - get_electricity_prices

# %%
response['messages']
# Out:
# [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='7db969f2-8196-4fb3-8306-d05b7bf69870'),
#  HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', additional_kwargs={}, response_metadata={}, id='5eb8b975-98d8-463a-b9ad-915bff1eb7b4'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 1079, 'total_tokens': 1140, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0vQboXJSXCiUh0OrVLr26BJ9bwK', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--a6654b5a-68ca-4684-8903-cb441884ea8c-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_efBrozfaFeOzzAVRJoEjOexd', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_WxOVdtkyRWwoDWDncrr8YMHZ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1079, 'output_tokens': 61, 'total_tokens': 1140, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='{"location": "San Francisco", "forecast_days": 1, "current": {"temperature_c": 11.6, "condition": "partly_cloudy", "humidity": 87, "wind_speed": 11.7}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.5, "condition": "partly_cloudy", "solar_irradiance": 216.2, "humidity": 96, "wind_speed": 12.8}, {"hour": 14, "temperature_c": 11.6, "condition": "partly_cloudy", "solar_irradiance": 377.8, "humidity": 87, "wind_speed": 11.7}, {"hour": 15, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 323.5, "humidity": 87, "wind_speed": 12.0}, {"hour": 16, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 185.0, "humidity": 84, "wind_speed": 11.4}, {"hour": 17, "temperature_c": 9.9, "condition": "sunny", "solar_irradiance": 34.2, "humidity": 85, "wind_speed": 9.6}, {"hour": 18, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.4}, {"hour": 19, "temperature_c": 8.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 20, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.4}, {"hour": 21, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.0}, {"hour": 22, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.1}, {"hour": 23, "temperature_c": 8.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 8.3}]}', name='get_weather_forecast', id='43e5806f-c216-4fbd-beec-503aee663b9e', tool_call_id='call_efBrozfaFeOzzAVRJoEjOexd'),
#  ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='2beb2324-4733-4d70-ba74-284fe106d1fa', tool_call_id='call_WxOVdtkyRWwoDWDncrr8YMHZ'),
#  AIMessage(content='To minimize costs and maximize solar power for charging your electric vehicle (EV) tomorrow in San Francisco, consider the following:\n\n1. **Solar Generation**: Solar power generation is expected to peak between 11 AM and 3 PM, with the highest solar irradiance at 2 PM (377.8 W/m²). This is when your solar panels will produce the most energy.\n\n2. **Electricity Pricing**: The electricity rates are lowest during the off-peak hours (midnight to 6 AM) at $0.096 per kWh. The rates increase to $0.132 during mid-peak hours (6 AM to 8 AM) and peak at $0.192 from 2 PM to 7 PM.\n\n### Recommendation:\n- **Charge your EV between 11 AM and 3 PM** when solar generation is at its peak. This will allow you to utilize the solar energy produced, reducing your reliance on grid electricity and minimizing costs.\n- If you need to charge overnight, consider starting your charge after midnight to take advantage of the lower off-peak rates.\n\nBy following this strategy, you can effectively reduce your energy costs while maximizing the use of renewable solar energy.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 243, 'prompt_tokens': 3250, 'total_tokens': 3493, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0vT5BNGflbuNRjtkk2uT70AIeG4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--e0648ce3-eb4e-4e50-96ce-768139f28a1f-0', usage_metadata={'input_tokens': 3250, 'output_tokens': 243, 'total_tokens': 3493, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %% [markdown]
# ## 2. Define Test Cases

# %%
# TODO: Define comprehensive test cases for the Energy Advisor
# Create 10 test cases covering different scenarios:
# - EV charging optimization
# - Thermostat settings
# - Appliance scheduling
# - Solar power maximization
# - Cost savings calculations

# %%
test_cases = [
    {
        "id": "ev_charging_1",
        "question": "When should I charge my electric car tomorrow to minimize cost and maximize solar power?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "The response should contain time recommendation, cost analysis and solar consideration",
    },
    {
        "id": "ev_charging_2",
        "question": "To minimize cost of charing my vehicle using solar energy, how does the time range differs comparing summer to winter?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "The response to provide insights about time range difference between summer and winter.",
    },
    {
        "id": "thermostat_setting",
        "question": "What is the optimal thermostat_setting I should be setting to next week in my living room?",
        "expected_tools": ["query_energy_usage", "get_weather_forecast"],
        "expected_response": "The response should contain time recommendation and thermostat temperature setting.",
    },
    {
        "id": "appliance_scheduling",
        "question": "When is the best time this week to do my laundry to save money?",
        "expected_tools": ["get_electricity_prices","query_energy_usage","get_recent_energy_summary"],
        "expected_response": "The response should include a date and time for doing laundry.",
    },
    {
        "id": "solar_power_maximization",
        "question": "While having my solar panel, when is the best time to do my laundry this week?",
        "expected_tools": ["get_weather_forecast","calculate_energy_savings","get_electricity_prices","query_solar_generation"],
        "expected_response": "The response should include a time and a day..",
    },
    {
        "id": "costs_savings_calculation",
        "question": "How do I optimize my electric bill with my appliances using my usage data from the last 2 weeks?",
        "expected_tools": ["query_energy_usage","get_electricity_prices"],
        "expected_response": "The result should provide suggestions on suggestions on how to arrange the appliances usage.",
    },
    {
        "id": "general_tips",
        "question": "Can you give me 5 general ways to save energy for my home?",
        "expected_tools": ["search_energy_tips"],
        "expected_response": "There should be 5 points related to energy saving given.",
    },
    {
        "id": "solar_saving",
        "question": "Can you estimate the total solar saving for the whole week next week?",
        "expected_tools": ["get_weather_forecast", "get_electricity_prices"],
        "expected_response": "The response should be a total saving amount.",
    },
    {
        "id": "general_consumption",
        "question": "How much does it cost for my energy consumption in the last 2 weeks?",
        "expected_tools": ["query_energy_usage", "get_electricity_prices"],
        "expected_response": "The response should e a total cost amount.",
    },
    {
        "id": "energy_consumption",
        "question": "What is my energy consumption for the last 2 hours?",
        "expected_tools": ["query_energy_usage"],
        "expected_response": "The response should contain the energy consumption of last 2 hours.",
    },
    

]

if len(test_cases) < 10:
    raise ValueError("You MUST have at least 10 test cases")

# %% [markdown]
# ## 3. Run Agent Tests

# %%
CONTEXT = "Location: San Francisco, CA"

# %%
# Run the agent tests
# For each test case, call the agent and collect the response
# Store results for evaluation

print("=== Running Agent Tests ===")
test_results = []

for i, test_case in enumerate(test_cases):
    print(f"\nTest {i+1}: {test_case['id']}")
    print(f"Question: {test_case['question']}")
    print("-" * 50)
    
    try:
        # Call the agent
        response = ecohome_agent.invoke(
            question=test_case['question'],
            context=CONTEXT
        )
        
        # Store the result
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': response,
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat()
        }
        test_results.append(result)
                
    except Exception as e:
        print(f"Error: {e}")
        result = {
            'test_id': test_case['id'],
            'question': test_case['question'],
            'response': f"Error: {str(e)}",
            'expected_tools': test_case['expected_tools'],
            'expected_response': test_case['expected_response'],
            'timestamp': datetime.now().isoformat(),
            'error': str(e)
        }
        test_results.append(result)

print(f"\nCompleted {len(test_results)} tests")
# Out:
# === Running Agent Tests ===
#
# Test 1: ev_charging_1
# Question: When should I charge my electric car tomorrow to minimize cost and maximize solar power?
# --------------------------------------------------
#
# Test 2: ev_charging_2
# Question: To minimize cost of charing my vehicle using solar energy, how does the time range differs comparing summer to winter?
# --------------------------------------------------
#
# Test 3: thermostat_setting
# Question: What is the optimal thermostat_setting I should be setting to next week in my living room?
# --------------------------------------------------
#
# Test 4: appliance_scheduling
# Question: When is the best time this week to do my laundry to save money?
# --------------------------------------------------
#
# Test 5: solar_power_maximization
# Question: While having my solar panel, when is the best time to do my laundry this week?
# --------------------------------------------------
#
# Test 6: costs_savings_calculation
# Question: How do I optimize my electric bill with my appliances using my usage data from the last 2 weeks?
# --------------------------------------------------
#
# Test 7: general_tips
# Question: Can you give me 5 general ways to save energy for my home?
# --------------------------------------------------
#
# Test 8: solar_saving
# Question: Can you estimate the total solar saving for the whole week next week?
# --------------------------------------------------
#
# Test 9: general_consumption
# Question: How much does it cost for my energy consumption in the last 2 weeks?
# --------------------------------------------------
#
# Test 10: energy_consumption
# Question: What is my energy consumption for the last 2 hours?
# --------------------------------------------------
#
# Completed 10 tests

# %%
test_results
# Out:
# [{'test_id': 'ev_charging_1',
#   'question': 'When should I charge my electric car tomorrow to minimize cost and maximize solar power?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='339d3faf-cb67-4206-847d-1612ad88bbfd'),
#     HumanMessage(content='When should I charge my electric car tomorrow to minimize cost and maximize solar power?', additional_kwargs={}, response_metadata={}, id='b1776947-5f43-4629-a2a3-0a6edb06e59c'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 1079, 'total_tokens': 1140, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0vZW2jKI2HUcFxzW9tWEeOCgSTG', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--56370820-344b-4504-adbb-0420be05bbf0-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 1}, 'id': 'call_uZIrggJW0BMh0XaasGcXXrQ5', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {'date': '2023-10-07'}, 'id': 'call_S7bZPLR488cmtWt1Ma6ZJdOs', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1079, 'output_tokens': 61, 'total_tokens': 1140, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 1, "current": {"temperature_c": 11.6, "condition": "partly_cloudy", "humidity": 87, "wind_speed": 11.7}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.5, "condition": "partly_cloudy", "solar_irradiance": 216.2, "humidity": 96, "wind_speed": 12.8}, {"hour": 14, "temperature_c": 11.6, "condition": "partly_cloudy", "solar_irradiance": 377.8, "humidity": 87, "wind_speed": 11.7}, {"hour": 15, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 323.5, "humidity": 87, "wind_speed": 12.0}, {"hour": 16, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 185.0, "humidity": 84, "wind_speed": 11.4}, {"hour": 17, "temperature_c": 9.9, "condition": "sunny", "solar_irradiance": 34.2, "humidity": 85, "wind_speed": 9.6}, {"hour": 18, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.4}, {"hour": 19, "temperature_c": 8.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 20, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.4}, {"hour": 21, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.0}, {"hour": 22, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.1}, {"hour": 23, "temperature_c": 8.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 8.3}]}', name='get_weather_forecast', id='3d785322-2725-4d9c-a765-746e82f11990', tool_call_id='call_uZIrggJW0BMh0XaasGcXXrQ5'),
#     ToolMessage(content='{"date": "2023-10-07", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='8d8a78cb-fcc6-4e67-9cc3-94789f71658b', tool_call_id='call_S7bZPLR488cmtWt1Ma6ZJdOs'),
#     AIMessage(content='To minimize costs and maximize solar power for charging your electric vehicle (EV) tomorrow in San Francisco, consider the following:\n\n1. **Solar Generation**: Solar power generation is expected to peak between 12 PM and 3 PM, with the highest solar irradiance at 2 PM (377.8 W/m²). This is when your solar panels will produce the most energy.\n\n2. **Electricity Pricing**: The electricity prices are lowest during the off-peak hours (12 AM to 6 AM) at $0.096 per kWh. Mid-peak rates (6 AM to 8 AM) are $0.132 per kWh, and peak rates (2 PM to 7 PM) rise to $0.192 per kWh.\n\n### Recommendation:\n- **Charge your EV between 12 PM and 3 PM** when solar generation is at its peak. This will allow you to utilize solar energy, reducing reliance on grid electricity and minimizing costs.\n- If you need to charge overnight, consider charging between **12 AM and 6 AM** to take advantage of the lower off-peak rates.\n\nBy following this strategy, you can effectively reduce your energy costs while maximizing the use of solar power.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 249, 'prompt_tokens': 3250, 'total_tokens': 3499, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2816}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0vdcQkEzu4bfHyjn8zng5KyrCYr', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--4f021798-764c-44db-b469-58432b31ec16-0', usage_metadata={'input_tokens': 3250, 'output_tokens': 249, 'total_tokens': 3499, 'input_token_details': {'audio': 0, 'cache_read': 2816}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'The response should contain time recommendation, cost analysis and solar consideration',
#   'timestamp': '2025-11-28T23:08:34.578851'},
#  {'test_id': 'ev_charging_2',
#   'question': 'To minimize cost of charing my vehicle using solar energy, how does the time range differs comparing summer to winter?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='3ee90e15-625a-4794-a5fe-be023edb08ee'),
#     HumanMessage(content='To minimize cost of charing my vehicle using solar energy, how does the time range differs comparing summer to winter?', additional_kwargs={}, response_metadata={}, id='d9c2fea8-e727-4c62-9b3f-de14a305d230'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 1086, 'total_tokens': 1140, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0vjoX9g9nnx76FsYg7UjQnkRn8Z', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--ef7a6f65-ba0e-42a1-a60f-85a2491f2a11-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_pCBFUHx83zzM2VK1WCBZ0qVZ', 'type': 'tool_call'}, {'name': 'get_electricity_prices', 'args': {}, 'id': 'call_8Pk0SDT7ANU1RPrwTZ3ng1JJ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1086, 'output_tokens': 54, 'total_tokens': 1140, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 7, "current": {"temperature_c": 11.6, "condition": "partly_cloudy", "humidity": 87, "wind_speed": 11.7}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.5, "condition": "partly_cloudy", "solar_irradiance": 216.2, "humidity": 96, "wind_speed": 12.8}, {"hour": 14, "temperature_c": 11.6, "condition": "partly_cloudy", "solar_irradiance": 377.8, "humidity": 87, "wind_speed": 11.7}, {"hour": 15, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 323.5, "humidity": 87, "wind_speed": 12.0}, {"hour": 16, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 185.0, "humidity": 84, "wind_speed": 11.4}, {"hour": 17, "temperature_c": 9.9, "condition": "sunny", "solar_irradiance": 34.2, "humidity": 85, "wind_speed": 9.6}, {"hour": 18, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.4}, {"hour": 19, "temperature_c": 8.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 20, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.4}, {"hour": 21, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.0}, {"hour": 22, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.1}, {"hour": 23, "temperature_c": 8.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 8.3}, {"hour": 0, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 84, "wind_speed": 8.4}, {"hour": 1, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 80, "wind_speed": 7.6}, {"hour": 2, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 78, "wind_speed": 7.3}, {"hour": 3, "temperature_c": 6.7, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 80, "wind_speed": 9.4}, {"hour": 4, "temperature_c": 6.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 83, "wind_speed": 9.7}, {"hour": 5, "temperature_c": 6.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 10.2}, {"hour": 6, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0 ...
#     ToolMessage(content='{"date": "2025-11-28", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='e1acd719-3969-4209-9180-8de6531b5426', tool_call_id='call_8Pk0SDT7ANU1RPrwTZ3ng1JJ'),
#     AIMessage(content="To minimize the cost of charging your vehicle using solar energy, it's essential to understand the differences in solar generation between summer and winter in San Francisco.\n\n**Summer**: During summer, solar irradiance is typically higher, especially from late morning to early afternoon. For instance, solar generation peaks around 1 PM to 3 PM, with values reaching over 300 W/m². This means you can generate more solar energy during these hours, making it ideal for charging your vehicle.\n\n**Winter**: In contrast, winter months see lower solar irradiance, with peak generation occurring later in the day and at lower levels, often below 200 W/m². The sun sets earlier, reducing the available hours for solar generation.\n\n**Electricity Pricing**: Additionally, electricity prices vary throughout the day. For example, peak rates can reach $0.192 per kWh from 2 PM to 7 PM, while off-peak rates can be as low as $0.096 per kWh during the night. \n\nIn summary, charge your vehicle during peak solar hours in summer for maximum efficiency, while in winter, consider charging during off-peak hours to save on costs.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 238, 'prompt_tokens': 10514, 'total_tokens': 10752, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0vllh9n1IrrgEMIUvoO7YT1plbb', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--a1894a00-a3c8-423e-8640-777f89e974af-0', usage_metadata={'input_tokens': 10514, 'output_tokens': 238, 'total_tokens': 10752, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'The response to provide insights about time range difference between summer and winter.',
#   'timestamp': '2025-11-28T23:08:43.997773'},
#  {'test_id': 'thermostat_setting',
#   'question': 'What is the optimal thermostat_setting I should be setting to next week in my living room?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='f8befd4e-d408-4771-b4f2-4c246f6a04c3'),
#     HumanMessage(content='What is the optimal thermostat_setting I should be setting to next week in my living room?', additional_kwargs={}, response_metadata={}, id='56ce7927-ef87-408f-a4b3-a5295fba98de'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 76, 'prompt_tokens': 1081, 'total_tokens': 1157, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0vsnpBKQ6kcWXv5LLH6U9WphZFs', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--0df494f3-8f2f-448f-a80d-068bf6fce126-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_oUf1IcO1ZCfsLChp62AB7p8x', 'type': 'tool_call'}, {'name': 'query_energy_usage', 'args': {'start_date': '2023-10-01', 'end_date': '2023-10-07', 'device_type': 'HVAC'}, 'id': 'call_GFZroE47o1LsHMlCzrHc7vgq', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1081, 'output_tokens': 76, 'total_tokens': 1157, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 7, "current": {"temperature_c": 11.6, "condition": "partly_cloudy", "humidity": 87, "wind_speed": 11.7}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.5, "condition": "partly_cloudy", "solar_irradiance": 216.2, "humidity": 96, "wind_speed": 12.8}, {"hour": 14, "temperature_c": 11.6, "condition": "partly_cloudy", "solar_irradiance": 377.8, "humidity": 87, "wind_speed": 11.7}, {"hour": 15, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 323.5, "humidity": 87, "wind_speed": 12.0}, {"hour": 16, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 185.0, "humidity": 84, "wind_speed": 11.4}, {"hour": 17, "temperature_c": 9.9, "condition": "sunny", "solar_irradiance": 34.2, "humidity": 85, "wind_speed": 9.6}, {"hour": 18, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.4}, {"hour": 19, "temperature_c": 8.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 20, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.4}, {"hour": 21, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.0}, {"hour": 22, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.1}, {"hour": 23, "temperature_c": 8.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 8.3}, {"hour": 0, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 84, "wind_speed": 8.4}, {"hour": 1, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 80, "wind_speed": 7.6}, {"hour": 2, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 78, "wind_speed": 7.3}, {"hour": 3, "temperature_c": 6.7, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 80, "wind_speed": 9.4}, {"hour": 4, "temperature_c": 6.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 83, "wind_speed": 9.7}, {"hour": 5, "temperature_c": 6.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 10.2}, {"hour": 6, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0 ...
#     ToolMessage(content='{"start_date": "2023-10-01", "end_date": "2023-10-07", "device_type": "HVAC", "total_records": 0, "total_consumption_kwh": 0, "total_cost_usd": 0, "records": []}', name='query_energy_usage', id='433e06b5-01d1-49f1-9678-6eb6625a68b3', tool_call_id='call_GFZroE47o1LsHMlCzrHc7vgq'),
#     AIMessage(content='To determine the optimal thermostat setting for your living room next week in San Francisco, we can analyze the weather forecast and your HVAC usage patterns.\n\nThe weather forecast indicates that temperatures will range from about 6.5°C (43.7°F) at night to around 18.4°C (65.1°F) during the day. Given this range, a comfortable thermostat setting would typically be around 20°C (68°F) during the day when the temperature is cooler, and you might want to lower it to about 18°C (64°F) at night to save energy while still maintaining comfort.\n\nSince there is no recent HVAC usage data available, I recommend setting your thermostat to 20°C during the day and 18°C at night. This approach balances comfort and energy efficiency, especially considering the cooler temperatures expected in the evenings. \n\nFeel free to adjust these settings based on your personal comfort preferences!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 184, 'prompt_tokens': 9760, 'total_tokens': 9944, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0vvFmcL5t5paCYNMzaj6M38OgY5', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--5a754afd-5f92-4c41-9534-38fb76be5c35-0', usage_metadata={'input_tokens': 9760, 'output_tokens': 184, 'total_tokens': 9944, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['query_energy_usage', 'get_weather_forecast'],
#   'expected_response': 'The response should contain time recommendation and thermostat temperature setting.',
#   'timestamp': '2025-11-28T23:08:51.985887'},
#  {'test_id': 'appliance_scheduling',
#   'question': 'When is the best time this week to do my laundry to save money?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='7e2b8211-014c-4ca4-b723-2f3496015cfd'),
#     HumanMessage(content='When is the best time this week to do my laundry to save money?', additional_kwargs={}, response_metadata={}, id='7262b267-3f6d-4b5c-ba60-655f975d11c4'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 1078, 'total_tokens': 1131, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0w0sl87XHaYjp7VL4fPYCltSRSc', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--8259d728-fdfc-429c-ac4e-0d87a6e455d4-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_1a0G4BNllxiOv6caHWpKlHzE', 'type': 'tool_call'}, {'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_FeyhO2gnM8k2gs6RAj3W87TY', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1078, 'output_tokens': 53, 'total_tokens': 1131, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2025-11-28", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='789559c7-f802-4367-b9e1-44dc7918ec9b', tool_call_id='call_1a0G4BNllxiOv6caHWpKlHzE'),
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 7, "current": {"temperature_c": 11.6, "condition": "partly_cloudy", "humidity": 87, "wind_speed": 11.7}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.5, "condition": "partly_cloudy", "solar_irradiance": 216.2, "humidity": 96, "wind_speed": 12.8}, {"hour": 14, "temperature_c": 11.6, "condition": "partly_cloudy", "solar_irradiance": 377.8, "humidity": 87, "wind_speed": 11.7}, {"hour": 15, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 323.5, "humidity": 87, "wind_speed": 12.0}, {"hour": 16, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 185.0, "humidity": 84, "wind_speed": 11.4}, {"hour": 17, "temperature_c": 9.9, "condition": "sunny", "solar_irradiance": 34.2, "humidity": 85, "wind_speed": 9.6}, {"hour": 18, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.4}, {"hour": 19, "temperature_c": 8.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 20, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.4}, {"hour": 21, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.0}, {"hour": 22, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.1}, {"hour": 23, "temperature_c": 8.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 8.3}, {"hour": 0, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 84, "wind_speed": 8.4}, {"hour": 1, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 80, "wind_speed": 7.6}, {"hour": 2, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 78, "wind_speed": 7.3}, {"hour": 3, "temperature_c": 6.7, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 80, "wind_speed": 9.4}, {"hour": 4, "temperature_c": 6.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 83, "wind_speed": 9.7}, {"hour": 5, "temperature_c": 6.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 10.2}, {"hour": 6, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0 ...
#     AIMessage(content="To save money on laundry this week in San Francisco, you should aim to do your laundry during off-peak hours when electricity rates are the lowest. \n\nBased on the electricity pricing data, the best times to do laundry are:\n- **Midnight to 6 AM**: $0.096 per kWh (Off-Peak)\n- **After 10 PM**: $0.096 per kWh (Off-Peak)\n\nDuring the day, electricity prices rise significantly, especially from 2 PM to 7 PM, where rates peak at $0.192 per kWh. \n\nAdditionally, the weather forecast indicates partly cloudy conditions with temperatures ranging from 8°C to 18°C throughout the week. This means you can also consider air-drying your laundry during the day when it's warmer, which can further save energy.\n\nIn summary, the best time to do your laundry is early in the morning or late at night to take advantage of the lower electricity rates.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 199, 'prompt_tokens': 10505, 'total_tokens': 10704, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0w3r0XUaZtFbjDFgcVsCXbM9lPX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--74e2861f-dd39-452b-b9b7-8f549e918c08-0', usage_metadata={'input_tokens': 10505, 'output_tokens': 199, 'total_tokens': 10704, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_electricity_prices',
#    'query_energy_usage',
#    'get_recent_energy_summary'],
#   'expected_response': 'The response should include a date and time for doing laundry.',
#   'timestamp': '2025-11-28T23:09:00.234194'},
#  {'test_id': 'solar_power_maximization',
#   'question': 'While having my solar panel, when is the best time to do my laundry this week?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='de527877-af24-49ec-b07d-9d18e441a1e1'),
#     HumanMessage(content='While having my solar panel, when is the best time to do my laundry this week?', additional_kwargs={}, response_metadata={}, id='3d1ec3dc-47ea-414d-a06e-fcccdea0fdcc'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1081, 'total_tokens': 1104, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0w8jwfGEXTWsLpHzb9oUr10dc7n', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--5afea99a-4105-44c2-8035-653d68f7d055-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_pvq3BwZDaiX8RVAsCe2tXc9N', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1081, 'output_tokens': 23, 'total_tokens': 1104, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 7, "current": {"temperature_c": 11.6, "condition": "partly_cloudy", "humidity": 87, "wind_speed": 11.7}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.5, "condition": "partly_cloudy", "solar_irradiance": 216.2, "humidity": 96, "wind_speed": 12.8}, {"hour": 14, "temperature_c": 11.6, "condition": "partly_cloudy", "solar_irradiance": 377.8, "humidity": 87, "wind_speed": 11.7}, {"hour": 15, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 323.5, "humidity": 87, "wind_speed": 12.0}, {"hour": 16, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 185.0, "humidity": 84, "wind_speed": 11.4}, {"hour": 17, "temperature_c": 9.9, "condition": "sunny", "solar_irradiance": 34.2, "humidity": 85, "wind_speed": 9.6}, {"hour": 18, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.4}, {"hour": 19, "temperature_c": 8.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 20, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.4}, {"hour": 21, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.0}, {"hour": 22, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.1}, {"hour": 23, "temperature_c": 8.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 8.3}, {"hour": 0, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 84, "wind_speed": 8.4}, {"hour": 1, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 80, "wind_speed": 7.6}, {"hour": 2, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 78, "wind_speed": 7.3}, {"hour": 3, "temperature_c": 6.7, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 80, "wind_speed": 9.4}, {"hour": 4, "temperature_c": 6.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 83, "wind_speed": 9.7}, {"hour": 5, "temperature_c": 6.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 10.2}, {"hour": 6, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0 ...
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 9643, 'total_tokens': 9656, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0wAdnB1tdN2zaBfynJcu4yxAv1r', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--16029a2d-f5b8-4081-ac56-a13585125865-0', tool_calls=[{'name': 'get_electricity_prices', 'args': {}, 'id': 'call_2lWvbRGxbDYRD6cY4CUBWKfb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 9643, 'output_tokens': 13, 'total_tokens': 9656, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"date": "2025-11-28", "pricing_type": "time_of_use", "region": "Simulated US Utility", "currency": "USD", "unit": "per_kWh", "demand_unit": "per_kW", "hourly_rates": [{"hour": 0, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 1, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 2, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 3, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 4, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 5, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}, {"hour": 6, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 7, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 8, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 9, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 10, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 11, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 12, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 13, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 14, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 15, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 16, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 17, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 18, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 19, "rate": 0.192, "period": "Peak", "demand_charge": 8.0}, {"hour": 20, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 21, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 22, "rate": 0.132, "period": "Mid-Peak", "demand_charge": 0.0}, {"hour": 23, "rate": 0.096, "period": "Off-Peak", "demand_charge": 0.0}]}', name='get_electricity_prices', id='effb78bf-c239-445e-bb11-01790ec506e2', tool_call_id='call_2lWvbRGxbDYRD6cY4CUBWKfb'),
#     AIMessage(content='To optimize your laundry schedule with your solar panel this week in San Francisco, consider the following:\n\n1. **Solar Generation**: The best time for solar generation is typically between 10 AM and 3 PM, when solar irradiance is highest. For example, on sunny days, solar irradiance peaks around 12 PM to 2 PM.\n\n2. **Electricity Pricing**: Electricity prices vary throughout the day. Off-peak rates (0.096 USD/kWh) are from midnight to 6 AM and after 8 PM. Mid-peak rates (0.132 USD/kWh) are from 6 AM to 8 AM and 8 PM to 10 PM. Peak rates (0.192 USD/kWh) are from 2 PM to 8 PM.\n\n### Recommendation:\n- **Best Time to Do Laundry**: Schedule your laundry between **10 AM and 2 PM**. This timing allows you to utilize solar energy, reducing your electricity costs and maximizing the efficiency of your solar panel.\n\nBy doing laundry during these hours, you can save on energy costs while making the most of your solar generation.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 230, 'prompt_tokens': 10504, 'total_tokens': 10734, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 9600}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0wCG9LJqJbD9O7CPqBNY8fdUfdi', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--300e1432-95be-47c1-a855-292c65e3b88f-0', usage_metadata={'input_tokens': 10504, 'output_tokens': 230, 'total_tokens': 10734, 'input_token_details': {'audio': 0, 'cache_read': 9600}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast',
#    'calculate_energy_savings',
#    'get_electricity_prices',
#    'query_solar_generation'],
#   'expected_response': 'The response should include a time and a day..',
#   'timestamp': '2025-11-28T23:09:10.622436'},
#  {'test_id': 'costs_savings_calculation',
#   'question': 'How do I optimize my electric bill with my appliances using my usage data from the last 2 weeks?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='fa4aa4a0-6cb9-4d47-8de8-17da6e91ae34'),
#     HumanMessage(content='How do I optimize my electric bill with my appliances using my usage data from the last 2 weeks?', additional_kwargs={}, response_metadata={}, id='f083f2f8-a03f-42b7-b2f4-593c01ea83b3'),
# ...
#   'expected_tools': ['search_energy_tips'],
#   'expected_response': 'There should be 5 points related to energy saving given.',
#   'timestamp': '2025-11-28T23:09:27.283555'},
#  {'test_id': 'solar_saving',
#   'question': 'Can you estimate the total solar saving for the whole week next week?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='1116c4ee-dd5f-4873-9b6b-c302005f3ea0'),
#     HumanMessage(content='Can you estimate the total solar saving for the whole week next week?', additional_kwargs={}, response_metadata={}, id='a1a9f436-bcc5-4a7e-a51c-1be6c7b9e5a1'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 32, 'prompt_tokens': 1077, 'total_tokens': 1109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0wZiPef9lT8oPJlwtg54TbweC7K', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--46334b1e-d6e6-4789-ac5b-e0119ad79606-0', tool_calls=[{'name': 'query_solar_generation', 'args': {'start_date': '2023-10-30', 'end_date': '2023-11-05'}, 'id': 'call_vFQu3YEoNo2syR2kqWMRAsQu', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1077, 'output_tokens': 32, 'total_tokens': 1109, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"start_date": "2023-10-30", "end_date": "2023-11-05", "total_records": 0, "total_generation_kwh": 0, "average_daily_generation": 0.0, "records": []}', name='query_solar_generation', id='d1b41104-3551-4b6d-b7ce-604fe87160d9', tool_call_id='call_vFQu3YEoNo2syR2kqWMRAsQu'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1178, 'total_tokens': 1201, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0wbCaOnHsH2jMdrOCDTo4R6A8eO', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--95c098b3-e03c-4c5d-964e-de671818612b-0', tool_calls=[{'name': 'get_weather_forecast', 'args': {'location': 'San Francisco, CA', 'days': 7}, 'id': 'call_sax4MUbnEvtiTlGkzNL5Xz3I', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1178, 'output_tokens': 23, 'total_tokens': 1201, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"location": "San Francisco", "forecast_days": 7, "current": {"temperature_c": 11.6, "condition": "partly_cloudy", "humidity": 87, "wind_speed": 11.7}, "hourly": [{"hour": 0, "temperature_c": 8.4, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 11.2}, {"hour": 1, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 91, "wind_speed": 8.7}, {"hour": 2, "temperature_c": 8.1, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 89, "wind_speed": 8.4}, {"hour": 3, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 7.3}, {"hour": 4, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 5, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 90, "wind_speed": 4.5}, {"hour": 6, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 92, "wind_speed": 6.1}, {"hour": 7, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 5.5}, {"hour": 8, "temperature_c": 8.5, "condition": "partly_cloudy", "solar_irradiance": 38.8, "humidity": 89, "wind_speed": 4.1}, {"hour": 9, "temperature_c": 9.2, "condition": "partly_cloudy", "solar_irradiance": 119.2, "humidity": 88, "wind_speed": 5.2}, {"hour": 10, "temperature_c": 9.6, "condition": "cloudy", "solar_irradiance": 126.0, "humidity": 88, "wind_speed": 6.2}, {"hour": 11, "temperature_c": 9.9, "condition": "cloudy", "solar_irradiance": 212.0, "humidity": 90, "wind_speed": 5.9}, {"hour": 12, "temperature_c": 10.4, "condition": "cloudy", "solar_irradiance": 189.2, "humidity": 90, "wind_speed": 10.8}, {"hour": 13, "temperature_c": 10.5, "condition": "partly_cloudy", "solar_irradiance": 216.2, "humidity": 96, "wind_speed": 12.8}, {"hour": 14, "temperature_c": 11.6, "condition": "partly_cloudy", "solar_irradiance": 377.8, "humidity": 87, "wind_speed": 11.7}, {"hour": 15, "temperature_c": 11.8, "condition": "sunny", "solar_irradiance": 323.5, "humidity": 87, "wind_speed": 12.0}, {"hour": 16, "temperature_c": 11.3, "condition": "sunny", "solar_irradiance": 185.0, "humidity": 84, "wind_speed": 11.4}, {"hour": 17, "temperature_c": 9.9, "condition": "sunny", "solar_irradiance": 34.2, "humidity": 85, "wind_speed": 9.6}, {"hour": 18, "temperature_c": 9.2, "condition": "sunny", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.4}, {"hour": 19, "temperature_c": 8.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 8.7}, {"hour": 20, "temperature_c": 8.4, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.4}, {"hour": 21, "temperature_c": 8.2, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 9.0}, {"hour": 22, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 87, "wind_speed": 9.1}, {"hour": 23, "temperature_c": 8.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 88, "wind_speed": 8.3}, {"hour": 0, "temperature_c": 7.9, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 84, "wind_speed": 8.4}, {"hour": 1, "temperature_c": 7.8, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 80, "wind_speed": 7.6}, {"hour": 2, "temperature_c": 7.3, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 78, "wind_speed": 7.3}, {"hour": 3, "temperature_c": 6.7, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 80, "wind_speed": 9.4}, {"hour": 4, "temperature_c": 6.5, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 83, "wind_speed": 9.7}, {"hour": 5, "temperature_c": 6.6, "condition": "partly_cloudy", "solar_irradiance": 0.0, "humidity": 86, "wind_speed": 10.2}, {"hour": 6, "temperature_c": 6.4, "condition": "partly_cloudy", "solar_irradiance": 0.0 ...
#     AIMessage(content='For the week of October 30 to November 5, 2023, the solar generation data indicates no records of solar energy production. However, based on the weather forecast, we can estimate potential solar generation.\n\nThe forecast shows several hours of sunny and partly cloudy conditions, particularly during midday when solar irradiance peaks. For instance, on average, the solar irradiance reaches around 377.8 W/m² during peak hours. Assuming a typical solar panel system generates about 1 kWh for every 1 kW of installed capacity per hour of peak sunlight, we can estimate the potential generation.\n\nIf we assume an average of 5 hours of effective sunlight per day, a 5 kW solar system could generate approximately 25 kWh per day. Over a week, this would yield around 175 kWh.\n\nTo calculate savings, we need the local electricity price. If we assume a price of $0.12 per kWh, the total savings could be approximately $21.00 for the week.\n\nIf you have a specific solar system size or electricity price, please provide that for a more tailored estimate!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 227, 'prompt_tokens': 9740, 'total_tokens': 9967, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0wdwJERMyuMxXq5AJVq8kbkWeyM', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--22196250-d679-4bda-bbc6-4f1fba350368-0', usage_metadata={'input_tokens': 9740, 'output_tokens': 227, 'total_tokens': 9967, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['get_weather_forecast', 'get_electricity_prices'],
#   'expected_response': 'The response should be a total saving amount.',
#   'timestamp': '2025-11-28T23:09:37.656272'},
#  {'test_id': 'general_consumption',
#   'question': 'How much does it cost for my energy consumption in the last 2 weeks?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='fd3a9877-18bc-4b34-a7e3-2a1b56a08472'),
#     HumanMessage(content='How much does it cost for my energy consumption in the last 2 weeks?', additional_kwargs={}, response_metadata={}, id='b83c6870-2119-44c4-87cc-6bc607763089'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 1079, 'total_tokens': 1110, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0wkUeiOvQZCAgfKqteO2tORMzu6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--e3ca5d18-a450-4380-a4d2-4467e540c476-0', tool_calls=[{'name': 'query_energy_usage', 'args': {'start_date': '2023-10-01', 'end_date': '2023-10-15'}, 'id': 'call_ByxMGmwt6xbaaJm7Hks2lTQ6', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1079, 'output_tokens': 31, 'total_tokens': 1110, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"start_date": "2023-10-01", "end_date": "2023-10-15", "device_type": null, "total_records": 0, "total_consumption_kwh": 0, "total_cost_usd": 0, "records": []}', name='query_energy_usage', id='2eac3316-6399-4082-8da9-13b272583ca9', tool_call_id='call_ByxMGmwt6xbaaJm7Hks2lTQ6'),
#     AIMessage(content="It appears that there is no recorded energy consumption for the last two weeks (from October 1 to October 15, 2023) in your account. This could be due to various reasons, such as a lack of data from your energy provider or devices not being monitored.\n\nIf you have any specific devices or appliances that you would like to inquire about, or if you want to check a different date range, please let me know! I'm here to help you with any further questions or analyses you may need.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 104, 'prompt_tokens': 1184, 'total_tokens': 1288, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0wl9R79EsqDNVpEYr5F2Nfrzfak', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--a550b39d-7cf3-40d1-86db-0dfd1757020d-0', usage_metadata={'input_tokens': 1184, 'output_tokens': 104, 'total_tokens': 1288, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['query_energy_usage', 'get_electricity_prices'],
#   'expected_response': 'The response should e a total cost amount.',
#   'timestamp': '2025-11-28T23:09:42.450548'},
#  {'test_id': 'energy_consumption',
#   'question': 'What is my energy consumption for the last 2 hours?',
#   'response': {'messages': [SystemMessage(content='Location: San Francisco, CA', additional_kwargs={}, response_metadata={}, id='125b0954-9867-47bc-aa58-2a9e80ac2c9b'),
#     HumanMessage(content='What is my energy consumption for the last 2 hours?', additional_kwargs={}, response_metadata={}, id='c9c8dee1-15e7-4d25-ba3a-24eddf89a115'),
#     AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 16, 'prompt_tokens': 1075, 'total_tokens': 1091, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0worD15Uh5TIDowqk4mheaLCfar', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, name='energy_advisor', id='lc_run--2daf94a1-b72e-4a51-85bc-5621480d2adc-0', tool_calls=[{'name': 'get_recent_energy_summary', 'args': {'hours': 2}, 'id': 'call_pB50YW7uWl13nWch9hXYPuBM', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1075, 'output_tokens': 16, 'total_tokens': 1091, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#     ToolMessage(content='{"time_period_hours": 2, "usage": {"total_consumption_kwh": 0, "total_cost_usd": 0, "device_breakdown": {}}, "generation": {"total_generation_kwh": 0, "average_weather": "unknown"}}', name='get_recent_energy_summary', id='b0983e63-2bc8-47ee-a819-67aee79c1fb0', tool_call_id='call_pB50YW7uWl13nWch9hXYPuBM'),
#     AIMessage(content='In the last 2 hours, your total energy consumption was 0 kWh, and there were no associated costs. It appears that there was no energy usage recorded during this period. If you have specific devices or appliances that you typically use, please let me know, and I can help you analyze their usage patterns or check for any issues.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 1161, 'total_tokens': 1231, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1024}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b547601dbd', 'id': 'chatcmpl-Ch0wq4w0N8ccN0LSBGChZqqPGSsSU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, name='energy_advisor', id='lc_run--501ac881-0e35-48f5-a718-a77b1fbd6663-0', usage_metadata={'input_tokens': 1161, 'output_tokens': 70, 'total_tokens': 1231, 'input_token_details': {'audio': 0, 'cache_read': 1024}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]},
#   'expected_tools': ['query_energy_usage'],
#   'expected_response': 'The response should contain the energy consumption of last 2 hours.',
#   'timestamp': '2025-11-28T23:09:46.156483'}]

# %% [markdown]
# ## 4. Evaluate Responses

# %%
# Set up all required libraries
from langchain_openai import ChatOpenAI
from langchain_core.messages import BaseMessage, HumanMessage, AIMessage, SystemMessage, ToolMessage
# from langgraph.graph.message import MessagesState
from langchain_core.prompts import PromptTemplate
from typing import List, Dict
from tools import TOOL_KIT
from pydantic import BaseModel, Field

# %%
class QualityEvalSchema(BaseModel):
    accuracy: float = Field(description="Accuracy of final_response with respect to the customer's question and espected response description.")
    relevance: float = Field(description="Relevancy of final_response with respect to the customer's question and espected response description.")
    completeness: float = Field(description="Completeness of final_response with respect to the customer's question and espected response description.")
    usefulness: float = Field(description="Usefulness of final_response with respect to the customer's question.")
    quality_evaluation_description: str = Field(description="Description of the analysis logic of other metrics")

class ToolEvalSchema(BaseModel):
    tool_appropriateness: float = Field(description="Appropriateness of the tools selected based on the given tools.")
    tool_completness: float = Field(description="Metric measuring whether all the necessary tools were used.")
    tool_evaluation_description: str = Field(description="The reasoning and description of the analysis of coming up with the metrics.")

# %%
# Set up LLM Judge for Evaluation
# (LangChain is used instead of LangGraph, because analysis are independant and only simple single step LLM evaluation is required)
from dotenv import load_dotenv
import os

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
llm_base_url = "https://openai.vocareum.com/v1"

# Create LLM Evaluation Agent
llm = ChatOpenAI(
    model="gpt-4o",             # using a more sophisticated model for evaluation purpose
    temperature=0.0,
    api_key = OPENAI_API_KEY,
    base_url = llm_base_url,
)

qual_structured_llm = llm.with_structured_output(QualityEvalSchema)
tool_structured_llm = llm.with_structured_output(ToolEvalSchema)

# %%
# TODO: Implement evaluation functions
# Create functions to evaluate:
# - Final Response
# - Tool usage

# %%
# TODO: Create a response evaluator
def evaluate_response(question, final_response, expected_response):
    """Evaluate a single response against expected response"""

    template = PromptTemplate(
        input_variables=["question", "final_response", "expected_response"],
        template="""You're a judging evaluator for the response given by an energy advisor.

        Given the response from the energy advisor with the expected response description provide the following:
        - accuracy: Out of a score of 100, how accurate is the advisor response provided with respect to the customer's question and the espected response description? 
        - relevance: Out of a score of 100, how relevant the advisor response provided with respect to the customer's question and the espected response description?
        - completeness: Out of a score of 100, how complete the advisor response provided with respect to the customer's question and the espected response description?
        - usefulness: Out of a score of 100, how useful the advisor response provided with respect to the customer's question?  (Consider whether customer can take any action based on this anwser)
        - quality_evaluation_description: Provide a detail description to justify your metrics provided above within 200 to 500 words.

        Customer's question: 
        {question}
        
        Energy advisor response: 
        {final_response}

        Expected response description: 
        {expected_response}
        """
    )

    messages = template.invoke(
            {
                "question": question, 
                "final_response": final_response, 
                "expected_response": expected_response
            }
        ).to_messages()

    ai_message = qual_structured_llm.invoke(messages)
    return ai_message

# %%
# TODO: Create a tool udage evaluator
def evaluate_tool_usage(messages: list, expected_tools: str):
    """Evaluate if the right tools were used"""
    
    template = PromptTemplate(
        input_variables=["messages", "expected_tools"],
        template="""You're a judging evaluator for the tools used by an energy advisor AI agent to answer the user's question.

        Given the message history from the energy advisor AI agent please evaluat the selection of tool(s) used by the following:
        - tool_appropriateness: Out of a score of 100, how appropriate the tool selected to answer the customer's question?
        - tool_completeness: Out of a score of 100, evaluate whether all necessary tools were used?
        - tool_evaluation_description: Provide a detail description to justify your metrics provided above within 200 to 500 words.

        Available toolset for the energy advisor AI agent: 
        {TOOL_KIT}
        
        Expected tools to use: 
        {expected_tools}
        """
    ) 


    tool_info: List[Dict[str, str]] = [
        {"name": tool.name, "description": tool.description}
        for tool in TOOL_KIT
    ]

    prompt_message = template.invoke(
            {"TOOL_KIT": str(tool_info), "expected_tools": expected_tools}
        ).to_messages()

    ai_message = tool_structured_llm.invoke(messages + prompt_message)
    return ai_message

# %%
def results_reporting(metrics: List[List[tuple]]):
    """Produce a report for the evaluation"""

    template = PromptTemplate(
        input_variables=["metrics"],
        template="""You are an expert report writer by looking at the provided metrics for the AI energy advisor you need to write a report from a list of test samples.
        Your task is listed as follow:
            - Calculate overall scores and metrics across all samples
            - Identify strengths and weaknesses
            - Provide recommendations for improvement
        
        Metrics:
        {metrics}

        The report must have a proper structure with the following sections names with a total of less than 300 words:
            - Overall Score
            - Strength and Weaknesses
            - Recommendations
        """
        )
    
    prompt_message = template.invoke({"metrics": metrics})
    report = llm.invoke(prompt_message)
    return report

# %%
# TODO: Generate a comprehensive evaluation report
# Calculate overall scores and metrics
# Identify strengths and weaknesses
# Provide recommendations for improvement

def generate_evaluation_report(test_results: List[Dict]):

    metrics = []

    for result in test_results:
        # Qualitative Evaluation using LLM
        quality_metric = evaluate_response(
            question = result.get('question',''),
            final_response = result.get('response', None).get('messages', None)[-1].content,
            expected_response = result.get('expected_response', None),
            )
        
        # Tool Evaluation using LLM
        tool_metric = evaluate_tool_usage(
            messages = result.get('response', None).get('messages', None),
            expected_tools = result.get('expected_tools', None),
            )

        # Join Metrics
        metrics.append( list(quality_metric) + list(tool_metric) )
        
    report = results_reporting(metrics)
    print(report.content)

    return metrics, report

# %%
metrics, report = generate_evaluation_report(test_results)
# Out:
# ### Overall Score
#
# The AI energy advisor demonstrated strong performance across various metrics, with an average accuracy of 85.5%, relevance of 90.5%, completeness of 84.5%, and usefulness of 84.5%. Tool appropriateness and completeness averaged 88.5% and 82.5%, respectively. These scores indicate a generally effective system, though there is room for improvement in certain areas.
#
# ### Strengths and Weaknesses
#
# **Strengths:**
# - **Relevance:** The advisor consistently provided responses that were highly relevant to user queries, ensuring that the information was pertinent and directly addressed the questions posed.
# - **Tool Appropriateness:** The selection of tools was generally well-suited to the tasks, effectively leveraging available data to provide informed recommendations.
#
# **Weaknesses:**
# - **Completeness:** Some responses lacked comprehensive details, such as specific time recommendations or day-specific guidance, which affected the overall completeness of the advice.
# - **Usefulness:** While the advice was often actionable, it could be enhanced by providing more specific guidance or examples, such as cost-saving estimates or detailed steps for implementation.
# - **Tool Completeness:** There were instances where additional tools could have been utilized to provide a more thorough analysis, such as incorporating electricity pricing data for cost calculations.
#
# ### Recommendations
#
# To enhance the AI energy advisor's performance, the following recommendations are proposed:
# 1. **Enhance Completeness:** Incorporate more detailed information in responses, such as specific time frames or day-specific advice, to improve the comprehensiveness of the recommendations.
# 2. **Improve Usefulness:** Provide more specific examples or data, such as potential cost savings or energy reduction percentages, to make the advice more actionable and motivating for users.
# 3. **Optimize Tool Usage:** Ensure the use of all relevant tools, such as electricity pricing data, to provide a more complete and accurate analysis. This will enhance the advisor's ability to deliver precise and personalized recommendations.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # TESTING...

# %%
# Set up all required libraries
from langchain_openai import ChatOpenAI
from langchain_core.messages import BaseMessage, HumanMessage, AIMessage, SystemMessage, ToolMessage
# from langgraph.graph import StateGraph, START, END
# from langgraph.graph.message import MessagesState
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate, MessagesPlaceholder
from typing import List, Dict
from tools import TOOL_KIT
from pydantic import BaseModel, Field
from langchain.agents import create_agent

# %%
class QualityEval(BaseModel):
    accuracy: float = Field(description="Accuracy of final_response with respect to the customer's question and espected response description.")
    relevance: float = Field(description="Relevancy of final_response with respect to the customer's question and espected response description.")
    completeness: float = Field(description="Completeness of final_response with respect to the customer's question and espected response description.")
    usefulness: float = Field(description="Usefulness of final_response with respect to the customer's question.")
    description: str = Field(description="Description of the analysis logic of other metrics")

# %%
# Set up LLM Judge for Evaluation
from dotenv import load_dotenv
import os

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
llm_base_url = "https://openai.vocareum.com/v1"

# Create LLM Evaluation Agent
llm = ChatOpenAI(
    model="gpt-4o",             # using a more sophisticated model for evaluation purpose
    temperature=0.0,
    api_key = OPENAI_API_KEY,
    base_url = llm_base_url,
)

qual_structured_llm = llm.with_structured_output(QualityEval)
tool_structured_llm = llm.with_structured_output(ToolEvalSchema)

# %%
question = test_results[-1].get('question','')
final_response = test_results[-1].get('response', None).get('messages', None)[-1].content
expected_response = test_results[-1].get('expected_response')

template = PromptTemplate(
    input_variables=["question", "final_response", "expected_response"],
    template="""You're a judging evaluator for the response given by an energy advisor.

    Given the response from the energy advisor with the expected response description provide the following:
    - accuracy: Out of a score of 100, how accurate is the advisor response provided with respect to the customer's question and the espected response description?  (Use the provided tools to evaluate)
    - relevance: Out of a score of 100, how relevant the advisor response provided with respect to the customer's question and the espected response description?
    - completeness: Out of a score of 100, how complete the advisor response provided with respect to the customer's question and the espected response description?
    - usefulness: Out of a score of 100, how useful the advisor response provided with respect to the customer's question?  (Consider whether customer can take any action based on this anwser)
    - description: Provide a detail description to justify your metrics provided above in less than 200 words.

    Customer's question: 
    {question}
    
    Energy advisor response: 
    {final_response}

    Expected response description: 
    {expected_response}
    """
)

messages = template.invoke(
    {"question": question, "final_response": final_response, "expected_response": expected_response}
    ).to_messages()

ai_message = structured_llm.invoke(messages)

# %%
ai_message

# %%
messages = result.get('response').get('messages')
expected_tools = result.get('expected_tools')

template = PromptTemplate(
    input_variables=["messages", "expected_tools"],
    template="""You're a judging evaluator for the tools used by an energy advisor AI agent to answer the user's question.

    Given the message history from the energy advisor AI agent please evaluat the selection of tool(s) used by the following:
    - tool_appropriateness: Out of a score of 100, how appropriate the tool selected to answer the customer's question?
    - tool_completeness: Out of a score of 100, evaluate whether all necessary tools were used?
    - description: Provide a detail description to justify your metrics provided above within 200 to 500 words.

    Available toolset for the energy advisor AI agent: 
    {TOOL_KIT}
    
    Expected tools to use: 
    {expected_tools}
    """
) 

tool_info: List[Dict[str, str]] = [
    {"name": tool.name, "description": tool.description}
    for tool in TOOL_KIT
]

prompt_message = template.invoke(
        {"TOOL_KIT": str(tool_info), "expected_tools": expected_tools}
    ).to_messages()

ai_message = tool_structured_llm.invoke(messages + prompt_message)

# %%
ai_message

# %%
messages = result.get('response').get('messages')

# %%
messages

# %%
messages + template.invoke({"TOOL_KIT": str(tool_info), "expected_tools": expected_tools}).to_messages()

# %%
result.get('response').get('messages')

# %%
human_message = template.invoke(
        {"TOOL_KIT": str(tool_info), "expected_tools": expected_tools}
    ).to_messages()

# %%
new_messages = messages
new_messages.append(human_message)
new_messages

# %%
messages

# %%
test_results[0]

# %%
test_results[0].get('response').get('messages')

# %%
test_results[0].get('response').get('messages')[-1].content

# %%
# Testing for Extracting Outputs

tool_calls = [msg.name for msg in response["messages"] if isinstance(msg, ToolMessage)]
final_message = response['messages'][-1].content

print(tool_calls)
print(final_message)
